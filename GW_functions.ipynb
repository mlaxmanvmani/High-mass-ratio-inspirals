# %%
#!/usr/bin/env python
# coding: utf-8
# edits by chandra starts
import numpy as np
from lal import MSUN_SI, MTSUN_SI, G_SI, PC_SI, C_SI

EulerGamma=np.euler_gamma
gamma=np.euler_gamma

# %% [markdown]
# ## Eccentricity $e (\xi_{\phi})$

# %%
# ## Eccentricity $e (\xi_{\phi})$
# Eq. (4.17a, 4.17b), Pg. 18, Moore et al (2016)

def epsilon(xi, eta):
    return(( 1 + ( ( -2833/2016 + 197/72 * eta ) * ( xi )**( 2/3 ) + 
                  ( -377/144 * np.pi * xi + ( ( 77006005/24385536 + ( -1143767/145152 * eta + 
 	 43807/10368 * ( eta )**( 2 ) ) ) * ( xi )**( 4/3 ) + ( np.pi * ( 9901567/1451520 + 
 	 -202589/362880 * eta ) * ( xi )**( 5/3 ) + ( xi )**( 2 ) * ( -33320661414619/386266890240 + 
 	 ( 3317/252 * EulerGamma + ( 180721/41472 * ( np.pi )**( 2 ) + ( ( 161339510737/8778792960 + 
 	 3977/2304 * ( np.pi )**( 2 ) ) * eta + ( -359037739/20901888 * ( eta )**( 2 ) + 
      ( 10647791/2239488 * ( eta )**( 3 ) + ( -87419/3780 * np.log( 2 ) + 
 	 ( 26001/1120 * np.log( 3 ) + 3317/504 * np.log( 16 * ( xi )**( 2/3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ))

# %% [markdown]
# ## Oscillatory terms in phasing $W(\xi_{\phi})$

# %%
# ## Oscillatory terms in phasing $W(\xi_{\phi})$
# Eq. (5.3), Pg. 22, Moore et al (2016)

#
#

def W(xie, xi0, eta, e0, l):
    
    xiphi=xie
    xiphi0=xi0
    
    w=e0 * ( ( xiphi )**( -1 ) * xiphi0 )**( 19/18 ) * np.sin(l) * ( ( ( 2 +
         ( ( 7247/1008 + 161/36 * eta ) * ( xiphi )**( 2/3 ) + ( ( 539690101/12192768 +
         ( -477299/72576 * eta + 30055/5184 * ( eta )**( 2 ) ) ) * ( xiphi )**( 4/3 ) +
         ( ( 2833/1008 + -197/36 * eta ) * ( xiphi0 )**( 2/3 ) + ( ( 20530751/2032128 +
         ( -485773/36288 * eta + -31717/2592 * ( eta )**( 2 ) ) ) * ( xiphi )**( 2/3 ) * ( xiphi0 )**( 2/3 ) +
         ( ( -28850671/12192768 + ( 27565/72576 * eta +
         33811/5184 * ( eta )**( 2 ) ) ) * ( xiphi0 )**( 4/3 ) + 377/72 * np.pi * ( -1 * xiphi +
         xiphi0 ) ) ) ) ) ) ) ) ) #+ ( e0 )**( 2 ) * ( ( xiphi )**( -1 ) * xiphi0 )**( 19/9 ) * np.sin(2*l) * ( ( ( 5/4 +
         #( ( 17083/4032 + 841/144 * eta ) * ( xiphi )**( 2/3 ) + ( ( 176530423/6096384 +
         #( 168745/72576 * eta + 37667/2592 * ( eta )**( 2 ) ) ) * ( xiphi )**( 4/3 ) +
         #( ( 14165/4032 + -985/144 * eta ) * ( xiphi0 )**( 2/3 ) + ( ( 48396139/4064256 +
         #( -491399/72576 * eta + -165677/5184 * ( eta )**( 2 ) ) ) * ( xiphi )**( 2/3 ) * ( xiphi0 )**( 2/3 ) +
         #( ( -5966255/12192768 + ( -331585/36288 * eta +
         #90775/5184 * ( eta )**( 2 ) ) ) * ( xiphi0 )**( 4/3 ) +
         #1885/288 * np.pi * ( -1 * xiphi + xiphi0 ) ) ) ) ) ) ) ) )
    w2=e0 * ( ( xiphi )**( -1 ) * xiphi0 )**( 19/18 ) * np.sin(l) * ( ( ( 2 +
         ( ( 7247/1008 + 161/36 * eta ) * ( xiphi )**( 2/3 ) + ( ( 539690101/12192768 +
         ( -477299/72576 * eta + 30055/5184 * ( eta )**( 2 ) ) ) * ( xiphi )**( 4/3 ) +
         ( ( 2833/1008 + -197/36 * eta ) * ( xiphi0 )**( 2/3 ) + ( ( 20530751/2032128 +
         ( -485773/36288 * eta + -31717/2592 * ( eta )**( 2 ) ) ) * ( xiphi )**( 2/3 ) * ( xiphi0 )**( 2/3 ) +
         ( ( -28850671/12192768 + ( 27565/72576 * eta +
         33811/5184 * ( eta )**( 2 ) ) ) * ( xiphi0 )**( 4/3 ) + 377/72 * np.pi * ( -1 * xiphi +
         xiphi0 ) ) ) ) ) ) ) ) ) + ( e0 )**( 2 ) * ( ( xiphi )**( -1 ) * xiphi0 )**( 19/9 ) * np.sin(2*l) * ( ( ( 5/4 +
         ( ( 17083/4032 + 841/144 * eta ) * ( xiphi )**( 2/3 ) + ( ( 176530423/6096384 +
         ( 168745/72576 * eta + 37667/2592 * ( eta )**( 2 ) ) ) * ( xiphi )**( 4/3 ) +
         ( ( 14165/4032 + -985/144 * eta ) * ( xiphi0 )**( 2/3 ) + ( ( 48396139/4064256 +
         ( -491399/72576 * eta + -165677/5184 * ( eta )**( 2 ) ) ) * ( xiphi )**( 2/3 ) * ( xiphi0 )**( 2/3 ) +
         ( ( -5966255/12192768 + ( -331585/36288 * eta +
         90775/5184 * ( eta )**( 2 ) ) ) * ( xiphi0 )**( 4/3 ) +
         1885/288 * np.pi * ( -1 * xiphi + xiphi0 ) ) ) ) ) ) ) ) )
    return(w)

# %% [markdown]
# ## Phasing $\phi (v, v_0, e_0)$ (TaylorT2)

# %%
# ## Phasing $\phi (v, v_0, e_0)$ (TaylorT2)   
# Eq. (6.6a, 6.6b), Pg. 24, Moore et al (2016)


def phase_TT2(v, v0, e0, phiC, eta):
    
    psiNewt=-1/32 * ( v )**( -5 ) * ( eta )**( -1 )
    
    psi= phiC+( 1 + 
 	 ( -10 * np.pi * ( v )**( 3 ) + 
 	 ( ( v )**( 2 ) * ( 3715/1008 + 
 	 55/12 * eta ) + 
 	 ( np.pi * ( v )**( 7 ) * ( 77096675/2032128 + 
 	 ( 378515/12096 * eta + 
 	 -74045/6048 * ( eta )**( 2 ) ) ) + 
 	 ( ( v )**( 4 ) * ( 15293365/1016064 + 
 	 ( 27145/1008 * eta + 
 	 3085/144 * ( eta )**( 2 ) ) ) + 
 	 ( ( v )**( 5 ) * ( 38645/672 * np.pi * np.log( v ) + 
 	 -65/8 * np.pi * eta * np.log( v ) ) + 
 	 ( ( v )**( 6 ) * ( -5/3 * ( 3147553127/4064256 + 
 	 -451/16 * ( np.pi )**( 2 ) ) * eta + 
 	 ( 76055/6912 * ( eta )**( 2 ) + 
 	 ( -127825/5184 * ( eta )**( 3 ) + 
 	 -5/3 * ( -12348611926451/31294771200 + 
 	 ( 1712/35 * EulerGamma + 
 	 ( 32 * ( np.pi )**( 2 ) + 
 	 856/35 * ( 4 * np.log( 2 ) + 
 	 2 * np.log( v ) ) ) ) ) ) ) ) + 
 	 -785/272 * ( e0 )**( 2 ) * ( v )**( -19/3 ) * ( v0 )**( 19/3 ) * ( 1 + 
 	 ( 377/72 * np.pi * ( v0 )**( 3 ) + 
 	 ( ( v0 )**( 2 ) * ( 2833/1008 + 
 	 -197/36 * eta ) + 
 	 ( ( v0 )**( 5 ) * ( 764881/90720 * np.pi + 
 	 -949457/22680 * np.pi * eta ) + 
 	 ( ( v )**( 5 ) * ( -131697334/8456805 * np.pi + 
 	 -268652717/9664920 * np.pi * eta ) + 
 	 ( ( v0 )**( 4 ) * ( -1193251/3048192 + 
 	 ( -66317/9072 * eta + 
 	 18155/1296 * ( eta )**( 2 ) ) ) + 
 	 ( ( v )**( 3 ) * ( -1114537/141300 * np.pi + 
 	 ( -420180449/10173600 * ( np.pi )**( 2 ) * ( v0 )**( 3 ) + 
 	 ( v0 )**( 2 ) * ( -3157483321/142430400 * np.pi + 
 	 219563789/5086800 * np.pi * eta ) ) ) + 
 	 ( ( v )**( 4 ) * ( 377620541/107433216 + 
 	 ( 561233971/31334688 * eta + 
 	 ( 36339727/2238192 * ( eta )**( 2 ) + 
 	 ( v0 )**( 2 ) * ( 1069798992653/108292681728 + 
 	 ( 5894683956785/189512193024 * eta + 
 	 ( -39391912661/752032512 * ( eta )**( 2 ) + 
 	 -7158926219/80574912 * ( eta )**( 3 ) ) ) ) ) ) ) + 
 	 ( ( v )**( 2 ) * ( 6955261/2215584 + 
 	 ( 436441/79128 * eta + 
 	 ( ( v0 )**( 3 ) * ( 2622133397/159522048 * np.pi + 
 	 164538257/5697216 * np.pi * eta ) + 
 	 ( ( v0 )**( 2 ) * ( 19704254413/2233308672 + 
 	 ( -16718633/9970128 * eta + 
 	 -85978877/2848608 * ( eta )**( 2 ) ) ) + 
 	 ( v0 )**( 4 ) * ( -8299372143511/6753525424128 + 
 	 ( -6055808184535/241197336576 * eta + 
 	 ( 3499644089/957132288 * ( eta )**( 2 ) + 
 	 7923586355/102549888 * ( eta )**( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( v )**( 6 ) * ( -204814565759250649/1061268280934400 + 
 	 ( 12483797/791280 * EulerGamma + 
 	 ( 365639621/13022208 * ( np.pi )**( 2 ) + 
 	 ( ( 34787542048195/137827049472 + 
 	 -8764775/1446912 * ( np.pi )**( 2 ) ) * eta + 
 	 ( 80353703837/1640798208 * ( eta )**( 2 ) + 
 	 ( 5885194385/175799808 * ( eta )**( 3 ) + 
 	 ( 89383841/2373840 * np.log( 2 ) + 
 	 ( -26079003/703360 * np.log( 3 ) + 
 	 12483797/1582560 * ( 4 * np.log( 2 ) + 
 	 2 * np.log( v ) ) ) ) ) ) ) ) ) ) + 
 	 ( v0 )**( 6 ) * ( 26531900578691/168991764480 + 
 	 ( -3317/126 * EulerGamma + 
 	 ( 122833/10368 * ( np.pi )**( 2 ) + 
 	 ( ( 9155185261/548674560 + 
 	 -3977/1152 * ( np.pi )**( 2 ) ) * eta + 
 	 ( -5732473/1306368 * ( eta )**( 2 ) + 
 	 ( -3090307/139968 * ( eta )**( 3 ) + 
 	 ( 87419/1890 * np.log( 2 ) + 
 	 ( -26001/560 * np.log( 3 ) + 
 	 -3317/252 * ( 4 * np.log( 2 ) + 
 	 2 * np.log( v0 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ))
    
    return(psi)

# %% [markdown]
# ##      PNBHP Phasing  (TaylorT2)

# %%
import numpy as np
from scipy.special import zeta

C=np.euler_gamma
EulerGamma=np.euler_gamma



def phasePNBHP_TT2(vp, vp0, eta, e0):
    
    phiNewt=-1/32 * ( vp )**( -5 ) * ( eta )**( -1 )
    
    phie0v7=( 1 + ( -10 * np.pi * ( vp )**( 3 ) + ( ( vp )**( 2 ) * ( \
        3715/1008 + 55/12 * eta ) + ( ( vp )**( 4 ) * ( 15293365/1016064 + ( \
        27145/1008 * eta + 3085/144 * ( eta )**( 2 ) ) ) + ( ( vp )**( 7 ) * \
        ( 77096675/2032128 * np.pi + ( 378515/12096 * np.pi * eta + \
        -74045/6048 * np.pi * ( eta )**( 2 ) ) ) + ( ( vp )**( 6 ) * ( \
        12348611926451/18776862720 + ( -1712/21 * C + ( -160/3 * ( np.pi \
        )**( 2 ) + ( ( -15737765635/12192768 + 2255/48 * ( np.pi )**( 2 ) \
        ) * eta + ( 76055/6912 * ( eta )**( 2 ) + ( -127825/5184 * ( eta )**( \
        3 ) + ( -3424/21 * np.log( 2 ) + -1712/21 * np.log( vp ) ) ) ) \
        ) ) ) ) + ( vp )**( 5 ) * ( 38645/672 * np.pi * np.log( vp ) + \
        -65/8 * np.pi * eta * np.log( vp ) ) ) ) ) ) ) )
    
    phie0v8Tov24=( ( vp )**( 8 ) * ( 2554404624135128353/1107234040872960 + ( \
        -9203/63 * EulerGamma + ( -45245/378 * ( np.pi )**( 2 ) + ( \
        -252755/1323 * np.log( 2 ) + ( -78975/784 * np.log( 3 ) + \
        -9203/63 * np.log( vp ) ) ) ) ) ) + ( ( vp )**( 10 ) * ( \
        474387630222958367413/84204465330585600 + ( -6470582647/55010340 * \
        EulerGamma + ( -578223115/6096384 * ( np.pi )**( 2 ) + ( \
        -53992839431/110020680 * np.log( 2 ) + ( 5512455/43904 * \
        np.log( 3 ) + -6470582647/55010340 * np.log( vp ) ) ) ) ) ) + ( \
        ( vp )**( 9 ) * ( 160/3 * ( np.pi )**( 3 ) + ( np.pi * ( \
        -93098188434443/75107450880 + ( 3424/21 * EulerGamma + 6848/21 * \
        np.log( 2 ) ) ) + 3424/21 * np.pi * np.log( vp ) ) ) + ( ( \
        vp )**( 13 ) * ( 1279263245/12192768 * ( np.pi )**( 3 ) + ( \
        np.pi * ( -109674388411510301896873/7275265804562595840 + ( \
        214170945619/704132352 * EulerGamma + ( 394200458495/704132352 * \
        np.log( 2 ) + 30721275/702464 * np.log( 3 ) ) ) ) + \
        214170945619/704132352 * np.pi * np.log( vp ) ) ) + ( ( vp )**( \
        11 ) * ( 47195/378 * ( np.pi )**( 3 ) + ( np.pi * ( \
        -1821104938211478251/369078013624320 + ( 3558011/10584 * EulerGamma + \
        ( 862549/1512 * np.log( 2 ) + 78975/784 * np.log( 3 ) ) ) ) + \
        3558011/10584 * np.pi * np.log( vp ) ) ) + ( ( vp )**( 16 ) * ( \
        -7020619302153905764736083791978248541318631/\
        129422325961468628892951559224164352000 + ( \
        -362659047537859/838687643640 * ( EulerGamma )**( 2 ) + ( \
        -26996009/381024 * ( np.pi )**( 4 ) + ( \
        4083530408595241633396336843/53196686724947602636800 * np.log( 2 ) \
        + ( -2565322132571243/838687643640 * ( np.log( 2 ) )**( 2 ) + ( ( \
        np.pi )**( 2 ) * ( 43838941329678861572497/1429070068753367040 + ( \
        -3219899214725/5809091904 * np.log( 2 ) + -149236425/482944 * \
        np.log( 3 ) ) ) + ( 485435534500522840500913/35380429297051238400 \
        * np.log( 3 ) + ( 2757917565/845152 * np.log( 2 ) * np.log( \
        3 ) + ( -19826120925/13522432 * ( np.log( 3 ) )**( 2 ) + ( \
        EulerGamma * ( 51210530260708352131625323/1182148593887724503040 + ( \
        -3472481167919/5809091904 * ( np.pi )**( 2 ) + ( \
        -876627606865651/419343821820 * np.log( 2 ) + 137190105/845152 * \
        np.log( 3 ) ) ) ) + ( -109381686589111328125/46038554693074944 * \
        np.log( 5 ) + ( -2025852318599963/3243833049600 * np.log( 7 ) + \
        ( ( 50815712613071909206651243/1182148593887724503040 + ( \
        -362659047537859/419343821820 * EulerGamma + ( \
        -3472481167919/5809091904 * ( np.pi )**( 2 ) + ( \
        -876627606865651/419343821820 * np.log( 2 ) + 137190105/845152 * \
        np.log( 3 ) ) ) ) ) * np.log( vp ) + ( \
        -362659047537859/838687643640 * ( np.log( vp ) )**( 2 ) + \
        -310622273305/121022748 * zeta( 3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) \
        + ( ( vp )**( 14 ) * ( \
        -138326388420944755913360026401967699/\
        187255952325202891538983550976000 + ( -182562637/416745 * ( \
        EulerGamma )**( 2 ) + ( -71402/567 * ( np.pi )**( 4 ) + ( \
        1865838422485485389933/83496692027548800 * np.log( 2 ) + ( \
        -282286637/416745 * ( np.log( 2 ) )**( 2 ) + ( EulerGamma * ( \
        120326979517939102893917/9351629507085465600 + ( -370792/567 * ( \
        np.pi )**( 2 ) + ( -584285242/416745 * np.log( 2 ) + \
        -475605/1372 * np.log( 3 ) ) ) ) + ( ( np.pi )**( 2 ) * ( \
        182081268358978253737/19930212735713280 + ( -15006136/11907 * \
        np.log( 2 ) + -8775/196 * np.log( 3 ) ) ) + ( \
        38285987205098767/28154785218560 * np.log( 3 ) + ( -40365/28 * \
        np.log( 2 ) * np.log( 3 ) + ( 1026675/2744 * ( np.log( 3 ) \
        )**( 2 ) + ( 1039284912109375/854845415424 * np.log( 5 ) + ( ( \
        119988143756751159674717/9351629507085465600 + ( -365125274/416745 * \
        EulerGamma + ( -370792/567 * ( np.pi )**( 2 ) + ( \
        -584285242/416745 * np.log( 2 ) + -475605/1372 * np.log( 3 ) ) \
        ) ) ) * np.log( vp ) + ( -182562637/416745 * ( np.log( vp ) \
        )**( 2 ) + -273886/189 * zeta( 3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) + \
        ( ( vp )**( 12 ) * ( \
        2777942744746065918045693927569/350982066886345200815308800 + ( \
        -2930944/15435 * ( EulerGamma )**( 2 ) + ( -1024/21 * ( np.pi )**( \
        4 ) + ( EulerGamma * ( 996670478204758057/370039154284800 + ( \
        -109568/441 * ( np.pi )**( 2 ) + -11723776/15435 * np.log( 2 ) \
        ) ) + ( ( np.pi )**( 2 ) * ( 1476979134143899/788628234240 + \
        -219136/441 * np.log( 2 ) ) + ( \
        2253229104792852289/370039154284800 * np.log( 2 ) + ( \
        -11723776/15435 * ( np.log( 2 ) )**( 2 ) + ( \
        -4043034784143/108287635456 * np.log( 3 ) + ( \
        -188720703125/913296384 * np.log( 5 ) + ( ( \
        996670478204758057/370039154284800 + ( -5861888/15435 * EulerGamma + \
        ( -109568/441 * ( np.pi )**( 2 ) + -11723776/15435 * np.log( 2 \
        ) ) ) ) * np.log( vp ) + ( -2930944/15435 * ( np.log( vp ) )**( \
        2 ) + -54784/147 * zeta( 3 ) ) ) ) ) ) ) ) ) ) ) ) + ( ( vp \
        )**( 15 ) * ( 2048/45 * ( np.pi )**( 5 ) + ( ( np.pi )**( 3 ) * \
        ( -838117975570409/321889075200 + ( 109568/315 * EulerGamma + \
        219136/315 * np.log( 2 ) ) ) + ( ( 109568/315 * ( np.pi )**( 3 \
        ) + np.pi * ( -114382966272717367/14786779392000 + ( \
        11723776/11025 * EulerGamma + 23447552/11025 * np.log( 2 ) ) ) ) * \
        np.log( vp ) + ( 5861888/11025 * np.pi * ( np.log( vp ) )**( \
        2 ) + np.pi * ( \
        -453317988408545897262711451631/17531571772544715325440000 + ( \
        5861888/11025 * ( EulerGamma )**( 2 ) + ( \
        -2342930191956193549/162654573312000 * np.log( 2 ) + ( \
        23447552/11025 * ( np.log( 2 ) )**( 2 ) + ( EulerGamma * ( \
        -114382966272717367/14786779392000 + 23447552/11025 * np.log( 2 ) \
        ) + ( -69120873720189/154696622080 * np.log( 3 ) + ( \
        -37744140625/130470912 * np.log( 5 ) + 109568/105 * zeta( 3 \
        ) ) ) ) ) ) ) ) ) ) ) ) + ( ( vp )**( 19 ) * ( 405069545/4000752 * ( \
        np.pi )**( 5 ) + ( ( np.pi )**( 3 ) * ( \
        -3739319074492005465724037/76390290947907256320 + ( \
        227231932601/264049632 * EulerGamma + ( 3152920672801/1848347424 * \
        np.log( 2 ) + -5923125/307328 * np.log( 3 ) ) ) ) + ( ( \
        227231932601/264049632 * ( np.pi )**( 3 ) + np.pi * ( \
        -340821593388992408532187605151/2437375464488508338995200 + ( \
        695520298806979/266855159340 * EulerGamma + ( \
        657977400807889/133427579670 * np.log( 2 ) + 214101225/1075648 * \
        np.log( 3 ) ) ) ) ) * np.log( vp ) + ( \
        695520298806979/533710318680 * np.pi * ( np.log( vp ) )**( 2 ) \
        + np.pi * ( \
        2710768603972283743006713589660236518179201/\
        20589915493870009142060475331117056000 + ( \
        695520298806979/533710318680 * ( EulerGamma )**( 2 ) + ( \
        468133310198633/106742063736 * ( np.log( 2 ) )**( 2 ) + ( \
        -24271388563759937086577/5628704660894515200 * np.log( 3 ) + ( \
        -1198129725/4302592 * ( np.log( 3 ) )**( 2 ) + ( EulerGamma * ( \
        -345764630309035752755434350751/2437375464488508338995200 + ( \
        657977400807889/133427579670 * np.log( 2 ) + 214101225/1075648 * \
        np.log( 3 ) ) ) + ( np.log( 2 ) * ( \
        -621982754342469537744803905639/2437375464488508338995200 + \
        143739765/153664 * np.log( 3 ) ) + ( \
        -495218832177490234375/58594524154822656 * np.log( 5 ) + ( \
        -289407474085709/98297971200 * np.log( 7 ) + 125076673559/38507238 \
        * zeta( 3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) + ( ( vp )**( 17 ) * ( \
        68132/567 * ( np.pi )**( 5 ) + ( ( np.pi )**( 3 ) * ( \
        -24141218065974374705/1771574465396736 + ( 3967625/3969 * EulerGamma \
        + 7911217/3969 * np.log( 2 ) ) ) + ( ( 3967625/3969 * ( np.pi \
        )**( 3 ) + np.pi * ( -25470993928789286455429/639427658604134400 + \
        ( 1573299001/555660 * EulerGamma + ( 2848666241/555660 * np.log( 2 \
        ) + 1426815/2744 * np.log( 3 ) ) ) ) ) * np.log( vp ) + ( \
        1573299001/1111320 * np.pi * ( np.log( vp ) )**( 2 ) + np.pi \
        * ( -472009817641425716917694936385598549/\
        38411477400041618777227395072000 + ( 1573299001/1111320 * ( \
        EulerGamma )**( 2 ) + ( 639497071/158760 * ( np.log( 2 ) )**( 2 ) \
        + ( -86893148652728463/20476207431680 * np.log( 3 ) + ( \
        -3080025/5488 * ( np.log( 3 ) )**( 2 ) + ( EulerGamma * ( \
        -25610003471840750340229/639427658604134400 + ( 2848666241/555660 * \
        np.log( 2 ) + 1426815/2744 * np.log( 3 ) ) ) + ( np.log( 2 ) \
        * ( -2018334067017696486022871/24937678685561241600 + 121095/56 * \
        np.log( 3 ) ) + ( 624099365234375/253287530496 * np.log( 5 ) + \
        19526807/5292 * zeta( 3 ) ) ) ) ) ) ) ) ) ) ) ) ) + ( ( vp )**( \
        23 ) * ( 1352192/11907 * ( np.pi )**( 7 ) + ( ( np.pi )**( 5 ) \
        * ( -471372717096988521197/26573616980951040 + ( 230611904/178605 * \
        EulerGamma + ( 432463552/178605 * np.log( 2 ) + 7020/49 * \
        np.log( 3 ) ) ) ) + ( ( 6576001084/1250235 * ( np.pi )**( 3 ) + \
        np.pi * ( -2134563252333494991352980079/10029622646349161856000 + \
        ( 674103160307/43758225 * EulerGamma + ( 252632581967/8751645 * \
        np.log( 2 ) + 8592597/4802 * np.log( 3 ) ) ) ) ) * ( np.log( \
        vp ) )**( 2 ) + ( 674103160307/131274675 * np.pi * ( np.log( vp \
        ) )**( 3 ) + ( ( np.pi )**( 3 ) * ( \
        -1393880056511627097557426866444849859131/\
        8988285711609738793871210446848000 + ( 6576001084/1250235 * ( \
        EulerGamma )**( 2 ) + ( \
        -116523977465435928896193617/448878216340102348800 * np.log( 2 ) + \
        ( 5201134796/250047 * ( np.log( 2 ) )**( 2 ) + ( EulerGamma * ( \
        -21626861165924649597858743/149626072113367449600 + 5231995352/250047 \
        * np.log( 2 ) ) + ( 4803045697534840583/450476563496960 * \
        np.log( 3 ) + ( -5323999755859375/284948471808 * np.log( 5 ) + \
        126387208/11907 * zeta( 3 ) ) ) ) ) ) ) ) + ( np.log( vp ) * \
        ( 230611904/178605 * ( np.pi )**( 5 ) + ( ( np.pi )**( 3 ) * ( \
        -21164237406649377789244343/149626072113367449600 + ( \
        13152002168/1250235 * EulerGamma + 5231995352/250047 * np.log( 2 ) \
        ) ) + np.pi * ( \
        -244524712338924907792340212350663916825864531/\
        908162344104623617515881679783198720000 + ( 674103160307/43758225 * ( \
        EulerGamma )**( 2 ) + ( 87450112859/1750329 * ( np.log( 2 ) )**( 2 \
        ) + ( -134385147935291473151/10065335715635200 * np.log( 3 ) + ( \
        -18548595/4802 * ( np.log( 3 ) )**( 2 ) + ( EulerGamma * ( \
        -2134563252333494991352980079/5014811323174580928000 + ( \
        505265163934/8751645 * np.log( 2 ) + 8592597/2401 * np.log( 3 ) \
        ) ) + ( np.log( 2 ) * ( \
        -8592421185082187659899411889/10531103778666619948800 + 729261/49 * \
        np.log( 3 ) ) + ( -515538875341796875/47538903379968 * np.log( \
        5 ) + 15421682042/416745 * zeta( 3 ) ) ) ) ) ) ) ) ) ) ) + \
        np.pi * ( \
        207977507747745025083706165215428966685201294447077880439327/\
        94107055160404633008942267051774329149560151080960000 + ( \
        674103160307/131274675 * ( EulerGamma )**( 3 ) + ( \
        85353785417/3750705 * ( np.log( 2 ) )**( 3 ) + ( \
        -4391792937027068019798426711512942710441/\
        15819232157199444640684245516288000 * np.log( 3 ) + ( \
        8053236871201394991693/1127317600151142400 * ( np.log( 3 ) )**( 2 \
        ) + ( 13346775/4802 * ( np.log( 3 ) )**( 3 ) + ( ( EulerGamma )**( \
        2 ) * ( -2158263942536634279110599279/10029622646349161856000 + ( \
        252632581967/8751645 * np.log( 2 ) + 8592597/4802 * np.log( 3 ) \
        ) ) + ( ( np.log( 2 ) )**( 2 ) * ( \
        -188203270569481660493942452613/210622075573332398976000 + 61893/2 * \
        np.log( 3 ) ) + ( \
        42483009486594502824228901865234375/133419180001369743429344428032 * \
        np.log( 5 ) + ( -943603515625/48570368 * np.log( 3 ) * \
        np.log( 5 ) + ( -2412144046630859375/81495262937088 * ( np.log( \
        5 ) )**( 2 ) + ( \
        -3012031912014675879845567569/17562760123342690713600 * np.log( 7 \
        ) + ( -19527923098803605735803/43294581051321600 * zeta( 3 ) + \
        ( -461565/49 * np.log( 3 ) * zeta( 3 ) + ( EulerGamma * ( \
        -287041590713762414234068855675068374940117331/\
        908162344104623617515881679783198720000 + ( 87450112859/1750329 * ( \
        np.log( 2 ) )**( 2 ) + ( -134385147935291473151/10065335715635200 \
        * np.log( 3 ) + ( -18548595/4802 * ( np.log( 3 ) )**( 2 ) + ( \
        np.log( 2 ) * ( \
        -8667078359222076416335912369/10531103778666619948800 + 729261/49 * \
        np.log( 3 ) ) + ( -515538875341796875/47538903379968 * np.log( \
        5 ) + 15421682042/416745 * zeta( 3 ) ) ) ) ) ) ) + ( np.log( \
        2 ) * ( -478617065777641424383783442756680715653183379/\
        908162344104623617515881679783198720000 + ( \
        172199062596090512777/2588229184020480 * np.log( 3 ) + ( \
        -1574235/98 * ( np.log( 3 ) )**( 2 ) + ( \
        8119964949853515625/142616710139904 * np.log( 5 ) + \
        34689254218/416745 * zeta( 3 ) ) ) ) ) + -252096982/3969 * \
        zeta( 5 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + ( ( vp \
        )**( 21 ) * ( 2048/63 * ( np.pi )**( 7 ) + ( ( np.pi )**( 5 ) * \
        ( -4867929021385931/1689917644800 + ( 438272/945 * EulerGamma + \
        876544/945 * np.log( 2 ) ) ) + ( ( 11723776/6615 * ( np.pi )**( \
        3 ) + np.pi * ( -2909110845706836891260741/76198462650326016000 + \
        ( 1254444032/231525 * EulerGamma + 2508888064/231525 * np.log( 2 ) \
        ) ) ) * ( np.log( vp ) )**( 2 ) + ( 1254444032/694575 * np.pi * \
        ( np.log( vp ) )**( 3 ) + ( ( np.pi )**( 3 ) * ( \
        -160656723702414719830353425017459/1415725984079375599927296000 + ( \
        11723776/6615 * ( EulerGamma )**( 2 ) + ( \
        -2209122139052774191723/40598581498675200 * np.log( 2 ) + ( \
        46895104/6615 * ( np.log( 2 ) )**( 2 ) + ( EulerGamma * ( \
        -1028063732774341815899/40598581498675200 + 46895104/6615 * \
        np.log( 2 ) ) + ( -19183463325/314703872 * np.log( 3 ) + ( \
        188720703125/97853184 * np.log( 5 ) + 219136/63 * zeta( 3 ) \
        ) ) ) ) ) ) ) + ( np.log( vp ) * ( 438272/945 * ( np.pi )**( 5 \
        ) + ( ( np.pi )**( 3 ) * ( \
        -1028063732774341815899/40598581498675200 + ( 23447552/6615 * \
        EulerGamma + 46895104/6615 * np.log( 2 ) ) ) + np.pi * ( \
        -28647644201976731791455442552248257713/\
        99254147065796317227295703040000 + ( 1254444032/231525 * ( EulerGamma \
        )**( 2 ) + ( -5772412400261141618350357/38099231325163008000 * \
        np.log( 2 ) + ( 5017776128/231525 * ( np.log( 2 ) )**( 2 ) + ( \
        EulerGamma * ( -2909110845706836891260741/38099231325163008000 + \
        5017776128/231525 * np.log( 2 ) ) + ( \
        -85224987219778941/30970263740416 * np.log( 3 ) + ( \
        161884619140625/261202765824 * np.log( 5 ) + 23447552/2205 * \
        zeta( 3 ) ) ) ) ) ) ) ) ) ) + np.pi * ( \
        450059834468539297671266518103155514497065232987709413/\
        671958065822709430334684767843928404698071040000 + ( \
        1254444032/694575 * ( EulerGamma )**( 3 ) + ( \
        -953069482269883656385999/6927132968211456000 * ( np.log( 2 ) )**( \
        2 ) + ( 10035552256/694575 * ( np.log( 2 ) )**( 3 ) + ( ( \
        EulerGamma )**( 2 ) * ( \
        -2909110845706836891260741/76198462650326016000 + 2508888064/231525 * \
        np.log( 2 ) ) + ( \
        -808193164044493858362025279630261/8785387423956862120860057600 * \
        np.log( 3 ) + ( 38008842429969538227/4955242198466560 * ( \
        np.log( 3 ) )**( 2 ) + ( \
        -3774879782499167357392578125/300840224721429627666432 * np.log( 5 \
        ) + ( 729405517578125/223888084992 * ( np.log( 5 ) )**( 2 ) + ( \
        45385748308543142507/1283378311987200 * np.log( 7 ) + ( \
        -68593734344568278759/845803781222400 * zeta( 3 ) + ( \
        EulerGamma * ( \
        -29969896009576162233721401840588737713/\
        99254147065796317227295703040000 + ( \
        -5772412400261141618350357/38099231325163008000 * np.log( 2 ) + ( \
        5017776128/231525 * ( np.log( 2 ) )**( 2 ) + ( \
        -85224987219778941/30970263740416 * np.log( 3 ) + ( \
        161884619140625/261202765824 * np.log( 5 ) + 23447552/2205 * \
        zeta( 3 ) ) ) ) ) ) + ( np.log( 2 ) * ( \
        -2701090852290614435332319958796214753749/\
        4863453206224019544137489448960000 + ( \
        -571504883673423551/22121616957440 * np.log( 3 ) + ( \
        -4134530908203125/783608297472 * np.log( 5 ) + 46895104/2205 * \
        zeta( 3 ) ) ) ) + -219136/21 * zeta( 5 ) ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) + ( ( vp )**( 18 ) * ( \
        -504049773465027265457082344698997595199946892561127/\
        2256057555706410793995584189558643920732160000 + ( \
        -5017776128/9029475 * ( EulerGamma )**( 3 ) + ( -32768/819 * ( \
        np.pi )**( 6 ) + ( ( EulerGamma )**( 2 ) * ( \
        32292879038918605470217/2814147768335904000 + ( -93790208/85995 * ( \
        np.pi )**( 2 ) + -10035552256/3009825 * np.log( 2 ) ) ) + ( ( \
        np.pi )**( 4 ) * ( 3688291241374637/1189983674880 + -3506176/4095 \
        * np.log( 2 ) ) + ( \
        62933230502346036624740617660228089683/\
        329296310838084656634309181440000 * np.log( 2 ) + ( \
        1544718905670033551996323/30955625451694944000 * ( np.log( 2 ) \
        )**( 2 ) + ( -40142209024/9029475 * ( np.log( 2 ) )**( 3 ) + ( \
        1449920125859628982906197261503/396562626775830581844377600 * \
        np.log( 3 ) + ( -2684948834816170393/251633392890880 * np.log( \
        2 ) * np.log( 3 ) + ( 9441010581979717287/2013067143127040 * ( \
        np.log( 3 ) )**( 2 ) + ( \
        -1599441857994996625615234375/122216341293080786239488 * np.log( 5 \
        ) + ( -4134530908203125/1273363483392 * np.log( 2 ) * np.log( 5 \
        ) + ( 729405517578125/363818138112 * ( np.log( 5 ) )**( 2 ) + ( \
        10614597927041548993/1564117317734400 * np.log( 7 ) + ( ( \
        32292879038918605470217/2814147768335904000 + ( -5017776128/3009825 * \
        EulerGamma + ( -93790208/85995 * ( np.pi )**( 2 ) + \
        -10035552256/3009825 * np.log( 2 ) ) ) ) * ( np.log( vp ) )**( \
        2 ) + ( -5017776128/9029475 * ( np.log( vp ) )**( 3 ) + ( \
        EulerGamma * ( \
        1909356753774841604665638639396090623/\
        22452021193505772043248353280000 + ( -1753088/4095 * ( np.pi )**( \
        4 ) + ( ( np.pi )**( 2 ) * ( 2042174080411052033/128852919795600 + \
        -375160832/85995 * np.log( 2 ) ) + ( \
        693412253491294404648899/15477812725847472000 * np.log( 2 ) + ( \
        -20071104512/3009825 * ( np.log( 2 ) )**( 2 ) + ( \
        44111547682284331/50326678578176 * np.log( 3 ) + ( \
        161884619140625/424454494464 * np.log( 5 ) + -93790208/28665 * \
        zeta( 3 ) ) ) ) ) ) ) ) + ( np.log( vp ) * ( \
        1864297837801002988466353497789690623/\
        22452021193505772043248353280000 + ( -5017776128/3009825 * ( \
        EulerGamma )**( 2 ) + ( -1753088/4095 * ( np.pi )**( 4 ) + ( \
        EulerGamma * ( 32292879038918605470217/1407073884167952000 + ( \
        -187580416/85995 * ( np.pi )**( 2 ) + -20071104512/3009825 * \
        np.log( 2 ) ) ) + ( ( np.pi )**( 2 ) * ( \
        2042174080411052033/128852919795600 + -375160832/85995 * np.log( 2 \
        ) ) + ( 693412253491294404648899/15477812725847472000 * np.log( 2 \
        ) + ( -20071104512/3009825 * ( np.log( 2 ) )**( 2 ) + ( \
        44111547682284331/50326678578176 * np.log( 3 ) + ( \
        161884619140625/424454494464 * np.log( 5 ) + -93790208/28665 * \
        zeta( 3 ) ) ) ) ) ) ) ) ) ) + ( ( np.pi )**( 2 ) * ( \
        186826319334143170969372134091853/3008417716168673149845504000 + ( \
        29329616853340129303/1030823358364800 * np.log( 2 ) + ( \
        -375160832/85995 * ( np.log( 2 ) )**( 2 ) + ( \
        632421821599629/804422434816 * np.log( 3 ) + ( \
        1321044921875/1272091392 * np.log( 5 ) + -1753088/819 * \
        zeta( 3 ) ) ) ) ) ) + ( 609824085676533461/26431368163200 * \
        zeta( 3 ) + ( -187580416/28665 * np.log( 2 ) * zeta( 3 \
        ) + 876544/273 * zeta( 5 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) \
        ) ) ) ) + ( ( vp )**( 20 ) * ( \
        -805881362034933110014965489834852319407278655898091188017067/\
        1176338189505057912611778338147179114369501888512000000 + ( \
        -326800201792/218791125 * ( EulerGamma )**( 3 ) + ( -2438944/19845 * \
        ( np.pi )**( 6 ) + ( \
        -7383684422783336554645613778265290115269341/\
        189200488355129920315808683288166400000 * np.log( 2 ) + ( \
        1925987391269364911707103537/10637478564309717120000 * ( np.log( 2 \
        ) )**( 2 ) + ( -266845766624/218791125 * ( np.log( 2 ) )**( 3 ) + \
        ( ( EulerGamma )**( 2 ) * ( \
        22166010582518496113583187669/351036792622220664960000 + ( \
        -6589493084/2083725 * ( np.pi )**( 2 ) + ( -573052573216/72930375 \
        * np.log( 2 ) + -25777791/24010 * np.log( 3 ) ) ) ) + ( ( \
        np.pi )**( 4 ) * ( 21726410119449169787351/1328680849047552000 + ( \
        -46632128/19845 * np.log( 2 ) + -3861/49 * np.log( 3 ) ) ) + ( \
        983039791051052653017583399919547959/99117995972427597999274721280000 \
        * np.log( 3 ) + ( 51471654149618114476579/528430125070848000 * \
        np.log( 2 ) * np.log( 3 ) + ( -185679/10 * ( np.log( 2 ) \
        )**( 2 ) * np.log( 3 ) + ( \
        -6497626278782069908821/402613428625408000 * ( np.log( 3 ) )**( 2 \
        ) + ( 944541/98 * np.log( 2 ) * ( np.log( 3 ) )**( 2 ) + ( \
        -8008065/4802 * ( np.log( 3 ) )**( 3 ) + ( \
        73065066864889785227342468123046875/533676720005478973717377712128 * \
        np.log( 5 ) + ( 2213232984150390625/91682170804224 * np.log( 2 \
        ) * np.log( 5 ) + ( -566162109375/97140736 * np.log( 3 ) * \
        np.log( 5 ) + ( -803367237060546875/61121447202816 * ( np.log( \
        5 ) )**( 2 ) + ( -839337151526409339507875101/29271266872237817856000 \
        * np.log( 7 ) + ( ( \
        22041581958952014852855686869/351036792622220664960000 + ( \
        -326800201792/72930375 * EulerGamma + ( -6589493084/2083725 * ( \
        np.pi )**( 2 ) + ( -573052573216/72930375 * np.log( 2 ) + \
        -25777791/24010 * np.log( 3 ) ) ) ) ) * ( np.log( vp ) )**( 2 ) \
        + ( -326800201792/218791125 * ( np.log( vp ) )**( 3 ) + ( \
        EulerGamma * ( \
        2627468063603583247439123873277908785638151/\
        37840097671025984063161736657633280000 + ( -13448704/11025 * ( \
        np.pi )**( 4 ) + ( -815664712192/72930375 * ( np.log( 2 ) )**( \
        2 ) + ( np.log( 2 ) * ( \
        8716273873487009596603881917/35103679262222066496000 + -2187783/245 * \
        np.log( 3 ) ) + ( ( np.pi )**( 2 ) * ( \
        1249710522845237676755611/14387122318593024000 + ( \
        -25678092728/2083725 * np.log( 2 ) + -95121/343 * np.log( 3 ) ) \
        ) + ( 6862917963659488726951/528430125070848000 * np.log( 3 ) + ( \
        11129157/4802 * ( np.log( 3 ) )**( 2 ) + ( \
        -2566285304345703125/641775195629568 * np.log( 5 ) + \
        -8713301312/694575 * zeta( 3 ) ) ) ) ) ) ) ) ) + ( np.log( \
        vp ) * ( 2371823362101873167559688425282472333880071/\
        37840097671025984063161736657633280000 + ( -326800201792/72930375 * ( \
        EulerGamma )**( 2 ) + ( -13448704/11025 * ( np.pi )**( 4 ) + ( \
        8678945286417065218385631677/35103679262222066496000 * np.log( 2 ) \
        + ( -815664712192/72930375 * ( np.log( 2 ) )**( 2 ) + ( EulerGamma \
        * ( 22041581958952014852855686869/175518396311110332480000 + ( \
        -13178986168/2083725 * ( np.pi )**( 2 ) + ( \
        -1146105146432/72930375 * np.log( 2 ) + -25777791/12005 * \
        np.log( 3 ) ) ) ) + ( ( np.pi )**( 2 ) * ( \
        1236365606712297143814811/14387122318593024000 + ( \
        -25678092728/2083725 * np.log( 2 ) + -95121/343 * np.log( 3 ) ) \
        ) + ( 6862917963659488726951/528430125070848000 * np.log( 3 ) + ( \
        -2187783/245 * np.log( 2 ) * np.log( 3 ) + ( 11129157/4802 * ( \
        np.log( 3 ) )**( 2 ) + ( -2566285304345703125/641775195629568 * \
        np.log( 5 ) + -8713301312/694575 * zeta( 3 ) ) ) ) ) ) ) ) ) \
        ) ) ) + ( ( np.pi )**( 2 ) * ( \
        23007641266855007645152507433448171977/\
        340465367864005257343606456320000 + ( -24367229788/2083725 * ( \
        np.log( 2 ) )**( 2 ) + ( np.log( 2 ) * ( \
        33224865842212702960654717/187032590141709312000 + -8073/7 * \
        np.log( 3 ) ) + ( 3233877203458956073/563095704371200 * np.log( \
        3 ) + ( 205335/686 * ( np.log( 3 ) )**( 2 ) + ( \
        -5223826806640625/854845415424 * np.log( 5 ) + -44946392/6615 * \
        zeta( 3 ) ) ) ) ) ) ) + ( \
        614350997432647461647627/3896512294618944000 * zeta( 3 ) + ( \
        -3046519936/99225 * np.log( 2 ) * zeta( 3 ) + ( 276939/49 * \
        np.log( 3 ) * zeta( 3 ) + 6961344/245 * zeta( 5 ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + ( ( vp )**( 22 ) \
        * ( -224200259349965273716867993750941364636146949222970461761472350959/128442076973715036965343525813792227655996605242948976640000 + ( \
        -92424778092259871/67367584975383 * ( EulerGamma )**( 3 ) + ( \
        -2503246985/8501598 * ( np.pi )**( 6 ) + ( \
        -1024661153836347122213932830425231393454599602100087/\
        2091666342587779598820124704592306435522560000 * np.log( 2 ) + ( \
        15154423388834307194080028204425193/17169786787656235930509312000 * ( \
        np.log( 2 ) )**( 2 ) + ( -59262219420958368113/1684189624384575 * \
        ( np.log( 2 ) )**( 3 ) + ( \
        6570295678854493182568171959367166886895256231/\
        8587285618827217863007968028985917440000 * np.log( 3 ) + ( \
        1192391448137550473870888509699/10467786488435443335168000 * \
        np.log( 2 ) * np.log( 3 ) + ( 68106385737/1142876 * ( \
        np.log( 2 ) )**( 2 ) * np.log( 3 ) + ( \
        -199072489183741987999262992249/1550783183471917531136000 * ( \
        np.log( 3 ) )**( 2 ) + ( -953398946565/18286016 * np.log( 2 ) * \
        ( np.log( 3 ) )**( 2 ) + ( 78519077325/5224576 * ( np.log( 3 ) \
        )**( 3 ) + ( ( EulerGamma )**( 2 ) * ( \
        5254260684122492108838577198779857/22664118559706231428272291840 + ( \
        -20557680798999019/7776921786480 * ( np.pi )**( 2 ) + ( \
        -188169036483694349/22455861658461 * np.log( 2 ) + 8648289/163268 \
        * np.log( 3 ) ) ) ) + ( ( np.pi )**( 4 ) * ( \
        399608555812025592668440841/6307655452555770593280 + ( \
        -1550365266533/400789620 * np.log( 2 ) + 79419015/93296 * \
        np.log( 3 ) ) ) + ( \
        -71703442881442095576982982559389638671875/\
        198651552841079449344766940540829696 * np.log( 5 ) + ( \
        -1803825083028134839111328125/19069595210502552748032 * np.log( 2 \
        ) * np.log( 5 ) + ( 146565216064453125/2404427497472 * np.log( \
        3 ) * np.log( 5 ) + ( \
        351746766944618555908203125/12713063473668368498688 * ( np.log( 5 \
        ) )**( 2 ) + ( \
        -56512971273018149546828851536563/597379578285912246190080000 * \
        np.log( 7 ) + ( -1376711354225717713/230815923624000 * np.log( \
        2 ) * np.log( 7 ) + ( 42358546129606626367/4154686625232000 * ( \
        np.log( 7 ) )**( 2 ) + ( ( \
        5210835891957349933425888358747601/22664118559706231428272291840 + ( \
        -92424778092259871/22455861658461 * EulerGamma + ( \
        -20557680798999019/7776921786480 * ( np.pi )**( 2 ) + ( \
        -188169036483694349/22455861658461 * np.log( 2 ) + 8648289/163268 \
        * np.log( 3 ) ) ) ) ) * ( np.log( vp ) )**( 2 ) + ( \
        -92424778092259871/67367584975383 * ( np.log( vp ) )**( 3 ) + ( \
        np.log( vp ) * ( \
        -191402464187057934679162566389528946228629295594583/\
        597618955025079885377178487026373267292160000 + ( \
        -92424778092259871/22455861658461 * ( EulerGamma )**( 2 ) + ( \
        -2480855964989/2805527340 * ( np.pi )**( 4 ) + ( \
        1321415420086962497893639983556919/1618865611407587959162306560 * \
        np.log( 2 ) + ( -950324695671628169/51036049223775 * ( np.log( \
        2 ) )**( 2 ) + ( ( np.pi )**( 2 ) * ( \
        2195128805921033423157088133/7046833825902149959680 + ( \
        -34060441335203977/3888460893240 * np.log( 2 ) + -520875225/653072 \
        * np.log( 3 ) ) ) + ( \
        93945795601156219302913805759/2093557297687088667033600 * np.log( \
        3 ) + ( 2088524061/285719 * np.log( 2 ) * np.log( 3 ) + ( \
        -64063082655/18286016 * ( np.log( 3 ) )**( 2 ) + ( EulerGamma * ( \
        5193283540017238333797165656886737/11332059279853115714136145920 + ( \
        -20557680798999019/3888460893240 * ( np.pi )**( 2 ) + ( \
        -376338072967388698/22455861658461 * np.log( 2 ) + 8648289/81634 * \
        np.log( 3 ) ) ) ) + ( \
        314136536274139086669921875/19069595210502552748032 * np.log( 5 ) \
        + ( 599362878831503339/83093732504640 * np.log( 7 ) + \
        -433483115925830/32403840777 * zeta( 3 ) ) ) ) ) ) ) ) ) ) ) ) \
        ) + ( EulerGamma * ( \
        -188425641283145608274684047209408010761026913565783/\
        597618955025079885377178487026373267292160000 + ( \
        -2480855964989/2805527340 * ( np.pi )**( 4 ) + ( \
        -950324695671628169/51036049223775 * ( np.log( 2 ) )**( 2 ) + ( ( \
        np.pi )**( 2 ) * ( \
        2257117487354587818390081413/7046833825902149959680 + ( \
        -34060441335203977/3888460893240 * np.log( 2 ) + -520875225/653072 \
        * np.log( 3 ) ) ) + ( \
        96372993621609335069026061759/2093557297687088667033600 * np.log( \
        3 ) + ( -64063082655/18286016 * ( np.log( 3 ) )**( 2 ) + ( \
        np.log( 2 ) * ( \
        266268860688745627921959568872715/323773122281517591832461312 + \
        2088524061/285719 * np.log( 3 ) ) + ( \
        314136536274139086669921875/19069595210502552748032 * np.log( 5 ) \
        + ( 599362878831503339/83093732504640 * np.log( 7 ) + \
        -433483115925830/32403840777 * zeta( 3 ) ) ) ) ) ) ) ) ) ) + ( \
        ( np.pi )**( 2 ) * ( \
        -98650516015688217757432997191187277369750431/\
        600048965821354552140048138221125632000 + ( \
        -6186546664726613/1110988826640 * ( np.log( 2 ) )**( 2 ) + ( \
        np.log( 2 ) * ( \
        92831954351398174110336305383/147983510343945149153280 + \
        -6733929735/653072 * np.log( 3 ) ) + ( \
        -32498731452010385655421/2711347699698892800 * np.log( 3 ) + ( \
        22867132275/5224576 * ( np.log( 3 ) )**( 2 ) + ( \
        4524184659575439453125/543331042162900992 * np.log( 5 ) + ( \
        14180966230199741/3759897398400 * np.log( 7 ) + \
        -470544021557/2244421872 * zeta( 3 ) ) ) ) ) ) ) ) + ( \
        616445250063621226080122344433/1109876327579588618649600 * \
        zeta( 3 ) + ( 9911332672657838/162019203885 * np.log( 2 ) * \
        zeta( 3 ) + ( -1478343555/40817 * np.log( 3 ) * zeta( \
        3 ) + 5533508250448/46758789 * zeta( 5 ) ) ) ) ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + ( vp )**( 24 ) * ( \
        -339042420331064819359769510050465720620839166904426435306655923192162710721591/\
        91185704553575039810864567398390286963190173903231553624355110912000000 + ( -2147608182784/1385677125 * ( EulerGamma )**( 4 ) + ( \
        -262144/10773 * ( np.pi )**( 8 ) + ( ( EulerGamma )**( 3 ) * ( \
        2493325346531962428354335837/60002027526809498130000 + ( \
        -160568836096/39590775 * ( np.pi )**( 2 ) + \
        -17180865462272/1385677125 * np.log( 2 ) ) ) + ( ( np.pi )**( 6 \
        ) * ( 552373215564228017/266901368025600 + -112197632/125685 * \
        np.log( 2 ) ) + ( \
        -31578589287954045087412757310986150655669372259589542143373469/\
        7585951744646766695132726800430029201954018689024000000 * np.log( \
        2 ) + ( 1780979724640915954685745499105006260305120741/\
        1105640353825290471845506992965222400000 * ( np.log( 2 ) )**( 2 ) \
        + ( 2955414379001038174257851578841/7260245330743949273730000 * ( \
        np.log( 2 ) )**( 3 ) + ( -34361730924544/1385677125 * ( np.log( \
        2 ) )**( 4 ) + ( \
        -607807691332001473877438863082653973232184470041612410909/\
        246660017099727210531166242558310150345504849920000 * np.log( 3 ) \
        + ( 569208284384896938409196050333832358083/\
        6324590454309853839674284179456000 * np.log( 2 ) * np.log( 3 ) \
        + ( -1814733014897445162816209/8283142210485542400 * ( np.log( 2 ) \
        )**( 2 ) * np.log( 3 ) + ( \
        1896127015572392187612892393363349228187/\
        3747905454405839312399575810048000 * ( np.log( 3 ) )**( 2 ) + ( \
        48858412043337699489279/184069826899678720 * np.log( 2 ) * ( \
        np.log( 3 ) )**( 2 ) + ( \
        -352575782581627247981607/4207310329135513600 * ( np.log( 3 ) )**( \
        3 ) + ( -39462502238391176546966808151288428035195624609375/\
        225238421917811358647205507510978319937961984 * np.log( 5 ) + ( \
        107758457002680199034081756462890625/909613055321838511192770084864 * \
        np.log( 2 ) * np.log( 5 ) + ( \
        -90580130043095703125/2794396164303744 * ( np.log( 2 ) )**( 2 ) * \
        np.log( 5 ) + ( -3213439242370148779296875/12072668935646871552 * \
        np.log( 3 ) * np.log( 5 ) + ( \
        379559059113846900762082872412109375/2425634814191569363180720226304 \
        * ( np.log( 5 ) )**( 2 ) + ( 15979961960205078125/399199452043392 \
        * np.log( 2 ) * ( np.log( 5 ) )**( 2 ) + ( \
        -2819152325439453125/171085479447168 * ( np.log( 5 ) )**( 3 ) + ( \
        254552854418995137066329276959922820720109/\
        140067427233452550596057093898240000 * np.log( 7 ) + ( \
        37527733708977518967989/473634275276448000 * np.log( 2 ) * \
        np.log( 7 ) + ( -41343924869387/1891901440 * np.log( 3 ) * \
        np.log( 7 ) + ( -221940628056511747894637/1894537101105792000 * ( \
        np.log( 7 ) )**( 2 ) + ( \
        -71390211212258470496382517/10054840331118772224000 * np.log( 11 ) \
        + ( ( 2493325346531962428354335837/60002027526809498130000 + ( \
        -8590432731136/1385677125 * EulerGamma + ( -160568836096/39590775 * ( \
        np.pi )**( 2 ) + -17180865462272/1385677125 * np.log( 2 ) ) ) ) \
        * ( np.log( vp ) )**( 3 ) + ( -2147608182784/1385677125 * ( \
        np.log( vp ) )**( 4 ) + ( ( EulerGamma )**( 2 ) * ( \
        31259152980458629791883092782668733535755477/\
        57870982707108867672354360513331200000 + ( -1500643328/628425 * ( \
        np.pi )**( 4 ) + ( ( np.pi )**( 2 ) * ( \
        176487483333251487382628003/2063073376257576883200 + \
        -321137672192/13196925 * np.log( 2 ) ) + ( \
        596272166327061353428911579329/2420081776914649757910000 * np.log( \
        2 ) + ( -17180865462272/461892375 * ( np.log( 2 ) )**( 2 ) + ( \
        41322005827908123591503/8283142210485542400 * np.log( 3 ) + ( \
        -138864626298828125/310488462700416 * np.log( 5 ) + \
        -80284418048/4398975 * zeta( 3 ) ) ) ) ) ) ) ) + ( ( np.log( \
        vp ) )**( 2 ) * ( \
        30339182094680904004187782301804787193355477/\
        57870982707108867672354360513331200000 + ( -4295216365568/461892375 * \
        ( EulerGamma )**( 2 ) + ( -1500643328/628425 * ( np.pi )**( 4 ) + \
        ( EulerGamma * ( 2493325346531962428354335837/20000675842269832710000 \
        + ( -160568836096/13196925 * ( np.pi )**( 2 ) + \
        -17180865462272/461892375 * np.log( 2 ) ) ) + ( ( np.pi )**( 2 \
        ) * ( 176487483333251487382628003/2063073376257576883200 + \
        -321137672192/13196925 * np.log( 2 ) ) + ( \
        596272166327061353428911579329/2420081776914649757910000 * np.log( \
        2 ) + ( -17180865462272/461892375 * ( np.log( 2 ) )**( 2 ) + ( \
        41322005827908123591503/8283142210485542400 * np.log( 3 ) + ( \
        -138864626298828125/310488462700416 * np.log( 5 ) + \
        -80284418048/4398975 * zeta( 3 ) ) ) ) ) ) ) ) ) ) + ( ( \
        np.pi )**( 4 ) * ( \
        70499577706493944915646761295816405117/\
        412694742304018582695806238720000 + ( \
        45718219934650995118117/572503434414912000 * np.log( 2 ) + ( \
        -6002573312/628425 * ( np.log( 2 ) )**( 2 ) + ( \
        -61856875841407/133601628160 * np.log( 3 ) + ( \
        -3359228515625/464802624 * np.log( 5 ) + -28049408/5985 * \
        zeta( 3 ) ) ) ) ) ) + ( \
        18730202910790587676859274895672315026137/\
        13716457870678680120575263211520000 * zeta( 3 ) + ( \
        -343798413763254587934661/26862934586687199000 * np.log( 2 ) * \
        zeta( 3 ) + ( -321137672192/4398975 * ( np.log( 2 ) )**( 2 ) \
        * zeta( 3 ) + ( 697774173785667217/18388594095872 * np.log( \
        3 ) * zeta( 3 ) + ( 36388408837890625/155089142208 * np.log( \
        5 ) * zeta( 3 ) + ( -750321664/41895 * ( zeta( 3 ) )**( 2 \
        ) + ( -9337435219071821153/59635774418220 * zeta( 5 ) + ( \
        3001286656/41895 * np.log( 2 ) * zeta( 5 ) + ( ( np.pi \
        )**( 2 ) * ( \
        -11475039734101049516517816433252349101993202598276635221/\
        8746761842379739339572879850660750748653977600000 + ( \
        635856053627351089679030947/2063073376257576883200 * ( np.log( 2 ) \
        )**( 2 ) + ( -1284550688768/39590775 * ( np.log( 2 ) )**( 3 ) + ( \
        30177901779526373208008157432799/298075644741393536243466240 * \
        np.log( 3 ) + ( -60860276209445290659/2942175055339520 * ( \
        np.log( 3 ) )**( 2 ) + ( \
        30711938388651958026378408203125/285083717951644750917402624 * \
        np.log( 5 ) + ( -5105838623046875/398800651392 * ( np.log( 5 ) \
        )**( 2 ) + ( -226583189018657375989/6858052854681600 * np.log( 7 ) \
        + ( np.log( 2 ) * ( \
        263700407814462873973593089444476826294399/\
        219463325930858881929204211384320000 + ( \
        281690099080898123087/4413262583009280 * np.log( 3 ) + ( \
        4134530908203125/199400325696 * np.log( 5 ) + -6002573312/125685 * \
        zeta( 3 ) ) ) ) + ( 20739799054169359302703/114500686882982400 \
        * zeta( 3 ) + 28049408/1197 * zeta( 5 ) ) ) ) ) ) ) ) ) ) \
        ) + ( EulerGamma * ( \
        -14958797730943009248979359684307400793946353140693579085130097/\
        7585951744646766695132726800430029201954018689024000000 + ( \
        -56098816/125685 * ( np.pi )**( 6 ) + ( ( np.pi )**( 4 ) * ( \
        18621130512899564933221/572503434414912000 + -6002573312/628425 * \
        np.log( 2 ) ) + ( \
        1141492859819320740155640865933/2420081776914649757910000 * ( \
        np.log( 2 ) )**( 2 ) + ( -68723461849088/1385677125 * ( np.log( \
        2 ) )**( 3 ) + ( \
        24871801429857664712600600251413145513/\
        100390324671584981582131494912000 * np.log( 3 ) + ( \
        -613652094902831301159/131478447785484800 * ( np.log( 3 ) )**( 2 ) \
        + ( 8665489077887742041216086361328125/909613055321838511192770084864 \
        * np.log( 5 ) + ( -625684052978515625/133066484014464 * ( \
        np.log( 5 ) )**( 2 ) + ( -6985987213214917114627/78939045879408000 \
        * np.log( 7 ) + ( np.log( 2 ) * ( \
        7403815909802659732363630710658722667277034509/\
        3501194453780086494177438811056537600000 + ( \
        142402901279390045029823/4141571105242771200 * np.log( 3 ) + ( \
        3546600613056640625/465732694050624 * np.log( 5 ) + \
        -321137672192/4398975 * zeta( 3 ) ) ) ) + ( ( np.pi )**( 2 ) \
        * ( 499462944879507074927421208316634860828311/\
        658389977792576645787612634152960000 + ( \
        352369453458667498004095331/1031536688128788441600 * np.log( 2 ) + \
        ( -642275344384/13196925 * ( np.log( 2 ) )**( 2 ) + ( \
        3715098855731414131/882652516601856 * np.log( 3 ) + ( \
        -161884619140625/66466775232 * np.log( 5 ) + -3001286656/125685 * \
        zeta( 3 ) ) ) ) ) ) + ( \
        7152282585687066745126007/26862934586687199000 * zeta( 3 ) + \
        1500643328/41895 * zeta( 5 ) ) ) ) ) ) ) ) ) ) ) ) ) ) + ( \
        np.log( vp ) * ( \
        -13890257576425968478652682377833134049367629077694981289290097/\
        7585951744646766695132726800430029201954018689024000000 + ( \
        -8590432731136/1385677125 * ( EulerGamma )**( 3 ) + ( \
        -56098816/125685 * ( np.pi )**( 6 ) + ( ( EulerGamma )**( 2 ) * ( \
        2493325346531962428354335837/20000675842269832710000 + ( \
        -160568836096/13196925 * ( np.pi )**( 2 ) + \
        -17180865462272/461892375 * np.log( 2 ) ) ) + ( ( np.pi )**( 4 \
        ) * ( 18621130512899564933221/572503434414912000 + -6002573312/628425 \
        * np.log( 2 ) ) + ( \
        7233706702552394866020741951939119258381034509/\
        3501194453780086494177438811056537600000 * np.log( 2 ) + ( \
        1141492859819320740155640865933/2420081776914649757910000 * ( \
        np.log( 2 ) )**( 2 ) + ( -68723461849088/1385677125 * ( np.log( \
        2 ) )**( 3 ) + ( \
        24145193189845171899347163941581465513/\
        100390324671584981582131494912000 * np.log( 3 ) + ( \
        142402901279390045029823/4141571105242771200 * np.log( 2 ) * \
        np.log( 3 ) + ( -613652094902831301159/131478447785484800 * ( \
        np.log( 3 ) )**( 2 ) + ( \
        8665489077887742041216086361328125/909613055321838511192770084864 * \
        np.log( 5 ) + ( 3546600613056640625/465732694050624 * np.log( 2 \
        ) * np.log( 5 ) + ( -625684052978515625/133066484014464 * ( \
        np.log( 5 ) )**( 2 ) + ( -6985987213214917114627/78939045879408000 \
        * np.log( 7 ) + ( EulerGamma * ( \
        30167226428263480144396170527520612079115477/\
        28935491353554433836177180256665600000 + ( -3001286656/628425 * ( \
        np.pi )**( 4 ) + ( ( np.pi )**( 2 ) * ( \
        176487483333251487382628003/1031536688128788441600 + \
        -642275344384/13196925 * np.log( 2 ) ) + ( \
        596272166327061353428911579329/1210040888457324878955000 * np.log( \
        2 ) + ( -34361730924544/461892375 * ( np.log( 2 ) )**( 2 ) + ( \
        41322005827908123591503/4141571105242771200 * np.log( 3 ) + ( \
        -138864626298828125/155244231350208 * np.log( 5 ) + \
        -160568836096/4398975 * zeta( 3 ) ) ) ) ) ) ) ) + ( ( np.pi \
        )**( 2 ) * ( \
        459772627683744444784892147345931930908311/\
        658389977792576645787612634152960000 + ( \
        352369453458667498004095331/1031536688128788441600 * np.log( 2 ) + \
        ( -642275344384/13196925 * ( np.log( 2 ) )**( 2 ) + ( \
        3715098855731414131/882652516601856 * np.log( 3 ) + ( \
        -161884619140625/66466775232 * np.log( 5 ) + -3001286656/125685 * \
        zeta( 3 ) ) ) ) ) ) + ( \
        7152282585687066745126007/26862934586687199000 * zeta( 3 ) + ( \
        -321137672192/4398975 * np.log( 2 ) * zeta( 3 ) + \
        1500643328/41895 * zeta( 5 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) \
        ) ) + -14024704/399 * zeta( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) )
    
    
    phie2v6=-785/272 * ( e0 )**( 2 ) * ( vp )**( -19/3 ) * ( vp0 )**( 19/3 ) * ( \
        1 + ( 377/72 * np.pi * ( vp0 )**( 3 ) + ( ( vp0 )**( 2 ) * ( \
        2833/1008 + -197/36 * eta ) + ( ( vp0 )**( 5 ) * ( 764881/90720 * \
        np.pi + -949457/22680 * np.pi * eta ) + ( ( vp )**( 5 ) * ( \
        -131697334/8456805 * np.pi + -268652717/9664920 * np.pi * eta ) \
        + ( ( vp0 )**( 4 ) * ( -1193251/3048192 + ( -66317/9072 * eta + \
        18155/1296 * ( eta )**( 2 ) ) ) + ( ( vp )**( 3 ) * ( -1114537/141300 \
        * np.pi + ( -420180449/10173600 * ( np.pi )**( 2 ) * ( vp0 )**( \
        3 ) + ( vp0 )**( 2 ) * ( -3157483321/142430400 * np.pi + \
        219563789/5086800 * np.pi * eta ) ) ) + ( ( vp )**( 4 ) * ( \
        377620541/107433216 + ( 561233971/31334688 * eta + ( 36339727/2238192 \
        * ( eta )**( 2 ) + ( vp0 )**( 2 ) * ( 1069798992653/108292681728 + ( \
        5894683956785/189512193024 * eta + ( -39391912661/752032512 * ( eta \
        )**( 2 ) + -7158926219/80574912 * ( eta )**( 3 ) ) ) ) ) ) ) + ( ( vp \
        )**( 2 ) * ( 6955261/2215584 + ( 436441/79128 * eta + ( ( vp0 )**( 3 \
        ) * ( 2622133397/159522048 * np.pi + 164538257/5697216 * np.pi \
        * eta ) + ( ( vp0 )**( 2 ) * ( 19704254413/2233308672 + ( \
        -16718633/9970128 * eta + -85978877/2848608 * ( eta )**( 2 ) ) ) + ( \
        vp0 )**( 4 ) * ( -8299372143511/6753525424128 + ( \
        -6055808184535/241197336576 * eta + ( 3499644089/957132288 * ( eta \
        )**( 2 ) + 7923586355/102549888 * ( eta )**( 3 ) ) ) ) ) ) ) ) + ( ( \
        vp )**( 6 ) * ( -204814565759250649/1061268280934400 + ( \
        12483797/791280 * C + ( 365639621/13022208 * ( np.pi )**( 2 ) + ( \
        ( 34787542048195/137827049472 + -8764775/1446912 * ( np.pi )**( 2 \
        ) ) * eta + ( 80353703837/1640798208 * ( eta )**( 2 ) + ( \
        5885194385/175799808 * ( eta )**( 3 ) + ( 164286623/2373840 * \
        np.log( 2 ) + ( -26079003/703360 * np.log( 3 ) + \
        12483797/791280 * np.log( vp ) ) ) ) ) ) ) ) ) + ( vp0 )**( 6 ) * \
        ( 26531900578691/168991764480 + ( -3317/126 * C + ( 122833/10368 * ( \
        np.pi )**( 2 ) + ( ( 9155185261/548674560 + -3977/1152 * ( \
        np.pi )**( 2 ) ) * eta + ( -5732473/1306368 * ( eta )**( 2 ) + ( \
        -3090307/139968 * ( eta )**( 3 ) + ( -12091/1890 * np.log( 2 ) + ( \
        -26001/560 * np.log( 3 ) + -3317/126 * np.log( vp0 ) ) ) ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) ) )    
    
    
    phie2v10 = -785/272 * ( e0 )**( 2 ) * ( vp )**( -19/3 ) * ( vp0 )**( 19/3 ) * ( \
        1 + ( -1114537/141300 * np.pi * ( vp )**( 3 ) + ( \
        171505695307519/1279822602240 * np.pi * ( vp )**( 7 ) + ( ( \
        -41144741521/8778792960 * np.pi + ( \
        -14757587498275687/1215634576343040 * np.pi * ( vp )**( 2 ) + \
        50314299761111581/2480886890496000 * ( np.pi )**( 2 ) * ( vp )**( \
        3 ) ) ) * ( vp0 )**( 7 ) + ( ( vp )**( 2 ) * ( 6955261/2215584 + \
        436441/79128 * eta ) + ( ( vp0 )**( 5 ) * ( 764881/90720 * np.pi + \
        ( 68789266429/2430812160 * np.pi * ( vp )**( 2 ) + ( \
        -4285376283331/68366592000 * ( np.pi )**( 2 ) * ( vp )**( 3 ) + ( \
        -33797921687964109/15282263245455360 * np.pi * ( vp )**( 4 ) + ( \
        -163701830288804587/523742787993600 * ( np.pi )**( 2 ) * ( vp )**( \
        5 ) + -949457/22680 * np.pi * eta ) ) ) ) ) + ( ( vp )**( 5 ) * ( \
        -131697334/8456805 * np.pi + -268652717/9664920 * np.pi * eta ) \
        + ( ( vp )**( 4 ) * ( 377620541/107433216 + ( 561233971/31334688 * \
        eta + 36339727/2238192 * ( eta )**( 2 ) ) ) + ( ( vp0 )**( 4 ) * ( \
        -1193251/3048192 + ( -18390541100627/3445676236800 * np.pi * ( vp \
        )**( 3 ) + ( 5223115682631934207/513484045047300096 * ( vp )**( 4 ) + \
        ( -108354439414096307/1885474036776960 * np.pi * ( vp )**( 5 ) + ( \
        -66317/9072 * eta + ( 18155/1296 * ( eta )**( 2 ) + ( ( vp )**( 2 ) * \
        ( -8299372143511/6753525424128 + ( -6055808184535/241197336576 * eta \
        + ( 3499644089/957132288 * ( eta )**( 2 ) + 7923586355/102549888 * ( \
        eta )**( 3 ) ) ) ) + ( vp )**( 6 ) * ( \
        43564610659168600099012633/103518383481535699353600 + ( \
        -1626860487019/24580620288 * C + ( 28216806397/1794623040 * \
        EulerGamma + ( 1472728447441693/90729577709568 * ( np.pi )**( 2 ) \
        + ( -2191259861259761/57887360778240 * np.log( 2 ) + ( \
        -4488596448961/70583582720 * np.log( 3 ) + \
        -973698379929371/19295786926080 * np.log( vp ) ) ) ) ) ) ) ) ) ) ) \
        ) ) ) + ( ( vp )**( 10 ) * ( \
        -22354438731336776202951521171/1057366345561400357683200 + ( \
        439909770676963/137827049472 * C + ( -65082207436457/17273246760 * \
        EulerGamma + ( -10561744817393519329/3969419024793600 * ( np.pi \
        )**( 2 ) + ( 199259108250976763/14471840194560 * np.log( 2 ) + ( \
        -160378563971617/27729264640 * np.log( 3 ) + ( \
        -6520263671875/1316056896 * np.log( 5 ) + \
        -30567279534165149/53063414046720 * np.log( vp ) ) ) ) ) ) ) ) + ( \
        ( vp )**( 6 ) * ( -204814565759250649/1061268280934400 + ( \
        12483797/791280 * C + ( 365639621/13022208 * ( np.pi )**( 2 ) + ( \
        ( 34787542048195/137827049472 + -8764775/1446912 * ( np.pi )**( 2 \
        ) ) * eta + ( 80353703837/1640798208 * ( eta )**( 2 ) + ( \
        5885194385/175799808 * ( eta )**( 3 ) + ( 164286623/2373840 * \
        np.log( 2 ) + ( -26079003/703360 * np.log( 3 ) + \
        12483797/791280 * np.log( vp ) ) ) ) ) ) ) ) ) + ( ( vp )**( 8 ) * \
        ( -1138390715410262916604727/238403306629103616000 + ( \
        87591909539/199402560 * C + ( -834091519/5192775 * EulerGamma + ( \
        899126217449/18231091200 * ( np.pi )**( 2 ) + ( \
        -2300615476499/2991038400 * np.log( 2 ) + ( 69914173599/98470400 * \
        np.log( 3 ) + 1769515771/6350400 * np.log( vp ) ) ) ) ) ) ) + ( \
        ( vp )**( 9 ) * ( 1104987210004202051/4862538305372160 * np.pi + ( \
        -4056229937/9970128 * C * np.pi + ( 160472180/207711 * EulerGamma \
        * np.pi + ( 87879716411/1640798208 * ( np.pi )**( 3 ) + ( \
        -120237902719/149551920 * np.pi * np.log( 2 ) + ( \
        1074445101/703360 * np.pi * np.log( 3 ) + 3646434703/9970128 * \
        np.pi * np.log( vp ) ) ) ) ) ) ) + ( ( vp0 )**( 2 ) * ( \
        2833/1008 + ( -18931302101099/242473512960 * np.pi * ( vp )**( 5 ) \
        + ( 797102084311518911/4515214140702720 * np.pi * ( vp )**( 7 ) + \
        ( -197/36 * eta + ( ( vp )**( 3 ) * ( -3157483321/142430400 * \
        np.pi + 219563789/5086800 * np.pi * eta ) + ( ( vp )**( 2 ) * ( \
        19704254413/2233308672 + ( -16718633/9970128 * eta + \
        -85978877/2848608 * ( eta )**( 2 ) ) ) + ( ( vp )**( 4 ) * ( \
        1069798992653/108292681728 + ( 5894683956785/189512193024 * eta + ( \
        -39391912661/752032512 * ( eta )**( 2 ) + -7158926219/80574912 * ( \
        eta )**( 3 ) ) ) ) + ( ( vp )**( 6 ) * ( \
        -79776280540147311563/1901792759434444800 + ( 159750037/2032128 * C + \
        ( -66991951/593460 * EulerGamma + ( 925648881485/17501847552 * ( \
        np.pi )**( 2 ) + ( 839424605711/4785661440 * np.log( 2 ) + ( \
        -7652542095/31510528 * np.log( 3 ) + -54670585243/1595220480 * \
        np.log( vp ) ) ) ) ) ) ) + ( vp )**( 8 ) * ( \
        -2470762026362567694728402681/240310533082136444928000 + ( \
        58904790893047/80399112192 * C + ( -2362981273327/5234317200 * \
        EulerGamma + ( 19829798076199271/110261639577600 * ( np.pi )**( 2 \
        ) + ( -13770778062844931/6029933414400 * np.log( 2 ) + ( \
        24488552693319/22057369600 * np.log( 3 ) + \
        80747851909801/287139686400 * np.log( vp ) ) ) ) ) ) ) ) ) ) ) ) ) \
        ) ) + ( ( vp0 )**( 3 ) * ( 377/72 * np.pi + ( -420180449/10173600 \
        * ( np.pi )**( 2 ) * ( vp )**( 3 ) + ( \
        -21678169277921/3032195088384 * np.pi * ( vp )**( 4 ) + ( \
        -2519273170531/17319536640 * ( np.pi )**( 2 ) * ( vp )**( 5 ) + ( \
        46292444720325197/99235475619840 * ( np.pi )**( 2 ) * ( vp )**( 7 \
        ) + ( ( vp )**( 2 ) * ( 2622133397/159522048 * np.pi + \
        164538257/5697216 * np.pi * eta ) + ( vp )**( 6 ) * ( \
        -9534567330772892941/43663609272729600 * np.pi + ( 21258653/145152 \
        * C * np.pi + ( -8914919/42390 * EulerGamma * np.pi + ( \
        123180242965/1250131968 * ( np.pi )**( 3 ) + ( \
        111705992359/341832960 * np.pi * np.log( 2 ) + ( \
        -1018358055/2250752 * np.pi * np.log( 3 ) + \
        -7275259667/113944320 * np.pi * np.log( vp ) ) ) ) ) ) ) ) ) ) \
        ) ) ) + ( ( vp0 )**( 8 ) * ( 7414432310322899683/32705990130401280 + \
        ( -9397061/254016 * C + ( 684616409/69672960 * ( np.pi )**( 2 ) + \
        ( -34253803/3810240 * np.log( 2 ) + ( -8184537/125440 * np.log( \
        3 ) + ( ( vp )**( 2 ) * ( \
        79427523005688885167781541/72462868437074989547520 + ( \
        -201771804982739/1125587570688 * C + ( \
        14699945926149791/308732590817280 * ( np.pi )**( 2 ) + ( \
        -735490773001597/16883813560320 * np.log( 2 ) + ( \
        -19526303708007/61760634880 * np.log( 3 ) + \
        -201771804982739/1125587570688 * np.log( vp0 ) ) ) ) ) ) + \
        -9397061/254016 * np.log( vp0 ) ) ) ) ) ) ) + ( ( vp0 )**( 10 ) * \
        ( -6253399439854454014703/32967638051444490240 + ( \
        95697675707/3072577536 * C + ( -71038219571281/12641461862400 * ( \
        np.pi )**( 2 ) + ( 348833463061/46088663040 * np.log( 2 ) + ( \
        3087021797/56197120 * np.log( 3 ) + 95697675707/3072577536 * \
        np.log( vp0 ) ) ) ) ) ) + ( ( vp0 )**( 9 ) * ( \
        40733897021722489/97339256340480 * np.pi + ( -1250509/18144 * C * \
        np.pi + ( 39033449/2985984 * ( np.pi )**( 3 ) + ( \
        -4558307/272160 * np.pi * np.log( 2 ) + ( -1089153/8960 * \
        np.pi * np.log( 3 ) + -1250509/18144 * np.pi * np.log( \
        vp0 ) ) ) ) ) ) + ( vp0 )**( 6 ) * ( 26531900578691/168991764480 + ( \
        -3317/126 * C + ( 122833/10368 * ( np.pi )**( 2 ) + ( ( \
        9155185261/548674560 + -3977/1152 * ( np.pi )**( 2 ) ) * eta + ( \
        -5732473/1306368 * ( eta )**( 2 ) + ( -3090307/139968 * ( eta )**( 3 \
        ) + ( -12091/1890 * np.log( 2 ) + ( -26001/560 * np.log( 3 ) + \
        ( ( vp )**( 4 ) * ( \
        33452030502710734380742921/28467555457422317322240 + ( \
        -145699634473699/758048772096 * C + ( \
        -5549176400969449/873272185454592 * ( np.pi )**( 2 ) + ( \
        -531098667597677/11370731581440 * np.log( 2 ) + ( \
        -4699988208829/13864632320 * np.log( 3 ) + \
        -145699634473699/758048772096 * np.log( vp0 ) ) ) ) ) ) + ( ( vp \
        )**( 2 ) * ( 218642467042630407737/285268913915166720 + ( \
        -71221957283/558327168 * C + ( 51854496721/1134379008 * ( np.pi \
        )**( 2 ) + ( -259615521709/8374907520 * np.log( 2 ) + ( \
        -62032027311/275717120 * np.log( 3 ) + -71221957283/558327168 * \
        np.log( vp0 ) ) ) ) ) ) + ( -3317/126 * np.log( vp0 ) + ( vp \
        )**( 3 ) * ( -32444826473558654951/47757072642048000 * np.pi + ( \
        4056229937/35607600 * C * np.pi + ( -147809139301/1953331200 * ( \
        np.pi )**( 3 ) + ( 14785612351/534114000 * np.pi * np.log( 2 \
        ) + ( 3532845429/17584000 * np.pi * np.log( 3 ) + \
        4056229937/35607600 * np.pi * np.log( vp0 ) ) ) ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    phie4v10=68795/10176 * ( e0 )**( 4 ) * ( vp )**( -38/3 ) * ( vp0 )**( 38/3 ) \
        * ( 1 + ( -219468283/21794256 * np.pi * ( vp )**( 3 ) + ( \
        13319682358489025/128839906492416 * np.pi * ( vp )**( 7 ) + ( ( \
        49628063069/1463132160 * np.pi + ( \
        383558343439817039/2980429399406592 * np.pi * ( vp )**( 2 ) + \
        -18292865677917393589/42517169142497280 * ( np.pi )**( 2 ) * ( vp \
        )**( 3 ) ) ) * ( vp0 )**( 7 ) + ( ( vp )**( 2 ) * ( \
        313945871/93120912 + 169422503/23280228 * eta ) + ( ( vp0 )**( 5 ) * \
        ( 8399729/181440 * np.pi + ( 5029779897500371/31538935443456 * \
        np.pi * ( vp )**( 2 ) + ( -4844558133179453/10544932823040 * ( \
        np.pi )**( 2 ) * ( vp )**( 3 ) + ( \
        82612635791075702429/415991848087388160 * np.pi * ( vp )**( 4 ) + \
        ( -19867808321703660149/13114061910835200 * ( np.pi )**( 2 ) * ( \
        vp )**( 5 ) + -6397243/45360 * np.pi * eta ) ) ) ) ) + ( ( vp )**( \
        5 ) * ( -681125805529/47432226240 * np.pi + \
        -626289377047/11858056560 * np.pi * eta ) + ( ( vp )**( 4 ) * ( \
        13759262427067/1719543022848 + ( 50411102587/2558843784 * eta + \
        20001313681/731098224 * ( eta )**( 2 ) ) ) + ( ( vp0 )**( 4 ) * ( \
        21691165/3048192 + ( -1394417193487093/16104988311552 * np.pi * ( \
        vp )**( 3 ) + ( 2131792079595130139155/27954652191472484352 * ( vp \
        )**( 4 ) + ( -276493359993645391129/771106840357109760 * np.pi * ( \
        vp )**( 5 ) + ( -823369/18144 * eta + ( 75119/1296 * ( eta )**( 2 ) + \
        ( ( vp )**( 2 ) * ( 6809851688929715/283850418991104 + ( \
        -7181747042808763/70962604747776 * eta + ( \
        -12656819395519/93865879296 * ( eta )**( 2 ) + \
        12726849002857/30171175488 * ( eta )**( 3 ) ) ) ) + ( vp )**( 6 ) * ( \
        5504613685463743808845301/29400112256007159152640 + ( \
        484825580009/2560481280 * C + ( -64531359036689/240827767110 * \
        EulerGamma + ( 909956719821710593/2705638036340736 * ( np.pi )**( \
        2 ) + ( 17602918324572453391/3699114502809600 * np.log( 2 ) + ( \
        -40969463023587459/13531283046400 * np.log( 3 ) + \
        -6461701855387573/82202544506880 * np.log( vp ) ) ) ) ) ) ) ) ) ) \
        ) ) ) ) + ( ( vp )**( 6 ) * ( \
        -134781786304051213123/406902595309056000 + ( 6382217123/151692975 * \
        C + ( 62047572707/1248216480 * ( np.pi )**( 2 ) + ( ( \
        30937788483356567/264222464486400 + 821604781/277381440 * ( np.pi \
        )**( 2 ) ) * eta + ( 620230279777/12838798080 * ( eta )**( 2 ) + ( \
        949659939551/13480737984 * ( eta )**( 3 ) + ( 310196253977/455078925 \
        * np.log( 2 ) + ( -8947698129/26967640 * np.log( 3 ) + \
        6382217123/151692975 * np.log( vp ) ) ) ) ) ) ) ) ) + ( ( vp )**( \
        8 ) * ( -1485205934436154311246044749/315376204174770674073600 + ( \
        43000995016807/84462648480 * C + ( -1307601412969/5278915530 * \
        EulerGamma + ( 559014623933641/13900138721280 * ( np.pi )**( 2 ) + \
        ( -513472446732059/253387945440 * np.log( 2 ) + ( \
        -6370746742107/25025969920 * np.log( 3 ) + ( \
        841064453125/625649248 * np.log( 5 ) + 7359790803101/28154216160 * \
        np.log( vp ) ) ) ) ) ) ) ) + ( ( vp )**( 10 ) * ( \
        -86216057904547924800734017658381/5718935036134732033079377920 + ( \
        1697743755678996989/810282224424960 * C + ( \
        -6378348827367668/4352101791345 * EulerGamma + ( \
        -200553595617239824339/222248838699417600 * ( np.pi )**( 2 ) + ( \
        998000569565452678717/26739313406023680 * np.log( 2 ) + ( \
        -811814849671111257/97811846021120 * np.log( 3 ) + ( \
        -90924411376953125/9284483821536 * np.log( 5 ) + \
        374154860934665521/594206964578304 * np.log( vp ) ) ) ) ) ) ) ) + \
        ( ( vp )**( 9 ) * ( 10039757354068423809649/3810440234513203200 * \
        np.pi + ( -666666750767/1081787616 * C * np.pi + ( \
        5340017756/13002255 * EulerGamma * np.pi + ( \
        -65480971888655/534094000128 * ( np.pi )**( 3 ) + ( \
        -152479337828257/16226814240 * np.pi * np.log( 2 ) + ( \
        1680036318963/320529664 * np.pi * np.log( 3 ) + \
        -370628789113/1802979360 * np.pi * np.log( vp ) ) ) ) ) ) ) + ( \
        ( vp0 )**( 2 ) * ( 2833/504 + ( -17109906226453703/127497824133120 * \
        np.pi * ( vp )**( 5 ) + ( 39220839774253242523/129870625744355328 \
        * np.pi * ( vp )**( 7 ) + ( -197/18 * eta + ( ( vp )**( 3 ) * ( \
        -621753645739/10984305024 * np.pi + 43235251751/392296608 * \
        np.pi * eta ) + ( ( vp )**( 2 ) * ( 889408652543/46932939648 + ( \
        23521297445/5866617456 * eta + -33376233091/419044104 * ( eta )**( 2 \
        ) ) ) + ( ( vp )**( 4 ) * ( 38979990455880811/866649683515392 + ( \
        716976988963105/30951774411264 * eta + ( -7594725339613/122824501632 \
        * ( eta )**( 2 ) + -3940258795157/13159768032 * ( eta )**( 3 ) ) ) ) \
        + ( ( vp )**( 6 ) * ( \
        -1243866452255634316182583/1093754176190742528000 + ( \
        498044233/1481760 * C + ( -674255495824/3185552475 * EulerGamma + ( \
        162609389687819/671041179648 * ( np.pi )**( 2 ) + ( \
        23742620082089/6241082400 * np.log( 2 ) + ( \
        -1271410531191/616403200 * np.log( 3 ) + 469880634921/3775469600 * \
        np.log( vp ) ) ) ) ) ) ) + ( vp )**( 8 ) * ( \
        -899574075116881531909434784873/39737401726021104933273600 + ( \
        128698120631360983/56758899778560 * C + ( \
        -3704434802941177/2660573427120 * EulerGamma + ( \
        12097141193325433459/28022679662100480 * ( np.pi )**( 2 ) + ( \
        -93530835947557871/8108414254080 * np.log( 2 ) + ( \
        -13897195575044841/5605817262080 * np.log( 3 ) + ( \
        2382735595703125/315327220992 * np.log( 5 ) + \
        149010534505847621/170276699335680 * np.log( vp ) ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) + ( ( vp0 )**( 3 ) * ( 377/36 * np.pi + ( \
        -82739542691/784593216 * ( np.pi )**( 2 ) * ( vp )**( 3 ) + ( \
        6775851336989059/165076130193408 * np.pi * ( vp )**( 4 ) + ( \
        -2276891862821407/9106987438080 * ( np.pi )**( 2 ) * ( vp )**( 5 ) \
        + ( 5424476637188532703/6184315511635968 * ( np.pi )**( 2 ) * ( vp \
        )**( 7 ) + ( ( vp )**( 2 ) * ( 118357593367/3352352832 * np.pi + \
        63872283631/838088208 * np.pi * eta ) + ( vp )**( 6 ) * ( \
        -7613386130304323971823/3255220762472448000 * np.pi + ( \
        66276977/105840 * C * np.pi + ( -179452398112/455078925 * \
        EulerGamma * np.pi + ( 21639159870211/47931512832 * ( np.pi \
        )**( 3 ) + ( 3159536805841/445791600 * np.pi * np.log( 2 ) + ( \
        -169192294479/44028800 * np.pi * np.log( 3 ) + \
        62529120849/269676400 * np.pi * np.log( vp ) ) ) ) ) ) ) ) ) ) \
        ) ) ) + ( ( vp0 )**( 8 ) * ( 7282864718628003073/5450998355066880 + ( \
        -9397061/42336 * C + ( 6080363797/34836480 * ( np.pi )**( 2 ) + ( \
        -34253803/635040 * np.log( 2 ) + ( -24553611/62720 * np.log( 3 \
        ) + ( ( vp )**( 2 ) * ( \
        4723285405783310014056337711/710642713388058761232384 + ( \
        -20238582727274795/18397712342016 * C + ( \
        6193543764080806055/9083213407715328 * ( np.pi )**( 2 ) + ( \
        -14754579665690657/55193137026048 * np.log( 2 ) + ( \
        -3525430539589803/1817058009088 * np.log( 3 ) + \
        -20238582727274795/18397712342016 * np.log( vp0 ) ) ) ) ) ) + \
        -9397061/42336 * np.log( vp0 ) ) ) ) ) ) ) + ( ( vp0 )**( 10 ) * ( \
        39276226585972868713/50875984647290880 + ( -9147652453/73156608 * C + \
        ( 39836495783143/702303436800 * ( np.pi )**( 2 ) + ( \
        -33344668619/1097349120 * np.log( 2 ) + ( -885256689/4014080 * \
        np.log( 3 ) + -9147652453/73156608 * np.log( vp0 ) ) ) ) ) ) + \
        ( ( vp0 )**( 9 ) * ( 567384033050731/231760134144 * np.pi + ( \
        -1250509/3024 * C * np.pi + ( 224265613/1492992 * ( np.pi )**( \
        3 ) + ( -4558307/45360 * np.pi * np.log( 2 ) + ( -3267459/4480 \
        * np.pi * np.log( 3 ) + -1250509/3024 * np.pi * np.log( \
        vp0 ) ) ) ) ) ) + ( vp0 )**( 6 ) * ( 13172987087063/42247941120 + ( \
        -3317/63 * C + ( 132481/2592 * ( np.pi )**( 2 ) + ( ( \
        -235506541/68584320 + -3977/576 * ( np.pi )**( 2 ) ) * eta + ( \
        48979219/326592 * ( eta )**( 2 ) + ( -1727489/8748 * ( eta )**( 3 ) + \
        ( -12091/945 * np.log( 2 ) + ( -26001/280 * np.log( 3 ) + ( ( \
        vp )**( 4 ) * ( 2965895294503562601219724379/774902958747617266237440 \
        + ( -181048204280870809/288883227838464 * C + ( \
        884934716938669/7888157540352 * ( np.pi )**( 2 ) + ( \
        -659949905927045207/4333248417576960 * np.log( 2 ) + ( \
        -17520793962664917/15850931568640 * np.log( 3 ) + \
        -181048204280870809/288883227838464 * np.log( vp0 ) ) ) ) ) ) + ( \
        ( vp )**( 2 ) * ( 3392988950455777853423/2175934234114916352 + ( \
        -7143869653115/27377548128 * C + ( 121097210577863/643651743744 * ( \
        np.pi )**( 2 ) + ( -5208111424529/82132644384 * np.log( 2 ) + ( \
        -3733248012273/8111866112 * np.log( 3 ) + \
        -7143869653115/27377548128 * np.log( vp0 ) ) ) ) ) ) + ( -3317/63 \
        * np.log( vp0 ) + ( vp )**( 3 ) * ( \
        -21524367274994726726669/9821466071916871680 * np.pi + ( \
        666666750767/1830717504 * C * np.pi + ( \
        -145580598896015/301283794944 * ( np.pi )**( 3 ) + ( \
        2430107833441/27460762560 * np.pi * np.log( 2 ) + ( \
        1741935703617/2712174080 * np.pi * np.log( 3 ) + \
        666666750767/1830717504 * np.pi * np.log( vp0 ) ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )

    phie6v10=-4998965/331776 * ( e0 )**( 6 ) * ( vp )**( -19 ) * ( vp0 )**( 19 ) \
        * ( 1 + ( -269673521/20995653 * np.pi * ( vp )**( 3 ) + ( \
        163270846170011917/2072341496494080 * np.pi * ( vp )**( 7 ) + ( ( \
        140400867659/585252864 * np.pi + ( \
        316669107037278463/341326834716672 * np.pi * ( vp )**( 2 ) + \
        -242682734657278786715/73726596298801152 * ( np.pi )**( 2 ) * ( vp \
        )**( 3 ) ) ) * ( vp0 )**( 7 ) + ( ( vp )**( 2 ) * ( \
        163767481/43990892 + 101473799/10997723 * eta ) + ( ( vp0 )**( 5 ) * \
        ( 2289989/20160 * np.pi + ( 191218973425366003/446975616890880 * \
        np.pi * ( vp )**( 2 ) + ( -1261999815148007/870731721216 * ( \
        np.pi )**( 2 ) * ( vp )**( 3 ) + ( \
        96322507548475722319/91020489257779200 * np.pi * ( vp )**( 4 ) + ( \
        -25728838324571441917/6176390342492160 * ( np.pi )**( 2 ) * ( vp \
        )**( 5 ) + -1499443/5040 * np.pi * eta ) ) ) ) ) + ( ( vp )**( 5 ) \
        * ( -78592511093/3989174070 * np.pi + -364528420171/3989174070 * \
        np.pi * eta ) + ( ( vp )**( 4 ) * ( 3633233103937/282181576320 + ( \
        41707910933/1679652240 * eta + 5237672951/119975160 * ( eta )**( 2 ) \
        ) ) + ( ( vp )**( 6 ) * ( -95962533481958371271/211195978980940800 + \
        ( 20185228786/314934795 * C + ( 71589232177/863821152 * ( np.pi \
        )**( 2 ) + ( ( 4983001981572103/45713415363840 + 238270557/31993376 * \
        ( np.pi )**( 2 ) ) * eta + ( 18341275891/281244096 * ( eta )**( 2 \
        ) + ( 6760982795/47990064 * ( eta )**( 3 ) + ( 83125347442/26994411 * \
        np.log( 2 ) + ( -4239333045/3999172 * np.log( 3 ) + ( \
        -10449218750/20995653 * np.log( 5 ) + 20185228786/314934795 * \
        np.log( vp ) ) ) ) ) ) ) ) ) ) + ( ( vp )**( 8 ) * ( \
        -215484718969544506188583337/36332466656049207705600 + ( \
        39185713131671/56436315264 * C + ( -6471685742/20995653 * EulerGamma \
        + ( 447926828515081/9287805026304 * ( np.pi )**( 2 ) + ( \
        -3674492959939463/846544728960 * np.log( 2 ) + ( \
        -1652519246699637/250828067840 * np.log( 3 ) + ( \
        3092580078125/447907264 * np.log( 5 ) + 21789821857175/56436315264 \
        * np.log( vp ) ) ) ) ) ) ) ) + ( ( vp )**( 10 ) * ( \
        -4701905080776935842408031308649/218212794736231541479833600 + ( \
        9104701853244593549/2986609803770880 * C + ( \
        -27986115055941991/12833089000578 * EulerGamma + ( \
        -10901913454609771147/11430480046325760 * ( np.pi )**( 2 ) + ( \
        3365589670404292672169/19711624704887808 * np.log( 2 ) + ( \
        -268264909783442097/25152805314560 * np.log( 3 ) + ( \
        -5352152092194765625/136886282672832 * np.log( 5 ) + ( \
        -152212635349397/7126524504 * np.log( 7 ) + \
        3167473982497670231/3650300871275520 * np.log( vp ) ) ) ) ) ) ) ) \
        ) + ( ( vp )**( 9 ) * ( 33942269368870339097923/6758271327390105600 * \
        np.pi + ( -823358454061/755843508 * C * np.pi + ( \
        878706968192/1574673975 * EulerGamma * np.pi + ( \
        -115089887073359/373170737664 * ( np.pi )**( 3 ) + ( \
        -2750340058627471/56688263100 * np.pi * np.log( 2 ) + ( \
        19213987735773/1119768160 * np.pi * np.log( 3 ) + ( \
        49111328125/5998758 * np.pi * np.log( 5 ) + \
        -10039477733221/18896087700 * np.pi * np.log( vp ) ) ) ) ) ) ) \
        ) + ( ( vp0 )**( 4 ) * ( 357569/15876 + ( \
        -158986156419455495/511990252075008 * np.pi * ( vp )**( 3 ) + ( \
        26166807347905969361611/82573787854657290240 * ( vp )**( 4 ) + ( \
        -52199851445379116197/51881678876934144 * np.pi * ( vp )**( 5 ) + \
        ( -230245/2016 * eta + ( 4747/36 * ( eta )**( 2 ) + ( ( vp )**( 2 ) * \
        ( 58558174413689/698399401392 + ( -24784372164307/114024392064 * eta \
        + ( -594294076117/1055781408 * ( eta )**( 2 ) + \
        481696123853/395918028 * ( eta )**( 3 ) ) ) ) + ( vp )**( 6 ) * ( \
        -82945077092603271257571679/20019930606394461388800 + ( \
        1118824050245/768144384 * C + ( -165732018625952/178568028765 * \
        EulerGamma + ( 224619017452779160871/126388450797944832 * ( np.pi \
        )**( 2 ) + ( 796393646185373385403/11519780671687680 * np.log( 2 ) \
        + ( -358030709796041749/14046371799040 * np.log( 3 ) + ( \
        -1868158349609375/166663493514 * np.log( 5 ) + \
        2029060939800524617/3839926890562560 * np.log( vp ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) + ( ( vp0 )**( 2 ) * ( 2833/336 + ( \
        -2633407911313877/11029268468736 * np.pi * ( vp )**( 5 ) + ( \
        1584596448127259459/5802556190183424 * np.pi * ( vp )**( 7 ) + ( \
        -197/12 * eta + ( ( vp )**( 3 ) * ( -763985084993/7054539408 * \
        np.pi + 53125683637/251947836 * np.pi * eta ) + ( ( vp )**( 2 ) \
        * ( 463953273673/14780939712 + ( 733808527/43990892 * eta + \
        -19990338403/131972676 * ( eta )**( 2 ) ) ) + ( ( vp )**( 4 ) * ( \
        10292949383453521/94813009643520 + ( -1359170287291/677235783168 * \
        eta + ( -531529812473/13437217920 * ( eta )**( 2 ) + \
        -1031821571347/1439701920 * ( eta )**( 3 ) ) ) ) + ( ( vp )**( 6 ) * \
        ( -9774144594101446353824479/3406168749004613222400 + ( \
        46985305/63504 * C + ( -328271472616/944804385 * EulerGamma + ( \
        969909428380661/1492682950656 * ( np.pi )**( 2 ) + ( \
        24692634764371751/952362820080 * np.log( 2 ) + ( \
        -288416888185491/31353508480 * np.log( 3 ) + ( \
        -14801318359375/3527269704 * np.log( 5 ) + \
        124578680410349/317454273360 * np.log( vp ) ) ) ) ) ) ) ) + ( vp \
        )**( 8 ) * ( \
        -546913927675542058005543468931/12207708796432533789081600 + ( \
        574827202358542627/113775611572224 * C + ( -9167142853543/3527269704 \
        * EulerGamma + ( 37569388311065521/42458537263104 * ( np.pi )**( 2 \
        ) + ( -62791657948801215187/1706634173583360 * np.log( 2 ) + ( \
        -3200535173242431441/56185487196160 * np.log( 3 ) + ( \
        8761279361328125/150496840704 * np.log( 5 ) + \
        279131842474659619/113775611572224 * np.log( vp ) ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) + ( ( vp0 )**( 3 ) * ( 377/24 * np.pi + ( \
        -101666917417/503895672 * ( np.pi )**( 2 ) * ( vp )**( 3 ) + ( \
        69595224959890123/487609763880960 * np.pi * ( vp )**( 4 ) + ( \
        -350439386715613/787804890624 * ( np.pi )**( 2 ) * ( vp )**( 5 ) + \
        ( 1355029469494600601/1218029287735296 * ( np.pi )**( 2 ) * ( vp \
        )**( 7 ) + ( ( vp )**( 2 ) * ( 61740340337/1055781408 * np.pi + \
        38255622223/263945352 * np.pi * eta ) + ( vp )**( 6 ) * ( \
        -114851258907380951603323/20274813982170316800 * np.pi + ( \
        6252545/4536 * C * np.pi + ( -87369110608/134972055 * EulerGamma * \
        np.pi + ( 903491345392363/746341475328 * ( np.pi )**( 3 ) + ( \
        3285959515061119/68025915720 * np.pi * np.log( 2 ) + ( \
        -38380927231179/2239536320 * np.pi * np.log( 3 ) + ( \
        -1969677734375/251947836 * np.pi * np.log( 5 ) + \
        16578243033781/22675305240 * np.pi * np.log( vp ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) + ( ( vp0 )**( 10 ) * ( 258683748225895823/39154196938752 \
        + ( -1118824050245/1024192512 * C + ( 20295594711811/17199267840 * ( \
        np.pi )**( 2 ) + ( -815658823727/3072577536 * np.log( 2 ) + ( \
        -21654659037/11239424 * np.log( 3 ) + -1118824050245/1024192512 * \
        np.log( vp0 ) ) ) ) ) ) + ( ( vp0 )**( 8 ) * ( \
        7236324787330330183/2180399342026752 + ( -46985305/84672 * C + ( \
        10106878367/13934592 * ( np.pi )**( 2 ) + ( -34253803/254016 * \
        np.log( 2 ) + ( -24553611/25088 * np.log( 3 ) + ( ( vp )**( 2 ) \
        * ( 1070366785073777875357839553/61038543982162668945408 + ( \
        -41477977024364105/14221951446528 * C + ( \
        930059591093682337/317849327566848 * ( np.pi )**( 2 ) + ( \
        -30238783250020283/42665854339584 * np.log( 2 ) + ( \
        -7225195997792457/1404637179904 * np.log( 3 ) + \
        -41477977024364105/14221951446528 * np.log( vp0 ) ) ) ) ) ) + \
        -46985305/84672 * np.log( vp0 ) ) ) ) ) ) ) + ( ( vp0 )**( 9 ) * ( \
        13528567626112877/2163094585344 * np.pi + ( -6252545/6048 * C * \
        np.pi + ( 1657154395/2985984 * ( np.pi )**( 3 ) + ( \
        -4558307/18144 * np.pi * np.log( 2 ) + ( -3267459/1792 * \
        np.pi * np.log( 3 ) + -6252545/6048 * np.pi * np.log( vp0 \
        ) ) ) ) ) ) + ( vp0 )**( 6 ) * ( 122368757429/251475840 + ( -3317/42 \
        * C + ( 135697/1152 * ( np.pi )**( 2 ) + ( ( -181019477/952560 + \
        -3977/384 * ( np.pi )**( 2 ) ) * eta + ( 17310847/24192 * ( eta \
        )**( 2 ) + ( -1788605/2592 * ( eta )**( 3 ) + ( -12091/630 * \
        np.log( 2 ) + ( -78003/560 * np.log( 3 ) + ( ( vp )**( 4 ) * ( \
        13030561905284221360640777621/1525963599554066723635200 + ( \
        -1159836514737403369/853317086791680 * C + ( \
        16096798299544420477/20061658856816640 * ( np.pi )**( 2 ) + ( \
        -4227791166623438087/12799756301875200 * np.log( 2 ) + ( \
        -336726730085052591/140463717990400 * np.log( 3 ) + \
        -1159836514737403369/853317086791680 * np.log( vp0 ) ) ) ) ) ) + ( \
        ( vp )**( 2 ) * ( 192929051266732168287523/75692638866769182720 + ( \
        -2928201696037/7054539408 * C + ( 841913440392331/1824390273024 * ( \
        np.pi )**( 2 ) + ( -10673767472651/105818091120 * np.log( 2 ) + \
        ( -22953322972161/31353508480 * np.log( 3 ) + \
        -2928201696037/7054539408 * np.log( vp0 ) ) ) ) ) ) + ( -3317/42 * \
        np.log( vp0 ) + ( vp )**( 3 ) * ( \
        -426645165032136199487/86014362348601344 * np.pi + ( \
        4116792270305/5290904556 * C * np.pi + ( \
        -1278354590972875/870731721216 * ( np.pi )**( 3 ) + ( \
        3001274364803/15872713668 * np.pi * np.log( 2 ) + ( \
        2151355960611/1567675424 * np.pi * np.log( 3 ) + \
        4116792270305/5290904556 * np.pi * np.log( vp0 ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    phie8v10=350105555/10063872 * ( e0 )**( 8 ) * ( vp )**( -76/3 ) * ( vp0 )**( \
        76/3 ) * ( 1 + ( -811345764229/51675579918 * np.pi * ( vp )**( 3 ) \
        + ( 63196267769388210431/1536752090745446400 * np.pi * ( vp )**( 7 \
        ) + ( ( 231173672249/313528320 * np.pi + ( \
        3247038007373937428821/1049656561982380800 * np.pi * ( vp )**( 2 ) \
        + -442832423013004730549779/37032589158208634880 * ( np.pi )**( 2 \
        ) * ( vp )**( 3 ) ) ) * ( vp0 )**( 7 ) + ( ( vp )**( 2 ) * ( \
        3521904540557/857058398640 + 2407168987769/214264599660 * eta ) + ( ( \
        vp0 )**( 5 ) * ( 19080139/90720 * np.pi + ( \
        90267399627211852903/103669783899494400 * np.pi * ( vp )**( 2 ) + \
        ( -2611153073632542829/793736907540480 * ( np.pi )**( 2 ) * ( vp \
        )**( 3 ) + ( 317978162325276643707829/109263073652001239040 * \
        np.pi * ( vp )**( 4 ) + ( \
        -623996614304612592070183/66738947940945100800 * ( np.pi )**( 2 ) \
        * ( vp )**( 5 ) + -11596073/22680 * np.pi * eta ) ) ) ) ) + ( ( vp \
        )**( 5 ) * ( -3893365319247859/137935986981120 * np.pi + \
        -4927058320841917/34483996745280 * np.pi * eta ) + ( ( vp )**( 4 ) \
        * ( 41675584861994239/2408797920017664 + ( \
        236115722291917/7169041428624 * eta + 461906153167823/7169041428624 * \
        ( eta )**( 2 ) ) ) + ( ( vp )**( 6 ) * ( \
        -25601088808764212402523839/45041435403703661260800 + ( \
        140301303766/1678973355 * C + ( 412382142701347/3312278634744 * ( \
        np.pi )**( 2 ) + ( ( 10492389491307691955/80130644731726848 + \
        514127986918/46003869927 * ( np.pi )**( 2 ) ) * eta + ( \
        100767772055103517/953936246806272 * ( eta )**( 2 ) + ( \
        179681699244765445/715452185104704 * ( eta )**( 3 ) + ( \
        1309440409669210/138011609781 * np.log( 2 ) + ( \
        -150420476282427/102230822060 * np.log( 3 ) + ( \
        -30088525390625/10223082206 * np.log( 5 ) + \
        140301303766/1678973355 * np.log( vp ) ) ) ) ) ) ) ) ) ) + ( ( vp \
        )**( 8 ) * ( \
        -13467700605399839801016863139721/1835768345779938071229235200 + ( \
        197208323271729341/212802558862320 * C + ( \
        -3669894431933119/8866773285930 * EulerGamma + ( \
        834786002026740257/11673740371875840 * ( np.pi )**( 2 ) + ( \
        -7250564771591138881/638407676586960 * np.log( 2 ) + ( \
        -63807988420653633/2101753667776 * np.log( 3 ) + ( \
        691738805544921875/37831566019968 * np.log( 5 ) + ( \
        4011689475901835/600501047936 * np.log( 7 ) + \
        21826171381066897/42560511772464 * np.log( vp ) ) ) ) ) ) ) ) ) + \
        ( ( vp )**( 10 ) * ( \
        -515995191964550270912362339093660849/\
        16872566904523857062827288166400 + ( \
        2014981067228467421915/468709387677361152 * C + ( \
        -1526201352173367493/490020839458920 * EulerGamma + ( \
        -1223196999706016593534211/1928404337872571596800 * ( np.pi )**( 2 \
        ) + ( 11597370998415731394303451/15467409793352918016 * np.log( 2 \
        ) + ( 2586135266572197670447/94299099486986240 * np.log( 3 ) + ( \
        -11913216040363676796875/81838147054777344 * np.log( 5 ) + ( \
        -1872428470478765600765/11691163864968192 * np.log( 7 ) + \
        30533557962429191133581/25779016322254863360 * np.log( vp ) ) ) ) \
        ) ) ) ) ) + ( ( vp )**( 9 ) * ( \
        669738723421209873033660109/77894889975705187123200 * np.pi + ( \
        -5013085387867297/2903915515392 * C * np.pi + ( \
        228286043931569/302491199520 * EulerGamma * np.pi + ( \
        -679358944092318035/1115103557910528 * ( np.pi )**( 3 ) + ( \
        -7591110107199481343/43558732730880 * np.pi * np.log( 2 ) + ( \
        37526112406875339/1434032353280 * np.pi * np.log( 3 ) + ( \
        8941046435546875/161328639744 * np.pi * np.log( 5 ) + \
        -14107696830621173/14519577576960 * np.pi * np.log( vp ) ) ) ) \
        ) ) ) ) + ( ( vp0 )**( 4 ) * ( 69846499/1524096 + ( \
        -268962092665819900477/360039061260361728 * np.pi * ( vp )**( 3 ) \
        + ( 48596633038236119099132441/58739828395315866107904 * ( vp )**( 4 \
        ) + ( -3826249988942722365927019/1681821488111816540160 * np.pi * \
        ( vp )**( 5 ) + ( -1939571/9072 * eta + ( 152737/648 * ( eta )**( 2 ) \
        + ( ( vp )**( 2 ) * ( 245992701970109959943/1306239277133629440 + ( \
        -16966999713076304749/46651402754772480 * eta + ( \
        -53069279855950787/37024922821248 * ( eta )**( 2 ) + \
        367663769684873753/138843460579680 * ( eta )**( 3 ) ) ) ) + ( vp )**( \
        6 ) * ( -16527164222363194921183409147975041/\
        1098359544528690165007043788800 + ( 4985448688051/1144378368 * C + ( \
        -4162280764349669/1903955784570 * EulerGamma + ( \
        508861546103040375252605/92310502730949328896 * ( np.pi )**( 2 ) + \
        ( 3655000638280022176324829/8413717696831319040 * np.log( 2 ) + ( \
        -721797769091798283443/10259067455365120 * np.log( 3 ) + ( \
        -2101578158607763671875/15580958697835776 * np.log( 5 ) + \
        6347125650003559681/2924476085099520 * np.log( vp ) ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) + ( ( vp0 )**( 2 ) * ( 2833/252 + ( \
        -1996025733460866757/4878578065858560 * np.pi * ( vp )**( 5 ) + ( \
        -93635968145933497254997/1549046107471409971200 * np.pi * ( vp \
        )**( 7 ) + ( -197/9 * eta + ( ( vp )**( 3 ) * ( \
        -328363221437251/1860320877048 * np.pi + \
        159835115553113/465080219262 * np.pi * eta ) + ( ( vp )**( 2 ) * ( \
        9977555563397981/215978716457280 + ( 140200241494391/3856762793880 * \
        eta + -474212290590493/1928381396940 * ( eta )**( 2 ) ) ) + ( ( vp \
        )**( 4 ) * ( 118066931914029679087/607017075844451328 + ( \
        -183100122776854751/21679181280158976 * eta + ( \
        293609893439447/86028497143488 * ( eta )**( 2 ) + \
        -90995512174061131/64521372857616 * ( eta )**( 3 ) ) ) ) + ( ( vp \
        )**( 6 ) * ( \
        -104697545848706645261292288293/20178563060859240244838400 + ( \
        122161793/94608 * C + ( -2701178515568/5036920065 * EulerGamma + ( \
        1135039974123575117/847943330494464 * ( np.pi )**( 2 ) + ( \
        74161713250410981871/695578513296240 * np.log( 2 ) + ( \
        -386242360910546283/22899704141440 * np.log( 3 ) + ( \
        -85240792431640625/2576216715912 * np.log( 5 ) + \
        182529725691131/241772163120 * np.log( vp ) ) ) ) ) ) ) ) + ( vp \
        )**( 8 ) * ( \
        -69961407088893799917130369809814901/925227246273088787899534540800 + \
        ( 573915409115548349837/61287136952348160 * C + ( \
        -10396810925666526127/2234426868054360 * EulerGamma + ( \
        38971609853729365792967/23534260589701693440 * ( np.pi )**( 2 ) + \
        ( -23522344456564781926969/183861410857044480 * np.log( 2 ) + ( \
        -1615577684119720256949/4707928215818240 * np.log( 3 ) + ( \
        1959696036108763671875/9533554637031936 * np.log( 5 ) + ( \
        1623588040747128365/21618037725696 * np.log( 7 ) + \
        404244033216173086495/85801991733287424 * np.log( vp ) ) ) ) ) ) ) \
        ) ) ) ) ) ) ) ) ) ) + ( ( vp0 )**( 3 ) * ( 377/18 * np.pi + ( \
        -305877353114333/930160438524 * ( np.pi )**( 2 ) * ( vp )**( 3 ) + \
        ( 99267146381270233769/346866900482543616 * np.pi * ( vp )**( 4 ) \
        + ( -265620085250528333/348469861847040 * ( np.pi )**( 2 ) * ( vp \
        )**( 5 ) + ( 27779735734580918835877/31613185866763468800 * ( \
        np.pi )**( 2 ) * ( vp )**( 7 ) + ( ( vp )**( 2 ) * ( \
        1327758011789989/15427051175520 * np.pi + \
        907502708388913/3856762793880 * np.pi * eta ) + ( vp )**( 6 ) * ( \
        -8187576800300105687805626183/810745837266665902694400 * np.pi + ( \
        113796319/47304 * C * np.pi + ( -5032410944288/5036920065 * \
        EulerGamma * np.pi + ( 1057313975189592211/423971665247232 * ( \
        np.pi )**( 3 ) + ( 9869031378540395399/49684179521160 * np.pi * \
        np.log( 2 ) + ( -51399001081283427/1635693152960 * np.pi * \
        np.log( 3 ) + ( -11343374072265625/184015479708 * np.pi * \
        np.log( 5 ) + 170030337486373/120886081560 * np.pi * np.log( \
        vp ) ) ) ) ) ) ) ) ) ) ) ) ) ) + ( ( vp0 )**( 10 ) * ( \
        1766265548637583435637/84101117478174720 + ( -383496052927/109734912 \
        * C + ( 2553885741016649/451480780800 * ( np.pi )**( 2 ) + ( \
        -1397904967121/1646023680 * np.log( 2 ) + ( -12370840417/2007040 * \
        np.log( 3 ) + -383496052927/109734912 * np.log( vp0 ) ) ) ) ) ) \
        + ( ( vp0 )**( 8 ) * ( 7274812516429881013/1168071076085760 + ( \
        -9397061/9072 * C + ( 1570376993/829440 * ( np.pi )**( 2 ) + ( \
        -34253803/136080 * np.log( 2 ) + ( -8184537/4480 * np.log( 3 ) \
        + ( ( vp )**( 2 ) * ( \
        102397560685926188105068220549/2918673836640708644044800 + ( \
        -90424314964327067113/15550467584924160 * C + ( \
        34949801100309115215377/4265271109007769600 * ( np.pi )**( 2 ) + ( \
        -329611212611901889799/233257013773862400 * np.log( 2 ) + ( \
        -8750740157838103269/853249250201600 * np.log( 3 ) + \
        -90424314964327067113/15550467584924160 * np.log( vp0 ) ) ) ) ) ) \
        + -9397061/9072 * np.log( vp0 ) ) ) ) ) ) ) + ( ( vp0 )**( 9 ) * ( \
        5417544839510609/434550251520 * np.pi + ( -1250509/648 * C * \
        np.pi + ( 341130335/248832 * ( np.pi )**( 3 ) + ( -4558307/9720 \
        * np.pi * np.log( 2 ) + ( -1089153/320 * np.pi * np.log( \
        3 ) + -1250509/648 * np.pi * np.log( vp0 ) ) ) ) ) ) + ( vp0 \
        )**( 6 ) * ( 29725783048601/42247941120 + ( -6634/63 * C + ( \
        137305/648 * ( np.pi )**( 2 ) + ( ( -13183707857/19595520 + \
        -3977/288 * ( np.pi )**( 2 ) ) * eta + ( 635177951/326592 * ( eta \
        )**( 2 ) + ( -58215241/34992 * ( eta )**( 3 ) + ( -24182/945 * \
        np.log( 2 ) + ( -26001/140 * np.log( 3 ) + ( ( vp )**( 4 ) * ( \
        578129952933094652474716738913/37006091889048995647979520 + ( \
        -1415938793092788305627/607017075844451328 * C + ( \
        33774837999114105226099/14271095334138937344 * ( np.pi )**( 2 ) + \
        ( -5161325278047905759221/9105256137666769920 * np.log( 2 ) + ( \
        -45675444938477042117/11102278479093760 * np.log( 3 ) + \
        -1415938793092788305627/607017075844451328 * np.log( vp0 ) ) ) ) ) \
        ) + ( ( vp )**( 2 ) * ( \
        744673308175838306075263193/193114414731435776409600 + ( \
        -31918219189667161/53994679114320 * C + ( \
        2668067879625906121/2961993825699840 * ( np.pi )**( 2 ) + ( \
        -116347057046206103/809920186714800 * np.log( 2 ) + ( \
        -27799739294226237/26664039068800 * np.log( 3 ) + \
        -31918219189667161/53994679114320 * np.log( vp0 ) ) ) ) ) ) + ( \
        -6634/63 * np.log( vp0 ) + ( vp )**( 3 ) * ( \
        -188714301379602990685598749/19960565556274454200320 * np.pi + ( \
        5013085387867297/3720641754096 * C * np.pi + ( \
        -518915414919530993/158747381508096 * ( np.pi )**( 3 ) + ( \
        18273504800935631/55809626311440 * np.pi * np.log( 2 ) + ( \
        4366235660400549/1837353952640 * np.pi * np.log( 3 ) + \
        5013085387867297/3720641754096 * np.pi * np.log( vp0 ) ) ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )

    phie10v10=-4889369329/58392576 * ( e0 )**( 10 ) * ( vp )**( -95/3 ) * ( vp0 \
        )**( 95/3 ) * ( 1 + ( -1650687953797949/88888734401220 * np.pi * ( \
        vp )**( 3 ) + ( -633786858990139161373/42445841477106622464 * \
        np.pi * ( vp )**( 7 ) + ( ( 321946476839/195084288 * np.pi + ( \
        3625979196271625691448555/480734923695769387008 * np.pi * ( vp \
        )**( 2 ) + -3969680704753707905087489/127038794592550256640 * ( \
        np.pi )**( 2 ) * ( vp )**( 3 ) ) ) * ( vp0 )**( 7 ) + ( ( vp )**( \
        2 ) * ( 1155654647473975/256281182748864 + 3279248105815/247375659024 \
        * eta ) + ( ( vp0 )**( 5 ) * ( 3052543/9072 * np.pi + ( \
        11974178286853168265/7850527854460928 * np.pi * ( vp )**( 2 ) + ( \
        -152750874623240288483/24505940314920960 * ( np.pi )**( 2 ) * ( vp \
        )**( 3 ) + ( 276862098929121758371385/44740762129330864128 * np.pi \
        * ( vp )**( 4 ) + ( -1551538014293971373321663/83644354855491010560 * \
        ( np.pi )**( 2 ) * ( vp )**( 5 ) + -443609/567 * np.pi * eta ) \
        ) ) ) ) + ( ( vp )**( 5 ) * ( -1658388962349405187/42138540625053600 \
        * np.pi + -543393301527064021/2633658789065850 * np.pi * eta ) \
        + ( ( vp )**( 4 ) * ( 15914899402852012475/730283087211455232 + ( \
        14389319702044925/334378702935648 * eta + \
        566658168807665/6336622650384 * ( eta )**( 2 ) ) ) + ( ( vp )**( 6 ) \
        * ( -54013338903063737234881087/79471492073456876789760 + ( \
        2912463632329471/28338784630884 * C + ( \
        156503738116573331/896875821285120 * ( np.pi )**( 2 ) + ( ( \
        4276829907310174510637/24680587600452446208 + \
        3820189783072135/259097459482368 * ( np.pi )**( 2 ) ) * eta + ( \
        49812629324834129435/293816519053005312 * ( eta )**( 2 ) + ( \
        12874489892055907775/31480341327107712 * ( eta )**( 3 ) + ( \
        48624627988675990933/2125408847316300 * np.log( 2 ) + ( \
        723910234795580349/629750769575200 * np.log( 3 ) + ( \
        -114789396240234375/12595015391504 * np.log( 5 ) + ( \
        -50290919074826199/44982197826800 * np.log( 7 ) + \
        2912463632329471/28338784630884 * np.log( vp ) ) ) ) ) ) ) ) ) ) ) \
        + ( ( vp )**( 8 ) * ( \
        -49350064961191872344621666730013/5546604173220100202645422080 + ( \
        2428193349485167/2030070159936 * C + ( \
        -3475447253524697/6468635622267 * EulerGamma + ( \
        118228936757300300459/976549589895979008 * ( np.pi )**( 2 ) + ( \
        -4188520627712938931887/63577447258852800 * np.log( 2 ) + ( \
        -11292100135823122855767/131864335055398400 * np.log( 3 ) + ( \
        9678209481337890625/304302311666304 * np.log( 5 ) + ( \
        31169624358602362017/672777219670400 * np.log( 7 ) + \
        11728396639935463279/17801685232478784 * np.log( vp ) ) ) ) ) ) ) \
        ) ) + ( ( vp )**( 10 ) * ( \
        -1643088581529841950978679079355539/40317122816699917103058124800 + ( \
        1097345227295167517117/190224328781168640 * C + ( \
        -439471155019669058759/97805770608677040 * EulerGamma + ( \
        18331850041566888869821757/54941134136659358515200 * ( np.pi )**( \
        2 ) + ( 14324360974478217513393276641/5007655455164264448000 * \
        np.log( 2 ) + ( -43772212983064814193483/1485234999492608000 * \
        np.log( 3 ) + ( -2933629439281448112578125/6676873940219019264 * \
        np.log( 5 ) + ( -515839052076426735935663/811087699249152000 * \
        np.log( 7 ) + 36495371265932737597967/28615174029510082560 * \
        np.log( vp ) ) ) ) ) ) ) ) ) + ( ( vp )**( 9 ) * ( \
        621190670696448831175621697279/45996984574168823709696000 * np.pi \
        + ( -1029917643242224099/409064195541456 * C * np.pi + ( \
        1938270417286393058/1917488416600575 * EulerGamma * np.pi + ( \
        -1051664363859405083029/1009804185565194240 * ( np.pi )**( 3 ) + ( \
        -14894957063994386123393/30679814665609200 * np.pi * np.log( 2 \
        ) + ( -264896905804276794543/9090315456476800 * np.pi * np.log( \
        3 ) + ( 53463413810791015625/272709463694304 * np.pi * np.log( \
        5 ) + ( 8119189490635829683/324654123445600 * np.pi * np.log( 7 \
        ) + -6604499509512074071/4382830666515600 * np.pi * np.log( vp \
        ) ) ) ) ) ) ) ) ) + ( ( vp0 )**( 4 ) * ( 33544345/435456 + ( \
        -70531390829548463511829/48168876283008638976 * np.pi * ( vp )**( \
        3 ) + ( 504406190527284527559468875/293141473471375821766656 * ( vp \
        )**( 4 ) + ( -10925481322180220911636741/2403674618478846935040 * \
        np.pi * ( vp )**( 5 ) + ( -1561045/4536 * eta + ( 478865/1296 * ( \
        eta )**( 2 ) + ( ( vp )**( 2 ) * ( \
        38765678195720395921375/111599178715089321984 + ( \
        -14806634301252060953675/27899794678772330496 * eta + ( \
        -11874535550649383425/4100498923981824 * ( eta )**( 2 ) + \
        1570317144191099975/320598854095104 * ( eta )**( 3 ) ) ) ) + ( vp \
        )**( 6 ) * ( \
        -6042456461122708088614820310438533/172262660527199761191489503232 + \
        ( 149387506346375/15704285184 * C + ( \
        -270363373601175149515/64272363542844912 * EulerGamma + ( \
        4248527726681618993209091/324011816703375704064 * ( np.pi )**( 2 ) \
        + ( 225451033163068801977348977/127973417187531202560 * np.log( 2 \
        ) + ( 1061018723375985687085377/12639349845682094080 * np.log( 3 ) \
        + ( -1283511703274708251953125/1828191674107588608 * np.log( 5 ) + \
        ( -5355479174009685188237/62183390275768320 * np.log( 7 ) + \
        1222249744010664590135365/230352150937556164608 * np.log( vp ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) ) ) + ( ( vp0 )**( 2 ) * ( 14165/1008 + ( \
        -716335053225015027551/1078746640001372160 * np.pi * ( vp )**( 5 ) \
        + ( -18856338285932585455598845/21392704104461737721856 * np.pi * \
        ( vp )**( 7 ) + ( -985/36 * eta + ( ( vp )**( 3 ) * ( \
        -4676398973109589517/17919968855285952 * np.pi + \
        325185526898195953/639998887688784 * np.pi * eta ) + ( ( vp )**( 2 \
        ) * ( 16369848081468855875/258331432210854912 + ( \
        36271906296019075/576632661184944 * eta + \
        -3230059384227775/8905523724864 * ( eta )**( 2 ) ) ) + ( ( vp )**( 4 \
        ) * ( 225434550041398756708375/736125351909146873856 + ( \
        222151747389143996875/26290191139612388352 * eta + ( \
        8266152509165877425/104326155315922176 * ( eta )**( 2 ) + \
        -558158296275550025/228118415413824 * ( eta )**( 3 ) ) ) ) + ( ( vp \
        )**( 6 ) * ( \
        -230958049960754013595452226369/28482582759126944641449984 + ( \
        2584191775/1298304 * C + ( -114168191003897855/148778619312141 * \
        EulerGamma + ( 191171836648736684213/80360073587146752 * ( np.pi \
        )**( 2 ) + ( 1457466059910296123677/4534205540941440 * np.log( 2 ) \
        + ( 444736973389621190751/28212834476968960 * np.log( 3 ) + ( \
        -541997265914306640625/4231925171545344 * np.log( 5 ) + ( \
        -2261494821253692409/143943033045760 * np.log( 7 ) + \
        23291675566318281485/19043663271954048 * np.log( vp ) ) ) ) ) ) ) \
        ) ) + ( vp )**( 8 ) * ( \
        -130032908242671455614719842693436859/1118195401321172200853317091328 \
        + ( 20559070220169609560245/1329192497358415872 * C + ( \
        -49229710346177333005/6520384707245136 * EulerGamma + ( \
        29796154303107616596182659/9843619866151468400640 * ( np.pi )**( 2 \
        ) + ( -2103589706019811012566211/2271404900549191680 * np.log( 2 ) \
        + ( -7122977863412941111023783/5907522210481848320 * np.log( 3 ) + \
        ( 137091837303151220703125/306736730159634432 * np.log( 5 ) + ( \
        4204930752758118647341/6458661308835840 * np.log( 7 ) + \
        284134570199219417267095/35888197428677228544 * np.log( vp ) ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) ) ) + ( ( vp0 )**( 3 ) * ( 1885/72 * np.pi + \
        ( -47869950660140521/98461367336736 * ( np.pi )**( 2 ) * ( vp )**( \
        3 ) + ( 572541099456172771375/1198413271321362432 * np.pi * ( vp \
        )**( 4 ) + ( -7332762634495388563/5927179340666880 * ( np.pi )**( \
        2 ) * ( vp )**( 5 ) + ( \
        -78698244950913947990125/470169320977181048832 * ( np.pi )**( 2 ) \
        * ( vp )**( 7 ) + ( ( vp )**( 2 ) * ( \
        167569923883726375/1419403473686016 * np.pi + \
        475490975343175/1370080573056 * np.pi * eta ) + ( vp )**( 6 ) * ( \
        -612973488134748279743581693/39124426866932616265728 * np.pi + ( \
        343889975/92736 * C * np.pi + ( -2337365011728230/1634929882551 * \
        EulerGamma * np.pi + ( 25440092628511729597/5740005256224768 * ( \
        np.pi )**( 3 ) + ( 14919349007200348601/24913217257920 * np.pi \
        * np.log( 2 ) + ( 4552549321672790163/155015574049280 * np.pi * \
        np.log( 3 ) + ( -5548154151611328125/23252336107392 * np.pi * \
        np.log( 5 ) + ( -162048517018884419/5536270501760 * np.pi * \
        np.log( 7 ) + 238425199937603305/104635512483264 * np.pi * \
        np.log( vp ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + ( ( vp0 )**( 10 ) * ( \
        11669143671238048099879/244204726306996224 + ( \
        -2716136479025/341397504 * C + ( 228462585131579/13377208320 * ( \
        np.pi )**( 2 ) + ( -1980151110515/1024192512 * np.log( 2 ) + ( \
        -157711150395/11239424 * np.log( 3 ) + -2716136479025/341397504 * \
        np.log( vp0 ) ) ) ) ) ) + ( ( vp0 )**( 8 ) * ( \
        7398327905926655563/726799780675584 + ( -46985305/28224 * C + ( \
        2594272501/663552 * ( np.pi )**( 2 ) + ( -34253803/84672 * \
        np.log( 2 ) + ( -73660833/25088 * np.log( 3 ) + ( ( vp )**( 2 ) \
        * ( 1032433487807447796420154351682165/16933191583013965183284412416 \
        + ( -16043635536717419142325/1607395578200875008 * C + ( \
        1176698959953674582823035/64345472412303753216 * ( np.pi )**( 2 ) \
        + ( -11696327842897215245695/4822186734602625024 * np.log( 2 ) + ( \
        -25152280228531179687645/1428796069511888896 * np.log( 3 ) + \
        -16043635536717419142325/1607395578200875008 * np.log( vp0 ) ) ) ) \
        ) ) + -46985305/28224 * np.log( vp0 ) ) ) ) ) ) ) + ( ( vp0 )**( 9 \
        ) * ( 47980849826789893/2163094585344 * np.pi + ( -6252545/2016 * \
        C * np.pi + ( 2728807055/995328 * ( np.pi )**( 3 ) + ( \
        -4558307/6048 * np.pi * np.log( 2 ) + ( -9802377/1792 * \
        np.pi * np.log( 3 ) + -6252545/2016 * np.pi * np.log( vp0 \
        ) ) ) ) ) ) + ( vp0 )**( 6 ) * ( 4755931189663/4828336128 + ( \
        -16585/126 * C + ( 3456745/10368 * ( np.pi )**( 2 ) + ( ( \
        -173532672409/109734912 + -19885/1152 * ( np.pi )**( 2 ) ) * eta + \
        ( 5343532765/1306368 * ( eta )**( 2 ) + ( -459404825/139968 * ( eta \
        )**( 3 ) + ( -12091/378 * np.log( 2 ) + ( -26001/112 * np.log( \
        3 ) + ( ( vp )**( 4 ) * ( \
        210005007772384200353675897886605/7978138341996964365201309696 + ( \
        -10841569685922357827225/3029322435840110592 * C + ( \
        10026227622782568525973975/1922939694783077548032 * ( np.pi )**( 2 \
        ) + ( -7903854029091783448235/9087967307520331776 * np.log( 2 ) + \
        ( -16996783443091180335585/2692731054080098304 * np.log( 3 ) + \
        -10841569685922357827225/3029322435840110592 * np.log( vp0 ) ) ) ) \
        ) ) + ( ( vp )**( 2 ) * ( \
        7885904942126188980320244845/1399900097802080454967296 + ( \
        -5663125851294535525/7175873116968192 * C + ( \
        67381091881991388325/43738655189139456 * ( np.pi )**( 2 ) + ( \
        -4128601427072790415/21527619350904576 * np.log( 2 ) + ( \
        -8878319882997239565/6378553881749504 * np.log( 3 ) + \
        -5663125851294535525/7175873116968192 * np.log( vp0 ) ) ) ) ) ) + \
        ( -16585/126 * np.log( vp0 ) + ( vp )**( 3 ) * ( \
        -27704090792951956874121737/1685910669905302364160 * np.pi + ( \
        1029917643242224099/497776912646832 * C * np.pi + ( \
        -55707683998592214809/9102206402684928 * ( np.pi )**( 3 ) + ( \
        3754215925366816877/7466653689702480 * np.pi * np.log( 2 ) + ( \
        8073225397027756647/2212341833985920 * np.pi * np.log( 3 ) + \
        1029917643242224099/497776912646832 * np.pi * np.log( vp0 ) ) ) \
        ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    
    return((phie0v7+phie2v6))

#     return((phie0v7+phie0v8Tov24+phie2v10+phie4v10+phie6v10+phie8v10+phie10v10))

# %%
import matplotlib.pyplot as plt

# %matplotlib notebook

# plt.xscale("log")
# plt.yscale("log")

plt.ylim([-0.0000000001,0.0000000001])

plt.xlabel('$v$')
plt.ylabel('$-32 \eta v^{5}\phi$')

xlist=np.arange(0.01,0.4,0.001)

ylist1=phasePNBHP_TT2(xlist, 0.01, 0.045, 0.1)
ylist2=phase_TT2(xlist, 0.01, 0.1, 0, 0.045)

plt.minorticks_on()

plt.plot(xlist,ylist1-ylist2, color='red', linestyle='-', label='$PNBHP$', linewidth=1)
# plt.plot(xlist,ylist2, color='black', linestyle='--', label='$phase Moore$', linewidth=1)

plt.tick_params(width=1, color="black",direction="in",which="minor",right="true", length=7.5)
plt.tick_params(width=1, color="black",direction="in",which="major",right="true",length=10)

plt.tick_params(width=1, color="black",direction="in",which="minor",top="true",length=7.5)
plt.tick_params(width=1, color="black",direction="in",which="major",top="true",length=10)


plt.title("$q=20,$", fontsize=9)

plt.rcParams["figure.figsize"] = (4,4)
plt.legend(loc='best', prop={"size":5.5})

# plt.savefig("PNBHPv10e10_Moore_phaseDifference.pdf", dpi=500, bbox_inches='tight')
# plt.savefig("PNBHPv6e2_Moore_phaseDifference.pdf", dpi=500, bbox_inches='tight')


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# # Taylor T2 Phase from Omkar

# %%
def Time_TT2_aligned(x, x0,e0, SO, chiS, chiA, M, nu, delta):
    taligned = -5/256 * M * ( x )**( -4 ) * ( nu )**( -1 ) * ( 1 + ( x * ( 743/252 \
+ 11/3 * nu ) + ( ( x )**( 3/2 ) * ( -32/5 * numpy.pi + ( 226/15 * SO \
* delta * chiA + ( 226/15 * SO * chiS + -152/15 * SO * nu * chiS ) ) \
) + ( ( x )**( 5/2 ) * ( -7729/252 * numpy.pi + ( 146597/756 * SO * \
delta * chiA + ( 146597/756 * SO * chiS + ( -68/3 * SO * ( nu )**( 2 \
) * chiS + nu * ( 13/3 * numpy.pi + ( 28/3 * SO * delta * chiA + \
-4852/27 * SO * chiS ) ) ) ) ) ) + ( ( x )**( 2 ) * ( 3058673/508032 \
+ ( 617/72 * ( nu )**( 2 ) + ( -81/8 * ( SO )**( 2 ) * ( chiA )**( 2 \
) + ( -81/4 * ( SO )**( 2 ) * delta * chiA * chiS + ( -81/8 * ( SO \
)**( 2 ) * ( chiS )**( 2 ) + nu * ( 5429/504 + ( 40 * ( SO )**( 2 ) * \
( chiA )**( 2 ) + 1/2 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) ) ) ) ) ) \
+ ( ( x )**( 3 ) * ( -10052469856691/23471078400 + ( 6848/105 * \
EulerGamma + ( 128/3 * ( numpy.pi )**( 2 ) + ( 25565/1296 * ( nu )**( \
3 ) + ( ( -39085/96 * ( SO )**( 2 ) + 12769/36 * ( SO )**( 2 ) * ( \
delta )**( 2 ) ) * ( chiA )**( 2 ) + ( -454/3 * numpy.pi * SO * chiS \
+ ( -15103/288 * ( SO )**( 2 ) * ( chiS )**( 2 ) + ( chiA * ( -454/3 \
* numpy.pi * SO * delta + -15103/144 * ( SO )**( 2 ) * delta * chiS ) \
+ ( ( nu )**( 2 ) * ( -15211/1728 + ( 96 * ( SO )**( 2 ) * ( chiA \
)**( 2 ) + -251/9 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) + ( nu * ( \
3147553127/3048192 + ( -451/12 * ( numpy.pi )**( 2 ) + ( 136727/84 * \
( SO )**( 2 ) * ( chiA )**( 2 ) + ( 104 * numpy.pi * SO * chiS + ( \
1645/18 * ( SO )**( 2 ) * delta * chiA * chiS + 46483/504 * ( SO )**( \
2 ) * ( chiS )**( 2 ) ) ) ) ) ) + ( 13696/105 * numpy.log( 2 ) + \
3424/105 * numpy.log( x ) ) ) ) ) ) ) ) ) ) ) ) + -157/43 * ( e0 )**( \
2 ) * ( x )**( -19/6 ) * ( x0 )**( 19/6 ) * ( 1 + ( x0 * ( 2833/1008 \
+ -197/36 * nu ) + ( ( x0 )**( 3/2 ) * ( 377/72 * numpy.pi + ( \
-157/54 * SO * delta * chiA + ( -157/54 * SO * chiS + 55/27 * SO * nu \
* chiS ) ) ) + ( ( x )**( 5/2 ) * ( -166558393/12462660 * numpy.pi + \
( 99676976761/1196415360 * SO * delta * chiA + ( \
99676976761/1196415360 * SO * chiS + ( -15948055/534114 * SO * ( nu \
)**( 2 ) * chiS + nu * ( -679533343/28486080 * numpy.pi + ( \
941785441/42729120 * SO * delta * chiA + -16542059881/299103840 * SO \
* chiS ) ) ) ) ) ) + ( ( x0 )**( 5/2 ) * ( 764881/90720 * numpy.pi + \
( -1279073/38880 * SO * delta * chiA + ( -1279073/38880 * SO * chiS + \
( -4322/243 * SO * ( nu )**( 2 ) * chiS + nu * ( -949457/22680 * \
numpy.pi + ( 242719/9720 * SO * delta * chiA + 146807/2430 * SO * \
chiS ) ) ) ) ) ) + ( ( x0 )**( 2 ) * ( -1193251/3048192 + ( \
18155/1296 * ( nu )**( 2 ) + ( 191/96 * ( SO )**( 2 ) * ( chiA )**( 2 \
) + ( 191/48 * ( SO )**( 2 ) * delta * chiA * chiS + ( 191/96 * ( SO \
)**( 2 ) * ( chiS )**( 2 ) + nu * ( -66317/9072 + ( -89/12 * ( SO \
)**( 2 ) * ( chiA )**( 2 ) + -13/24 * ( SO )**( 2 ) * ( chiS )**( 2 ) \
) ) ) ) ) ) ) + ( x * ( 17592719/5855472 + ( 1103939/209124 * nu + ( \
x0 * ( 49840172927/5902315776 + ( -42288307/26349624 * nu + \
-217475983/7528464 * ( nu )**( 2 ) ) ) + ( ( x0 )**( 3/2 ) * ( \
6632455063/421593984 * numpy.pi + ( -17592719/2013984 * SO * delta * \
chiA + ( -17592719/2013984 * SO * chiS + ( 60716645/5646348 * SO * ( \
nu )**( 2 ) * chiS + nu * ( 416185003/15056928 * numpy.pi + ( \
-1103939/71928 * SO * delta * chiA + -1458858377/158097744 * SO * \
chiS ) ) ) ) ) ) + ( x0 )**( 2 ) * ( -20992529539469/17848602906624 + \
( 20042012545/271024704 * ( nu )**( 3 ) + ( 3360209329/562125312 * ( \
SO )**( 2 ) * ( chiA )**( 2 ) + ( 3360209329/281062656 * ( SO )**( 2 \
) * delta * chiA * chiS + ( 3360209329/562125312 * ( SO )**( 2 ) * ( \
chiS )**( 2 ) + ( ( nu )**( 2 ) * ( 8852040931/2529563904 + ( \
-98250571/2509488 * ( SO )**( 2 ) * ( chiA )**( 2 ) + \
-14351207/5018976 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) + nu * ( \
-15317632466765/637450103808 + ( -1655537539/140531328 * ( SO )**( 2 \
) * ( chiA )**( 2 ) + ( 210852349/10037952 * ( SO )**( 2 ) * delta * \
chiA * chiS + 155907637/17566416 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) \
) ) ) ) ) ) ) ) ) ) ) ) + ( ( x )**( 2 ) * ( 955157839/302766336 + ( \
91918133/6307632 * ( nu )**( 2 ) + ( -2255909/467232 * ( SO )**( 2 ) \
* ( chiA )**( 2 ) + ( -2255909/233616 * ( SO )**( 2 ) * delta * chiA \
* chiS + ( -2255909/467232 * ( SO )**( 2 ) * ( chiS )**( 2 ) + ( nu * \
( 1419591809/88306848 + ( 1090007/58404 * ( SO )**( 2 ) * ( chiA )**( \
2 ) + 75895/116808 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) + x0 * ( \
2705962157887/305188466688 + ( -18107872201/227074752 * ( nu )**( 3 ) \
+ ( -6390990197/470969856 * ( SO )**( 2 ) * ( chiA )**( 2 ) + ( \
-6390990197/235484928 * ( SO )**( 2 ) * delta * chiA * chiS + ( \
-6390990197/470969856 * ( SO )**( 2 ) * ( chiS )**( 2 ) + ( ( nu )**( \
2 ) * ( -99638367319/2119364352 + ( -214731379/2102544 * ( SO )**( 2 \
) * ( chiA )**( 2 ) + -14951315/4205088 * ( SO )**( 2 ) * ( chiS )**( \
2 ) ) ) + nu * ( 14910082949515/534079816704 + ( 9286878173/117742464 \
* ( SO )**( 2 ) * ( chiA )**( 2 ) + ( 444414073/8410176 * ( SO )**( 2 \
) * delta * chiA * chiS + 1662954523/58871232 * ( SO )**( 2 ) * ( \
chiS )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + ( ( x )**( 3/2 ) * ( \
-2819123/384336 * numpy.pi + ( 657685/72063 * SO * delta * chiA + ( \
657685/72063 * SO * chiS + ( -1151497/144126 * SO * nu * chiS + ( x0 \
* ( -7986575459/387410688 * numpy.pi + ( 266174515/10377072 * SO * \
delta * chiA + ( 266174515/10377072 * SO * chiS + ( 226844909/5188536 \
* SO * ( nu )**( 2 ) * chiS + nu * ( 555367231/13836096 * numpy.pi + \
( -129563945/2594268 * SO * delta * chiA + -10517771921/145279008 * \
SO * chiS ) ) ) ) ) ) + ( x0 )**( 3/2 ) * ( -1062809371/27672192 * ( \
numpy.pi )**( 2 ) + ( -657685/24786 * ( SO )**( 2 ) * ( delta )**( 2 \
) * ( chiA )**( 2 ) + ( 1434391291/20754144 * numpy.pi * SO * chiS + \
( -657685/24786 * ( SO )**( 2 ) * ( chiS )**( 2 ) + ( \
-63332335/3891402 * ( SO )**( 2 ) * ( nu )**( 2 ) * ( chiS )**( 2 ) + \
( chiA * ( 1434391291/20754144 * numpy.pi * SO * delta + \
-657685/12393 * ( SO )**( 2 ) * delta * chiS ) + nu * ( \
-294583067/5188536 * numpy.pi * SO * chiS + ( 325475729/7782804 * ( \
SO )**( 2 ) * delta * chiA * chiS + 325475729/7782804 * ( SO )**( 2 ) \
* ( chiS )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) + ( ( x )**( 3 ) * ( \
-2604595243207055311/16582316889600000 + ( 31576663/2472750 * \
EulerGamma + ( 924853159/40694400 * ( numpy.pi )**( 2 ) + ( \
2977215983/109874880 * ( nu )**( 3 ) + ( ( -2497935059/45577728 * ( \
SO )**( 2 ) + 902441473/22890600 * ( SO )**( 2 ) * ( delta )**( 2 ) ) \
* ( chiA )**( 2 ) + ( -157431815/2441664 * numpy.pi * SO * chiS + ( \
-157741608371/10254988800 * ( SO )**( 2 ) * ( chiS )**( 2 ) + ( chiA \
* ( -157431815/2441664 * numpy.pi * SO * delta + \
-157741608371/5127494400 * ( SO )**( 2 ) * delta * chiS ) + ( nu * ( \
17598403624381/86141905920 + ( -886789/180864 * ( numpy.pi )**( 2 ) + \
( 2355620453/11394432 * ( SO )**( 2 ) * ( chiA )**( 2 ) + ( \
797232427/15260400 * numpy.pi * SO * chiS + ( -5656032047/183124800 * \
( SO )**( 2 ) * delta * chiA * chiS + -1684416511/91562400 * ( SO \
)**( 2 ) * ( chiS )**( 2 ) ) ) ) ) ) + ( ( nu )**( 2 ) * ( \
203247603823/5127494400 + ( 20547593/339120 * ( SO )**( 2 ) * ( chiA \
)**( 2 ) + 227093621/18312480 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) + \
( 415548517/7418250 * numpy.log( 2 ) + ( -65964537/2198000 * \
numpy.log( 3 ) + 31576663/4945500 * numpy.log( x ) ) ) ) ) ) ) ) ) ) \
) ) ) + ( x0 )**( 3 ) * ( 26531900578691/168991764480 + ( -3317/126 * \
EulerGamma + ( 122833/10368 * ( numpy.pi )**( 2 ) + ( -3090307/139968 \
* ( nu )**( 3 ) + ( ( 10898429/290304 * ( SO )**( 2 ) + -110371/11664 \
* ( SO )**( 2 ) * ( delta )**( 2 ) ) * ( chiA )**( 2 ) + ( \
-157043/15552 * numpy.pi * SO * chiS + ( 73362757/2612736 * ( SO )**( \
2 ) * ( chiS )**( 2 ) + ( chiA * ( -157043/15552 * numpy.pi * SO * \
delta + 73362757/1306368 * ( SO )**( 2 ) * delta * chiS ) + ( nu * ( \
9155185261/548674560 + ( -3977/1152 * ( numpy.pi )**( 2 ) + ( \
-11796881/72576 * ( SO )**( 2 ) * ( chiA )**( 2 ) + ( 37663/3888 * \
numpy.pi * SO * chiS + ( -3284705/46656 * ( SO )**( 2 ) * delta * \
chiA * chiS + -18949901/326592 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) \
) ) ) + ( ( nu )**( 2 ) * ( -5732473/1306368 + ( 24271/432 * ( SO \
)**( 2 ) * ( chiA )**( 2 ) + 272239/23328 * ( SO )**( 2 ) * ( chiS \
)**( 2 ) ) ) + ( -12091/1890 * numpy.log( 2 ) + ( -26001/560 * \
numpy.log( 3 ) + -3317/252 * numpy.log( x0 ) ) ) ) ) ) ) ) ) ) ) ) ) \
) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    return taligned

# %%
def New_phase_TT2(x, x0,e0, SO, chiS, chiA, M, nu, delta):
    PHI_TT2 = -1/32 * M * ( x )**( -5/2 ) * ( nu )**( -1 ) * ( 1 + ( x * ( \
3715/1008 + 55/12 * nu ) + ( ( x )**( 3/2 ) * ( -10 * numpy.pi + ( \
565/24 * SO * delta * chiA + ( 565/24 * SO * chiS + -95/6 * SO * nu * \
chiS ) ) ) + ( ( x )**( 2 ) * ( 15293365/1016064 + ( 3085/144 * ( nu \
)**( 2 ) + ( -405/16 * ( SO )**( 2 ) * ( chiA )**( 2 ) + ( -405/8 * ( \
SO )**( 2 ) * delta * chiA * chiS + ( -405/16 * ( SO )**( 2 ) * ( \
chiS )**( 2 ) + nu * ( 27145/1008 + ( 100 * ( SO )**( 2 ) * ( chiA \
)**( 2 ) + 5/4 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) ) ) ) ) ) + ( ( \
x )**( 3 ) * ( 12348611926451/18776862720 + ( -1712/21 * EulerGamma + \
( -160/3 * ( numpy.pi )**( 2 ) + ( -127825/5184 * ( nu )**( 3 ) + ( ( \
195425/384 * ( SO )**( 2 ) + -63845/144 * ( SO )**( 2 ) * ( delta \
)**( 2 ) ) * ( chiA )**( 2 ) + ( 1135/6 * numpy.pi * SO * chiS + ( \
75515/1152 * ( SO )**( 2 ) * ( chiS )**( 2 ) + ( chiA * ( 1135/6 * \
numpy.pi * SO * delta + 75515/576 * ( SO )**( 2 ) * delta * chiS ) + \
( nu * ( -15737765635/12192768 + ( 2255/48 * ( numpy.pi )**( 2 ) + ( \
-683635/336 * ( SO )**( 2 ) * ( chiA )**( 2 ) + ( -130 * numpy.pi * \
SO * chiS + ( -8225/72 * ( SO )**( 2 ) * delta * chiA * chiS + \
-232415/2016 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) ) ) ) + ( ( nu \
)**( 2 ) * ( 76055/6912 + ( -120 * ( SO )**( 2 ) * ( chiA )**( 2 ) + \
1255/36 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) + ( -3424/21 * \
numpy.log( 2 ) + -856/21 * numpy.log( x ) ) ) ) ) ) ) ) ) ) ) ) + ( ( \
x )**( 5/2 ) * ( 38645/1344 * numpy.pi * numpy.log( x ) + ( \
-732985/4032 * SO * delta * chiA * numpy.log( x ) + ( -732985/4032 * \
SO * chiS * numpy.log( x ) + ( 85/4 * SO * ( nu )**( 2 ) * chiS * \
numpy.log( x ) + nu * ( -65/16 * numpy.pi * numpy.log( x ) + ( -35/4 \
* SO * delta * chiA * numpy.log( x ) + 6065/36 * SO * chiS * \
numpy.log( x ) ) ) ) ) ) ) + -785/272 * ( e0 )**( 2 ) * ( x )**( \
-19/6 ) * ( x0 )**( 19/6 ) * ( 1 + ( x0 * ( 2833/1008 + -197/36 * nu \
) + ( ( x0 )**( 3/2 ) * ( 377/72 * numpy.pi + ( -157/54 * SO * delta \
* chiA + ( -157/54 * SO * chiS + 55/27 * SO * nu * chiS ) ) ) + ( ( x \
)**( 5/2 ) * ( -131697334/8456805 * numpy.pi + ( \
39407176859/405926640 * SO * delta * chiA + ( 39407176859/405926640 * \
SO * chiS + ( -25220180/724869 * SO * ( nu )**( 2 ) * chiS + nu * ( \
-268652717/9664920 * numpy.pi + ( 372333779/14497380 * SO * delta * \
chiA + -6539884139/101481660 * SO * chiS ) ) ) ) ) ) + ( ( x0 )**( \
5/2 ) * ( 764881/90720 * numpy.pi + ( -1279073/38880 * SO * delta * \
chiA + ( -1279073/38880 * SO * chiS + ( -4322/243 * SO * ( nu )**( 2 \
) * chiS + nu * ( -949457/22680 * numpy.pi + ( 242719/9720 * SO * \
delta * chiA + 146807/2430 * SO * chiS ) ) ) ) ) ) + ( ( x0 )**( 2 ) \
* ( -1193251/3048192 + ( 18155/1296 * ( nu )**( 2 ) + ( 191/96 * ( SO \
)**( 2 ) * ( chiA )**( 2 ) + ( 191/48 * ( SO )**( 2 ) * delta * chiA \
* chiS + ( 191/96 * ( SO )**( 2 ) * ( chiS )**( 2 ) + nu * ( \
-66317/9072 + ( -89/12 * ( SO )**( 2 ) * ( chiA )**( 2 ) + -13/24 * ( \
SO )**( 2 ) * ( chiS )**( 2 ) ) ) ) ) ) ) ) + ( x * ( 6955261/2215584 \
+ ( 436441/79128 * nu + ( x0 * ( 19704254413/2233308672 + ( \
-16718633/9970128 * nu + -85978877/2848608 * ( nu )**( 2 ) ) ) + ( ( \
x0 )**( 3/2 ) * ( 2622133397/159522048 * numpy.pi + ( -6955261/762048 \
* SO * delta * chiA + ( -6955261/762048 * SO * chiS + ( \
24004255/2136456 * SO * ( nu )**( 2 ) * chiS + nu * ( \
164538257/5697216 * numpy.pi + ( -436441/27216 * SO * delta * chiA + \
-576757963/59820768 * SO * chiS ) ) ) ) ) ) + ( x0 )**( 2 ) * ( \
-8299372143511/6753525424128 + ( 7923586355/102549888 * ( nu )**( 3 ) \
+ ( 1328454851/212696064 * ( SO )**( 2 ) * ( chiA )**( 2 ) + ( \
1328454851/106348032 * ( SO )**( 2 ) * delta * chiA * chiS + ( \
1328454851/212696064 * ( SO )**( 2 ) * ( chiS )**( 2 ) + ( ( nu )**( \
2 ) * ( 3499644089/957132288 + ( -38843249/949536 * ( SO )**( 2 ) * ( \
chiA )**( 2 ) + -5673733/1899072 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) \
) + nu * ( -6055808184535/241197336576 + ( -654514841/53174016 * ( SO \
)**( 2 ) * ( chiA )**( 2 ) + ( 83360231/3798144 * ( SO )**( 2 ) * \
delta * chiA * chiS + 61637903/6646752 * ( SO )**( 2 ) * ( chiS )**( \
2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) + ( ( x )**( 2 ) * ( \
377620541/107433216 + ( 36339727/2238192 * ( nu )**( 2 ) + ( \
-891871/165792 * ( SO )**( 2 ) * ( chiA )**( 2 ) + ( -891871/82896 * \
( SO )**( 2 ) * delta * chiA * chiS + ( -891871/165792 * ( SO )**( 2 \
) * ( chiS )**( 2 ) + ( nu * ( 561233971/31334688 + ( 430933/20724 * \
( SO )**( 2 ) * ( chiA )**( 2 ) + 30005/41448 * ( SO )**( 2 ) * ( \
chiS )**( 2 ) ) ) + x0 * ( 1069798992653/108292681728 + ( \
-7158926219/80574912 * ( nu )**( 3 ) + ( -2526670543/167118336 * ( SO \
)**( 2 ) * ( chiA )**( 2 ) + ( -2526670543/83559168 * ( SO )**( 2 ) * \
delta * chiA * chiS + ( -2526670543/167118336 * ( SO )**( 2 ) * ( \
chiS )**( 2 ) + ( ( nu )**( 2 ) * ( -39391912661/752032512 + ( \
-84893801/746064 * ( SO )**( 2 ) * ( chiA )**( 2 ) + -5910985/1492128 \
* ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) + nu * ( \
5894683956785/189512193024 + ( 3671556487/41779584 * ( SO )**( 2 ) * \
( chiA )**( 2 ) + ( 175698587/2984256 * ( SO )**( 2 ) * delta * chiA \
* chiS + 657447137/20889792 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) ) ) \
) ) ) ) ) ) ) ) ) ) ) + ( ( x )**( 3/2 ) * ( -1114537/141300 * \
numpy.pi + ( 208012/21195 * SO * delta * chiA + ( 208012/21195 * SO * \
chiS + ( -910486/105975 * SO * nu * chiS + ( x0 * ( \
-3157483321/142430400 * numpy.pi + ( 21046357/763020 * SO * delta * \
chiA + ( 21046357/763020 * SO * chiS + ( 89682871/1907550 * SO * ( nu \
)**( 2 ) * chiS + nu * ( 219563789/5086800 * numpy.pi + ( \
-10244591/190755 * SO * delta * chiA + -4158188899/53411400 * SO * \
chiS ) ) ) ) ) ) + ( x0 )**( 3/2 ) * ( -420180449/10173600 * ( \
numpy.pi )**( 2 ) + ( -104006/3645 * ( SO )**( 2 ) * ( delta )**( 2 ) \
* ( chiA )**( 2 ) + ( 567084929/7630200 * numpy.pi * SO * chiS + ( \
-104006/3645 * ( SO )**( 2 ) * ( chiS )**( 2 ) + ( -10015346/572265 * \
( SO )**( 2 ) * ( nu )**( 2 ) * ( chiS )**( 2 ) + ( chiA * ( \
567084929/7630200 * numpy.pi * SO * delta + -208012/3645 * ( SO )**( \
2 ) * delta * chiS ) + nu * ( -116463073/1907550 * numpy.pi * SO * \
chiS + ( 128676451/2861325 * ( SO )**( 2 ) * delta * chiA * chiS + \
128676451/2861325 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) ) ) ) ) ) ) ) \
) ) ) ) + ( ( x )**( 3 ) * ( -204814565759250649/1061268280934400 + ( \
12483797/791280 * EulerGamma + ( 365639621/13022208 * ( numpy.pi )**( \
2 ) + ( 5885194385/175799808 * ( nu )**( 3 ) + ( ( \
-24688893025/364621824 * ( SO )**( 2 ) + 356779187/7324992 * ( SO \
)**( 2 ) * ( delta )**( 2 ) ) * ( chiA )**( 2 ) + ( \
-1556012125/19533312 * numpy.pi * SO * chiS + ( \
-62362961449/3281596416 * ( SO )**( 2 ) * ( chiS )**( 2 ) + ( chiA * \
( -1556012125/19533312 * numpy.pi * SO * delta + \
-62362961449/1640798208 * ( SO )**( 2 ) * delta * chiS ) + ( nu * ( \
34787542048195/137827049472 + ( -8764775/1446912 * ( numpy.pi )**( 2 \
) + ( 23282295175/91155456 * ( SO )**( 2 ) * ( chiA )**( 2 ) + ( \
315184913/4883328 * numpy.pi * SO * chiS + ( -2236105693/58599936 * ( \
SO )**( 2 ) * delta * chiA * chiS + -665932109/29299968 * ( SO )**( 2 \
) * ( chiS )**( 2 ) ) ) ) ) ) + ( ( nu )**( 2 ) * ( \
80353703837/1640798208 + ( 40617335/542592 * ( SO )**( 2 ) * ( chiA \
)**( 2 ) + 448905995/29299968 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) + \
( 164286623/2373840 * numpy.log( 2 ) + ( -26079003/703360 * \
numpy.log( 3 ) + 12483797/1582560 * numpy.log( x ) ) ) ) ) ) ) ) ) ) \
) ) ) + ( x0 )**( 3 ) * ( 26531900578691/168991764480 + ( -3317/126 * \
EulerGamma + ( 122833/10368 * ( numpy.pi )**( 2 ) + ( -3090307/139968 \
* ( nu )**( 3 ) + ( ( 10898429/290304 * ( SO )**( 2 ) + -110371/11664 \
* ( SO )**( 2 ) * ( delta )**( 2 ) ) * ( chiA )**( 2 ) + ( \
-157043/15552 * numpy.pi * SO * chiS + ( 73362757/2612736 * ( SO )**( \
2 ) * ( chiS )**( 2 ) + ( chiA * ( -157043/15552 * numpy.pi * SO * \
delta + 73362757/1306368 * ( SO )**( 2 ) * delta * chiS ) + ( nu * ( \
9155185261/548674560 + ( -3977/1152 * ( numpy.pi )**( 2 ) + ( \
-11796881/72576 * ( SO )**( 2 ) * ( chiA )**( 2 ) + ( 37663/3888 * \
numpy.pi * SO * chiS + ( -3284705/46656 * ( SO )**( 2 ) * delta * \
chiA * chiS + -18949901/326592 * ( SO )**( 2 ) * ( chiS )**( 2 ) ) ) \
) ) ) + ( ( nu )**( 2 ) * ( -5732473/1306368 + ( 24271/432 * ( SO \
)**( 2 ) * ( chiA )**( 2 ) + 272239/23328 * ( SO )**( 2 ) * ( chiS \
)**( 2 ) ) ) + ( -12091/1890 * numpy.log( 2 ) + ( -26001/560 * \
numpy.log( 3 ) + -3317/252 * numpy.log( x0 ) ) ) ) ) ) ) ) ) ) ) ) ) \
) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    return PHI_TT2

# %%
#import numpy
#EulerGamma=0.577
#print(New_phase_TT2(0.05,0.045, 0.1,0, 0, 0, 1, 1, 1))
#print(Time_TT2_aligned(0.05,0.045, 0.1,0, 0, 0, 1, 1, 1))

# %% [markdown]
# ##  Relation between post-Newtonian parameter $x$ and time $t (v, v_0, e_0)$ (from TaylorT2)

# %%
# ##  Relation between post-Newtonian parameter $x$ and time $t (v, v_0, e_0)$ (from TaylorT2)
# Eq. (6.7a, 6.7b), Pg. 25, Moore et al (2016)

def t_from_x(v, v0, e0, M, eta):
    
    t = -5/256 * M * ( v )**( -8 ) * ( eta )**( -1 ) * ( -1 + ( 32/5 * np.pi * ( v )**( 3 ) + 
 	 ( ( v )**( 2 ) * ( -743/252 + -11/3 * eta ) + ( ( v )**( 5 ) * ( 7729/252 * np.pi + 
 	 -13/3 * np.pi * eta ) + ( ( v )**( 4 ) * ( -3058673/508032 + ( -5429/504 * eta + 
 	 -617/72 * ( eta )**( 2 ) ) ) + ( -1 * np.pi * ( v )**( 7 ) * ( -15419335/127008 + 
 	 ( -75703/756 * eta + 14809/378 * ( eta )**( 2 ) ) ) + ( ( v )**( 6 ) * ( 8/3 * ( -3147553127/8128512 + 
 	 451/32 * ( np.pi )**( 2 ) ) * eta + ( 15211/1728 * ( eta )**( 2 ) + 
 	 ( -25565/1296 * ( eta )**( 3 ) + 8/3 * ( 10052469856691/62589542400 + ( -856/35 * EulerGamma + 
 	 ( -16 * ( np.pi )**( 2 ) + -428/35 * ( 4 * np.log( 2 ) + 2 * np.log( v ) ) ) ) ) ) ) ) + 
 	 157/43 * ( e0 )**( 2 ) * ( v )**( -19/3 ) * ( v0 )**( 19/3 ) * ( 1 + ( 377/72 * np.pi * ( v0 )**( 3 ) + 
 	 ( ( v0 )**( 2 ) * ( 2833/1008 + -197/36 * eta ) + ( ( v0 )**( 5 ) * ( 764881/90720 * np.pi + 
 	 -949457/22680 * np.pi * eta ) + ( ( v )**( 5 ) * ( -166558393/12462660 * np.pi + 
 	 -679533343/28486080 * np.pi * eta ) + ( ( v0 )**( 4 ) * ( -1193251/3048192 + 
 	 ( -66317/9072 * eta + 18155/1296 * ( eta )**( 2 ) ) ) + ( ( v )**( 3 ) * ( -2819123/384336 * np.pi + 
 	 ( -1062809371/27672192 * ( np.pi )**( 2 ) * ( v0 )**( 3 ) + ( v0 )**( 2 ) 
      * ( -7986575459/387410688 * np.pi + 
 	 555367231/13836096 * np.pi * eta ) ) ) + ( ( v )**( 4 ) * ( 955157839/302766336 + 
 	 ( 1419591809/88306848 * eta + ( 91918133/6307632 * ( eta )**( 2 ) + 
 	 ( v0 )**( 2 ) * ( 2705962157887/305188466688 + ( 14910082949515/534079816704 * eta + 
 	 ( -99638367319/2119364352 * ( eta )**( 2 ) + -18107872201/227074752 * ( eta )**( 3 ) ) ) ) ) ) ) + 
 	 ( ( v )**( 2 ) * ( 17592719/5855472 + ( 1103939/209124 * eta + 
 	 ( ( v0 )**( 3 ) * ( 6632455063/421593984 * np.pi + 416185003/15056928 * np.pi * eta ) + 
 	 ( ( v0 )**( 2 ) * ( 49840172927/5902315776 + ( -42288307/26349624 * eta + 
 	 -217475983/7528464 * ( eta )**( 2 ) ) ) + ( v0 )**( 4 ) * ( -20992529539469/17848602906624 + 
 	 ( -15317632466765/637450103808 * eta + ( 8852040931/2529563904 * ( eta )**( 2 ) + 
 	 20042012545/271024704 * ( eta )**( 3 ) ) ) ) ) ) ) ) + 
      ( ( v )**( 6 ) * ( -2604595243207055311/16582316889600000 + ( 31576663/2472750 * EulerGamma + 
 	 ( 924853159/40694400 * ( np.pi )**( 2 ) + ( ( 17598403624381/86141905920 + 
 	 -886789/180864 * ( np.pi )**( 2 ) ) * eta + ( 203247603823/5127494400 * ( eta )**( 2 ) + 
 	 ( 2977215983/109874880 * ( eta )**( 3 ) + ( 226088539/7418250 * np.log( 2 ) + 
 	 ( -65964537/2198000 * np.log( 3 ) + 31576663/4945500 * ( 4 * np.log( 2 ) + 
 	 2 * np.log( v ) ) ) ) ) ) ) ) ) ) + ( v0 )**( 6 ) * ( 26531900578691/168991764480 + 
 	 ( -3317/126 * EulerGamma + ( 122833/10368 * ( np.pi )**( 2 ) + 
 	 ( ( 9155185261/548674560 + -3977/1152 * ( np.pi )**( 2 ) ) * eta + ( -5732473/1306368 * ( eta )**( 2 ) + 
 	 ( -3090307/139968 * ( eta )**( 3 ) + ( 87419/1890 * np.log( 2 ) + ( -26001/560 * np.log( 3 ) + 
 	 -3317/252 * ( 4 * np.log( 2 ) + 2 * np.log( v0 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(t)

# %% [markdown]
# ##  Relation between time and post-Newtonian parameter $x$ as $v (\theta, \theta_{0}, e_0)$ (from TaylorT3)

# %%
# ##  Relation between time and post-Newtonian parameter $x$ as $v (\theta, \theta_{0}, e_0)$ (from TaylorT3)
# Eq. (6.8a, 6.8b), Pg. 26 , Moore et al (2016)

def x_from_t(theta, theta0, e0, M, eta):
    
    F_theta = 1/8 * ( M )**( -1 ) * ( np.pi )**( -1 ) * ( theta )**( 3 ) * ( 1 + ( ( 743/2688 + 
 	 11/32 * eta ) * ( theta )**( 2 ) + ( -3/10 * np.pi * ( theta )**( 3 ) + ( ( 1855099/14450688 + 
 	 ( 56975/258048 * eta + 371/2048 * ( eta )**( 2 ) ) ) * ( theta )**( 4 ) + 
 	 ( ( -7729/21504 * np.pi + 13/256 * np.pi * eta ) * ( theta )**( 5 ) + 
 	 ( np.pi * ( -188516689/433520640 + ( -97765/258048 * eta + 141769/1290240 * ( eta )**( 2 ) ) ) * ( theta )**( 7 ) + 
 	 ( ( theta )**( 6 ) * ( -720817631400877/288412611379200 + ( 107/280 * EulerGamma + 
 	 ( 53/200 * ( np.pi )**( 2 ) + ( ( 25302017977/4161798144 + -451/2048 * ( np.pi )**( 2 ) ) * eta + 
 	 ( -30913/1835008 * ( eta )**( 2 ) + ( 235925/1769472 * ( eta )**( 3 ) + ( 107/280 * np.log( 2 ) + 
 	 107/280 * np.log( theta ) ) ) ) ) ) ) ) + 
      -471/344 * ( e0 )**( 2 ) * ( theta )**( -19/3 ) * ( theta0 )**( 19/3 ) * ( 1 + 
 	 ( ( -7647061/70265664 + 209353/836496 * eta ) * ( theta )**( 2 ) + 
 	 ( -256883/3074688 * np.pi * ( theta )**( 3 ) + ( ( -1172375466061/6586984406016 + 
 	 ( 439689491/8477457408 * eta + 91590343/1867059072 * ( eta )**( 2 ) ) ) * ( theta )**( 4 ) + 
 	 ( ( 49653615200993/96325793464320 * np.pi + -449103385817/1146735636480 * np.pi * eta ) * ( theta )**( 5 ) + 
 	 ( ( 4445/3456 + -185/288 * eta ) * ( theta0 )**( 2 ) + ( ( -4855883735/34691162112 + 
 	 ( 495545305/1264781952 * eta + -1046765/6511104 * ( eta )**( 2 ) ) ) * ( theta )**( 2 ) * (theta0 )**( 2 ) + 
 	 ( ( -1141844935/10626121728 * np.pi + 47523355/885510144 * np.pi * eta ) * ( theta )**( 3 ) * ( theta0 )**( 2 ) + 
 	 ( ( -744458420948735/3252088301027328 + ( 12376149277895/68362216538112 * eta + 
 	 ( 896664159665/30111928713216 * ( eta )**( 2 ) + -457951715/14532784128 * ( eta )**( 3 ) ) ) ) * ( theta )**( 4 ) * ( theta0 )**( 2 ) + 
 	 ( 61/2880 * np.pi * ( theta0 )**( 3 ) + ( ( -466470721/202365112320 * np.pi + 
 	 12770533/2409108480 * np.pi * eta ) * ( theta )**( 2 ) * ( theta0 )**( 3 ) + 
 	 ( -15669863/8855101440 * ( np.pi )**( 2 ) * ( theta )**( 3 ) * ( theta0 )**( 3 ) + 
 	 ( ( 1024948915/1170505728 + ( -1026871/6967296 * eta + 
 	 14971/165888 * ( eta )**( 2 ) ) ) * ( theta0 )**( 4 ) + ( ( -7837846874888815/82246362193723392 + 
 	 ( 76760406851419/326374453149696 * eta + ( -60493466573/1295136718848 * ( eta )**( 2 ) + 
 	 3134223763/138764648448 * ( eta )**( 3 ) ) ) ) * ( theta )**( 2 ) * ( theta0 )**( 4 ) + 
 	 ( ( -12410299/17418240 * np.pi + 576391/1451520 * np.pi * eta ) * ( theta0 )**( 5 ) + 
 	 ( ( theta )**( 6 ) * ( 71857244107315089475141/32866417392257433600000 + 
 	 ( -75936937/158256000 * EulerGamma + ( -9863961577/44275507200 * ( np.pi )**( 2 ) + 
 	 ( ( -672050112032567/87421728522240 + 1214953/3858432 * ( np.pi )**( 2 ) ) * eta + 
 	 ( 380720733285643/1129197326745600 * ( eta )**( 2 ) + ( -231474834959/8065695191040 * ( eta )**( 3 ) + 
 	 ( -53821/14836500 * np.log( 2 ) + ( -65964537/140672000 * np.log( 3 ) + 
 	 -75936937/158256000 * np.log( theta ) ) ) ) ) ) ) ) ) + ( theta0 )**( 6 ) * ( -55579234653596057/23361421521715200 + 
 	 ( 15943/40320 * EulerGamma + ( 3968617/16588800 * ( np.pi )**( 2 ) + ( ( 21736949245913/1685528248320 + 
 	 -12751/24576 * ( np.pi )**( 2 ) ) * eta + ( -1742350567/4013162496 * ( eta )**( 2 ) + 
 	 ( 4790953/143327232 * ( eta )**( 3 ) + ( 8453/7560 * np.log( 2 ) + ( -26001/35840 * np.log( 3 ) + 
 	 15943/40320 * np.log( theta0 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(F_theta)

# %% [markdown]
# ## Mean Anomaly $l (\xi_{\phi})$

# %%
# ## Mean Anomaly $l (\xi_{\phi})$
# Eq. (C2), Pg. 41, Moore et al (2016)

def mean_anomaly(xie, xi0, cl, eta,e0):  #e0, ### cl is some constant, find out. At the moment set to lref/l0 as required.
    
    l= cl -1/32 * ( eta )**( -1 ) * ( xie )**( -5/3 ) * ( 1 + ( ( -1325/1008 + 
 	 55/12 * eta ) * ( xie )**( 2/3 ) + ( -10 * np.pi * xie + ( ( -41270555/1016064 + 
 	 ( 20845/1008 * eta + 3085/144 * ( eta )**( 2 ) ) ) * ( xie )**( 4/3 ) + 
 	 ( ( xie )**( 2 ) * ( 15398147061251/18776862720 + ( -1712/21 * EulerGamma + ( -160/3 * ( np.pi )**( 2 ) + 
 	 ( ( -22272871555/12192768 + 6355/96 * ( np.pi )**( 2 ) ) * eta + 
 	 ( 96935/6912 * ( eta )**( 2 ) + ( -127825/5184 * ( eta )**( 3 ) + 
 	 -856/21 * np.log( 16 * ( xie )**( 2/3 ) ) ) ) ) ) ) ) + 
 	 ( -1 * np.pi * ( 1675/2016 + 65/24 * eta ) * ( xie )**( 5/3 ) * np.log( xie ) + 
 	 -785/272 * ( e0 )**( 2 ) * ( ( xie )**( -1 ) * xi0 )**( 19/9 ) * ( 1 + 
 	 ( ( 2833/1008 + -197/36 * eta ) * ( xie )**( 2/3 ) + ( ( 117997/2215584 + 
 	 436441/79128 * eta ) * ( xie )**( 2/3 ) + ( -1114537/141300 * np.pi * xie + ( ( -732350735/68366592 + 
 	 ( 271164331/31334688 * eta + 36339727/2238192 * ( eta )**( 2 ) ) ) * ( xie )**( 4/3 ) + 
 	 ( np.pi * ( 270050729/33827220 + -268652717/9664920 * eta ) * ( xie )**( 5/3 ) + 
 	 ( ( 334285501/2233308672 + ( 151648993/9970128 * eta + 
 	 -85978877/2848608 * ( eta )**( 2 ) ) ) * ( xie )**( 2/3 ) * ( xi0 )**( 2/3 ) + 
      ( np.pi * ( -3157483321/142430400 + 
 	 219563789/5086800 * eta ) * xie * ( xi0 )**( 2/3 ) + ( ( -2074749632255/68913524736 + 
 	 ( 15718279597553/189512193024 * eta + ( -1296099941/752032512 * ( eta )**( 2 ) + 
 	 -7158926219/80574912 * ( eta )**( 3 ) ) ) ) * ( xie )**( 4/3 ) * ( xi0 )**( 2/3 ) + 
      ( 377/72 * np.pi * xi0 + 
 	 ( np.pi * ( 44484869/159522048 + 164538257/5697216 * eta ) * ( xie )**( 2/3 ) * xi0 + 
 	 ( -420180449/10173600 * ( np.pi )**( 2 ) * xie * xi0 + ( ( -1193251/3048192 + ( -66317/9072 * eta + 
 	 18155/1296 * ( eta )**( 2 ) ) ) * ( xi0 )**( 4/3 ) + ( ( -140800038247/6753525424128 + 
 	 ( -614686144279/241197336576 * eta + ( -37877198551/957132288 * ( eta )**( 2 ) + 
 	 7923586355/102549888 * ( eta )**( 3 ) ) ) ) * ( xie )**( 2/3 ) * ( xi0 )**( 4/3 ) + 
 	 ( np.pi * ( 764881/90720 + -949457/22680 * eta ) * ( xi0 )**( 5/3 ) + 
 	 ( ( xie )**( 2 ) * ( -231385908692247049/1061268280934400 + ( 12483797/791280 * EulerGamma + 
 	 ( 365639621/13022208 * ( np.pi )**( 2 ) + ( ( 43054867314787/137827049472 + 
 	 -14711579/1446912 * ( np.pi )**( 2 ) ) * eta + ( 55988213933/1640798208 * ( eta )**( 2 ) + 
 	 ( 5885194385/175799808 * ( eta )**( 3 ) + ( 89383841/2373840 * np.log( 2 ) + 
 	 -26079003/703360 * np.log( 16 * ( xie )**( 2/3 ) ) ) ) ) ) ) ) ) + 
 	 ( xi0 )**( 2 ) * ( 26531900578691/168991764480 + 
 	 ( -3317/126 * EulerGamma + ( 122833/10368 * ( np.pi )**( 2 ) + ( ( 9155185261/548674560 + 
 	 -3977/1152 * ( np.pi )**( 2 ) ) * eta + ( -5732473/1306368 * ( eta )**( 2 ) + 
 	 ( -3090307/139968 * ( eta )**( 3 ) + ( 87419/1890 * np.log( 2 ) + ( -26001/560 * np.log( 3 ) + 
 	 -3317/252 * np.log( 16 * ( xi0 )**( 2/3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) 
    return(l)

# %% [markdown]
# ## Amplitude $(\ell , m)$ = (2, 2)

# %%
# ## Amplitude $(\ell , m)$ = (2, 2)

def amplitude_22(xi, x, nu, Delta, e):
    h = 1 + ( e * ( 1/4 * ( np.e )**( complex( 0,-1 ) * xi ) + 
 	 5/4 * ( np.e )**( complex( 0,1 ) * xi ) ) + 
 	 ( ( e )**( 2 ) * ( -1/2 + 
 	 ( 1/4 * ( np.e )**( complex( 0,-2 ) * xi ) + 
 	 7/4 * ( np.e )**( complex( 0,2 ) * xi ) ) ) + 
 	 ( ( e )**( 3 ) * ( -5/32 * ( np.e )**( complex( 0,-1 ) * xi ) + 
 	 ( -33/32 * ( np.e )**( complex( 0,1 ) * xi ) + 
 	 ( 9/32 * ( np.e )**( complex( 0,-3 ) * xi ) + 
 	 77/32 * ( np.e )**( complex( 0,3 ) * xi ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -1/8 + 
 	 ( -1/6 * ( np.e )**( complex( 0,-2 ) * xi ) + 
 	 ( -11/6 * ( np.e )**( complex( 0,2 ) * xi ) + 
 	 ( 1/3 * ( np.e )**( complex( 0,-4 ) * xi ) + 
 	 79/24 * ( np.e )**( complex( 0,4 ) * xi ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( -47/768 * ( np.e )**( complex( 0,-1 ) * xi ) + 
 	 ( -11/768 * ( np.e )**( complex( 0,1 ) * xi ) + 
 	 ( -117/512 * ( np.e )**( complex( 0,-3 ) * xi ) + 
 	 ( -1585/512 * ( np.e )**( complex( 0,3 ) * xi ) + 
 	 ( 625/1536 * ( np.e )**( complex( 0,-5 ) * xi ) + 
 	 6901/1536 * ( np.e )**( complex( 0,5 ) * xi ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( -1/16 + 
 	 ( -1/32 * ( np.e )**( complex( 0,-2 ) * xi ) + 
 	 ( 1/3 * ( np.e )**( complex( 0,2 ) * xi ) + 
 	 ( -1/3 * ( np.e )**( complex( 0,-4 ) * xi ) + 
 	 ( -403/80 * ( np.e )**( complex( 0,4 ) * xi ) + 
 	 ( 81/160 * ( np.e )**( complex( 0,-6 ) * xi ) + 
 	 49/8 * ( np.e )**( complex( 0,6 ) * xi ) ) ) ) ) ) ) + 
 	 ( x * ( -107/42 + 
 	 ( 55/42 * nu + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -257/168 + 
 	 169/168 * nu ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( -31/24 + 
 	 35/24 * nu ) ) + 
 	 ( ( e )**( 2 ) * ( -221/84 + 
 	 ( 89/84 * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -289/168 + 
 	 181/168 * nu ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( -71/168 + 
 	 283/168 * nu ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -1115/1344 + 
 	 895/1344 * nu ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -685/192 + 
 	 79/64 * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( -2813/1344 + 
 	 559/448 * nu ) + 
 	 ( np.e )**( complex( 0,3 ) * xi ) * ( 1027/1344 + 
 	 2729/1344 * nu ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -183/112 + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -19/36 + 
 	 5/9 * nu ) + 
 	 ( 233/336 * nu + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -1367/252 + 
 	 82/63 * nu ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( -379/144 + 
 	 215/144 * nu ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( 160/63 + 
 	 157/63 * nu ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,-3 ) * xi ) * ( -2815/21504 + 
 	 3137/7168 * nu ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -20249/32256 + 
 	 16465/32256 * nu ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -38305/32256 + 
 	 21661/32256 * nu ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( -183655/21504 + 
 	 29423/21504 * nu ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( -217369/64512 + 
 	 117265/64512 * nu ) + 
 	 ( np.e )**( complex( 0,5 ) * xi ) * ( 337087/64512 + 
 	 199165/64512 * nu ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( -877/672 + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 4873/10080 + 
 	 551/2016 * nu ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -295/504 + 
 	 149/336 * nu ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -1495/4032 + 
 	 1895/4032 * nu ) + 
 	 ( 377/672 * nu + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -69071/5040 + 
 	 2389/1680 * nu ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( -458/105 + 
 	 313/140 * nu ) + 
 	 ( np.e )**( complex( 0,6 ) * xi ) * ( 62233/6720 + 
 	 5167/1344 * nu ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 2 ) * ( -2173/1512 + 
 	 ( -1069/216 * nu + 
 	 ( 2047/1512 * ( nu )**( 2 ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,-3 ) * xi ) * ( -35069/1512 + 
 	 ( -459619/48384 * nu + 
 	 -144821/48384 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( -1432/27 + 
 	 ( 1320281/48384 * nu + 
 	 -1679/6912 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -34127/3024 + 
 	 ( -632117/48384 * nu + 
 	 14285/48384 * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( -11833/3024 + 
 	 ( -519889/48384 * nu + 
 	 15457/48384 * ( nu )**( 2 ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( -34399/3024 + 
 	 ( -3271/432 * nu + 
 	 ( 829/3024 * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -77575/6048 + 
 	 ( -42697/6048 * nu + 
 	 -4523/6048 * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( -16033/672 + 
 	 ( 14467/2016 * nu + 
 	 209/224 * ( nu )**( 2 ) ) ) ) ) ) ) + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -4271/756 + 
 	 ( -35131/6048 * nu + 
 	 421/864 * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( -2155/252 + 
 	 ( -1655/672 * nu + 
 	 371/288 * ( nu )**( 2 ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -51565/4032 + 
 	 ( -7009/576 * nu + 
 	 ( -605/4032 * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( -348401/9072 + 
 	 ( -61651/4536 * nu + 
 	 -62557/9072 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -1258321/12096 + 
 	 ( 86113/1344 * nu + 
 	 -35033/12096 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -21593/6048 + 
 	 ( -59167/6048 * nu + 
 	 6779/6048 * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( -41117/18144 + 
 	 ( -462659/18144 * nu + 
 	 24575/18144 * ( nu )**( 2 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,-5 ) * xi ) * (-17610839/290304 + 
 	 ( -46898683/2322432 * nu + 
 	 -31148909/2322432 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( -677277/3584 + 
 	 ( 98415547/774144 * nu + 
 	 -2079481/258048 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -836161/72576 + 
 	 ( -20348767/1161216 * nu + 
 	 -694625/1161216 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -491/189 + 
 	 ( -2110099/129024 * nu + 
 	 -31631/387072 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 8789/13824 + 
 	 ( -5939153/774144 * nu + 
 	 2830337/774144 * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,3 ) * xi ) * ( 2717333/96768 + 
 	 ( -43930853/774144 * nu + 
 	 3420269/774144 * ( nu )**( 2 ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( -48545/3456 + 
 	 ( -53279/3456 * nu + 
 	 ( -9979/24192 * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( -22510693/241920 + 
 	 ( -1853953/60480 * nu + 
 	 -2900389/120960 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( -986303/3024 + 
 	 ( 11177365/48384 * nu + 
 	 -4196279/241920 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -1092307/72576 + 
 	 ( -2387339/145152 * nu + 
 	 -197119/145152 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -641191/145152 + 
 	 ( -291587/18144 * nu + 
 	 -30157/72576 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 210949/18144 + 
 	 ( -45317/18144 * nu + 
 	 866989/90720 * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( 36131317/362880 + 
 	 ( -44839757/362880 * nu + 
 	 4173977/362880 * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 3/2 ) * ( 2 * np.pi + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 13/4 * np.pi + 
 	 complex( 0,3/2 ) * np.log( 2 ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( 11/4 * np.pi + 
 	 ( complex( 0,-27/2 ) * np.log( 2 ) + 
 	 complex( 0,27/2 ) * np.log( 3 ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( 2 * np.pi + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 5 * np.pi + 
 	 ( complex( 0,-13/252 ) * nu + 
 	 complex( 0,3 ) * np.log( 2 ) ) ) + 
 	 ( complex( 0,-30 ) * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 4 * np.pi + 
 	 ( complex( 0,59 ) * np.log( 2 ) + 
 	 complex( 0,-27 ) * np.log( 3 ) ) ) + 
 	 complex( 0,27 ) * np.log( 3 ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( 703/96 * np.pi + 
 	 ( complex( 0,-13/126 ) * nu + 
 	 complex( 0,227/48 ) * np.log( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( 59/32 * np.pi + 
 	 ( complex( 0,13/126 ) * nu + 
 	 ( complex( 0,-811/16 ) * np.log( 2 ) + 
 	 complex( 0,351/8 ) * np.log( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 61/32 * np.pi + 
 	 ( complex( 0,2419/16 ) * np.log( 2 ) + 
 	 complex( 0,-1377/16 ) * np.log( 3 ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( 185/32 * np.pi + 
 	 ( complex( 0,-6683/48 ) * np.log( 2 ) + 
 	 ( complex( 0,81/8 ) * np.log( 3 ) + 
 	 complex( 0,3125/48 ) * np.log( 5 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( 2 * np.pi + 
 	 ( complex( 0,-13/336 ) * nu + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 125/12 * np.pi + 
 	 ( complex( 0,-169/1008 ) * nu + 
 	 complex( 0,85/12 ) * np.log( 2 ) ) ) + 
 	 ( complex( 0,527/2 ) * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 11/8 * np.pi + 
 	 ( complex( 0,5/72 ) * nu + 
 	 ( complex( 0,-467/6 ) * np.log( 2 ) + 
 	 complex( 0,531/8 ) * np.log( 3 ) ) ) ) + 
 	 ( complex( 0,-621/4 ) * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 199/24 * np.pi + 
 	 ( complex( 0,1837/12 ) * np.log( 2 ) + 
 	 ( complex( 0,981/8 ) * np.log( 3 ) + 
 	 complex( 0,-3125/24 ) * np.log( 5 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( 17/12 * np.pi + 
 	 ( complex( 0,-2555/6 ) * np.log( 2 ) + 
 	 ( complex( 0,351/4 ) * np.log( 3 ) + 
 	 complex( 0,3125/24 ) * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,5 ) * xi ) * ( 37257/2560 * np.pi + 
 	 ( complex( 0,-767/3024 ) * nu + 
 	 ( complex( 0,38203/3840 ) * np.log( 2 ) + 
 	 complex( 0,459/1280 ) * np.log( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( 469/1536 * np.pi + 
 	 ( complex( 0,25/336 ) * nu + 
 	 ( complex( 0,-88579/768 ) * np.log( 2 ) + 
 	 complex( 0,3105/32 ) * np.log( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( 1465/768 * np.pi + 
 	 ( complex( 0,185/1008 ) * nu + 
 	 ( complex( 0,53185/128 ) * np.log( 2 ) + 
 	 complex( 0,-15993/64 ) * np.log( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 1547/768 * np.pi + 
 	 ( complex( 0,-13/3024 ) * nu + 
 	 ( complex( 0,-301531/384 ) * np.log( 2 ) + 
 	 ( complex( 0,25245/128 ) * np.log( 3 ) + 
 	 complex( 0,40625/192 ) * np.log( 5 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 119/512 * np.pi + 
 	 ( complex( 0,517483/768 ) * np.log( 2 ) + 
 	 ( complex( 0,14121/64 ) * np.log( 3 ) + 
 	 complex( 0,-334375/768 ) * np.log( 5 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( 18151/1536 * np.pi + 
 	 ( complex( 0,-334321/1280 ) * np.log( 2 ) + 
 	 ( complex( 0,-3879/16 ) * np.log( 3 ) + 
 	 ( complex( 0,3125/64 ) * np.log( 5 ) + 
 	 complex( 0,823543/3840 ) * np.log( 7 ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( 1145/576 * np.pi + 
 	 ( complex( 0,-55/504 ) * nu + 
 	 ( complex( 0,-45929/36 ) * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -427/240 * np.pi + 
 	 ( complex( 0,169/1512 ) * nu + 
 	 ( complex( 0,-1667/10 ) * np.log( 2 ) + 
 	 complex( 0,44289/320 ) * np.log( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 689/384 * np.pi + 
 	 ( complex( 0,503/4032 ) * nu + 
 	 ( complex( 0,30199/48 ) * np.log( 2 ) + 
 	 complex( 0,-49167/128 ) * np.log( 3 ) ) ) ) + 
 	 ( complex( 0,22329/64 ) * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( 115751/5760 * np.pi + 
 	 ( complex( 0,-1495/4032 ) * nu + 
 	 ( complex( 0,1949/144 ) * np.log( 2 ) + 
 	 ( complex( 0,459/640 ) * np.log( 3 ) + 
 	 complex( 0,22/45 ) * np.log( 4 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 199/96 * np.pi + 
 	 ( complex( 0,-13/6048 ) * nu + 
 	 ( complex( 0,66655/48 ) * np.log( 2 ) + 
 	 ( complex( 0,18747/64 ) * np.log( 3 ) + 
 	 complex( 0,-303125/384 ) * np.log( 5 ) ) ) ) ) + 
 	 ( complex( 0,184375/576 ) * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( 2681/160 * np.pi + 
 	 ( complex( 0,829897/720 ) * np.log( 2 ) + 
 	 ( complex( 0,58563/640 ) * np.log( 3 ) + 
 	 ( complex( 0,3125/576 ) * np.log( 5 ) + 
 	 complex( 0,-823543/1920 ) * np.log( 7 ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( -32/15 * np.pi + 
 	 ( complex( 0,-28393/30 ) * np.log( 2 ) + 
 	 ( complex( 0,-538029/640 ) * np.log( 3 ) + 
 	 ( complex( 0,59375/128 ) * np.log( 5 ) + 
 	 complex( 0,823543/1920 ) * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 5/2 ) * ( -107/21 * np.pi + 
 	 ( complex( 0,-24 ) * nu + 
 	 ( 34/21 * np.pi * nu + 
 	 ( ( e )**( 2 ) * ( complex( 0,-18 ) + 
 	 ( -103/21 * np.pi + 
 	 ( complex( 0,-83233/630 ) * nu + 
 	 ( 191/42 * np.pi * nu + 
 	 ( complex( 0,-1381/7 ) * np.log( 2 ) + 
 	 ( complex( 0,-15/7 ) * nu * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-9 ) + 
 	 ( 611/42 * np.pi + 
 	 ( complex( 0,-255197/1008 ) * nu + 
 	 ( 37/84 * np.pi * nu + 
 	 ( complex( 0,-865/216 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,683/14 ) * np.log( 2 ) + 
 	 complex( 0,-33/14 ) * nu * np.log( 2 ) ) ) ) ) ) ) + 
 	 ( complex( 0,297/2 ) * np.log( 3 ) + 
 	 ( complex( 0,9/2 ) * nu * np.log( 3 ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-21 ) + 
 	 ( -185/21 * np.pi + 
 	 ( complex( 0,-69703/2520 ) * nu + 
 	 ( 449/84 * np.pi * nu + 
 	 ( complex( 0,9997/42 ) * np.log( 2 ) + 
 	 ( complex( 0,893/42 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-297/2 ) * np.log( 3 ) + 
 	 complex( 0,-9/2 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-9/2 ) + 
 	 ( 229/168 * np.pi + 
 	 ( complex( 0,-14579/140 ) * nu + 
 	 ( 61/42 * np.pi * nu + 
 	 ( complex( 0,473/28 ) * np.log( 2 ) + 
 	 complex( 0,-3/7 ) * nu * np.log( 2 ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-27/2 ) + 
 	 ( -1081/168 * np.pi + 
 	 ( complex( 0,-1291/180 ) * nu + 
 	 ( 137/42 * np.pi * nu + 
 	 ( complex( 0,-27/4 ) * np.log( 2 ) + 
 	 ( complex( 0,-9 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,27/4 ) * np.log( 3 ) + 
 	 complex( 0,9 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-63/2 ) + 
 	 ( -33/7 * np.pi + 
 	 ( complex( 0,-6292501/20160 ) * nu + 
 	 ( 157/21 * np.pi * nu + 
 	 ( complex( 0,-5951/2016 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,275803/84 ) * np.log( 2 ) + 
 	 ( complex( 0,-7211/42 ) * nu * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-105/4 ) + 
 	 ( 36341/504 * np.pi + 
 	 ( complex( 0,-18532993/20160 ) * nu + 
 	 ( -4805/1008 * np.pi * nu + 
 	 ( complex( 0,-77779/6048 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,81553/504 ) * np.log( 2 ) + 
 	 complex( 0,-1313/126 ) * nu * np.log( 2 ) ) ) ) ) ) ) + 
 	 ( complex( 0,-113265/56 ) * np.log( 3 ) + 
 	 ( complex( 0,855/7 ) * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-75/2 ) + 
 	 ( -2003/336 * np.pi + 
 	 ( complex( 0,-38756573/30240 ) * nu + 
 	 ( 2705/336 * np.pi * nu + 
 	 ( complex( 0,-5431/3024 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-259871/252 ) * np.log( 2 ) + 
 	 ( complex( 0,15241/252 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,12573/16 ) * np.log( 3 ) + 
 	 complex( 0,-669/16 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-63/2 ) + 
 	 ( -313/72 * np.pi + 
 	 ( complex( 0,799829/5040 ) * nu + 
 	 ( 593/72 * np.pi * nu + 
 	 ( complex( 0,-1218479/252 ) * np.log( 2 ) + 
 	 ( complex( 0,49009/252 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,69039/56 ) * np.log( 3 ) + 
 	 ( complex( 0,-2223/28 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,1269875/1008 ) * np.log( 5 ) + 
 	 complex( 0,-15625/1008 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,-183/4 ) + 
 	 ( -16481/1008 * np.pi + 
 	 ( complex( 0,-3723263/30240 ) * nu + 
 	 ( 3007/252 * np.pi * nu + 
 	 ( complex( 0,864361/504 ) * np.log( 2 ) + 
 	 ( complex( 0,-4283/126 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,85923/112 ) * np.log( 3 ) + 
 	 ( complex( 0,3135/112 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-1269875/1008 ) * np.log( 5 ) + 
 	 complex( 0,15625/1008 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,-255/16 ) + 
 	 ( 150523/4032 * np.pi + 
 	 ( complex( 0,-5123581/10080 ) * nu + 
 	 ( -395/252 * np.pi * nu + 
 	 ( complex( 0,-1504/189 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,191159/2016 ) * np.log( 2 ) + 
 	 complex( 0,-673/126 ) * nu * np.log( 2 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-447/16 ) + 
 	 ( -6325/1344 * np.pi + 
 	 ( complex( 0,-5623151/10080 ) * nu + 
 	 ( 1027/168 * np.pi * nu + 
 	 ( complex( 0,1504/189 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-353819/672 ) * np.log( 2 ) + 
 	 ( complex( 0,1699/84 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,6345/16 ) * np.log( 3 ) + 
 	 complex( 0,-45/4 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-429/16 ) + 
 	 ( -2045/448 * np.pi + 
 	 ( complex( 0,861379/10080 ) * nu + 
 	 ( 263/42 * np.pi * nu + 
 	 ( complex( 0,920711/672 ) * np.log( 2 ) + 
 	 ( complex( 0,-1349/42 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-188163/224 ) * np.log( 3 ) + 
 	 complex( 0,891/28 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,-501/16 ) + 
 	 ( -16183/1344 * np.pi + 
 	 ( complex( 0,-211109/3360 ) * nu + 
 	 ( 1369/168 * np.pi * nu + 
 	 ( complex( 0,-1963307/2016 ) * np.log( 2 ) + 
 	 ( complex( 0,-4933/252 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,2727/16 ) * np.log( 3 ) + 
 	 ( complex( 0,-27/4 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,613625/2016 ) * np.log( 5 ) + 
 	 complex( 0,3125/126 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) ) ) + 
     ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,-10599/256 ) + 
 	 ( 4383283/35840 * np.pi + 
 	 ( complex( 0,-3781718831/2419200 ) * nu + 
 	 ( -252673/26880 * np.pi * nu + 
 	 ( complex( 0,-175639/9072 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,40412251/161280 ) * np.log( 2 ) + 
 	 ( complex( 0,-651527/40320 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,158841/17920 ) * np.log( 3 ) + 
 	 complex( 0,-10377/4480 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,-12489/256 ) + 
 	 ( -500431/64512 * np.pi + 
 	 ( complex( 0,-168070547/69120 ) * nu + 
 	 ( 167341/16128 * np.pi * nu + 
 	 ( complex( 0,-8587/1008 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-58139783/32256 ) * np.log( 2 ) + 
 	 ( complex( 0,1043201/8064 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,1377 ) * np.log( 3 ) + 
 	 complex( 0,-1503/16 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-5147/128 ) + 
 	 ( -219055/32256 * np.pi + 
 	 ( complex( 0,-325429933/241920 ) * nu + 
 	 ( 74539/8064 * np.pi * nu + 
 	 ( complex( 0,85297/3024 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,11217979/1792 ) * np.log( 2 ) + 
 	 ( complex( 0,-569245/1344 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-3471381/896 ) * np.log( 3 ) + 
 	 complex( 0,15945/56 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-5073/128 ) + 
 	 ( -134497/32256 * np.pi + 
 	 ( complex( 0,64447877/241920 ) * nu + 
 	 ( 72731/8064 * np.pi * nu + 
 	 ( complex( 0,-2969/9072 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-183403471/16128 ) * np.log( 2 ) + 
 	 ( complex( 0,2846033/4032 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,5609547/1792 ) * np.log( 3 ) + 
 	 ( complex( 0,-113625/448 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,22545875/8064 ) * np.log( 5 ) + 
 	 complex( 0,-115625/1008 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) + 
     ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,-9075/256 ) + 
 	 ( -73769/21504 * np.pi + 
 	 ( complex( 0,3155465/10752 ) * nu + 
 	 ( 55913/5376 * np.pi * nu + 
 	 ( complex( 0,42181949/4608 ) * np.log( 2 ) + 
 	 ( complex( 0,-584993/1152 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,2026053/896 ) * np.log( 3 ) + 
 	 ( complex( 0,-1503/56 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-176228375/32256 ) * np.log( 5 ) + 
 	 complex( 0,2084375/8064 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,-16901/256 ) + 
 	 ( -203251/9216 * np.pi + 
 	 ( complex( 0,-77092807/345600 ) * nu + 
 	 ( 39193/2304 * np.pi * nu + 
 	 ( complex( 0,-143300477/53760 ) * np.log( 2 ) + 
 	 ( complex( 0,325579/13440 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-1226223/448 ) * np.log( 3 ) + 
 	 ( complex( 0,1761/28 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,919125/896 ) * np.log( 5 ) + 
 	 ( complex( 0,-15625/336 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,38035613/23040 ) * np.log( 7 ) + 
 	 complex( 0,117649/5760 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-177/4 ) + 
 	 ( -113761/24192 * np.pi + 
 	 ( complex( 0,-3714541/6720 ) * nu + 
 	 ( 253265/24192 * np.pi * nu + 
 	 ( complex( 0,-5851/432 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-32693669/1512 ) * np.log( 2 ) + 
 	 ( complex( 0,1218593/756 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,5561757/896 ) * np.log( 3 ) + 
 	 ( complex( 0,-501453/896 ) * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-611/10 ) + 
 	 ( -3783/320 * np.pi + 
 	 ( complex( 0,-2415997141/504000 ) * nu + 
 	 ( 37729/2880 * np.pi * nu + 
 	 ( complex( 0,-131717/9072 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-3710689/1260 ) * np.log( 2 ) + 
 	 ( complex( 0,395911/1680 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,10026567/4480 ) * np.log( 3 ) + 
 	 complex( 0,-775041/4480 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-739/16 ) + 
 	 ( -214073/16128 * np.pi + 
 	 ( complex( 0,-21480407/7560 ) * nu + 
 	 ( 186323/16128 * np.pi * nu + 
 	 ( complex( 0,73085/6048 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,21863689/2016 ) * np.log( 2 ) + 
 	 ( complex( 0,-1709585/2016 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-12073347/1792 ) * np.log( 3 ) + 
 	 complex( 0,999261/1792 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,-5079/80 ) + 
 	 ( 46553861/241920 * np.pi + 
 	 ( complex( 0,-686906611/403200 ) * nu + 
 	 ( -3802027/241920 * np.pi * nu + 
 	 ( complex( 0,-681661/24192 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,11023927/30240 ) * np.log( 2 ) + 
 	 ( complex( 0,-133255/6048 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,190971/8960 ) * np.log( 3 ) + 
 	 ( complex( 0,-44721/8960 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,28387/1890 ) * np.log( 4 ) + 
 	 complex( 0,-3622/945 ) * nu * np.log( 4 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( complex( 0,124010125/24192 ) * np.log( 5 ) + 
 	 ( complex( 0,-7090625/24192 ) * nu * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-709/16 ) + 
 	 ( -2429/576 * np.pi + 
 	 ( complex( 0,184865/432 ) * nu + 
 	 ( 6067/576 * np.pi * nu + 
 	 ( complex( 0,-5899/36288 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,2149273/96 ) * np.log( 2 ) + 
 	 ( complex( 0,-474119/288 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,3725739/896 ) * np.log( 3 ) + 
 	 ( complex( 0,-84471/896 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-9555875/768 ) * np.log( 5 ) + 
 	 complex( 0,1834375/2304 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) +
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,-739/20 ) + 
 	 ( -1123/840 * np.pi + 
 	 ( complex( 0,21076961/37800 ) * nu + 
 	 ( 128299/10080 * np.pi * nu + 
 	 ( complex( 0,-17518111/1260 ) * np.log( 2 ) + 
 	 ( complex( 0,3836549/5040 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-102979593/8960 ) * np.log( 3 ) + 
 	 ( complex( 0,5374791/8960 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,117328375/16128 ) * np.log( 5 ) + 
 	 ( complex( 0,-890625/1792 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,62741903/11520 ) * np.log( 7 ) + 
 	 complex( 0,-2000033/11520 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,-7557/80 ) + 
 	 ( -198661/6720 * np.pi + 
 	 ( complex( 0,-451473527/1008000 ) * nu + 
 	 ( 159743/6720 * np.pi * nu + 
 	 ( complex( 0,51609541/4320 ) * np.log( 2 ) + 
 	 ( complex( 0,-879077/4320 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,3700323/1792 ) * np.log( 3 ) + 
 	 ( complex( 0,-900477/8960 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,1007375/24192 ) * np.log( 5 ) + 
 	 ( complex( 0,-146875/24192 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,-62741903/11520 ) * np.log( 7 ) + 
 	 complex( 0,2000033/11520 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 3 ) * ( 27027409/646800 + 
 	 ( complex( 0,428/105 ) * np.pi + 
 	 ( 2/3 * ( np.pi )**( 2 ) + 
 	 ( -856/105 * gamma + 
 	 ( -278185/33264 * nu + 
 	 ( 41/96 * ( np.pi )**( 2 ) * nu + 
 	 ( -20261/2772 * ( nu )**( 2 ) + 
 	 ( 114635/99792 * ( nu )**( 3 ) + 
 	 ( -1712/105 * np.log( 2 ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,-5 ) * xi ) * ( 1023246543653/638668800 + 
 	 ( complex( 0,3521477/23040 ) * np.pi + 
 	 ( 230377/9216 * ( np.pi )**( 2 ) + 
 	 ( -3521477/11520 * gamma + 
 	 ( 1122957263/1064448 * nu + 
 	 ( -1691701/36864 * ( np.pi )**( 2 ) * nu + 
 	 ( -106366543/1596672 * ( nu )**( 2 ) + 
 	 ( -2622530395/153280512 * ( nu )**( 3 ) + 
 	 ( 466953457/403200 * np.log( 2 ) + 
 	 ( complex( 0,-2222607/1280 ) * np.pi * np.log( 2 ) + 
 	 ( -6749741/3840 * ( np.log( 2 ) )**( 2 ) + 
 	 ( 831069/560 * np.log( 3 ) + 
 	 ( complex( 0,-23301/16 ) * np.pi * np.log( 3 ) + 
 	 ( 27/8 * np.log( 2 ) * np.log( 3 ) + 
 	 ( 23301/16 * ( np.log( 3 ) )**( 2 ) + 
 	 ( -334375/1344 * np.log( 5 ) + 
 	 ( complex( 0,15625/64 ) * np.pi * np.log( 5 ) + 
 	 ( 15625/32 * np.log( 2 ) * np.log( 5 ) + 
 	 ( -15625/64 * ( np.log( 5 ) )**( 2 ) + 
 	 ( -88119101/57600 * np.log( 7 ) + 
 	 ( complex( 0,5764801/3840 ) * np.pi * np.log( 7 ) + 
 	 ( 5764801/1920 * np.log( 2 ) * np.log( 7 ) + 
 	 ( -5764801/3840 * ( np.log( 7 ) )**( 2 ) + 
 	 -3521477/23040 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 5894091113/9676800 + 
 	 ( complex( 0,514349/11520 ) * np.pi + 
 	 ( 33649/4608 * ( np.pi )**( 2 ) + 
 	 ( -514349/5760 * gamma + 
 	 ( -583640093/1451520 * nu + 
 	 ( complex( 0,-29/1512 ) * np.pi * nu + 
 	 ( 451451/73728 * ( np.pi )**( 2 ) * nu + 
 	 ( 2434895/145152 * ( nu )**( 2 ) + 
 	 ( -35629553/6967296 * ( nu )**( 3 ) + 
 	 ( 2719833/896 * np.log( 2 ) + 
 	 ( complex( 0,-1211153/384 ) * np.pi * np.log( 2 ) + 
 	 ( -56081/384 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -540243/896 * np.log( 3 ) + 
 	 ( complex( 0,75735/128 ) * np.pi * np.log( 3 ) + 
 	 ( 75735/64 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -75735/128 * ( np.log( 3 ) )**( 2 ) + 
 	 ( -4346875/4032 * np.log( 5 ) + 
 	 ( complex( 0,203125/192 ) * np.pi * np.log( 5 ) + 
 	 ( 203125/96 * np.log( 2 ) * np.log( 5 ) + 
 	 ( -203125/192 * ( np.log( 5 ) )**( 2 ) + 
 	 -514349/11520 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( 999566924003/2235340800 + 
 	 ( complex( 0,3333371/80640 ) * np.pi + 
 	 ( 31069/4608 * ( np.pi )**( 2 ) + 
 	 ( -3324383/40320 * gamma + 
 	 ( -178945301/506880 * nu + 
 	 ( complex( 0,3121/1512 ) * np.pi * nu + 
 	 ( 475313/73728 * ( np.pi )**( 2 ) * nu + 
 	 ( 206198197/6386688 * ( nu )**( 2 ) + 
 	 ( -262791967/76640256 * ( nu )**( 3 ) + 
 	 ( -63658687/40320 * np.log( 2 ) + 
 	 ( complex( 0,177573/128 ) * np.pi * np.log( 2 ) + 
 	 ( 49475/384 * ( np.log( 2 ) )**( 2 ) + 
 	 ( 1711251/2240 * np.log( 3 ) + 
 	 ( complex( 0,-47979/64 ) * np.pi * np.log( 3 ) + 
 	 ( -47979/32 * np.log( 2 ) * np.log( 3 ) + 
 	 ( 47979/64 * ( np.log( 3 ) )**( 2 ) + 
 	 -3324383/80640 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( 374231745511/496742400 + 
 	 ( complex( 0,6233713/161280 ) * np.pi + 
 	 ( 6733/1024 * ( np.pi )**( 2 ) + 
 	 ( -720431/8960 * gamma + 
 	 ( -1730857169/2661120 * nu + 
 	 ( complex( 0,-1381/1512 ) * np.pi * nu + 
 	 ( 166337/24576 * ( np.pi )**( 2 ) * nu + 
 	 ( 10069373/266112 * ( nu )**( 2 ) + 
 	 ( -452818469/51093504 * ( nu )**( 3 ) + 
 	 ( 12543289/80640 * np.log( 2 ) + 
 	 ( complex( 0,-237619/768 ) * np.pi * np.log( 2 ) + 
 	 ( -238421/768 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -66447/224 * np.log( 3 ) + 
 	 ( complex( 0,9315/32 ) * np.pi * np.log( 3 ) + 
 	 ( 9315/16 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -9315/32 * ( np.log( 3 ) )**( 2 ) + 
 	 -720431/17920 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 15182758817/30412800 + 
 	 ( complex( 0,299279/7680 ) * np.pi + 
 	 ( 19579/3072 * ( np.pi )**( 2 ) + 
 	 ( -299279/3840 * gamma + 
 	 ( -5235557539/21288960 * nu + 
 	 ( 2829/512 * ( np.pi )**( 2 ) * nu + 
 	 ( -115834225/4257792 * ( nu )**( 2 ) + 
 	 ( -16136275/1892352 * ( nu )**( 3 ) + 
 	 ( -53595551/16128 * np.log( 2 ) + 
 	 ( complex( 0,2386991/768 ) * np.pi * np.log( 2 ) + 
 	 ( 1059887/768 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -453573/320 * np.log( 3 ) + 
 	 ( complex( 0,89019/64 ) * np.pi * np.log( 3 ) + 
 	 ( -4293/32 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -89019/64 * ( np.log( 3 ) )**( 2 ) + 
 	 ( 35778125/16128 * np.log( 5 ) + 
 	 ( complex( 0,-1671875/768 ) * np.pi * np.log( 5 ) + 
 	 ( -1671875/384 * np.log( 2 ) * np.log( 5 ) + 
 	 ( 1671875/768 * ( np.log( 5 ) )**( 2 ) + 
 	 -299279/7680 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,5 ) * xi ) * ( -745940868881/496742400 + 
 	 ( complex( 0,3387941/89600 ) * np.pi + 
 	 ( 53077/9216 * ( np.pi )**( 2 ) + 
 	 ( -5679239/80640 * gamma + 
 	 ( 14000998499/12773376 * nu + 
 	 ( complex( 0,-1711/1512 ) * np.pi * nu + 
 	 ( -1192157/73728 * ( np.pi )**( 2 ) * nu + 
 	 ( -4649948663/12773376 * ( nu )**( 2 ) + 
 	 ( 1078514177/153280512 * ( nu )**( 3 ) + 
 	 ( -20619649/134400 * np.log( 2 ) + 
 	 ( complex( 0,35449/3840 ) * np.pi * np.log( 2 ) + 
 	 ( 47351/3840 * ( np.log( 2 ) )**( 2 ) + 
 	 ( 49113/44800 * np.log( 3 ) + 
 	 ( complex( 0,1377/1280 ) * np.pi * np.log( 3 ) + 
 	 ( -1377/640 * np.log( 2 ) * np.log( 3 ) + 
 	 ( 1377/1280 * ( np.log( 3 ) )**( 2 ) + 
 	 -5679239/161280 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 1490703301/2822400 + 
 	 ( complex( 0,172163/3360 ) * np.pi + 
 	 ( 1609/192 * ( np.pi )**( 2 ) + 
 	 ( -172163/1680 * gamma + 
 	 ( 1685011/6720 * nu + 
 	 ( -23247/2048 * ( np.pi )**( 2 ) * nu + 
 	 ( -83557/3024 * ( nu )**( 2 ) + 
 	 ( -181117/32256 * ( nu )**( 3 ) + 
 	 ( 2109719/5040 * np.log( 2 ) + 
 	 ( complex( 0,-29371/48 ) * np.pi * np.log( 2 ) + 
 	 ( -4795/48 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -8667/280 * np.log( 3 ) + 
 	 ( complex( 0,243/8 ) * np.pi * np.log( 3 ) + 
 	 ( 243/4 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -243/8 * ( np.log( 3 ) )**( 2 ) + 
 	 ( -334375/1008 * np.log( 5 ) + 
 	 ( complex( 0,15625/48 ) * np.pi * np.log( 5 ) + 
 	 ( 15625/24 * np.log( 2 ) * np.log( 5 ) + 
 	 ( -15625/48 * ( np.log( 5 ) )**( 2 ) + 
 	 -172163/3360 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 29596324927/93139200 + 
 	 ( complex( 0,86777/3360 ) * np.pi + 
 	 ( 811/192 * ( np.pi )**( 2 ) + 
 	 ( -86777/1680 * gamma + 
 	 ( -31314713/190080 * nu + 
 	 ( 17425/6144 * ( np.pi )**( 2 ) * nu + 
 	 ( -1917163/266112 * ( nu )**( 2 ) + 
 	 ( -7265101/3193344 * ( nu )**( 3 ) + 
 	 ( -351923/560 * np.log( 2 ) + 
 	 ( complex( 0,8245/16 ) * np.pi * np.log( 2 ) + 
 	 ( 53/16 * ( np.log( 2 ) )**( 2 ) + 
 	 ( 147339/560 * np.log( 3 ) + 
 	 ( complex( 0,-4131/16 ) * np.pi * np.log( 3 ) + 
 	 ( -4131/8 * np.log( 2 ) * np.log( 3 ) + 
 	 ( 4131/16 * ( np.log( 3 ) )**( 2 ) + 
 	 -86777/3360 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( 7012075729/31046400 + 
 	 ( complex( 0,25359/1120 ) * np.pi + 
 	 ( 237/64 * ( np.pi )**( 2 ) + 
 	 ( -25359/560 * gamma + 
 	 ( -13220077/73920 * nu + 
 	 ( complex( 0,29/63 ) * np.pi * nu + 
 	 ( 7011/2048 * ( np.pi )**( 2 ) * nu + 
 	 ( -9795/2464 * ( nu )**( 2 ) + 
 	 ( -1396459/1064448 * ( nu )**( 3 ) + 
 	 ( 84851/1680 * np.log( 2 ) + 
 	 ( complex( 0,-2215/16 ) * np.pi * np.log( 2 ) + 
 	 ( -2215/16 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -37557/280 * np.log( 3 ) + 
 	 ( complex( 0,1053/8 ) * np.pi * np.log( 3 ) + 
 	 ( 1053/4 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -1053/8 * ( np.log( 3 ) )**( 2 ) + 
 	 -25359/1120 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,3 ) * xi ) * ( -19357323527/93139200 + 
 	 ( complex( 0,177727/10080 ) * np.pi + 
 	 ( 183/64 * ( np.pi )**( 2 ) + 
 	 ( -19581/560 * gamma + 
 	 ( 36062333/443520 * nu + 
 	 ( complex( 0,-29/63 ) * np.pi * nu + 
 	 ( -16933/6144 * ( np.pi )**( 2 ) * nu + 
 	 ( -19613089/266112 * ( nu )**( 2 ) + 
 	 ( 2754901/3193344 * ( nu )**( 3 ) + 
 	 ( -10807/144 * np.log( 2 ) + 
 	 ( complex( 0,227/48 ) * np.pi * np.log( 2 ) + 
 	 ( 241/48 * ( np.log( 2 ) )**( 2 ) + 
 	 -19581/1120 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 219775769/1663200 + 
 	 ( complex( 0,749/60 ) * np.pi + 
 	 ( 49/24 * ( np.pi )**( 2 ) + 
 	 ( -749/30 * gamma + 
 	 ( -121717/20790 * nu + 
 	 ( -41/192 * ( np.pi )**( 2 ) * nu + 
 	 ( -86531/8316 * ( nu )**( 2 ) + 
 	 ( -33331/399168 * ( nu )**( 3 ) + 
 	 ( -1819/210 * np.log( 2 ) + 
 	 ( complex( 0,-81/2 ) * np.pi * np.log( 2 ) + 
 	 ( -81/2 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -2889/70 * np.log( 3 ) + 
 	 ( complex( 0,81/2 ) * np.pi * np.log( 3 ) + 
 	 ( 81 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -81/2 * ( np.log( 3 ) )**( 2 ) + 
 	 -749/60 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( 55608313/1058400 + 
 	 ( complex( 0,3103/420 ) * np.pi + 
 	 ( 29/24 * ( np.pi )**( 2 ) + 
 	 ( -3103/210 * gamma + 
 	 ( -199855/3024 * nu + 
 	 ( 41/48 * ( np.pi )**( 2 ) * nu + 
 	 ( -9967/1008 * ( nu )**( 2 ) + 
 	 ( 35579/36288 * ( nu )**( 3 ) + 
 	 ( -6527/210 * np.log( 2 ) + 
 	 ( complex( 0,3/2 ) * np.pi * np.log( 2 ) + 
 	 ( 3/2 * ( np.log( 2 ) )**( 2 ) + 
 	 -3103/420 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( 1523147009/2661120 + 
 	 ( complex( 0,462347/8640 ) * np.pi + 
 	 ( 35/4 * ( np.pi )**( 2 ) + 
 	 ( -107 * gamma + 
 	 ( -112895995/532224 * nu + 
 	 ( complex( 0,-641/672 ) * np.pi * nu + 
 	 ( 2665/768 * ( np.pi )**( 2 ) * nu + 
 	 ( 4185551/133056 * ( nu )**( 2 ) + 
 	 ( -9383735/1596672 * ( nu )**( 3 ) + 
 	 ( 1337179/270 * np.log( 2 ) + 
 	 ( complex( 0,-162239/32 ) * np.pi * np.log( 2 ) + 
 	 ( -4091/18 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -2389203/2240 * np.log( 3 ) + 
 	 ( complex( 0,66987/64 ) * np.pi * np.log( 3 ) + 
 	 ( 66987/32 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -66987/64 * ( np.log( 3 ) )**( 2 ) + 
 	 ( -19728125/12096 * np.log( 5 ) + 
 	 ( complex( 0,921875/576 ) * np.pi * np.log( 5 ) + 
 	 ( 921875/288 * np.log( 2 ) * np.log( 5 ) + 
 	 ( -921875/576 * ( np.log( 5 ) )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( 137078526587/51744000 + 
 	 ( complex( 0,4200713/16800 ) * np.pi + 
 	 ( 39259/960 * ( np.pi )**( 2 ) + 
 	 ( -4200713/8400 * gamma + 
 	 ( 50042307101/26611200 * nu + 
 	 ( -3329733/40960 * ( np.pi )**( 2 ) * nu + 
 	 ( -26363437/266112 * ( nu )**( 2 ) + 
 	 ( -133307197/5322240 * ( nu )**( 3 ) + 
 	 ( -150789857/15120 * np.log( 2 ) + 
 	 ( complex( 0,6339593/720 ) * np.pi * np.log( 2 ) + 
 	 ( -6250999/720 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -12506481/22400 * np.log( 3 ) + 
 	 ( complex( 0,350649/640 ) * np.pi * np.log( 3 ) + 
 	 ( 729/320 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -350649/640 * ( np.log( 3 ) )**( 2 ) + 
 	 ( -334375/12096 * np.log( 5 ) + 
 	 ( complex( 0,15625/576 ) * np.pi * np.log( 5 ) + 
 	 ( 15625/288 * np.log( 2 ) * np.log( 5 ) + 
 	 ( -15625/576 * ( np.log( 5 ) )**( 2 ) + 
 	 ( 88119101/28800 * np.log( 7 ) + 
 	 ( complex( 0,-5764801/1920 ) * np.pi * np.log( 7 ) + 
 	 ( -5764801/960 * np.log( 2 ) * np.log( 7 ) + 
 	 ( 5764801/1920 * ( np.log( 7 ) )**( 2 ) + 
 	 -4200713/16800 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 270820171/352800 + 
 	 ( complex( 0,64093/1120 ) * np.pi + 
 	 ( 599/64 * ( np.pi )**( 2 ) + 
 	 ( -64093/560 * gamma + 
 	 ( -187689179/483840 * nu + 
 	 ( complex( 0,-29/3024 ) * np.pi * nu + 
 	 ( 37351/8192 * ( np.pi )**( 2 ) * nu + 
 	 ( 296771/48384 * ( nu )**( 2 ) + 
 	 ( -290839/41472 * ( nu )**( 3 ) + 
 	 ( -33213121/5040 * np.log( 2 ) + 
 	 ( complex( 0,299621/48 ) * np.pi * np.log( 2 ) + 
 	 ( 36215/16 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -4710033/2240 * np.log( 3 ) + 
 	 ( complex( 0,132057/64 ) * np.pi * np.log( 3 ) + 
 	 ( -19575/32 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -132057/64 * ( np.log( 3 ) )**( 2 ) + 
 	 ( 32434375/8064 * np.log( 5 ) + 
 	 ( complex( 0,-1515625/384 ) * np.pi * np.log( 5 ) + 
 	 ( -1515625/192 * np.log( 2 ) * np.log( 5 ) + 
 	 ( 1515625/384 * ( np.log( 5 ) )**( 2 ) + 
 	 -64093/1120 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 90292317019/58212000 + 
 	 ( complex( 0,4778513/100800 ) * np.pi + 
 	 ( 1027/120 * ( np.pi )**( 2 ) + 
 	 ( -109889/1050 * gamma + 
 	 ( -2491605689/1900800 * nu + 
 	 ( complex( 0,-9223/6048 ) * np.pi * nu + 
 	 ( 361661/30720 * ( np.pi )**( 2 ) * nu + 
 	 ( 85326847/532224 * ( nu )**( 2 ) + 
 	 ( -169240997/7983360 * ( nu )**( 3 ) + 
 	 ( 391834/1575 * np.log( 2 ) + 
 	 ( complex( 0,-70961/160 ) * np.pi * np.log( 2 ) + 
 	 ( -6743/15 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -1197009/2800 * np.log( 3 ) + 
 	 ( complex( 0,132867/320 ) * np.pi * np.log( 3 ) + 
 	 ( 33561/40 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -33561/80 * ( np.log( 3 ) )**( 2 ) + 
 	 -109889/2100 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 308586650569/558835200 + 
 	 ( complex( 0,2041453/40320 ) * np.pi + 
 	 ( 4721/576 * ( np.pi )**( 2 ) + 
 	 ( -505147/5040 * gamma + 
 	 ( -3838426769/7983360 * nu + 
 	 ( complex( 0,13897/24192 ) * np.pi * nu + 
 	 ( 541241/73728 * ( np.pi )**( 2 ) * nu + 
 	 ( 49824815/1596672 * ( nu )**( 2 ) + 
 	 ( -1309163/342144 * ( nu )**( 3 ) + 
 	 ( -11732443/5040 * np.log( 2 ) + 
 	 ( complex( 0,400777/192 ) * np.pi * np.log( 2 ) + 
 	 ( 11887/48 * ( np.log( 2 ) )**( 2 ) + 
 	 ( 5260869/4480 * np.log( 3 ) + 
 	 ( complex( 0,-147501/128 ) * np.pi * np.log( 3 ) + 
 	 ( -147501/64 * np.log( 2 ) * np.log( 3 ) + 
 	 ( 147501/128 * ( np.log( 3 ) )**( 2 ) + 
 	 -505147/10080 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( -2826624953189/931392000 + 
 	 ( complex( 0,33207557/604800 ) * np.pi + 
 	 ( 7589/960 * ( np.pi )**( 2 ) + 
 	 ( -812023/8400 * gamma + 
 	 ( 6266140691/2661120 * nu + 
 	 ( complex( 0,-3335/2016 ) * np.pi * nu + 
 	 ( -3735961/122880 * ( np.pi )**( 2 ) * nu + 
 	 ( -474187663/665280 * ( nu )**( 2 ) + 
 	 ( 147111197/7983360 * ( nu )**( 3 ) + 
 	 ( -3235787/15120 * np.log( 2 ) + 
 	 ( complex( 0,6125/576 ) * np.pi * np.log( 2 ) + 
 	 ( 14603/720 * ( np.log( 2 ) )**( 2 ) + 
 	 ( 49113/22400 * np.log( 3 ) + 
 	 ( complex( 0,1377/640 ) * np.pi * np.log( 3 ) + 
 	 ( -1377/320 * np.log( 2 ) * np.log( 3 ) + 
 	 ( 1377/640 * ( np.log( 3 ) )**( 2 ) + 
 	 ( 9416/4725 * np.log( 4 ) + 
 	 ( complex( 0,88/45 ) * np.pi * np.log( 4 ) + 
 	 ( -176/45 * np.log( 2 ) * np.log( 4 ) + 
 	 ( 88/45 * ( np.log( 4 ) )**( 2 ) + 
 	 -812023/16800 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 623997833051/1397088000 + 
 	 ( complex( 0,192707/6300 ) * np.pi + 
 	 ( 1801/360 * ( np.pi )**( 2 ) + 
 	 ( -192707/3150 * gamma + 
 	 ( -1886302361/3991680 * nu + 
 	 ( 1384037/92160 * ( np.pi )**( 2 ) * nu + 
 	 ( -316527109/7983360 * ( nu )**( 2 ) + 
 	 ( -11054693/748440 * ( nu )**( 3 ) + 
 	 ( 17394241/3150 * np.log( 2 ) + 
 	 ( complex( 0,-33233/6 ) * np.pi * np.log( 2 ) + 
 	 ( -30545/6 * ( np.log( 2 ) )**( 2 ) + 
 	 ( 114979311/22400 * np.log( 3 ) + 
 	 ( complex( 0,-3223719/640 ) * np.pi * np.log( 3 ) + 
 	 ( -891/64 * np.log( 2 ) * np.log( 3 ) + 
 	 ( 3223719/640 * ( np.log( 3 ) )**( 2 ) + 
 	 ( -6353125/2688 * np.log( 5 ) + 
 	 ( complex( 0,296875/128 ) * np.pi * np.log( 5 ) + 
 	 ( 296875/64 * np.log( 2 ) * np.log( 5 ) + 
 	 ( -296875/128 * ( np.log( 5 ) )**( 2 ) + 
 	 ( -88119101/28800 * np.log( 7 ) + 
 	 ( complex( 0,5764801/1920 ) * np.pi * np.log( 7 ) + 
 	 ( 5764801/960 * np.log( 2 ) * np.log( 7 ) + 
 	 ( -5764801/1920 * ( np.log( 7 ) )**( 2 ) + 
 	 -192707/6300 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 -107/2 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( 3006246811/9313920 + 
 	 ( complex( 0,1391/42 ) * np.pi + 
 	 ( 65/12 * ( np.pi )**( 2 ) + 
 	 ( -1391/21 * gamma + 
 	 ( -26431039/266112 * nu + 
 	 ( complex( 0,-29/168 ) * np.pi * nu + 
 	 ( 3239/1536 * ( np.pi )**( 2 ) * nu + 
 	 ( 411151/66528 * ( nu )**( 2 ) + 
 	 ( -2257631/798336 * ( nu )**( 3 ) + 
 	 ( -108712/105 * np.log( 2 ) + 
 	 ( complex( 0,886 ) * np.pi * np.log( 2 ) + 
 	 ( 54 * ( np.log( 2 ) )**( 2 ) + 
 	 ( 66447/140 * np.log( 3 ) + 
 	 ( complex( 0,-1863/4 ) * np.pi * np.log( 3 ) + 
 	 ( -1863/2 * np.log( 2 ) * np.log( 3 ) + 
 	 ( 1863/4 * ( np.log( 3 ) )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 131282622323/139708800 + 
 	 ( complex( 0,57031/630 ) * np.pi + 
 	 ( 533/36 * ( np.pi )**( 2 ) + 
 	 ( -57031/315 * gamma + 
 	 ( 548729393/997920 * nu + 
 	 ( -223163/9216 * ( np.pi )**( 2 ) * nu + 
 	 ( -34741549/798336 * ( nu )**( 2 ) + 
 	 ( -6313787/598752 * ( nu )**( 3 ) + 
 	 ( -16799/15 * np.log( 2 ) + 
 	 ( complex( 0,2231/3 ) * np.pi * np.log( 2 ) + 
 	 ( 1655/3 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -29853/40 * np.log( 3 ) + 
 	 ( complex( 0,5859/8 ) * np.pi * np.log( 3 ) + 
 	 ( 27/4 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -5859/8 * ( np.log( 3 ) )**( 2 ) + 
 	 ( 334375/504 * np.log( 5 ) + 
 	 ( complex( 0,-15625/24 ) * np.pi * np.log( 5 ) + 
 	 ( -15625/12 * np.log( 2 ) * np.log( 5 ) + 
 	 ( 15625/24 * ( np.log( 5 ) )**( 2 ) + 
 	 -57031/630 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 29913154181/69854400 + 
 	 ( complex( 0,43763/1260 ) * np.pi + 
 	 ( 409/72 * ( np.pi )**( 2 ) + 
 	 ( -43763/630 * gamma + 
 	 ( -85085639/498960 * nu + 
 	 ( 12341/4608 * ( np.pi )**( 2 ) * nu + 
 	 ( -1125233/66528 * ( nu )**( 2 ) + 
 	 ( -5732197/1197504 * ( nu )**( 3 ) + 
 	 ( 1033513/630 * np.log( 2 ) + 
 	 ( complex( 0,-10477/6 ) * np.pi * np.log( 2 ) + 
 	 ( -493/6 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -37557/140 * np.log( 3 ) + 
 	 ( complex( 0,1053/4 ) * np.pi * np.log( 3 ) + 
 	 ( 1053/2 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -1053/4 * ( np.log( 3 ) )**( 2 ) + 
 	 ( -334375/504 * np.log( 5 ) + 
 	 ( complex( 0,15625/24 ) * np.pi * np.log( 5 ) + 
 	 ( 15625/12 * np.log( 2 ) * np.log( 5 ) + 
 	 ( -15625/24 * ( np.log( 5 ) )**( 2 ) + 
 	 -43763/1260 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 27122687651/69854400 + 
 	 ( complex( 0,8453/280 ) * np.pi + 
 	 ( 359/72 * ( np.pi )**( 2 ) + 
 	 ( -38413/630 * gamma + 
 	 ( -167972011/498960 * nu + 
 	 ( complex( 0,-473/1512 ) * np.pi * nu + 
 	 ( 20623/4608 * ( np.pi )**( 2 ) * nu + 
 	 ( 57403/199584 * ( nu )**( 2 ) + 
 	 ( -4225115/1197504 * ( nu )**( 3 ) + 
 	 ( 6527/70 * np.log( 2 ) + 
 	 ( complex( 0,-2527/12 ) * np.pi * np.log( 2 ) + 
 	 ( -1267/6 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -56817/280 * np.log( 3 ) + 
 	 ( complex( 0,1593/8 ) * np.pi * np.log( 3 ) + 
 	 ( 1593/4 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -1593/8 * ( np.log( 3 ) )**( 2 ) + 
 	 -38413/1260 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -22662221353/34927200 + 
 	 ( complex( 0,65377/2520 ) * np.pi + 
 	 ( 37/9 * ( np.pi )**( 2 ) + 
 	 ( -15836/315 * gamma + 
 	 ( 1657156441/3991680 * nu + 
 	 ( complex( 0,-377/504 ) * np.pi * nu + 
 	 ( -70315/9216 * ( np.pi )**( 2 ) * nu + 
 	 ( -45937741/266112 * ( nu )**( 2 ) + 
 	 ( 5581397/2395008 * ( nu )**( 3 ) + 
 	 ( -34133/315 * np.log( 2 ) + 
 	 ( complex( 0,85/12 ) * np.pi * np.log( 2 ) + 
 	 ( 23/3 * ( np.log( 2 ) )**( 2 ) + 
 	 -7918/315 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 -1391/42 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( 148112893/1058400 + 
 	 ( complex( 0,1712/105 ) * np.pi + 
 	 ( 8/3 * ( np.pi )**( 2 ) + 
 	 ( -3424/105 * gamma + 
 	 ( -35837/1440 * nu + 
 	 ( 205/192 * ( np.pi )**( 2 ) * nu + 
 	 ( -4279/504 * ( nu )**( 2 ) + 
 	 ( -1183/2592 * ( nu )**( 3 ) + 
 	 ( 428/21 * np.log( 2 ) + 
 	 ( complex( 0,-84 ) * np.pi * np.log( 2 ) + 
 	 ( -84 * ( np.log( 2 ) )**( 2 ) + 
 	 ( -2889/35 * np.log( 3 ) + 
 	 ( complex( 0,81 ) * np.pi * np.log( 3 ) + 
 	 ( 162 * np.log( 2 ) * np.log( 3 ) + 
 	 ( -81 * ( np.log( 3 ) )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 6487472689/23284800 + 
 	 ( complex( 0,5671/210 ) * np.pi + 
 	 ( 53/12 * ( np.pi )**( 2 ) + 
 	 ( -5671/105 * gamma + 
 	 ( 18175769/221760 * nu + 
 	 ( -779/192 * ( np.pi )**( 2 ) * nu + 
 	 ( -1137721/66528 * ( nu )**( 2 ) + 
 	 ( -883591/399168 * ( nu )**( 3 ) + 
 	 ( -321 * np.log( 2 ) + 
 	 ( complex( 0,209 ) * np.pi * np.log( 2 ) + 
 	 ( -47 * ( np.log( 2 ) )**( 2 ) + 
 	 ( 2889/35 * np.log( 3 ) + 
 	 ( complex( 0,-81 ) * np.pi * np.log( 3 ) + 
 	 ( -162 * np.log( 2 ) * np.log( 3 ) + 
 	 ( 81 * ( np.log( 3 ) )**( 2 ) + 
 	 -5671/210 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -69767507/7761600 + 
 	 ( complex( 0,2461/210 ) * np.pi + 
 	 ( 23/12 * ( np.pi )**( 2 ) + 
 	 ( -2461/105 * gamma + 
 	 ( -33218051/665280 * nu + 
 	 ( complex( 0,-29/126 ) * np.pi * nu + 
 	 ( -41/192 * ( np.pi )**( 2 ) * nu + 
 	 ( -260701/9504 * ( nu )**( 2 ) + 
 	 ( 295943/399168 * ( nu )**( 3 ) + 
 	 ( -749/15 * np.log( 2 ) + 
 	 ( complex( 0,3 ) * np.pi * np.log( 2 ) + 
 	 ( 3 * ( np.log( 2 ) )**( 2 ) + 
 	 -2461/210 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 -1712/105 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 -428/105 * np.log( x ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    return(h)

# %% [markdown]
# ## Amplitude $(\ell, m)$ = (2, 1)

# %%
# ## Amplitude $(\ell, m)$ = (2, 1)

def amplitude_21(xi, x, nu, Delta, e):
    
    h = ( ( x )**( 1/2 ) * ( complex( 0,1/3 ) * Delta + 
 	 ( e * ( complex( 0,1/3 ) * ( np.e )**( complex( 0,-1 ) * xi ) * Delta + 
 	 complex( 0,1/3 ) * ( np.e )**( complex( 0,1 ) * xi ) * Delta ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,5/12 ) * ( np.e )**( complex( 0,-2 ) * xi ) * Delta + 
 	 complex( 0,5/12 ) * ( np.e )**( complex( 0,2 ) * xi ) * Delta ) + 
 	 ( ( e )**( 3 ) * ( complex( 0,-1/24 ) * ( np.e )**( complex( 0,-1 ) * xi ) * Delta + 
 	 ( complex( 0,-1/24 ) * ( np.e )**( complex( 0,1 ) * xi ) * Delta + 
 	 ( complex( 0,13/24 ) * ( np.e )**( complex( 0,-3 ) * xi ) * Delta + 
 	 complex( 0,13/24 ) * ( np.e )**( complex( 0,3 ) * xi ) * Delta ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-11/72 ) * ( np.e )**( complex( 0,-2 ) * xi ) * Delta + 
 	 ( complex( 0,-11/72 ) * ( np.e )**( complex( 0,2 ) * xi ) * Delta + 
 	 ( complex( 0,103/144 ) * ( np.e )**( complex( 0,-4 ) * xi ) * Delta + 
 	 complex( 0,103/144 ) * ( np.e )**( complex( 0,4 ) * xi ) * Delta ) ) ) + 
 	 ( ( e )**( 5 ) * ( complex( 0,5/576 ) * ( np.e )**( complex( 0,-1 ) * xi ) * Delta + 
 	 ( complex( 0,5/576 ) * ( np.e )**( complex( 0,1 ) * xi ) * Delta + 
 	 ( complex( 0,-43/128 ) * ( np.e )**( complex( 0,-3 ) * xi ) * Delta + 
 	 ( complex( 0,-43/128 ) * ( np.e )**( complex( 0,3 ) * xi ) * Delta + 
 	 ( complex( 0,1097/1152 ) * ( np.e )**( complex( 0,-5 ) * xi ) * Delta + 
 	 complex( 0,1097/1152 ) * ( np.e )**( complex( 0,5 ) * xi ) * Delta ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,17/576 ) * ( np.e )**( complex( 0,-2 ) * xi ) * Delta + 
 	 ( complex( 0,17/576 ) * ( np.e )**( complex( 0,2 ) * xi ) * Delta + 
 	 ( complex( 0,-451/720 ) * ( np.e )**( complex( 0,-4 ) * xi ) * Delta + 
 	 ( complex( 0,-451/720 ) * ( np.e )**( complex( 0,4 ) * xi ) * Delta + 
 	 ( complex( 0,1223/960 ) * ( np.e )**( complex( 0,-6 ) * xi ) * Delta + 
 	 complex( 0,1223/960 ) * ( np.e )**( complex( 0,6 ) * xi ) * Delta ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 3/2 ) * ( complex( 0,-17/84 ) * Delta + 
 	 ( complex( 0,5/21 ) * Delta * nu + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-43/84 ) * Delta + 
 	 complex( 0,1/42 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,41/28 ) * Delta + 
 	 complex( 0,1/14 ) * Delta * nu ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,-27/56 ) * Delta + 
 	 ( complex( 0,3/14 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,643/168 ) * Delta + 
 	 complex( 0,-13/84 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-187/168 ) * Delta + 
 	 complex( 0,-23/84 ) * Delta * nu ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-835/672 ) * Delta + 
 	 complex( 0,31/112 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-5/672 ) * Delta + 
 	 complex( 0,103/336 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,5065/672 ) * Delta + 
 	 complex( 0,-179/336 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,-1409/672 ) * Delta + 
 	 complex( 0,-257/336 ) * Delta * nu ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-27/56 ) * Delta + 
 	 ( complex( 0,3/14 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-3665/1008 ) * Delta + 
 	 complex( 0,71/126 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,31/48 ) * Delta + 
 	 complex( 0,2/3 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,5963/448 ) * Delta + 
 	 complex( 0,-129/112 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,-14725/4032 ) * Delta + 
 	 complex( 0,-1573/1008 ) * Delta * nu ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-5813/16128 ) * Delta + 
 	 complex( 0,1403/8064 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-4651/16128 ) * Delta + 
 	 complex( 0,1417/8064 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,-31467/3584 ) * Delta + 
 	 complex( 0,2137/1792 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,7211/3584 ) * Delta + 
 	 complex( 0,2603/1792 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,715031/32256 ) * Delta + 
 	 complex( 0,-34505/16128 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,-195479/32256 ) * Delta + 
 	 complex( 0,-45475/16128 ) * Delta * nu ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-27/56 ) * Delta + 
 	 ( complex( 0,3/14 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-113/288 ) * Delta + 
 	 complex( 0,13/192 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,991/4032 ) * Delta + 
 	 complex( 0,335/4032 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-752819/40320 ) * Delta + 
 	 complex( 0,8123/3360 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,26867/5760 ) * Delta + 
 	 complex( 0,4291/1440 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,119563/3360 ) * Delta + 
 	 complex( 0,-24743/6720 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,-9343/960 ) * Delta + 
 	 complex( 0,-4583/960 ) * Delta * nu ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 5/2 ) * ( complex( 0,-43/378 ) * Delta + 
 	 ( complex( 0,-509/378 ) * Delta * nu + 
 	 ( complex( 0,79/504 ) * Delta * ( nu )**( 2 ) + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,2299/756 ) * Delta + 
 	 ( complex( 0,-2509/756 ) * Delta * nu + 
 	 complex( 0,13/252 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-149/378 ) * Delta + 
 	 ( complex( 0,-1685/756 ) * Delta * nu + 
 	 complex( 0,-1/12 ) * Delta * ( nu )**( 2 ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,-6163/3024 ) * Delta + 
 	 ( complex( 0,-1531/378 ) * Delta * nu + 
 	 ( complex( 0,-55/252 ) * Delta * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,66455/6048 ) * Delta + 
 	 ( complex( 0,-25735/3024 ) * Delta * nu + 
 	 complex( 0,169/2016 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-4207/864 ) * Delta + 
 	 ( complex( 0,-7561/3024 ) * Delta * nu + 
 	 complex( 0,-123/224 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-133/32 ) * Delta + 
 	 ( complex( 0,-7505/2016 ) * Delta * nu + 
 	 complex( 0,-281/672 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,743/27 ) * Delta + 
 	 ( complex( 0,-121249/6048 ) * Delta * nu + 
 	 complex( 0,845/2016 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,1585/1512 ) * Delta + 
 	 ( complex( 0,-38179/6048 ) * Delta * nu + 
 	 complex( 0,-985/2016 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,-9887/672 ) * Delta + 
 	 ( complex( 0,-4363/2016 ) * Delta * nu + 
 	 complex( 0,-2825/2016 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-3553/1008 ) * Delta + 
 	 ( complex( 0,-14209/2016 ) * Delta * nu + 
 	 ( complex( 0,-871/1344 ) * Delta * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,213251/36288 ) * Delta + 
 	 ( complex( 0,-159157/18144 ) * Delta * nu + 
 	 complex( 0,-1207/1728 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-534377/36288 ) * Delta + 
 	 ( complex( 0,44161/18144 ) * Delta * nu + 
 	 complex( 0,-4103/4032 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,529549/9072 ) * Delta + 
 	 ( complex( 0,-194513/4536 ) * Delta * nu + 
 	 complex( 0,16675/12096 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,-600449/18144 ) * Delta + 
 	 ( complex( 0,-14113/18144 ) * Delta * nu + 
 	 complex( 0,-1285/448 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,581389/32256 ) * Delta + 
 	 ( complex( 0,-58303/4608 ) * Delta * nu + 
 	 complex( 0,-323/512 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-353711/145152 ) * Delta + 
 	 ( complex( 0,-1302169/145152 ) * Delta * nu + 
 	 complex( 0,-11861/16128 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-37361/36288 ) * Delta + 
 	 ( complex( 0,-1363393/145152 ) * Delta * nu + 
 	 complex( 0,-40177/48384 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,-71507/1728 ) * Delta + 
 	 ( complex( 0,2091085/96768 ) * Delta * nu + 
 	 complex( 0,-82051/32256 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,32673913/290304 ) * Delta + 
 	 ( complex( 0,-3527227/41472 ) * Delta * nu + 
 	 complex( 0,340229/96768 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,-42149/648 ) * Delta + 
 	 ( complex( 0,703691/290304 ) * Delta * nu + 
 	 complex( 0,-24401/4608 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-2165/432 ) * Delta + 
 	 ( complex( 0,-30379/3024 ) * Delta * nu + 
 	 ( complex( 0,-2173/2016 ) * Delta * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,32959489/725760 ) * Delta + 
 	 ( complex( 0,-176021/9072 ) * Delta * nu + 
 	 complex( 0,1987/17280 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-106039/290304 ) * Delta + 
 	 ( complex( 0,-271003/20736 ) * Delta * nu + 
 	 complex( 0,-32089/48384 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-3547/3584 ) * Delta + 
 	 ( complex( 0,-538871/48384 ) * Delta * nu + 
 	 complex( 0,-16399/16128 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-3440683/34560 ) * Delta + 
 	 ( complex( 0,128671/1890 ) * Delta * nu + 
 	 complex( 0,-244921/40320 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,98695759/483840 ) * Delta + 
 	 ( complex( 0,-1101775/6912 ) * Delta * nu + 
 	 complex( 0,19547/2520 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,-57229453/483840 ) * Delta + 
 	 ( complex( 0,2098427/241920 ) * Delta * nu + 
 	 complex( 0,-61829/6720 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 2 ) * ( 1/6 * Delta + 
 	 ( complex( 0,1/3 ) * np.pi * Delta + 
 	 ( 2/3 * Delta * np.log( 2 ) + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 1/2 * Delta + 
 	 ( complex( 0,1 ) * np.pi * Delta + 
 	 -2/3 * Delta * np.log( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( 1/6 * Delta + 
 	 ( complex( 0,1/3 ) * np.pi * Delta + 
 	 2/3 * Delta * np.log( 2 ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( 1/3 * Delta + 
 	 ( complex( 0,2/3 ) * np.pi * Delta + 
 	 ( -4/3 * Delta * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 1/6 * Delta + 
 	 ( complex( 0,5/12 ) * np.pi * Delta + 
 	 2/3 * Delta * np.log( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( Delta + 
 	 ( complex( 0,2 ) * np.pi * Delta + 
 	 ( 20/3 * Delta * np.log( 2 ) + 
 	 -27/4 * Delta * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 19/48 * Delta + 
 	 ( complex( 0,17/24 ) * np.pi * Delta + 
 	 -17/12 * Delta * np.log( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( 7/48 * Delta + 
 	 ( complex( 0,43/72 ) * np.pi * Delta + 
 	 29/36 * Delta * np.log( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 17/48 * Delta + 
 	 ( complex( 0,17/24 ) * np.pi * Delta + 
 	 ( 89/12 * Delta * np.log( 2 ) + 
 	 -27/4 * Delta * np.log( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( 85/48 * Delta + 
 	 ( complex( 0,85/24 ) * np.pi * Delta + 
 	 ( -757/36 * Delta * np.log( 2 ) + 
 	 27/4 * Delta * np.log( 3 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( 7/16 * Delta + 
 	 ( complex( 0,83/96 ) * np.pi * Delta + 
 	 ( 101/12 * Delta * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 1/2 * Delta + 
 	 ( complex( 0,49/72 ) * np.pi * Delta + 
 	 -16/9 * Delta * np.log( 2 ) ) ) + 
 	 ( -243/32 * Delta * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 25/288 * Delta + 
 	 ( complex( 0,175/192 ) * np.pi * Delta + 
 	 ( 41/72 * Delta * np.log( 2 ) + 
 	 27/64 * Delta * np.log( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 7/36 * Delta + 
 	 ( complex( 0,7/18 ) * np.pi * Delta + 
 	 ( -31 * Delta * np.log( 2 ) + 
 	 135/8 * Delta * np.log( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( 283/96 * Delta + 
 	 ( complex( 0,283/48 ) * np.pi * Delta + 
 	 ( 971/24 * Delta * np.log( 2 ) + 
 	 ( 27/32 * Delta * np.log( 3 ) + 
 	 -15625/576 * Delta * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 61/128 * Delta + 
 	 ( complex( 0,541/576 ) * np.pi * Delta + 
 	 ( 2917/288 * Delta * np.log( 2 ) + 
 	 -9 * Delta * np.log( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( 521/768 * Delta + 
 	 ( complex( 0,69/128 ) * np.pi * Delta + 
 	 ( -1097/576 * Delta * np.log( 2 ) + 
 	 -27/64 * Delta * np.log( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 559/1152 * Delta + 
 	 ( complex( 0,185/192 ) * np.pi * Delta + 
 	 ( -9973/288 * Delta * np.log( 2 ) + 
 	 297/16 * Delta * np.log( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( -83/2304 * Delta + 
 	 ( complex( 0,8191/5760 ) * np.pi * Delta + 
 	 ( 61/576 * Delta * np.log( 2 ) + 
 	 ( 27/64 * Delta * np.log( 3 ) + 
 	 32/45 * Delta * np.log( 4 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( -253/768 * Delta + 
 	 ( complex( 0,-253/384 ) * np.pi * Delta + 
 	 ( 14675/192 * Delta * np.log( 2 ) + 
 	 ( -81/8 * Delta * np.log( 3 ) + 
 	 -15625/576 * Delta * np.log( 5 ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( 3629/768 * Delta + 
 	 ( complex( 0,3629/384 ) * np.pi * Delta + 
 	 ( -74753/2880 * Delta * np.log( 2 ) + 
 	 ( -3843/80 * Delta * np.log( 3 ) + 
 	 15625/576 * Delta * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( 25/48 * Delta + 
 	 ( complex( 0,887/864 ) * np.pi * Delta + 
 	 ( -503/12 * Delta * np.log( 2 ) + 
 	 ( 729/32 * Delta * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 289/576 * Delta + 
 	 ( complex( 0,2353/2304 ) * np.pi * Delta + 
 	 ( 611/48 * Delta * np.log( 2 ) + 
 	 -1413/128 * Delta * np.log( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 1417/1440 * Delta + 
 	 ( complex( 0,509/2880 ) * np.pi * Delta + 
 	 ( -647/360 * Delta * np.log( 2 ) + 
 	 ( -189/320 * Delta * np.log( 3 ) + 
 	 -32/45 * Delta * np.log( 4 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 323/576 * Delta + 
 	 ( complex( 0,5141/4608 ) * np.pi * Delta + 
 	 ( 4249/48 * Delta * np.log( 2 ) + 
 	 ( -7857/512 * Delta * np.log( 3 ) + 
 	 -15625/512 * Delta * np.log( 5 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( -251/960 * Delta + 
 	 ( complex( 0,153793/69120 ) * np.pi * Delta + 
 	 ( -1619/2160 * Delta * np.log( 2 ) + 
 	 ( 243/512 * Delta * np.log( 3 ) + 
 	 ( 32/45 * Delta * np.log( 4 ) + 
 	 15625/13824 * Delta * np.log( 5 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( -2191/1440 * Delta + 
 	 ( complex( 0,-2191/720 ) * np.pi * Delta + 
 	 ( -37727/360 * Delta * np.log( 2 ) + 
 	 ( -8001/160 * Delta * np.log( 3 ) + 
 	 15625/192 * Delta * np.log( 5 ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( 7087/960 * Delta + 
 	 ( complex( 0,7087/480 ) * np.pi * Delta + 
 	 ( 174263/2160 * Delta * np.log( 2 ) + 
 	 ( 125631/2560 * Delta * np.log( 3 ) + 
 	 ( 15625/4608 * Delta * np.log( 5 ) + 
 	 -5764801/69120 * Delta * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 3 ) * ( -17/168 * Delta + 
 	 ( complex( 0,-17/84 ) * np.pi * Delta + 
 	 ( 353/84 * Delta * nu + 
 	 ( complex( 0,1/14 ) * np.pi * Delta * nu + 
 	 ( -17/42 * Delta * np.log( 2 ) + 
 	 ( 1/7 * Delta * nu * np.log( 2 ) + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 41/56 * Delta + 
 	 ( complex( 0,41/28 ) * np.pi * Delta + 
 	 ( 19493/630 * Delta * nu + 
 	 ( complex( 0,-2/21 ) * np.pi * Delta * nu + 
 	 ( 41/14 * Delta * np.log( 2 ) + 
 	 -4/21 * Delta * nu * np.log( 2 ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( 541/168 * Delta + 
 	 ( complex( 0,-131/84 ) * np.pi * Delta + 
 	 ( -292/45 * Delta * nu + 
 	 ( complex( 0,-8/21 ) * np.pi * Delta * nu + 
 	 ( -41/14 * Delta * np.log( 2 ) + 
 	 4/21 * Delta * nu * np.log( 2 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( 549/112 * Delta + 
 	 ( complex( 0,101/56 ) * np.pi * Delta + 
 	 ( 1523/84 * Delta * nu + 
 	 ( complex( 0,-5/14 ) * np.pi * Delta * nu + 
 	 ( -267/28 * Delta * np.log( 2 ) + 
 	 ( 11/7 * Delta * nu * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 99/224 * Delta + 
 	 ( complex( 0,601/168 ) * np.pi * Delta + 
 	 ( 110371/1512 * Delta * nu + 
 	 ( complex( 0,-61/168 ) * np.pi * Delta * nu + 
 	 ( 211/56 * Delta * np.log( 2 ) + 
 	 -2/7 * Delta * nu * np.log( 2 ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( 691/96 * Delta + 
 	 ( complex( 0,-221/48 ) * np.pi * Delta + 
 	 ( -22315/1512 * Delta * nu + 
 	 ( complex( 0,-2 ) * np.pi * Delta * nu + 
 	 ( 661/168 * Delta * np.log( 2 ) + 
 	 ( -44/7 * Delta * nu * np.log( 2 ) + 
 	 ( -351/112 * Delta * np.log( 3 ) + 
 	 351/56 * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( -2321/1344 * Delta + 
 	 ( complex( 0,17803/2016 ) * np.pi * Delta + 
 	 ( 71111/504 * Delta * nu + 
 	 ( complex( 0,-173/168 ) * np.pi * Delta * nu + 
 	 ( 6317/1008 * Delta * np.log( 2 ) + 
 	 -53/84 * Delta * nu * np.log( 2 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( 10655/1344 * Delta + 
 	 ( complex( 0,839/224 ) * np.pi * Delta + 
 	 ( 2420707/15120 * Delta * nu + 
 	 ( complex( 0,-107/168 ) * np.pi * Delta * nu + 
 	 ( -1315/112 * Delta * np.log( 2 ) + 
 	 163/84 * Delta * nu * np.log( 2 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 2407/192 * Delta + 
 	 ( complex( 0,-1049/96 ) * np.pi * Delta + 
 	 ( -18709/1008 * Delta * nu + 
 	 ( complex( 0,-139/24 ) * np.pi * Delta * nu + 
 	 ( -48373/1008 * Delta * np.log( 2 ) + 
 	 ( 867/28 * Delta * nu * np.log( 2 ) + 
 	 ( 4131/112 * Delta * np.log( 3 ) + 
 	 -135/14 * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( 4171/448 * Delta + 
 	 ( complex( 0,363/224 ) * np.pi * Delta + 
 	 ( -809381/7560 * Delta * nu + 
 	 ( complex( 0,-17/56 ) * np.pi * Delta * nu + 
 	 ( 14081/336 * Delta * np.log( 2 ) + 
 	 ( -919/84 * Delta * nu * np.log( 2 ) + 
 	 ( -4131/112 * Delta * np.log( 3 ) + 
 	 135/14 * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( 187/16 * Delta + 
 	 ( complex( 0,12787/2688 ) * np.pi * Delta + 
 	 ( 8481/224 * Delta * nu + 
 	 ( complex( 0,-445/448 ) * np.pi * Delta * nu + 
 	 ( 5827/84 * Delta * np.log( 2 ) + 
 	 ( -2623/168 * Delta * nu * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 26141/2016 * Delta + 
 	 ( complex( 0,101/48 ) * np.pi * Delta + 
 	 ( 15989/45 * Delta * nu + 
 	 ( complex( 0,-73/144 ) * np.pi * Delta * nu + 
 	 ( -8819/504 * Delta * np.log( 2 ) + 
 	 353/126 * Delta * nu * np.log( 2 ) ) ) ) ) ) + 
 	 ( -56835/896 * Delta * np.log( 3 ) + 
 	 ( 6183/448 * Delta * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 3225/224 * Delta + 
 	 ( complex( 0,369/112 ) * np.pi * Delta + 
 	 ( -246493/840 * Delta * nu + 
 	 ( complex( 0,53/63 ) * np.pi * Delta * nu + 
 	 ( -10151/56 * Delta * np.log( 2 ) + 
 	 ( 1399/21 * Delta * nu * np.log( 2 ) + 
 	 ( 2781/28 * Delta * np.log( 3 ) + 
 	 -4293/112 * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -10097/1344 * Delta + 
 	 ( complex( 0,37007/1792 ) * np.pi * Delta + 
 	 ( 15097661/60480 * Delta * nu + 
 	 ( complex( 0,-2273/896 ) * np.pi * Delta * nu + 
 	 ( -2945/336 * Delta * np.log( 2 ) + 
 	 ( 1255/1008 * Delta * nu * np.log( 2 ) + 
 	 ( 4671/256 * Delta * np.log( 3 ) + 
 	 -297/128 * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( 78875/4032 * Delta + 
 	 ( complex( 0,-46453/2016 ) * np.pi * Delta + 
 	 ( -706451/60480 * Delta * nu + 
 	 ( complex( 0,-27109/2016 ) * np.pi * Delta * nu + 
 	 ( 118507/1008 * Delta * np.log( 2 ) + 
 	 ( -84533/1008 * Delta * nu * np.log( 2 ) + 
 	 ( -6453/896 * Delta * np.log( 3 ) + 
 	 ( -351/448 * Delta * nu * np.log( 3 ) + 
 	 ( -440875/16128 * Delta * np.log( 5 ) + 
 	 453125/8064 * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 179167/10752 * Delta + 
 	 ( complex( 0,75745/16128 ) * np.pi * Delta + 
 	 ( -60293123/181440 * Delta * nu + 
 	 ( complex( 0,-629/504 ) * np.pi * Delta * nu + 
 	 ( -805321/2688 * Delta * np.log( 2 ) + 
 	 ( 7283/84 * Delta * nu * np.log( 2 ) + 
 	 ( 72441/448 * Delta * np.log( 3 ) + 
 	 -10827/224 * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( 162817/7168 * Delta + 
 	 ( complex( 0,-3511/512 ) * np.pi * Delta + 
 	 ( 25701199/40320 * Delta * nu + 
 	 ( complex( 0,109/192 ) * np.pi * Delta * nu + 
 	 ( -31589/5376 * Delta * np.log( 2 ) + 
 	 ( 551/336 * Delta * nu * np.log( 2 ) + 
 	 ( -5211/256 * Delta * np.log( 3 ) + 
 	 81/32 * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( 484843/32256 * Delta + 
 	 ( complex( 0,43745/5376 ) * np.pi * Delta + 
 	 ( 22349323/51840 * Delta * nu + 
 	 ( complex( 0,-1033/672 ) * np.pi * Delta * nu + 
 	 ( 846347/8064 * Delta * np.log( 2 ) + 
 	 ( -153/7 * Delta * nu * np.log( 2 ) + 
 	 ( -21159/224 * Delta * np.log( 3 ) + 
 	 4329/224 * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( -20363/1024 * Delta + 
 	 ( complex( 0,2397683/53760 ) * np.pi * Delta + 
 	 ( 1523578837/3628800 * Delta * nu + 
 	 ( complex( 0,-6291/1120 ) * np.pi * Delta * nu + 
 	 ( -724405/16128 * Delta * np.log( 2 ) + 
 	 ( 5827/1008 * Delta * nu * np.log( 2 ) + 
 	 ( 5211/256 * Delta * np.log( 3 ) + 
 	 ( -81/32 * Delta * nu * np.log( 3 ) + 
 	 ( 12067/315 * Delta * np.log( 4 ) + 
 	 -1552/315 * Delta * nu * np.log( 4 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( 1837501/64512 * Delta + 
 	 ( complex( 0,-1451939/32256 ) * np.pi * Delta + 
 	 ( 31264819/1814400 * Delta * nu + 
 	 ( complex( 0,-12419/448 ) * np.pi * Delta * nu + 
 	 ( -1552143/8960 * Delta * np.log( 2 ) + 
 	 ( 113569/1680 * Delta * nu * np.log( 2 ) + 
 	 ( -127017/2240 * Delta * np.log( 3 ) + 
 	 ( 143271/1120 * Delta * nu * np.log( 3 ) + 
 	 ( 876125/5376 * Delta * np.log( 5 ) + 
 	 -15625/224 * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( 149287/7168 * Delta + 
 	 ( complex( 0,34151/3584 ) * np.pi * Delta + 
 	 ( -47983043/80640 * Delta * nu + 
 	 ( complex( 0,3401/672 ) * np.pi * Delta * nu + 
 	 ( 2344757/5376 * Delta * np.log( 2 ) + 
 	 ( -70513/336 * Delta * nu * np.log( 2 ) + 
 	 ( -2025/32 * Delta * np.log( 3 ) + 
 	 ( 945/32 * Delta * nu * np.log( 3 ) + 
 	 ( -876125/5376 * Delta * np.log( 5 ) + 
 	 15625/224 * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( 26707/1344 * Delta + 
 	 ( complex( 0,409321/48384 ) * np.pi * Delta + 
 	 ( 41645/672 * Delta * nu + 
 	 ( complex( 0,-3635/2016 ) * np.pi * Delta * nu + 
 	 ( -50215/112 * Delta * np.log( 2 ) + 
 	 ( 59081/504 * Delta * nu * np.log( 2 ) + 
 	 ( 433215/1792 * Delta * np.log( 3 ) + 
 	 ( -14607/224 * Delta * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 291/16 * Delta + 
 	 ( complex( 0,95105/8064 ) * np.pi * Delta + 
 	 ( 67339519/72576 * Delta * nu + 
 	 ( complex( 0,-71389/32256 ) * np.pi * Delta * nu + 
 	 ( 77951/504 * Delta * np.log( 2 ) + 
 	 ( -62719/2016 * Delta * nu * np.log( 2 ) + 
 	 ( -977373/7168 * Delta * np.log( 3 ) + 
 	 48537/1792 * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 212683/5040 * Delta + 
 	 ( complex( 0,-1700281/53760 ) * np.pi * Delta + 
 	 ( 5094644887/4536000 * Delta * nu + 
 	 ( complex( 0,25141/6720 ) * np.pi * Delta * nu + 
 	 ( 310/9 * Delta * np.log( 2 ) + 
 	 ( -613/180 * Delta * nu * np.log( 2 ) + 
 	 ( -559413/17920 * Delta * np.log( 3 ) + 
 	 ( 1917/448 * Delta * nu * np.log( 3 ) + 
 	 ( -13187/315 * Delta * np.log( 4 ) + 
 	 1664/315 * Delta * nu * np.log( 4 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 198697/6720 * Delta + 
 	 ( complex( 0,87257/3360 ) * np.pi * Delta + 
 	 ( -5303268037/4536000 * Delta * nu + 
 	 ( complex( 0,27319/1680 ) * np.pi * Delta * nu + 
 	 ( -43007/80 * Delta * np.log( 2 ) + 
 	 ( 14283/40 * Delta * nu * np.log( 2 ) + 
 	 ( -382509/1280 * Delta * np.log( 3 ) + 
 	 ( 25011/160 * Delta * nu * np.log( 3 ) + 
 	 ( 12721475/32256 * Delta * np.log( 5 ) + 
 	 -1109375/4032 * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( -587899/13440 * Delta + 
 	 ( complex( 0,173760451/1935360 ) * np.pi * Delta + 
 	 ( 520374349/1008000 * Delta * nu + 
 	 ( complex( 0,-3703279/322560 ) * np.pi * Delta * nu + 
 	 ( -3607831/30240 * Delta * np.log( 2 ) + 
 	 ( 153757/10080 * Delta * nu * np.log( 2 ) + 
 	 ( 49707/2048 * Delta * np.log( 3 ) + 
 	 ( -3105/1024 * Delta * nu * np.log( 3 ) + 
 	 ( 13187/315 * Delta * np.log( 4 ) + 
 	 ( -1664/315 * Delta * nu * np.log( 4 ) + 
 	 ( 28131325/387072 * Delta * np.log( 5 ) + 
 	 -203125/21504 * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 87229/4032 * Delta + 
 	 ( complex( 0,591805/129024 ) * np.pi * Delta + 
 	 ( -58177087/72576 * Delta * nu + 
 	 ( complex( 0,-118633/64512 ) * np.pi * Delta * nu + 
 	 ( 733459/1008 * Delta * np.log( 2 ) + 
 	 ( -559709/2016 * Delta * nu * np.log( 2 ) + 
 	 ( -1371789/14336 * Delta * np.log( 3 ) + 
 	 ( 372357/7168 * Delta * nu * np.log( 3 ) + 
 	 ( -35030375/129024 * Delta * np.log( 5 ) + 
 	 5828125/64512 * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( 527957/13440 * Delta + 
 	 ( complex( 0,-559927/6720 ) * np.pi * Delta + 
 	 ( 256650851/1008000 * Delta * nu + 
 	 ( complex( 0,-356299/6720 ) * np.pi * Delta * nu + 
 	 ( 3386737/30240 * Delta * np.log( 2 ) + 
 	 ( -176335/672 * Delta * nu * np.log( 2 ) + 
 	 ( 20972979/71680 * Delta * np.log( 3 ) + 
 	 ( -5490099/35840 * Delta * nu * np.log( 3 ) + 
 	 ( -3496625/129024 * Delta * np.log( 5 ) + 
 	 ( -453125/64512 * Delta * nu * np.log( 5 ) + 
 	 ( -24696343/276480 * Delta * np.log( 7 ) + 
 	 823543/3072 * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(h)

# %% [markdown]
# ## Amplitude $(\ell, m)$ = (3, 3)

# %%
# ## Amplitude $(\ell, m)$ = (3, 3)

def amplitude_33(xi, x, nu, Delta, e):
    
    h = ( x )**( 1/2 ) * ( complex( 0,-3/4 ) * ( 15/14 )**( 1/2 ) * Delta + ( e * ( complex( 0,-5/4 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,-1 ) * xi ) * Delta + 
 	 complex( 0,-5/4 ) * ( 15/14 )**( 1/2 ) * ( np.e )**( complex( 0,1 ) * xi ) * Delta ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,1/4 ) * ( 15/14 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-23/16 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,-2 ) * xi ) * Delta + 
 	 complex( 0,-95/16 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,2 ) * xi ) * Delta ) ) + 
 	 ( ( e )**( 3 ) * ( complex( 0,1/32 ) * ( 35/6 )**( 1/2 ) * ( np.e )**( complex( 0,-1 ) * xi ) * Delta + 
 	 ( complex( 0,85/32 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,1 ) * xi ) * Delta + 
 	 ( complex( 0,-19/32 ) * ( 15/14 )**( 1/2 ) * ( np.e )**( complex( 0,-3 ) * xi ) * Delta + 
 	 complex( 0,-97/32 ) * ( 15/14 )**( 1/2 ) * ( np.e )**( complex( 0,3 ) * xi ) * Delta ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,1/16 ) * ( 15/14 )**( 1/2 ) * Delta + 
 	 ( complex( 0,5/32 ) * ( 15/14 )**( 1/2 ) * ( np.e )**( complex( 0,-2 ) * xi ) * Delta + 
 	 ( complex( 0,589/96 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,2 ) * xi ) * Delta + 
 	 ( complex( 0,-437/192 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,-4 ) * xi ) * Delta + 
 	 complex( 0,-871/64 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,4 ) * xi ) * Delta ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( complex( 0,55/768 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,-1 ) * xi ) * Delta + 
 	 ( complex( 0,-155/768 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,1 ) * xi ) * Delta + 
 	 ( complex( 0,165/512 ) * ( 15/14 )**( 1/2 ) * ( np.e )**( complex( 0,-3 ) * xi ) * Delta + 
 	 ( complex( 0,2055/512 ) * ( 15/14 )**( 1/2 ) * ( np.e )**( complex( 0,3 ) * xi ) * Delta + 
 	 ( complex( 0,-4541/1536 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,-5 ) * xi ) * Delta + 
 	 complex( 0,-30791/1536 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,5 ) * xi ) * Delta ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,1/32 ) * ( 15/14 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-11/768 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,-2 ) * xi ) * Delta + 
 	 ( complex( 0,-173/768 ) * ( 35/6 )**( 1/2 ) * ( np.e )**( complex( 0,2 ) * xi ) * Delta + 
 	 ( complex( 0,341/192 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,-4 ) * xi ) * Delta + 
 	 ( complex( 0,4181/192 ) * ( 5/42 )**( 1/2 ) * ( np.e )**( complex( 0,4 ) * xi ) * Delta + 
 	 ( complex( 0,-331/256 ) * ( 15/14 )**( 1/2 ) * ( np.e )**( complex( 0,-6 ) * xi ) * Delta + 
 	 complex( 0,-2491/256 ) * ( 15/14 )**( 1/2 ) * ( np.e )**( complex( 0,6 ) * xi ) * Delta ) ) ) ) ) ) ) ) ) ) ) ) + ( ( x )**( 3/2 ) * ( complex( 0,3 ) * ( 15/14 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-3/2 ) * ( 15/14 )**( 1/2 ) * Delta * nu + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,331/36 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-295/72 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,341/36 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-521/72 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,545/48 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-107/24 ) * ( 5/42 )**( 1/2 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,3625/288 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-43/9 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,2489/288 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-787/72 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,73649/1536 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-8111/3072 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,53161/6912 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-53215/13824 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,4175/1536 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-13553/3072 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,481925/13824 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-235019/27648 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,-218165/13824 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-872149/27648 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,58319/6912 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-7511/13824 ) * ( 35/6 )**( 1/2 ) * Delta * nu ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,901/96 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-7/12 ) * ( 35/6 )**( 1/2 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,10399/1728 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-3601/864 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,48815/1728 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-3701/864 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-419/216 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-19457/864 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,2677/108 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-865/864 ) * ( 35/6 )**( 1/2 ) * Delta * nu ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,545/72 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-2333/576 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,1249/72 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-2683/576 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,47/8 ) * ( 15/14 )**( 1/2 ) * Delta + 
 	 complex( 0,-123/64 ) * ( 15/14 )**( 1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,43/8 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-145/64 ) * ( 35/6 )**( 1/2 ) * Delta * nu ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,1691/192 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-95/24 ) * ( 5/42 )**( 1/2 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,2862001/6912 ) * ( 210 )**( -1/2 ) * Delta + 
 	 complex( 0,3685/3456 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,47035/13824 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 complex( 0,-11591/3456 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,15221/13824 ) * ( 35/6 )**( 1/2 ) * Delta + 
 	 complex( 0,-6365/1728 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,125369/512 ) * ( 210 )**( -1/2 ) * Delta + 
 	 complex( 0,-655/64 ) * ( 5/42 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,-131839/6912 ) * ( 210 )**( -1/2 ) * Delta + 
 	 complex( 0,-83219/3456 ) * ( 210 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,-102191/512 ) * ( 210 )**( -1/2 ) * Delta + 
 	 complex( 0,-28013/128 ) * ( 210 )**( -1/2 ) * Delta * nu ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 5/2 ) * ( complex( 0,-369/88 ) * ( 3/70 )**( 1/2 ) * Delta + 
 	 ( complex( 0,919/22 ) * ( 3/70 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,-887/88 ) * ( 3/70 )**( 1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,137/11 ) * ( 10/21 )**( 1/2 ) * Delta + 
 	 ( complex( 0,299059/9504 ) * ( 5/42 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,-84509/9504 ) * ( 5/42 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,4039/792 ) * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,1641001/9504 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-28121/9504 ) * ( 7/30 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,18017/704 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 ( complex( 0,5493337/76032 ) * ( 5/42 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,-175103/76032 ) * ( 5/42 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,5615/99 ) * ( 5/42 )**( 1/2 ) * Delta + 
 	 ( complex( 0,6003983/76032 ) * ( 5/42 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,-320449/76032 ) * ( 5/42 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,1697/33 ) * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,2756689/8448 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,374497/8448 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,756179/704 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-603737/8448 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-460321/8448 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,3853/22 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,62443/1584 ) * ( 7/30 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,-15901/792 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,494203/3168 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,69757/297 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-4093/9504 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,465821/1056 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,547607/4752 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-520313/9504 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,2195267/8448 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,6000023/12672 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-3083/396 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,37915721/16896 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-118748369/228096 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-506563/114048 ) * ( 7/30 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,179357/1152 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,2153689/5184 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-73133/5184 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,9818213/38016 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,36853477/57024 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-1715459/57024 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,105237553/152064 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,105151787/228096 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,14944483/114048 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,10677659/50688 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,1026693709/1824768 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-104669/1824768 ) * ( 7/30 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,12115207/38016 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,1075891451/1824768 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-1034851/1824768 ) * ( 7/30 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,217898869/50688 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-5199621737/3649536 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,19486897/3649536 ) * ( 7/30 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,183031/1536 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,16901569/36864 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-1765343/36864 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,-254669/11264 ) * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,484531037/405504 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-27342379/405504 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,370367719/304128 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,2412629873/3649536 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,1047029609/3649536 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,2929327/8448 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,1205789/12672 ) * ( 7/30 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,5773/1584 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,-343729/5632 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,204847/891 ) * ( 2/105 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,-865033/28512 ) * ( 5/42 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,25746073/67584 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,636900463/912384 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,644201/456192 ) * ( 7/30 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-1113259727/760320 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,168740267/71280 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-3523589/142560 ) * ( 7/30 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,164121961/608256 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,567017279/912384 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,4774411/456192 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,58428511/22528 ) * ( 3/70 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-20891525/33792 ) * ( 5/42 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,1057079/5632 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,687043067/337920 ) * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,162272371/168960 ) * ( 210 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,46811069/84480 ) * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 2 ) * ( -9/4 * ( 21/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-9/4 ) * ( 15/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( -9/2 * ( 15/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 9/2 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -47/4 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-47/4 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( 209/2 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 -27/2 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( -19/4 * ( 21/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-19/4 ) * ( 15/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( -27/2 * ( 15/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 27/2 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( -17/4 * ( 21/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-17/4 ) * ( 15/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( 263/2 * ( 15/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -135/2 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -41/8 * ( 35/6 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-205/8 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -349/4 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 459/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( -31/8 * ( 35/6 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-155/8 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -1691/4 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 27/16 * ( 105/2 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 3125/16 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( -451/32 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-451/32 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( 4895/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 -675/4 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( -457/32 * ( 21/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-457/32 ) * ( 15/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( -269/648 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( -865/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 423/8 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( -327/32 * ( 21/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-327/32 ) * ( 15/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( 4057/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 639/4 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 -3125/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 5 ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( -461/32 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-461/32 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -29125/16 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 135/8 * ( 105/2 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 3125/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 5 ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -177/32 * ( 21/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-177/32 ) * ( 15/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( -24097/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 23679/64 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -287/24 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-41/24 ) * ( 35/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( 269/216 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( 21361/12 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 -10845/32 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -4397/64 * ( 7/30 )**( 1/2 ) * Delta +
 	 ( complex( 0,-2509/256 ) * ( 35/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( -269/216 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( -8909/32 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 23103/256 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) ) ) ) ) + 
 	 ( 53125/128 * ( 15/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -19/4 * ( 21/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-19/4 ) * ( 15/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( 411/2 * ( 105/2 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 13005/32 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 -28125/32 * ( 15/14 )**( 1/2 ) * Delta * np.log( 5 ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( -9071/192 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-9071/192 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -22169/96 * ( 35/6 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -124461/256 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 3125/128 * ( 105/2 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 117649/768 * ( 35/6 )**( 1/2 ) * Delta * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( -91/512 * ( 105/2 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-505/512 ) * ( 15/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( 911/2592 * ( 7/30 )**( 1/2 ) * Delta * nu + 
 	 ( 805547/256 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 -9801/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( -164669/1536 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-819431/1536 ) * ( 210 )**( -1/2 ) * np.pi * Delta + 
 	 ( -4573/1728 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( -83173/256 * ( 7/30 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 3357/32 * ( 21/10 )**( 1/2 ) * Delta * np.log( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -2801/768 * ( 35/6 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-14005/768 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -269/1728 * ( 7/30 )**( 1/2 ) * Delta * nu + 
 	 ( -1163951/128 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 105669/128 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 146875/64 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -2791/768 * ( 35/6 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-13955/768 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( 4601693/384 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 84519/128 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 -34375/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 5 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( -109819/1536 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-109819/1536 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( 29496409/768 * ( 210 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 68031/32 * ( 3/70 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -3125/32 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 -117649/256 * ( 35/6 )**( 1/2 ) * Delta * np.log( 7 ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( -349/512 * ( 105/2 )**( 1/2) * Delta + 
 	 ( complex( 0,-1745/512 ) * ( 15/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( -2156795/256 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -69579/32 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 90625/64 * ( 15/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 117649/256 * ( 35/6 )**( 1/2 ) * Delta * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( -21/16 * ( 105/2 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-15/16 ) * ( 105/2 )**( 1/2 ) * np.pi * Delta + 
 	 ( 269/1296 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( 204677/8 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 531/4 * ( 105/2 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 9541/480 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,17659/192 ) * ( 210 )**( -1/2 ) * np.pi * Delta + 
 	 ( 1229/288 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( 1263049/48 * ( 210 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 -166653/32 * ( 3/70 )**( 1/2 ) * Delta * np.log( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( -17503/320 * ( 21/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-831779/1024 ) * ( 210 )**( -1/2 ) * np.pi * Delta + 
 	 ( -12643/2592 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( -115069/32 * ( 210 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 37053/32 * ( 3/70 )**( 1/2 ) * Delta * np.log( 3 ) ) ) ) ) + 
 	 ( -821875/64 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -3899/192 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-17599/6144 ) * ( 35/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( 29/72 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( -1585139/96 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 3272733/2048 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 8021875/2048 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 521/480 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,521/96 ) * ( 210 )**( -1/2 ) * np.pi * Delta + 
 	 ( 7323269/48 * ( 210 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 8811 * ( 6/35 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -171875/64 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 -2000033/192 * ( 7/30 )**( 1/2 ) * Delta * np.log( 7 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -1907/96 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-1907/96 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -1182263/48 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -10619001/2048 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 80115625/6144 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 2000033/2048 * ( 35/6 )**( 1/2 ) * Delta * np.log( 7 ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( -2847/80 * ( 21/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-2847/16 ) * ( 3/70 )**( 1/2 ) * np.pi * Delta + 
 	 ( -249064513/2048 * ( 210 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -829683/2048 * ( 3/70 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -15625/2048 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 823543/2048 * ( 35/6 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 14348907/2048 * ( 3/70 )**( 1/2 ) * Delta * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 3 ) * ( 9 * ( 21/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,9 ) * ( 15/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( -48103/108 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-27/8 ) * ( 15/14 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 9 * ( 30/7 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -27/4 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -9 * ( 30/7 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 27/4 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 995/36 * ( 5/42 )**( 1/2 ) * Delta + 
 	 ( complex( 0,1945/36 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -181/18 * ( 35/6 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,-743/36 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -487/18 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 2201/18 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -27/2 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 -27/2 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( 2101/36 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,109/36 ) * ( 35/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( -34919/18 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-629/36 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -27/2 * ( 15/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -27/2 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 27/2 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 27/2 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( -473/16 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,961/16 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -37727/16 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-67/2 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 49523/24 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 691/3 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -3483/8 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -27 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -96361/288 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-589/288 ) * ( 35/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( -1461043/288 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-3503/144 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -65851/144 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -3407/72 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 2241/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 513/32 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( 68219/288 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,28337/288 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -1189571/1440 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-5003/144 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -189775/144 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -26507/72 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 1647/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 135/32 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 18125/72 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 59375/288 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( -1423/6 * ( 5/42 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-2465/24 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -154253503/14256 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-1387/48 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -25357/14256 * ( 7/30 )**( 1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( -2120/3 * ( 10/21 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -509/24 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 6849/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 135/16 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -16489/72 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,2689/36 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -2809117/288 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-7223/144 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 26051/3 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 2347/24 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -28593/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 27/16 * ( 105/2 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 5059/12 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,4049/24 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -2536357/1440 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-2573/48 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 7779/4 * ( 15/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 915/8 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 7407/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 2187/16 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -176875/48 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 -15625/48 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( -1241/72 * ( 5/42 )**( 1/2 ) * Delta + 
 	 ( complex( 0,445/36 ) * ( 35/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( 16871/20 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-7121/144 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -556565/36 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -31819/72 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 22761/16 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -351/16 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 176875/48 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 15625/48 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,5 ) * xi ) * ( -11296271/13824 * ( 7/30 )**( 1/2 ) * Delta +
 	 ( complex( 0,-42458597/13824 ) * ( 210 )**( -1/2 ) * np.pi * Delta + 
 	 ( -14207572661/380160 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-157043/13824 ) * ( 7/30 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -64951/4224 * ( 5/42 )**( 1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( -8280653/256 * ( 210 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 49633/256 * ( 7/30 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 1250973/128 * ( 3/70 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 -3231/8 * ( 3/70 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( -66287/1536 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,1042675/4608 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -622604221/12672 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-516077/4608 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 2906359/57024 * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( 12600773/256 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -552047/256 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -1300347/128 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 4725/64 * ( 105/2 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -473867/6912 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,790813/6912 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -155454617/47520 * ( 7/30 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,-587543/6912 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -398383/12672 * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( -23666251/1152 * ( 35/6 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 7104119/1152 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 1954035/128 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -113787/128 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 35385625/1152 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 -753125/1152 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -2298119/6912 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,899503/6912 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( 74323321/17280 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-587213/6912 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 644430959/3456 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -27764221/3456 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 640449/128 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 46827/128 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -14916875/1152 * ( 35/6 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 3353125/1152 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( 17318293/13824 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,6184459/13824 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -223694507/34560 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-1515569/13824 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 2189404103/6912 * ( 210 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 67187819/6912 * ( 210 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 4343427/128 * ( 3/70 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -42057/64 * ( 3/70 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -3773125/1152 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 134375/1152 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -10529071/2304 * ( 35/6 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 -117649/2304 * ( 35/6 )**( 1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( -432373/1536 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,27323/1536 ) * ( 35/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( 28626667/3840 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-145063/1536 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -29499277/256 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 36971/256 * ( 105/2 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -3277233/128 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 13473/32 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 72805625/1152 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( -390625/1152 * ( 35/6 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 10529071/2304 * ( 35/6 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 117649/2304 * ( 35/6 )**( 1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -2387/64 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,919/64 ) * ( 35/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( -15262819/2880 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-4223/64 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
	 ( -5457293/96 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 111091/96 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 184491/32 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -31887/128 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -9723697/3456 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-244337/864 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -157973743/38016 * ( 5/42 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,-385547/13824 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -2909/396 * ( 5/42 )**( 1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( -5606311/1728 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 118739/1728 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 62739/64 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 -9603/512 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -57805/864 * ( 5/42 )**( 1/2 ) * Delta + 
 	 ( complex( 0,100075/864 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -230611057/9504 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-32113/432 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 2909/396 * ( 5/42 )**( 1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( 9862459/432 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -119173/216 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -300627/64 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 10359/64 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( 4863125/384 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 15625/768 * ( 35/6 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -120863/864 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,13783/864 ) * ( 35/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( 13924543/4320 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-14957/216 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 22195057/432 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -78251/108 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 157851/64 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 14697/64 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -47179375/1728 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 -15625/1728 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( 2544839/3456 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,962177/3456 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -60085129/17280 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-38647/3456 ) * ( 35/6 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -23272927/1728 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -1002817/1728 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -128421/32 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -82791/512 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 2756875/384 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( -34375/768 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 2617433/3456 * ( 35/6 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 1294139/13824 * ( 35/6 )**( 1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( -6835/64 * ( 5/42 )**( 1/2 ) * Delta + 
 	 ( complex( 0,1345/64 ) * ( 35/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( -2560248479/285120 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-1685/16 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + ( 328367/57024 * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( 15171223/32 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -74223/8 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 1959075/256 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 83241/128 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( -5130373/480 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-36466937/6144 ) * ( 210 )**( -1/2 ) * np.pi * Delta + 
 	 ( -7007133211/1140480 * ( 7/30 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,478501/6144 ) * ( 210 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -1138517/57024 * ( 7/30 )**( 1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( -6841139/576 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 1919501/576 * ( 210 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 1050849/2048 * ( 105/2 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 -64773/64 * ( 3/70 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 4295981/3456 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,66212431/27648 ) * ( 210 )**( -1/2 ) * np.pi * Delta + 
 	 ( -3305812267/31680 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-11965657/13824 ) * ( 210 )**( -1/2 ) * np.pi * Delta * nu +
 	 ( 1164787/19008 * ( 210 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( 822554083/1728 * ( 210 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -46834601/1728 * ( 210 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -100994769/1024 * ( 3/70 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 449181/512 * ( 21/10 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( -337758125/1536 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 8384375/768 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -318109/432 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,7055215/55296 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + ( -19923667961/380160 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-11679667/110592 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 197471/19008 * ( 7/30 )**( 1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( -528182477/1728 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 7505605/432 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 68455827/2048 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -9356841/4096 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 583039375/9216 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 -94184375/36864 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -185837/3456 * ( 7/30 )**( 1/2 ) * Delta + 
 	 ( complex( 0,281369/1728 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( 385601989/34560 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-363269/3456 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -366401971/864 * ( 5/42 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 38818603/1728 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -161911035/2048 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 13075173/4096 * ( 15/14 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 6361480625/27648 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( -1460378125/110592 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 248877713/18432 * ( 35/6 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 -11882549/36864 * ( 35/6 )**( 1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( -10408487/17280 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,1820419/3456 ) * ( 210 )**( -1/2 ) * np.pi * Delta + 
 	 ( 2460907/768 * ( 5/42 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,-2213567/3456 ) * ( 210 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 3504388219/1728 * ( 210 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -18980539/1728 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 58128759/1024 * ( 15/14 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -6797961/512 * ( 3/70 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -87336875/1536 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 2478125/768 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -765285479/27648 * ( 35/6 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 11882549/13824 * ( 35/6 )**( 1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( 798827/384 * ( 210 )**( -1/2 ) * Delta + 
 	 ( complex( 0,67667/96 ) * ( 5/42 )**( 1/2 ) * np.pi * Delta + 
 	 ( -1121279/80 * ( 210 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-142117/192 ) * ( 210 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -6104192233/4608 * ( 210 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 283489981/36864 * ( 210 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -29461617/2048 * ( 3/70 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 336177/4096 * ( 21/10 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -1834375/9216 * ( 5/42 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 603125/36864 * ( 5/42 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 130880911/18432 * ( 35/6 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 ( -7882483/36864 * ( 35/6 )**( 1/2 ) * Delta * nu * np.log( 7 ) + 
 	 ( 27925803/512 * ( 3/70 )**( 1/2 ) * Delta * np.log( 18 ) + 
 	 4782969/4096 * ( 3/70 )**( 1/2 ) * Delta * nu * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(h)

# %% [markdown]
# ## Amplitude $(\ell, m)$ = (3, 2)

# %%
# ## Amplitude $(\ell, m)$ = (3, 2)

def amplitude_32(xi, x, nu, Delta, e):
    
    h = ( x * ( 1/3 * ( 5/7 )**( 1/2 ) + 
 	 ( -1 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( ( e )**( 2 ) * ( 1/6 * ( 5/7 )**( 1/2 ) + 
 	 ( -1/2 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 5/6 * ( 5/7 )**( 1/2 ) + 
 	 -5/2 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( 2/3 * ( 5/7 )**( 1/2 ) + 
 	 -2 * ( 5/7 )**( 1/2 ) * nu ) ) ) ) + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 13/24 * ( 5/7 )**( 1/2 ) + 
 	 -13/8 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( 11/24 * ( 5/7 )**( 1/2 ) + 
 	 -11/8 * ( 5/7 )**( 1/2 ) * nu ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,5 ) * xi ) * ( 24401/9216 * ( 5/7 )**( 1/2 ) + 
 	 -24401/3072 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 551/4608 * ( 5/7 )**( 1/2 ) + 
 	 -551/1536 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( 529/4608 * ( 5/7 )**( 1/2 ) + 
 	 -529/1536 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( -1361/3072 * ( 5/7 )**( 1/2 ) + 
 	 1361/1024 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( -2279/3072 * ( 5/7 )**( 1/2 ) + 
 	 2279/1024 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( 2593/9216 * ( 35 )**( 1/2 ) + 
 	 -2593/3072 * ( 35 )**( 1/2 ) * nu ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( 5/48 * ( 5/7 )**( 1/2 ) + 
 	 ( -5/16 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 83/576 * ( 5/7 )**( 1/2 ) + 
 	 -83/192 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( 383/192 * ( 7/5 )**( 1/2 ) + 
 	 -383/64 * ( 7/5 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( 3653/192 * ( 35 )**( -1/2 ) + 
 	 -3653/64 * ( 35 )**( -1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( -1507/288 * ( 35 )**( -1/2 ) + 
 	 1507/96 * ( 35 )**( -1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -2339/288 * ( 35 )**( -1/2 ) + 
 	 2339/96 * ( 35 )**( -1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( 13/576 * ( 35 )**( 1/2 ) + 
 	 -13/192 * ( 35 )**( 1/2 ) * nu ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( 239/192 * ( 5/7 )**( 1/2 ) + 
 	 -239/64 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 185/192 * ( 5/7 )**( 1/2 ) + 
 	 -185/64 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 17/192 * ( 5/7 )**( 1/2 ) + 
 	 -17/64 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( 1/192 * ( 35 )**( 1/2 ) + 
 	 -1/64 * ( 35 )**( 1/2 ) * nu ) ) ) ) + 
 	 ( e )**( 4 ) * ( 1/8 * ( 5/7 )**( 1/2 ) + 
 	 ( -3/8 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 263/144 * ( 5/7 )**( 1/2 ) + 
 	 -263/48 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 199/144 * ( 5/7 )**( 1/2 ) + 
 	 -199/48 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -17/72 * ( 5/7 )**( 1/2 ) + 
 	 17/24 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( -1/72 * ( 35 )**( 1/2 ) + 
 	 1/24 * ( 35 )**( 1/2 ) * nu ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 2 ) * ( -193/54 * ( 35 )**( -1/2 ) + 
 	 ( 145/54 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( -73/54 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 149/72 * ( 35 )**( \
-1/2 ) + 
 	 ( -83/144 * ( 5/7 )**( 1/2 ) * nu + 
 	 -215/144 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( -259/216 * ( 7/5 )**( 1/2 ) \
+ 
 	 ( 2549/432 * ( 5/7 )**( 1/2 ) * nu + 
 	 -479/432 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( -187/27 * ( 35 )**( -1/2 ) + 
 	 ( 139/27 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( -71/54 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 971/72 * ( 35 )**( -1/2 ) + 
 	 ( -59/8 * ( 5/7 )**( 1/2 ) * nu + 
 	 -97/72 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( -3637/216 * ( 35 )**( -1/2 \
) + 
 	 ( 2461/216 * ( 5/7 )**( 1/2 ) * nu + 
 	 -61/216 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -1303/144 * ( 35 )**( -1/2 ) + 
 	 ( 967/144 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( -211/144 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -197/48 * ( 35 )**( -1/2 \
) + 
 	 ( 1669/432 * ( 5/7 )**( 1/2 ) * nu + 
 	 -445/144 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -34669/1296 * ( 35 )**( \
-1/2 ) + 
 	 ( 3331/1296 * ( 35 )**( 1/2 ) * nu + 
 	 -3607/1296 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 61589/864 * ( 35 )**( -1/2 \
) + 
 	 ( -36781/864 * ( 5/7 )**( 1/2 ) * nu + 
 	 929/864 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( -137833/2592 * ( 35 )**( \
-1/2 ) + 
 	 ( 89329/2592 * ( 5/7 )**( 1/2 ) * nu + 
 	 13883/2592 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,-3 ) * xi ) * ( \
38099/27648 * ( 5/7 )**( 1/2 ) + 
 	 ( -19685/55296 * ( 35 )**( 1/2 ) * nu + 
 	 -373495/55296 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( -334213/27648 * ( 5/7 )**( \
1/2 ) + 
 	 ( 2177383/55296 * ( 5/7 )**( 1/2 ) * nu + 
 	 -287941/55296 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -82847/41472 * ( 5/7 )**( \
1/2 ) + 
 	 ( 614195/82944 * ( 5/7 )**( 1/2 ) * nu + 
 	 -129929/82944 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -26821/13824 * ( 5/7 )**( \
1/2 ) + 
 	 ( 199331/27648 * ( 5/7 )**( 1/2 ) * nu + 
 	 -40489/27648 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( 3658547/27648 * ( 35 )**( \
-1/2 ) + 
 	 ( -1476725/18432 * ( 5/7 )**( 1/2 ) * nu + 
 	 245629/55296 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( -7336159/82944 * ( 35 )**( \
-1/2 ) + 
 	 ( 1339775/165888 * ( 35 )**( 1/2 ) * nu + 
 	 1994437/165888 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( -929/432 * ( 5/7 )**( 1/2 ) + 
 	 ( 3445/432 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( -25/108 * ( 35 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 428987/12960 * ( 35 )**( \
-1/2 ) + 
 	 ( -33221/2592 * ( 7/5 )**( 1/2 ) * nu + 
 	 -9551/648 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -59263/5184 * ( 35 )**( \
-1/2 ) + 
 	 ( 43069/5184 * ( 5/7 )**( 1/2 ) * nu + 
 	 -2819/2592 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( 71309/2160 * ( 7/5 )**( \
1/2 ) + 
 	 ( -609811/864 * ( 35 )**( -1/2 ) * nu + 
 	 18163/1728 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -1680173/12960 * ( 35 )**( \
-1/2 ) + 
 	 ( 1077077/2592 * ( 35 )**( -1/2 ) * nu + 
 	 -33413/648 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( -154601/1080 * ( 35 )**( \
-1/2 ) + 
 	 ( 390941/864 * ( 35 )**( -1/2 ) * nu + 
 	 201863/1728 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( -38093/5184 * ( 35 )**( -1/2 \
) + 
 	 ( 4289/5184 * ( 35 )**( 1/2 ) * nu + 
 	 -251/1296 * ( 35 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( 4273/864 * \
( 7/5 )**( 1/2 ) + 
 	 ( -69691/3456 * ( 5/7 )**( 1/2 ) * nu + 
 	 -2183/3456 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -373/216 * ( 7/5 )**( 1/2 \
) + 
 	 ( 29641/3456 * ( 5/7 )**( 1/2 ) * nu + 
 	 -853/3456 * ( 35 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -887/864 * ( 7/5 )**( 1/2 \
) + 
 	 ( 18971/3456 * ( 5/7 )**( 1/2 ) * nu + 
 	 -815/3456 * ( 35 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( -13297/432 * ( 35 )**( -1/2 \
) + 
 	 ( 70199/3456 * ( 5/7 )**( 1/2 ) * nu + 
 	 805/3456 * ( 35 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) \
) + 
 	 ( ( x )**( 3 ) * ( -1451/2376 * ( 35 )**( -1/2 ) + 
 	 ( -17387/2376 * ( 35 )**( -1/2 ) * nu + 
 	 ( 5557/132 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( -763/792 * ( 7/5 )**( 1/2 ) * ( nu )**( 3 ) + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( -4399/4752 * ( 35 \
)**( -1/2 ) + 
 	 ( -62263/9504 * ( 35 )**( -1/2 ) * nu + 
 	 ( 193723/3168 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -123239/19008 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( -243/176 * ( 35 )**( -1/2 ) \
+ 
 	 ( -5831/9504 * ( 7/5 )**( 1/2 ) * nu + 
 	 ( 702287/9504 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -34697/19008 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( -20851/792 * ( 35 )**( -1/2 ) + 
 	 ( 13487/1584 * ( 7/5 )**( 1/2 ) * nu + 
 	 ( 110191/792 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( 19/88 * ( 7/5 )**( 1/2 ) * ( nu )**( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 27641/9504 * ( 5/7 )**( \
1/2 ) + 
 	 ( -64927/1188 * ( 35 )**( -1/2 ) * nu + 
 	 ( 45445/2376 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 -3145/3168 * ( 5/7 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( -1843/352 * ( 5/7 )**( 1/2 \
) + 
 	 ( 143417/1584 * ( 35 )**( -1/2 ) * nu + 
 	 ( 51929/594 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 13687/1056 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( \
-207679/3168 * ( 35 )**( -1/2 ) + 
 	 ( 4639931/25344 * ( 35 )**( -1/2 ) * nu + 
 	 ( 293255/8448 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 71317/50688 * ( 5/7 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( -105653/1188 * ( 35 )**( \
-1/2 ) + 
 	 ( 2820287/8448 * ( 35 )**( -1/2 ) * nu + 
 	 ( 991553/76032 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 1358113/152064 * ( 5/7 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( 614147/9504 * ( 35 )**( \
-1/2 ) + 
 	 ( -52133/8448 * ( 35 )**( 1/2 ) * nu + 
 	 ( 13187131/76032 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -357061/152064 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( -145867/4752 * ( 35 )**( \
-1/2 ) + 
 	 ( 132821/76032 * ( 35 )**( 1/2 ) * nu + 
 	 ( 16001221/76032 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 2030309/152064 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -105199/1584 * ( 35 )**( -1/2 ) + 
 	 ( 3112063/19008 * ( 35 )**( -1/2 ) * nu + 
 	 ( 2650639/9504 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( 13757/4752 * ( 7/5 )**( 1/2 ) * ( nu )**( 3 ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( -98029/3168 * ( 7/5 )**( \
1/2 ) + 
 	 ( 95020243/114048 * ( 35 )**( -1/2 ) * nu + 
 	 ( -1658843/57024 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 424961/28512 * ( 7/5 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 1043153/28512 * ( 5/7 )**( \
1/2 ) + 
 	 ( -69170461/114048 * ( 35 )**( -1/2 ) * nu + 
 	 ( 6565547/19008 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 6851/28512 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -575455/19008 * ( 5/7 )**( \
1/2 ) + 
 	 ( 26540047/57024 * ( 35 )**( -1/2 ) * nu + 
 	 ( 4890913/28512 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 919727/57024 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( -227129/57024 * ( 7/5 )**( \
1/2 ) + 
 	 ( 201527/57024 * ( 7/5 )**( 1/2 ) * nu + 
 	 ( 2959277/9504 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 1497809/57024 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) ) ) \
) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( \
-69178723/202752 * ( 35 )**( -1/2 ) + 
 	 ( 1347606737/1216512 * ( 35 )**( -1/2 ) * nu + 
 	 ( 66703981/1216512 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 11361227/2433024 * ( 7/5 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( 778627331/1824768 * ( 35 \
)**( -1/2 ) + 
 	 ( -5203140431/3649536 * ( 35 )**( -1/2 ) * nu + 
 	 ( 2562236093/3649536 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 26239/2433024 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -30252553/304128 * ( 35 \
)**( -1/2 ) + 
 	 ( 157588511/608256 * ( 35 )**( -1/2 ) * nu + 
 	 ( 630004709/1824768 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 11882389/405504 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 519055/202752 * ( 5/7 \
)**( 1/2 ) + 
 	 ( -211383577/1216512 * ( 35 )**( -1/2 ) * nu + 
 	 ( 599825299/1216512 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 80233091/2433024 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -2033327/912384 * ( 35 \
)**( 1/2 ) + 
 	 ( 341046667/1824768 * ( 35 )**( -1/2 ) * nu + 
 	 ( 666595931/1824768 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 42500113/1216512 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( -91802371/202752 * ( 35 \
)**( -1/2 ) + 
 	 ( 714871391/405504 * ( 35 )**( -1/2 ) * nu + 
 	 ( -943209277/3649536 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 508976849/2433024 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) \
) + 
 	 ( e )**( 6 ) * ( -898421/38016 * ( 5/7 )**( 1/2 ) + 
 	 ( 2278655/38016 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( 1702993/19008 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( 49661/38016 * ( 35 )**( 1/2 ) * ( nu )**( 3 ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( 677371979/760320 * ( 35 \
)**( -1/2 ) + 
 	 ( -2287005641/760320 * ( 35 )**( -1/2 ) * nu + 
 	 ( 532287269/380160 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -967547/760320 * ( 7/5 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -53733931/456192 * ( 35 \
)**( -1/2 ) + 
 	 ( 135141289/456192 * ( 35 )**( -1/2 ) * nu + 
 	 ( 102930479/228096 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 2499583/456192 * ( 7/5 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 167380639/1140480 * ( 35 \
)**( -1/2 ) + 
 	 ( -868861621/1140480 * ( 35 )**( -1/2 ) * nu + 
 	 ( 486535039/570240 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 20623151/1140480 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -5042671/50688 * ( 35 \
)**( -1/2 ) + 
 	 ( 12351949/50688 * ( 35 )**( -1/2 ) * nu + 
 	 ( 34309249/76032 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 7654211/152064 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -40421069/380160 * ( 7/5 \
)**( 1/2 ) + 
 	 ( 316393459/126720 * ( 35 )**( -1/2 ) * nu + 
 	 ( -64705511/190080 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 24768581/380160 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( -658519789/760320 * ( 35 \
)**( -1/2 ) + 
 	 ( 2584214551/760320 * ( 35 )**( -1/2 ) * nu + 
 	 ( -276713443/380160 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 293154703/760320 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) \
) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 5/2 ) * ( complex( 0,-1 ) * ( 5/7 )**( 1/2 ) + 
 	 ( 2/3 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,22 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -2 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-29/16 ) \
* ( 5/7 )**( 1/2 ) + 
 	 ( 29/24 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,309/8 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -29/8 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,1/4 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 complex( 0,-3/4 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-7/16 ) * ( 35 \
)**( 1/2 ) + 
 	 ( 7/24 * ( 35 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,549/8 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -7/8 * ( 35 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-27/4 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,81/4 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,27/4 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,-81/4 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) ) ) \
) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,-1/2 ) * ( 35 )**( 1/2 ) + 
 	 ( 1/3 * ( 35 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,303/4 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -1 * ( 35 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-2 ) * ( 35 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,6 ) * ( 35 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-23/8 ) * ( 5/7 \
)**( 1/2 ) + 
 	 ( 23/12 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,481/8 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -23/4 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,1/2 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 complex( 0,-3/2 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) ) ) ) ) ) + 
 	 ( complex( 0,27/2 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-81/2 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-53/8 ) * ( 5/7 \
)**( 1/2 ) + 
 	 ( 53/12 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,1201/8 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -53/4 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,209/6 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-209/2 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-27/2 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,81/2 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) ) ) \
) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( \
0,-549/128 ) * ( 5/7 )**( 1/2 ) + 
 	 ( 1661/576 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,807/64 ) * ( 7/5 )**( 1/2 ) * nu + 
 	 ( -1661/192 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,241/288 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 complex( 0,-241/96 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) ) ) ) ) \
) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-85/128 ) * ( \
35 )**( 1/2 ) + 
 	 ( 85/192 * ( 35 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,1279/64 ) * ( 5/7 )**( 1/2 ) * nu + 
 	 ( -85/64 * ( 35 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-2227/96 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,2227/32 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,351/16 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,-1053/16 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) \
) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-615/128 ) * ( \
5/7 )**( 1/2 ) + 
 	 ( 205/64 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,1327/64 ) * ( 5/7 )**( 1/2 ) * nu + 
 	 ( -615/64 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,8569/96 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-8569/32 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-1485/32 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,4455/32 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) ) \
) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,-1609/128 ) * ( \
5/7 )**( 1/2 ) + 
 	 ( 1609/192 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,18369/64 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -1609/64 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-29371/288 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,29371/96 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,81/16 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-243/16 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,15625/288 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,-15625/96 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) \
) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-6 ) * ( 5/7 )**( 1/2 ) + 
 	 ( 4 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,37/2 ) * ( 7/5 )**( 1/2 ) * nu + 
 	 ( -12 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,464/3 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-464 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-37/6 ) * ( 5/7 \
)**( 1/2 ) + 
 	 ( 611/144 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,1999/16 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -611/48 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,23/18 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 complex( 0,-23/6 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) ) ) ) ) ) \
+ 
 	 ( complex( 0,-675/8 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,2025/8 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-145/24 ) * ( \
5/7 )**( 1/2 ) + 
 	 ( 191/48 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,415/16 ) * ( 5/7 )**( 1/2 ) * nu + 
 	 ( -191/16 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-319/9 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,319/3 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,531/16 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,-1593/16 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) \
) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-125/24 ) * ( \
5/7 )**( 1/2 ) + 
 	 ( 125/36 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,351/16 ) * ( 5/7 )**( 1/2 ) * nu + 
 	 ( -125/12 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-2776/9 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,2776/3 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,405/8 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-1215/8 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,15625/144 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,-15625/48 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) \
) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,-533/24 ) * ( \
5/7 )**( 1/2 ) + 
 	 ( 533/36 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,8159/16 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -533/12 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,2231/18 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-2231/6 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,279/16 ) * ( 35 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-837/16 ) * ( 35 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-15625/144 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,15625/48 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) \
) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( \
0,-15807/2048 ) * ( 5/7 )**( 1/2 ) + 
 	 ( 44971/9216 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,24341/1024 ) * ( 7/5 )**( 1/2 ) * nu + 
 	 ( -44971/3072 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-240349/4608 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,240349/1536 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + \

 	 ( complex( 0,3105/64 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,-9315/64 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) \
) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-21841/3072 ) * \
( 5/7 )**( 1/2 ) + 
 	 ( 21925/4608 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,234961/1536 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -21925/1536 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,186437/768 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-186437/256 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-17397/128 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,52191/128 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,-53077/6144 ) * ( 5/7 )**( 1/2 ) + 
 	 ( 31663/1024 * ( 35 )**( -1/2 ) * np.pi + 
 	 ( complex( 0,75571/3072 ) * ( 7/5 )**( 1/2 ) * nu + 
 	 ( -94989/1024 * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( complex( 0,47351/4608 ) * ( 35 )**( -1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-47351/1536 ) * ( 35 )**( -1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-459/512 ) * ( 35 )**( -1/2 ) * np.log( 3 ) + 
 	 complex( 0,1377/512 ) * ( 35 )**( -1/2 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-22741/3072 ) * ( 5/7 )**( 1/2 ) + 
 	 ( 22741/4608 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,245761/1536 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -22741/1536 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-1308149/2304 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,1308149/768 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,30537/256 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-91611/256 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,203125/1152 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,-203125/384 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,-6707/2048 ) * ( 5/7 )**( 1/2 ) + 
 	 ( 6707/3072 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,8741/1024 ) * ( 7/5 )**( 1/2 ) * nu + 
 	 ( -6707/1024 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,2621959/4608 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-2621959/1536 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,29349/128 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-88047/128 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-1796875/4608 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,1796875/1536 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,-32911/6144 ) * ( 35 )**( 1/2 ) + 
 	 ( 32911/9216 * ( 35 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,2656597/3072 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -32911/3072 * ( 35 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-740869/512 ) * ( 35 )**( -1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,2222607/512 ) * ( 35 )**( -1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-7767/32 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,23301/32 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,15625/384 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,-15625/128 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,823543/4608 ) * ( 7/5 )**( 1/2 ) * np.log( 7 ) + 
 	 complex( 0,-823543/1536 ) * ( 7/5 )**( 1/2 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-17/2 ) * ( 5/7 )**( 1/2 ) + 
 	 ( 19591/3456 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,733/4 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -19591/1152 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-24761/27 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,24761/9 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,27081/128 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-81243/128 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-1049/128 ) * ( 5/7 )**( 1/2 ) + 
 	 ( 12839/2304 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,67559/384 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -12839/768 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,105257/288 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-105257/96 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-53415/256 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,160245/256 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-2341/48 ) * ( 35 )**( -1/2 ) + 
 	 ( 10813/384 * ( 35 )**( -1/2 ) * np.pi + 
 	 ( complex( 0,204103/960 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -10813/128 * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( complex( 0,-1943/36 ) * ( 7/5 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,1943/12 ) * ( 7/5 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,11187/32 ) * ( 35 )**( -1/2 ) * np.log( 3 ) + 
 	 complex( 0,-33561/32 ) * ( 35 )**( -1/2 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,-7589/128 ) * ( 35 )**( -1/2 ) + 
 	 ( 310351/6912 * ( 35 )**( -1/2 ) * np.pi + 
 	 ( complex( 0,148613/640 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -310351/2304 * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( complex( 0,14603/864 ) * ( 35 )**( -1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-14603/288 ) * ( 35 )**( -1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-459/256 ) * ( 35 )**( -1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,1377/256 ) * ( 35 )**( -1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-44/27 ) * ( 35 )**( -1/2 ) * np.log( 4 ) + 
 	 complex( 0,44/9 ) * ( 35 )**( -1/2 ) * nu * np.log( 4 ) ) ) ) ) ) ) ) ) ) + 
 	 ( complex( 0,921875/3456 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,-921875/1152 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-491/384 ) * ( 35 )**( 1/2 ) + 
 	 ( 491/576 * ( 35 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,74519/384 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -491/192 * ( 35 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,113425/96 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-113425/32 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,41427/128 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-124281/128 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-78125/768 ) * ( 35 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,78125/256 ) * ( 35 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,18 ) * ( 35 )**( -1/2 ) + 
 	 ( -12 * ( 35 )**( -1/2 ) * np.pi + 
 	 ( complex( 0,-103577/960 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 36 * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( complex( 0,-8866/9 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,8866/3 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-1152693/256 ) * ( 35 )**( -1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,3458079/256 ) * ( 35 )**( -1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,1015625/2304 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,-1015625/768 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,823543/2304 ) * ( 7/5 )**( 1/2 ) * np.log( 7 ) + 
 	 complex( 0,-823543/768 ) * ( 7/5 )**( 1/2 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,-39259/128 ) * ( 35 )**( -1/2 ) + 
 	 ( 39259/192 * ( 35 )**( -1/2 ) * np.pi + 
 	 ( complex( 0,908693/640 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -39259/64 * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( complex( 0,6339593/864 ) * ( 35 )**( -1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-6339593/288 ) * ( 35 )**( -1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,116883/256 ) * ( 35 )**( -1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-350649/256 ) * ( 35 )**( -1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,15625/3456 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,-15625/1152 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,-823543/2304 ) * ( 7/5 )**( 1/2 ) * np.log( 7 ) + 
 	 complex( 0,823543/768 ) * ( 7/5 )**( 1/2 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ))
    
    return(h)

# %% [markdown]
# ## Amplitude $(\ell, m)$ = (3, 1)

# %%
def amplitude_31(xi, x, nu, Delta, e):
    
    h = complex( 0,-1/12 ) * ( 14 )**( -1/2 ) * Delta * ( ( -1 + 
 	 ( 3 * ( e )**( 2 ) + 
 	 ( 3/4 * ( e )**( 4 ) + 
 	 ( 3/8 * ( e )**( 6 ) + 
 	 ( ( 5 * e + 
 	 ( 1/8 * ( e )**( 3 ) + 
 	 73/192 * ( e )**( 5 ) ) ) * ( np.e )**( complex( 0,-1 ) * xi ) + 
 	 ( ( -1 * e + 
 	 ( 19/8 * ( e )**( 3 ) + 
 	 43/192 * ( e )**( 5 ) ) ) * ( np.e )**( complex( 0,1 ) * xi ) + 
 	 ( ( 25/4 * ( e )**( 2 ) + 
 	 ( -43/24 * ( e )**( 4 ) + 
 	 109/192 * ( e )**( 6 ) ) ) * ( np.e )**( complex( 0,-2 ) * xi ) + 
 	 ( ( 1/4 * ( e )**( 2 ) + 
 	 ( 53/24 * ( e )**( 4 ) + 
 	 -35/192 * ( e )**( 6 ) ) ) * ( np.e )**( complex( 0,2 ) * xi ) + 
 	 ( ( 65/8 * ( e )**( 3 ) + 
 	 -591/128 * ( e )**( 5 ) ) * ( np.e )**( complex( 0,-3 ) * xi ) + 
 	 ( ( 11/8 * ( e )**( 3 ) + 
 	 219/128 * ( e )**( 5 ) ) * ( np.e )**( complex( 0,3 ) * xi ) + 
 	 ( ( 515/48 * ( e )**( 4 ) + 
 	 -2159/240 * ( e )**( 6 ) ) * ( np.e )**( complex( 0,-4 ) * xi ) + 
 	 ( ( 131/48 * ( e )**( 4 ) + 
 	 29/48 * ( e )**( 6 ) ) * ( np.e )**( complex( 0,4 ) * xi ) + 
 	 ( 5485/384 * ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) + 
 	 ( 1735/384 * ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) + 
 	 ( 1223/64 * ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) + 
 	 2227/320 * ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) * ( x )**( 1/2 ) + 
 	 ( ( x )**( 3/2 ) * ( 8/3 + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( -537277/1920 + 
 	 -227/60 * nu ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( -188705/1152 + 
 	 -5749/2304 * nu ) + 
 	 ( 2/3 * nu + 
 	 ( ( e )**( 2 ) * ( -79/12 + 
 	 13/6 * nu ) + 
 	 ( ( e )**( 4 ) * ( -347/24 + 
 	 11/3 * nu ) + 
 	 ( ( e )**( 6 ) * ( -805/48 + 
 	 25/6 * nu ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( -299155/1152 + 
 	 144661/2304 * nu ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( -777397/1920 + 
 	 46127/480 * nu ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( e * ( -7/3 + 
 	 7/6 * nu ) + 
 	 ( ( e )**( 3 ) * ( 7/6 + 
 	 173/48 * nu ) + 
 	 ( e )**( 5 ) * ( -7477/576 + 
 	 5407/1152 * nu ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 3 ) * ( -134/3 + 
 	 -23/48 * nu ) + 
 	 ( e )**( 5 ) * ( 23195/384 + 
 	 3859/768 * nu ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 2 ) * ( -421/24 + 
 	 1/3 * nu ) + 
 	 ( ( e )**( 4 ) * ( 2621/144 + 
 	 301/72 * nu ) + 
 	 ( e )**( 6 ) * ( -25799/1152 + 
 	 91/18 * nu ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 4 ) * ( -3247/36 + 
 	 -101/72 * nu ) + 
 	 ( e )**( 6 ) * ( 422443/2880 + 
 	 8879/1440 * nu ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( ( e )**( 3 ) * ( -53/3 + 
 	 139/48 * nu ) + 
 	 ( ( e )**( 5 ) * ( -14327/576 + 
 	 5345/1152 * nu ) + 
 	 e * ( -77/3 + 
 	 41/6 * nu ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 4 ) * ( 109/144 + 
 	 -79/72 * nu ) + 
 	 ( ( e )**( 6 ) * ( -32431/1152 + 
 	 1637/288 * nu ) + 
 	 ( e )**( 2 ) * ( -1301/24 + 
 	 85/6 * nu ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 5 ) * ( 17129/384 + 
 	 -8435/768 * nu ) + 
 	 ( e )**( 3 ) * ( -583/6 + 
 	 1183/48 * nu ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 6 ) * ( 384443/2880 + 
 	 -44477/1440 * nu ) + 
 	 ( e )**( 4 ) * ( -5837/36 + 
 	 2885/72 * nu ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 5/2 ) * ( -607/198 + 
 	 ( 136/99 * nu + 
 	 ( 247/198 * ( nu )**( 2 ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( -86987299/253440 + 
 	 ( 33747551/42240 * nu + 
 	 -6301373/12672 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( -3236527/19008 + 
 	 ( 145148405/304128 * nu + 
 	 -74335931/304128 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( -107691919/50688 + 
 	 ( 191528717/126720 * nu + 
 	 -852373/63360 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( -84368173/76032 + 
 	 ( 27685435/33792 * nu + 
 	 -1183621/304128 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( -715175/6336 + 
 	 ( 428063/3168 * nu + 
 	 -985/396 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 4 ) * ( -125489/2112 + 
 	 ( 261091/3168 * nu + 
 	 29/396 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 2 ) * ( -38/9 + 
 	 ( 103/4 * nu + 
 	 35/18 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 6 ) * ( 45688871/63360 + 
 	 ( -6067799/23760 * nu + 
 	 -40465/4752 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 4 ) * ( -20188603/38016 + 
 	 ( 7867861/19008 * nu + 
 	 925/9504 * ( nu )**( 2 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( ( e )**( 5 ) * ( -2380291/38016 + 
 	 ( 9536807/152064 * nu + 
 	 -410081/152064 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 3 ) * ( -4475/528 + 
 	 ( 183527/6336 * nu + 
 	 -7441/6336 * ( nu )**( 2 ) ) ) + 
 	 e * ( -3115/198 + 
 	 ( 10427/792 * nu + 
 	 691/792 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 4 ) * ( 248153/9504 + 
 	 ( 217429/4752 * nu + 
 	 -19585/4752 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( -21980947/152064 + 
 	 ( 9335929/76032 * nu + 
 	 -136259/38016 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 2 ) * ( -56989/792 + 
 	 ( 2240/33 * nu + 
 	 941/792 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 5 ) * ( 62365/288 + 
 	 ( -54637/3072 * nu + 
 	 -65815/9216 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 3 ) * ( -21877/99 + 
 	 ( 1182923/6336 * nu + 
 	 7963/6336 * ( nu )**( 2 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( ( e )**( 5 ) * ( -3312755/19008 + 
 	 ( 1034419/5632 * nu + 
 	 -376927/152064 * ( nu )**( 2 ) ) ) + 
 	 ( e * ( 1619/99 + 
 	 ( 20077/792 * nu + 
 	 2765/792 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 3 ) * ( -15047/198 + 
 	 ( 620129/6336 * nu + 
 	 25297/6336 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 6 ) * ( -7508873/50688 + 
 	 ( 13953961/76032 * nu + 
 	 -410455/38016 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 2 ) * ( 1141/72 + 
 	 ( 2363/36 * nu + 
 	 -445/72 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 4 ) * ( -394703/9504 + 
 	 ( 426131/4752 * nu + 
 	 104779/4752 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 3 ) * ( -439/48 + 
 	 ( 81767/576 * nu + 
 	 -21361/576 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 5 ) * ( 17817/2816 + 
 	 ( 5811589/101376 * nu + 
 	 8228413/101376 * ( nu )**( 2 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 4 ) * ( -229009/3456 + 
 	 ( 467731/1728 * nu + 
 	 -92249/864 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 6 ) * ( 3622489/38016 + 
 	 ( -831011/23760 * nu + 
 	 5492543/23760 * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 2 ) * ( complex( 0,7/5 ) + 
 	 ( -1 * np.pi + 
 	 ( ( e )**( 2 ) * ( complex( 0,-49/5 ) + 
 	 ( 7 * np.pi + 
 	 ( complex( 0,1232/45 ) * nu + 
 	 complex( 0,2 ) * np.log( 2 ) ) ) ) + 
 	 ( complex( 0,2 ) * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 3 ) * ( complex( 0,301/40 ) + 
 	 ( 65/24 * np.pi + 
 	 ( complex( 0,-154/5 ) * nu + 
 	 complex( 0,65/12 ) * np.log( 2 ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,-3857/128 ) + 
 	 ( 493/128 * np.pi + 
 	 ( complex( 0,-7503/80 ) * nu + 
 	 ( complex( 0,-2177/192 ) * np.log( 2 ) + 
 	 complex( 0,567/64 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( ( e )**( 3 ) * ( complex( 0,-539/40 ) + 
 	 ( 55/8 * np.pi + 
 	 ( complex( 0,-1747/18 ) * nu + 
 	 complex( 0,-5/4 ) * np.log( 2 ) ) ) ) + 
 	 ( e * ( complex( 0,7/5 ) + 
 	 ( -1 * np.pi + 
 	 ( complex( 0,-1232/45 ) * nu + 
 	 complex( 0,2 ) * np.log( 2 ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,-1099/64 ) + 
 	 ( 2171/192 * np.pi + 
 	 ( complex( 0,-7801/45 ) * nu + 
 	 ( complex( 0,-8339/96 ) * np.log( 2 ) + 
 	 complex( 0,81 ) * np.log( 3 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 4 ) * ( complex( 0,-98/5 ) + 
 	 ( 149/24 * np.pi + 
 	 ( complex( 0,-8119/90 ) * nu + 
 	 complex( 0,-4/3 ) * np.log( 2 ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,7/2 ) + 
 	 ( 1/4 * np.pi + 
 	 ( complex( 0,-1232/45 ) * nu + 
 	 complex( 0,5 ) * np.log( 2 ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-1099/60 ) + 
 	 ( 9593/768 * np.pi + 
 	 ( complex( 0,-32173/216 ) * nu + 
 	 ( complex( 0,-213/2 ) * np.log( 2 ) + 
 	 complex( 0,6399/64 ) * np.log( 3 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( e * ( complex( 0,-63/5 ) + 
 	 ( 9 * np.pi + 
 	 complex( 0,-2 ) * np.log( 2 ) ) ) + 
 	 ( ( e )**( 3 ) * ( complex( 0,-469/40 ) + 
 	 ( 67/8 * np.pi + 
 	 ( complex( 0,154/45 ) * nu + 
 	 ( complex( 0,-259/4 ) * np.log( 2 ) + 
 	 complex( 0,243/4 ) * np.log( 3 ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,-3367/192 ) + 
 	 ( 787/64 * np.pi + 
 	 ( complex( 0,6473/432 ) * nu + 
 	 ( complex( 0,34211/96 ) * np.log( 2 ) + 
 	 complex( 0,-2997/16 ) * np.log( 3 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-609/40 ) + 
 	 ( 337/32 * np.pi + 
 	 ( complex( 0,3733/30 ) * nu + 
 	 ( complex( 0,-295/4 ) * np.log( 2 ) + 
 	 complex( 0,2187/32 ) * np.log( 3 ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( complex( 0,-77/4 ) + 
 	 ( 1919/144 * np.pi + 
 	 ( complex( 0,53063/180 ) * nu + 
 	 ( complex( 0,857/2 ) * np.log( 2 ) + 
 	 complex( 0,-3645/16 ) * np.log( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 4 ) * ( complex( 0,3451/240 ) + 
 	 ( 449/64 * np.pi + 
 	 ( complex( 0,-4928/135 ) * nu + 
 	 ( complex( 0,365/24 ) * np.log( 2 ) + 
 	 complex( 0,-567/64 ) * np.log( 3 ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-28861/600 ) + 
 	 ( -47/24 * np.pi + 
 	 ( complex( 0,-13774/135 ) * nu + 
 	 ( complex( 0,-1759/60 ) * np.log( 2 ) + 
 	 ( complex( 0,891/80 ) * np.log( 3 ) + 
 	 complex( 0,208/15 ) * np.log( 4 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,48979/1920 ) + 
 	 ( 27209/1920 * np.pi + 
 	 ( complex( 0,-9625/216 ) * nu + 
 	 ( complex( 0,5845/192 ) * np.log( 2 ) + 
 	 ( complex( 0,-567/64 ) * np.log( 3 ) + 
 	 complex( 0,-208/15 ) * np.log( 4 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 3 ) * ( complex( 0,-2429/40 ) + 
 	 ( 347/8 * np.pi + 
 	 ( complex( 0,2519/12 ) * np.log( 2 ) + 
 	 complex( 0,-243/4 ) * np.log( 3 ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,1561/128 ) + 
 	 ( -1115/128 * np.pi + 
 	 ( complex( 0,77/40 ) * nu + 
 	 ( complex( 0,-55269/64 ) * np.log( 2 ) + 
 	 ( complex( 0,891/8 ) * np.log( 3 ) + 
 	 complex( 0,59375/192 ) * np.log( 5 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 2 ) * ( complex( 0,-63/2 ) + 
 	 ( 45/2 * np.pi + 
 	 ( complex( 0,-61 ) * np.log( 2 ) + 
 	 complex( 0,243/4 ) * np.log( 3 ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-203/30 ) + 
 	 ( 29/6 * np.pi + 
 	 ( complex( 0,308/135 ) * nu + 
 	 ( complex( 0,321 ) * np.log( 2 ) + 
 	 complex( 0,-1377/8 ) * np.log( 3 ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-4991/240 ) + 
 	 ( 22519/1536 * np.pi + 
 	 ( complex( 0,10583/1080 ) * nu + 
 	 ( complex( 0,-8011/8 ) * np.log( 2 ) + 
 	 ( complex( 0,88857/512 ) * np.log( 3 ) + 
 	 complex( 0,178125/512 ) * np.log( 5 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 4 ) * ( complex( 0,-8463/80 ) + 
 	 ( 1209/16 * np.pi + 
 	 ( complex( 0,-3609/8 ) * np.log( 2 ) + 
 	 ( complex( 0,-243/32 ) * np.log( 3 ) + 
 	 complex( 0,59375/192 ) * np.log( 5 ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,34279/600 ) + 
 	 ( -4897/120 * np.pi + 
 	 ( complex( 0,1232/675 ) * nu + 
 	 ( complex( 0,75269/60 ) * np.log( 2 ) + 
 	 ( complex( 0,47871/80 ) * np.log( 3 ) + 
 	 complex( 0,-15625/16 ) * np.log( 5 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,8617/200 ) + 
 	 ( 591407/23040 * np.pi + 
 	 ( complex( 0,-1386/25 ) * nu + 
 	 ( complex( 0,9799/180 ) * np.log( 2 ) + 
 	 ( complex( 0,-5103/512 ) * np.log( 3 ) + 
 	 ( complex( 0,-208/15 ) * np.log( 4 ) + 
 	 complex( 0,-96875/4608 ) * np.log( 5 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,-111657/640 ) + 
 	 ( 15951/128 * np.pi + 
 	 ( complex( 0,283687/960 ) * np.log( 2 ) + 
 	 ( complex( 0,46251/80 ) * np.log( 3 ) + 
 	 complex( 0,-59375/192 ) * np.log( 5 ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,-111181/400 ) + 
 	 ( 15883/80 * np.pi + 
 	 ( complex( 0,-362243/360 ) * np.log( 2 ) + 
 	 ( complex( 0,-1503927/2560 ) * np.log( 3 ) + 
 	 ( complex( 0,-59375/1536 ) * np.log( 5 ) + 
 	 complex( 0,23882747/23040 ) * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 3 ) * ( complex( 0,-56/15 ) + 
 	 ( 8/3 * np.pi + 
 	 ( nu * ( complex( 0,1/15 ) + 
 	 ( 7/6 * np.pi + 
 	 complex( 0,-7/3 ) * np.log( 2 ) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,793/60 ) + 
 	 ( -319/12 * np.pi + 
 	 ( complex( 0,3308/495 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,-13913/132 ) + 
 	 ( 14/3 * np.pi + 
 	 complex( 0,20/3 ) * np.log( 2 ) ) ) + 
 	 complex( 0,-17/6 ) * np.log( 2 ) ) ) ) ) + 
 	 ( complex( 0,-16/3 ) * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( e * ( complex( 0,49/15 ) + 
 	 ( -7/3 * np.pi + 
 	 ( complex( 0,-10084/495 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,246847/990 ) + 
 	 ( 5/3 * np.pi + 
 	 complex( 0,-10/3 ) * np.log( 2 ) ) ) + 
 	 complex( 0,14/3 ) * np.log( 2 ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( complex( 0,-103/15 ) + 
 	 ( -1/12 * np.pi + 
 	 ( complex( 0,140903/1980 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,520903/990 ) + 
 	 ( 31/6 * np.pi + 
 	 complex( 0,71/6 ) * np.log( 2 ) ) ) + 
 	 complex( 0,124/3 ) * np.log( 2 ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,35407/2880 ) + 
 	 ( -8173/192 * np.pi + 
 	 ( complex( 0,284199/880 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-58135/288 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,2849573/12672 ) + 
 	 ( 2639/192 * np.pi + 
 	 ( complex( 0,-5287/288 ) * np.log( 2 ) + 
 	 complex( 0,729/32 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,5265/32 ) * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 3 ) * ( complex( 0,-1949/30 ) + 
 	 ( -3419/36 * np.pi + 
 	 ( complex( 0,883/198 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,3076829/7920 ) + 
 	 ( -49/18 * np.pi + 
 	 complex( 0,-215/18 ) * np.log( 2 ) ) ) + 
 	 complex( 0,-58/9 ) * np.log( 2 ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,204679/1920 ) + 
 	 ( 216095/1152 * np.pi + 
 	 ( complex( 0,2878583/15840 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,180791/576 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-562073/576 ) + 
 	 ( 12539/1152 * np.pi + 
 	 ( complex( 0,16871/576 ) * np.log( 2 ) + 
 	 complex( 0,-729/64 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-19035/64 ) * np.log( 3 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 4 ) * ( complex( 0,2723/360 ) + 
 	 ( 7615/144 * np.pi + 
 	 ( complex( 0,61768/495 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,125537/495 ) + 
 	 ( 979/144 * np.pi + 
 	 complex( 0,40/3 ) * np.log( 2 ) ) ) + 
 	 complex( 0,41/12 ) * np.log( 2 ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,-379/120 ) + 
 	 ( -619/24 * np.pi + 
 	 ( complex( 0,-3308/495 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,1438003/3960 ) + 
 	 ( 5/24 * np.pi + 
 	 complex( 0,-53/6 ) * np.log( 2 ) ) ) + 
 	 complex( 0,-337/12 ) * np.log( 2 ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-1367/160 ) + 
 	 ( -76889/4608 * np.pi + 
 	 ( complex( 0,9338059/23760 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-7759/18 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-135963347/95040 ) + 
 	 ( 55729/4608 * np.pi + 
 	 ( complex( 0,895/144 ) * np.log( 2 ) + 
 	 complex( 0,-243/128 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,164511/512 ) * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( e * ( complex( 0,1019/15 ) + 
 	 ( -197/3 * np.pi + 
 	 ( nu * ( complex( 0,-1874/15 ) + 
 	 ( 31/3 * np.pi + 
 	 complex( 0,10/3 ) * np.log( 2 ) ) ) + 
 	 complex( 0,-14/3 ) * np.log( 2 ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( complex( 0,336/5 ) + 
 	 ( -201/2 * np.pi + 
 	 ( complex( 0,2521/990 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,437/3 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,3227063/7920 ) + 
 	 ( 63/4 * np.pi + 
 	 ( complex( 0,-365/6 ) * np.log( 2 ) + 
 	 complex( 0,243/4 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-729/4 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,286357/2880 ) + 
 	 ( -32743/192 * np.pi + 
 	 ( complex( 0,-86057/9504 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,96527/288 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,6242293/2970 ) + 
 	 ( 5413/192 * np.pi + 
 	 ( complex( 0,62783/288 ) * np.log( 2 ) + 
 	 complex( 0,-2673/32 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-13689/32 ) * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,8269/240 ) + 
 	 ( -7399/96 * np.pi + 
 	 ( complex( 0,-14237/99 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-889/24 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-3415001/7920 ) + 
 	 ( 2761/192 * np.pi + 
 	 ( complex( 0,-937/24 ) * np.log( 2 ) + 
 	 complex( 0,2673/64 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-243/32 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( complex( 0,993/16 ) + 
 	 ( -479759/3456 * np.pi + 
 	 ( complex( 0,-5511281/7920 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,90859/72 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-951557/880 ) + 
 	 ( 46109/1728 * np.pi + 
 	 ( complex( 0,2215/18 ) * np.log( 2 ) + 
 	 complex( 0,-1863/64 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-120447/128 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 4 ) * ( complex( 0,-341287/1440 ) + 
 	 ( -24449/96 * np.pi + 
 	 ( complex( 0,5146/297 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-47873/144 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,15119893/47520 ) + 
 	 ( -2807/384 * np.pi + 
 	 ( complex( 0,-3335/144 ) * np.log( 2 ) + 
 	 complex( 0,891/128 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,10935/32 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,3074807/7200 ) + 
 	 ( 5934253/11520 * np.pi + 
 	 ( complex( 0,5957267/23760 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,634709/720 ) * np.log( 2 ) + 
 	 ( complex( 0,-62127/256 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,-51139519/14850 ) + 
 	 ( 106109/5760 * np.pi + 
 	 ( complex( 0,40499/720 ) * np.log( 2 ) + 
 	 ( complex( 0,-11583/640 ) * np.log( 3 ) + 
 	 complex( 0,-112/9 ) * np.log( 4 ) ) ) ) ) + 
 	 complex( 0,-27836/45 ) * np.log( 4 ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,-3542717/5760 ) + 
 	 ( -3339643/5760 * np.pi + 
 	 ( complex( 0,1622647/47520 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-552179/576 ) * np.log( 2 ) + 
 	 ( complex( 0,19035/64 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,185395151/1900800 ) + 
 	 ( -78919/5760 * np.pi + 
 	 ( complex( 0,-22403/576 ) * np.log( 2 ) + 
 	 ( complex( 0,729/64 ) * np.log( 3 ) + 
 	 complex( 0,248/45 ) * np.log( 4 ) ) ) ) ) + 
 	 complex( 0,30956/45 ) * np.log( 4 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 4 ) * ( complex( 0,13933/360 ) + 
 	 ( -9049/72 * np.pi + 
 	 ( complex( 0,2521/1485 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-7261/12 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,20435989/5940 ) + 
 	 ( 697/36 * np.pi + 
 	 ( complex( 0,1945/6 ) * np.log( 2 ) + 
 	 complex( 0,-2349/16 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,1701/16 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,4933/24 ) + 
 	 ( -5195/24 * np.pi + 
 	 ( complex( 0,5867/12 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,9731/120 ) + 
 	 ( 449/12 * np.pi + 
 	 ( complex( 0,-545/6 ) * np.log( 2 ) + 
 	 complex( 0,729/8 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-486 ) * np.log( 3 ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,113089/720 ) + 
 	 ( -615811/2304 * np.pi + 
 	 ( complex( 0,-151307/23760 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,35/16 ) * np.log( 2 ) + 
 	 ( complex( 0,12555/128 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,967028773/95040 ) + 
 	 ( 408167/9216 * np.pi + 
 	 ( complex( 0,-19573/24 ) * np.log( 2 ) + 
 	 ( complex( 0,98739/1024 ) * np.log( 3 ) + 
 	 complex( 0,1103125/3072 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-633125/1536 ) * np.log( 5 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 3 ) * ( complex( 0,5137/10 ) + 
 	 ( -518 * np.pi + 
 	 ( complex( 0,-12889/9 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,10997/45 ) + 
 	 ( 377/4 * np.pi + 
 	 ( complex( 0,5641/18 ) * np.log( 2 ) + 
 	 complex( 0,-243/4 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,729/4 ) * np.log( 3 ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,-113081/640 ) + 
 	 ( -937/128 * np.pi + 
 	 ( complex( 0,2521/1760 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,1238561/576 ) * np.log( 2 ) + 
 	 ( complex( 0,5913/32 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,992335501/126720 ) + 
 	 ( -489/128 * np.pi + 
 	 ( complex( 0,-591151/576 ) * np.log( 2 ) + 
 	 ( complex( 0,2187/32 ) * np.log( 3 ) + 
 	 complex( 0,28125/64 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-80625/64 ) * np.log( 5 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 4 ) * ( complex( 0,321821/288 ) + 
 	 ( -309895/288 * np.pi + 
 	 ( complex( 0,458375/144 ) * np.log( 2 ) + 
 	 ( complex( 0,4131/32 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,506777/1440 ) + 
 	 ( 57995/288 * np.pi + 
 	 ( complex( 0,-109483/144 ) * np.log( 2 ) + 
 	 ( complex( 0,-729/64 ) * np.log( 3 ) + 
 	 complex( 0,228125/384 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-269375/96 ) * np.log( 5 ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-2021611/2400 ) + 
 	 ( 220873/480 * np.pi + 
 	 ( complex( 0,10084/7425 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-67407/16 ) * np.log( 2 ) + 
 	 ( complex( 0,-1885437/640 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,2370925619/148500 ) + 
 	 ( -8971/96 * np.pi + 
 	 ( complex( 0,27761/16 ) * np.log( 2 ) + 
 	 ( complex( 0,63099/64 ) * np.log( 3 ) + 
 	 complex( 0,-1684375/1152 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,9398125/2304 ) * np.log( 5 ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,12784993/5760 ) + 
 	 ( -2371159/1152 * np.pi + 
 	 ( complex( 0,-324001/320 ) * np.log( 2 ) + 
 	 ( complex( 0,-914733/160 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,4665157/14400 ) + 
 	 ( 451097/1152 * np.pi + 
 	 ( complex( 0,133007/320 ) * np.log( 2 ) + 
 	 ( complex( 0,200961/160 ) * np.log( 3 ) + 
 	 complex( 0,-28125/64 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,80625/64 ) * np.log( 5 ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,-3261839/2400 ) + 
 	 ( -82499293/69120 * np.pi + 
 	 ( complex( 0,141412/2475 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-2315569/1080 ) * np.log( 2 ) + 
 	 ( complex( 0,156573/512 ) * np.log( 3 ) + 
 	 ( complex( 0,27836/45 ) * np.log( 4 ) + 
 	 ( nu * ( complex( 0,457812343/792000 ) + 
 	 ( -602149/27648 * np.pi + 
 	 ( complex( 0,-6385/108 ) * np.log( 2 ) + 
 	 ( complex( 0,17091/1024 ) * np.log( 3 ) + 
 	 ( complex( 0,112/9 ) * np.log( 4 ) + 
 	 complex( 0,3125/27648 ) * np.log( 5 ) ) ) ) ) ) + 
 	 complex( 0,4384375/3456 ) * np.log( 5 ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,4970923/1200 ) + 
 	 ( -1789373/480 * np.pi + 
 	 ( complex( 0,23213621/2160 ) * np.log( 2 ) + 
 	 ( complex( 0,942111/320 ) * np.log( 3 ) + 
 	 ( complex( 0,1073125/1536 ) * np.log( 5 ) + 
 	 ( nu * ( complex( 0,-35896303/14400 ) + 
 	 ( 343819/480 * np.pi + 
 	 ( complex( 0,-5288227/2160 ) * np.log( 2 ) + 
 	 ( complex( 0,-1001889/1024 ) * np.log( 3 ) + 
 	 ( complex( 0,-228125/3072 ) * np.log( 5 ) + 
 	 complex( 0,346711603/138240 ) * np.log( 7 ) ) ) ) ) ) + 
 	 complex( 0,-78183763/6912 ) * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(h)

# %% [markdown]
# ## Amplitude $(\ell, m)$ = (4, 4)

# %%
# ## Amplitude $(\ell, m)$ = (4, 4)

def amplitude_44(xi, x, nu, Delta, e):
    
    h = ( x )**( 3/2 ) * ( complex( 0,5/6912 ) * ( 5/7 )**( 1/2 ) * ( e )**( 4 ) * ( np.e )**( complex( 0,4 ) * xi ) * nu + ( ( e )**( 5 ) * ( complex( 0,-5/1728 ) * ( 5/7 )**( 1/2 ) * ( np.e )**( complex( 0,3 ) * xi ) * nu + 
 	 complex( 0,5/1728 ) * ( 5/7 )**( 1/2 ) * ( np.e )**( complex( 0,5 ) * xi ) * nu ) + 
 	 ( e )**( 6 ) * ( complex( 0,55/13824 ) * ( 5/7 )**( 1/2 ) * ( np.e )**( complex( 0,2 ) * xi ) * nu + 
 	 ( complex( 0,-5/512 ) * ( 5/7 )**( 1/2 ) * ( np.e )**( complex( 0,4 ) * xi ) * nu + complex( 0,5/4608 ) * ( 35 )**( 1/2 ) * ( np.e )**( complex( 0,6 ) * xi ) * nu ) ) ) ) + ( x * ( -8/9 * ( 5/7 )**( 1/2 ) + 
 	 ( 8/3 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -113/144 * ( 5/7 )**( 1/2 ) + 
 	 113/48 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( -269/144 * ( 5/7 )**( 1/2 ) + 
 	 269/48 * ( 5/7 )**( 1/2 ) * nu ) ) + 
 	 ( ( e )**( 2 ) * ( -1/9 * ( 5/7 )**( 1/2 ) + 
 	 ( 1/3 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -37/36 * ( 5/7 )**( 1/2 ) 
    + 37/12 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( -121/36 * ( 5/7 )**( 1/2 ) + 121/12 * ( 5/7 )**( 1/2 ) * nu ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 341/384 * ( 5/7 )**( 1/2 ) + 
 	 -341/128 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -79/384 * ( 5/7 )**( 1/2 ) + 
 	 79/128 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( -1607/1152 * ( 5/7 )**( 1/2 ) + 
 	 1607/384 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,3 ) * xi ) * ( -6491/1152 * ( 5/7 )**( 1/2 ) + 
 	 6491/384 * ( 5/7 )**( 1/2 ) * nu ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -1/6 * ( 5/7 )**( 1/2 ) + 
 	 ( 1/2 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 80/27 * ( 5/7 )**( 1/2 ) + 
 	 -80/9 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -1/108 * ( 5/7 )**( 1/2 ) + 
 	 1/36 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( -827/432 * ( 5/7 )**( 1/2 ) + 
 	 827/144 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( -3917/432 * ( 5/7 )**( 1/2 ) +
 	 3917/144 * ( 5/7 )**( 1/2 ) * nu ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( 127229/18432 * ( 5/7 )**( 1/2 ) + 
 	 -127229/6144 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -5197/27648 * ( 5/7 )**( 1/2 ) + 
 	 5197/9216 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( -145885/55296 * ( 5/7 )**( 1/2 ) + 
 	 145885/18432 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( -785257/55296 * ( 5/7 )**( 1/2 ) + 
 	 785257/18432 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 1007/18432 * ( 35 )**( 1/2 ) + 
 	 -1007/6144 * ( 35 )**( 1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( -1183/27648 * ( 35 )**( 1/2 ) + 
 	 1183/9216 * ( 35 )**( 1/2 ) * nu ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( -11/72 * ( 5/7 )**( 1/2 ) + 
 	 ( 11/24 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -125/576 * ( 5/7 )**( 1/2 ) + 
 	 125/192 * ( 5/7 )**( 1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 20087/288 * ( 35 )**( -1/2 ) + 
 	 -20087/96 * ( 35 )**( -1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 1541/288 * ( 35 )**( -1/2 ) + 
 	 -1541/96 * ( 35 )**( -1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( -10489/576 * ( 35 )**( -1/2 ) + 
 	 10489/192 * ( 35 )**( -1/2 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( -62827/576 * ( 35 )**( -1/2 ) + 
 	 62827/192 * ( 35 )**( -1/2 ) * nu ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( -89/576 * ( 35 )**( 1/2 ) + 
 	 89/192 * ( 35 )**( 1/2 ) * nu ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 2 ) * ( 2372/99 * ( 35 )**( -1/2 ) + 
 	 ( -5092/297 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( 100/99 * ( 35 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 19463/576 * ( 35 )**( -1/2 ) + 
 	 ( -20875/864 * ( 5/7 )**( 1/2 ) * nu + 
 	 2311/288 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( 234301/6336 * ( 35 )**( -1/2 ) + 
 	 ( -267725/9504 * ( 5/7 )**( 1/2 ) * nu + 
 	 46217/3168 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( 4426/99 * ( 35 )**( -1/2 ) + 
 	 ( -9494/297 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( 1016/99 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 16783/1584 * ( 5/7 )**( 1/2 ) + 
 	 ( -44657/1188 * ( 5/7 )**( 1/2 ) * nu + 
 	 4091/396 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( 76049/1584 * ( 35 )**( -1/2 ) + 
 	 ( -11789/297 * ( 5/7 )**( 1/2 ) * nu + 
 	 2540/99 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 2244667/50688 * ( 35 )**( -1/2 ) + 
 	 ( -816583/25344 * ( 5/7 )**( 1/2 ) * nu + 
 	 31197/2816 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( 3451867/50688 * ( 35 )**( -1/2 ) + 
 	 ( -1191163/25344 * ( 5/7 )**( 1/2 ) * nu + 
 	 99299/8448 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 4141229/50688 * ( 35 )**( -1/2 ) + 
 	 ( -4379447/76032 * ( 5/7 )**( 1/2 ) * nu + 
 	 335711/25344 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,3 ) * xi ) * ( 546793/50688 * ( 5/7 )**( 1/2 ) + 
 	 ( -3855059/76032 * ( 5/7 )**( 1/2 ) * nu + 
 	 1063619/25344 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( 148640299/811008 * ( 35 )**( -1/2 ) + 
 	 ( -137256715/1216512 * ( 5/7 )**( 1/2 ) * nu + 
 	 1483039/405504 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 67113509/1216512 * ( 35 )**( -1/2 ) + 
 	 ( -10446547/1824768 * ( 35 )**( 1/2 ) * nu + 
 	 8033713/608256 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( 67714421/1216512 * ( 35 )**( -1/2 ) + 
 	 ( -10546255/1824768 * ( 35 )**( 1/2 ) * nu + 
 	 8238205/608256 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 29311771/811008 * ( 35 )**( -1/2 ) + 
 	 ( -4795873/1216512 * ( 35 )**( 1/2 ) * nu + 
 	 5915731/405504 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( 452139701/2433024 * ( 35 )**( -1/2 ) + 
 	 ( -473216725/3649536 * ( 5/7 )**( 1/2 ) * nu + 
 	 25164481/1216512 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,5 ) * xi ) * ( 55192901/2433024 * ( 35 )**( -1/2 ) + 
 	 ( -218399161/3649536 * ( 5/7 )**( 1/2 ) * nu + 
 	 122176909/1216512 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( 1217/99 * ( 5/7 )**( 1/2 ) + 
 	 ( -13217/297 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( 5717/396 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 4516483/76032 * ( 35 )**( -1/2 ) + 
 	 ( -819391/19008 * ( 5/7 )**( 1/2 ) * nu + 
 	 2425/176 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 3244069/76032 * ( 35 )**( -1/2 ) + 
 	 ( -628189/19008 * ( 5/7 )**( 1/2 ) * nu + 
 	 1406/99 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 12197/8640 * ( 7/5 )**( 1/2 ) + 
 	 ( -2581/1728 * ( 35 )**( 1/2 ) * nu + 
 	 7261/576 * ( 7/5 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 30351487/95040 * ( 35 )**( -1/2 ) + 
 	 ( -506105/19008 * ( 35 )**( 1/2 ) * nu + 
 	 -136483/2112 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( 4991197/126720 * ( 7/5 )**( 1/2 ) + 
 	 ( -1820429/9504 * ( 5/7 )**( 1/2 ) * nu + 
 	 790469/6336 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,6 ) * xi ) * ( -67951/11520 * ( 7/5 )**( 1/2 ) + 
 	 ( -5689/864 * ( 35 )**( 1/2 ) * nu + 
 	 432853/576 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 4 ) * ( 1754/33 * ( 35 )**( -1/2 ) + 
 	 ( -3799/99 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( 412/33 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 424789/9504 * ( 35 )**( -1/2 ) + 
 	 ( -468977/14256 * ( 5/7 )**( 1/2 ) * nu + 
 	 59621/4752 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 21113/432 * ( 35 )**( -1/2 ) + 
 	 ( -21799/2592 * ( 35 )**( 1/2 ) * nu + 
 	 56869/864 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 1035679/9504 * ( 35 )**( -1/2 ) + 
 	 ( -1015481/14256 * ( 5/7 )**( 1/2 ) * nu + 
 	 7079/4752 * ( 35 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( 589261/4752 * ( 35 )**( -1/2 ) + 
 	 ( -354131/28512 * ( 35 )**( 1/2 ) * nu + 
 	 22703/9504 * ( 35 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 3 ) * ( -1068671/45045 * ( 35 )**( -1/2 ) + 
 	 ( 1088119/6435 * ( 35 )**( -1/2 ) * nu + 
 	 ( -293758/1053 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( 226097/3861 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -31572787/1441440 * ( 35 )**( -1/2 ) + 
 	 ( 208697927/823680 * ( 35 )**( -1/2 ) * nu + 
 	 ( -335898197/741312 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 28299721/494208 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( 61094909/1441440 * ( 35 )**( -1/2 ) + 
 	 ( 4076519/91520 * ( 35 )**( -1/2 ) * nu + 
 	 ( -74689717/741312 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 56536741/494208 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( 924136/15015 * ( 35 )**( -1/2 ) + 
 	 ( 20868787/154440 * ( 35 )**( -1/2 ) * nu + 
 	 ( -38032441/46332 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( 580289/7722 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 1511203/90090 * ( 35 )**( -1/2 ) + 
 	 ( 56202313/205920 * ( 35 )**( -1/2 ) * nu + 
 	 ( -125411623/185328 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 2013637/61776 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( 170540309/720720 * ( 35 )**( -1/2 ) + 
 	 ( -101136407/205920 * ( 35 )**( -1/2 ) * nu + 
 	 ( -126735319/185328 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 2783497/15444 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 1290559999/7687680 * ( 35 )**( -1/2 ) + 
 	 ( -3659729/1797120 * ( 7/5 )**( 1/2 ) * nu + 
 	 ( -2505002083/1976832 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 16637317/1317888 * ( 7/5 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 799781569/7687680 * ( 35 )**( -1/2 ) + 
 	 ( 70048139/2196480 * ( 7/5 )**( 1/2 ) * nu + 
 	 ( -825252377/5930496 * ( 7/5 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 -171338273/3953664 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 497949703/7687680 * ( 35 )**( -1/2 ) + 
 	 ( 5416489019/19768320 * ( 35 )**( -1/2 ) * nu + 
 	 ( -2231122591/1976832 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 68319943/1317888 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,3 ) * xi ) * ( 1026374533/1537536 * ( 35 )**( -1/2 ) + 
 	 ( -2386671533/1317888 * ( 35 )**( -1/2 ) * nu + 
 	 ( -4220383163/5930496 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 983417971/3953664 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( 3625385/64064 * ( 5/7 )**( 1/2 ) + 
 	 ( 1188989/27456 * ( 5/7 )**( 1/2 ) * nu + 
 	 ( -189325405/370656 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( 973937/247104 * ( 5/7 )**( 1/2 ) * ( nu )**( 3 ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( 1389975737/1310400 * ( 35 )**( -1/2 ) + 
 	 ( -4195445161/4118400 * ( 35 )**( -1/2 ) * nu + 
 	 ( -38410520581/14826240 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -11311848187/9884160 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 928055077/3843840 * ( 35 )**( -1/2 ) + 
 	 ( 2269871987/7413120 * ( 35 )**( -1/2 ) * nu + 
 	 ( -7052314097/2965248 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -923873/59904 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 1176312779/3843840 * ( 35 )**( -1/2 ) + 
 	 ( 1340617919/7413120 * ( 35 )**( -1/2 ) * nu + 
 	 ( complex( 0,209/2304 ) * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( -1606428067/2965248 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 24372823/658944 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( 84498781021/14414400 * ( 35 )**( -1/2 ) + 
 	 ( -11295051359/4118400 * ( 7/5 )**( 1/2 ) * nu + 
 	 ( complex( 0,19/768 ) * ( 7/5 )**( 1/2 ) * np.pi * nu + 
 	 ( 9301303873/2965248 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 1710284903/9884160 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 1185603857/19219200 * ( 35 )**( -1/2 ) + 
 	 ( 24101359427/37065600 * ( 35 )**( -1/2 ) * nu + 
 	 ( -3418372499/1482624 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 26664581/137280 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( -3708478127/6406400 * ( 35 )**( -1/2 ) + 
 	 ( 149055955319/37065600 * ( 35 )**( -1/2 ) * nu + 
 	 ( complex( 0,-76793/414720 ) * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( -42426983437/7413120 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 57996979/205920 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 4073172127/17297280 * ( 35 )**( -1/2 ) + 
 	 ( 26396851583/158146560 * ( 35 )**( -1/2 ) * nu + 
 	 ( -306405551581/142331904 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 1033768573/94887936 * ( 5/7 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( 22332988529/39536640 * ( 35 )**( -1/2 ) + 
 	 ( -9136566451/28753920 * ( 35 )**( -1/2 ) * nu + 
 	 ( -539425734769/284663808 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -103047445003/189775872 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 3124006957/17297280 * ( 35 )**( -1/2 ) + 
 	 ( 47086670663/158146560 * ( 35 )**( -1/2 ) * nu + 
 	 ( -283213771129/142331904 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 2272169381/94887936 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 10628649359/92252160 * ( 35 )**( -1/2 ) + 
 	 ( 131237106331/316293120 * ( 35 )**( -1/2 ) * nu + 
 	 ( -15991413041/8626176 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 3503212319/63258624 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( 9751384043/92252160 * ( 35 )**( -1/2 ) + 
 	 ( 301896301027/316293120 * ( 35 )**( -1/2 ) * nu + 
 	 ( complex( 0,-19/288 ) * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( -306720498079/94887936 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 9223192427/63258624 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,5 ) * xi ) * ( 17443533467/39536640 * ( 7/5 )**( 1/2 ) + 
 	 ( -3092297615321/316293120 * ( 35 )**( -1/2 ) * nu + 
 	 ( complex( 0,19/288 ) * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( 197000495051/284663808 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 56925211457/189775872 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 4 ) * ( 224743501/1441440 * ( 35 )**( -1/2 ) + 
 	 ( 19521043/102960 * ( 35 )**( -1/2 ) * nu + 
 	 ( -12436777/7722 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( 23561/416 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 1469803/38016 * ( 7/5 )**( 1/2 ) + 
 	 ( 145793/19008 * ( 7/5 )**( 1/2 ) * nu + 
 	 ( -46862587/171072 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 -605723/14256 * ( 5/7 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 865028159/8648640 * ( 35 )**( -1/2 ) + 
 	 ( 395109499/1235520 * ( 35 )**( -1/2 ) * nu + 
 	 ( -81280789/277992 * ( 5/7 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 891223/185328 * ( 7/5 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 2050947011/8648640 * ( 35 )**( -1/2 ) + 
 	 ( 20880337/411840 * ( 35 )**( -1/2 ) * nu + 
 	 ( -99235337/50544 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 3480037/33696 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( 26258398553/17297280 * ( 35 )**( -1/2 ) + 
 	 ( -1875288577/411840 * ( 35 )**( -1/2 ) * nu + 
 	 ( complex( 0,19/1152 ) * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( -76343263/202176 * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 111702271/370656 * ( 35 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 5/2 ) * ( complex( 0,16/3 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -32/9 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-1193/9 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 32/3 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-64/9 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,64/3 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,1319/96 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -1319/144 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-4069/12 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 1319/48 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-2777/72 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,2777/24 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,81/8 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,-243/8 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,359/32 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -359/48 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-12713/45 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 359/16 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,739/72 ) * ( 35 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-739/24 ) * ( 35 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-3125/72 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,3125/24 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,199/12 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -199/18 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-595229/1440 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 199/6 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,3655/9 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-3655/3 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-81/2 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,243/2 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,671/24 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -671/36 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-198113/288 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 671/12 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-691/6 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,691/2 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,81/2 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,-243/2 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( complex( 0,-3125/18 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,3125/6 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,33/8 ) * ( 35 )**( 1/2 ) + 
 	 ( -55/4 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-2261653/4320 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 165/4 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-547/18 ) * ( 35 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,547/6 ) * ( 35 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-162 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,486 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,3125/18 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,-3125/6 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,7879/768 ) * ( 35 )**( 1/2 ) + 
 	 ( -39395/1152 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-4535/18 ) * ( 5/7 )**( 1/2 ) * nu + 
 	 ( 39395/384 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-66353/1728 ) * ( 35 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,66353/576 ) * ( 35 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,243/16 ) * ( 35 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,-729/16 ) * ( 35 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,16681/768 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -2383/1152 * ( 35 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-585313/1080 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 2383/384 * ( 35 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-300445/192 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,300445/64 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-9477/16 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,28431/16 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,596875/576 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,-596875/192 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,16939/768 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -16939/1152 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-2373559/4320 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 16939/384 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,732715/576 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-732715/192 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-12879/64 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,38637/64 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-3125/48 ) * ( 35 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,3125/16 ) * ( 35 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,27161/768 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -27161/1152 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-3900689/4320 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 27161/384 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,1270859/1728 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-1270859/576 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,648 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-1944 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-34375/144 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,34375/48 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,-117649/1728 ) * ( 35 )**( 1/2 ) * np.log( 7 ) + 
 	 complex( 0,117649/576 ) * ( 35 )**( 1/2 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,167/6 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -167/9 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-2398897/3456 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 167/3 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-7087/9 ) * ( 35 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,7087/3 ) * ( 35 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-5265/4 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,15795/4 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,12769/144 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -12769/216 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-94481767/304128 ) * ( 7/5 )**( 1/2 ) * nu + 
 	 ( 12769/72 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-6553/20736 ) * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-19757/36 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,19757/12 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,3699/16 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,-11097/16 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( complex( 0,115625/36 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,-115625/12 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,1163/48 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -1163/72 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-249247/2880 ) * ( 7/5 )**( 1/2 ) * nu + 
 	 ( 1163/24 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,331589/108 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-331589/36 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-2349/4 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,7047/4 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-428125/432 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,428125/144 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,2791/48 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -2791/72 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-103082309/69120 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 2791/24 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-22931/36 ) * ( 35 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,22931/12 ) * ( 35 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-891 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,2673 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,53125/432 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,-53125/144 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,117649/432 ) * ( 35 )**( 1/2 ) * np.log( 7 ) + 
 	 complex( 0,-117649/144 ) * ( 35 )**( 1/2 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,3701/144 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -3701/216 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-1103821/1728 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 3701/72 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,172703/36 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-172703/12 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,8451/16 ) * ( 35 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-25353/16 ) * ( 35 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-9375/4 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,28125/4 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,-117649/432 ) * ( 35 )**( 1/2 ) * np.log( 7 ) + 
 	 complex( 0,117649/144 ) * ( 35 )**( 1/2 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,5434439/36864 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -9056671/18432 * ( 35 )**( -1/2 ) * np.pi + 
 	 ( complex( 0,-549163721/152064 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 9056671/6144 * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( complex( 0,-1883/10368 ) * ( 7/5 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-20361019/27648 ) * ( 7/5 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,20361019/9216 ) * ( 7/5 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,57807/128 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 complex( 0,-173421/128 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,218291/12288 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -218291/18432 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-512543/7920 ) * ( 7/5 )**( 1/2 ) * nu + 
 	 ( 218291/6144 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,1883/10368 ) * ( 7/5 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,25403615/27648 ) * ( 35 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-25403615/9216 ) * ( 35 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-174879/128 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,524637/128 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-6690625/3456 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,6690625/1152 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,207481/6144 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -207481/9216 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-87239279/103680 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 207481/3072 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-65527687/4608 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,65527687/1536 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-175311/512 ) * ( 35 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,525933/512 ) * ( 35 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,8846875/1152 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,-8846875/384 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,611681/18432 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -87383/27648 * ( 35 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-2045153/17280 ) * ( 7/5 )**( 1/2 ) * nu + 
 	 ( 87383/9216 * ( 35 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,239411041/13824 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-239411041/4608 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,1418175/128 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-4254525/128 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-125115625/13824 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,125115625/4608 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,-823543/1152 ) * ( 35 )**( 1/2 ) * np.log( 7 ) + 
 	 complex( 0,823543/384 ) * ( 35 )**( 1/2 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,318257/12288 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -318257/18432 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-43851289/69120 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 318257/6144 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-213600463/9216 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,213600463/3072 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-1046763/128 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,3140289/128 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,8359375/3456 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,-8359375/1152 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,14235529/9216 ) * ( 35 )**( 1/2 ) * np.log( 7 ) + 
 	 complex( 0,-14235529/3072 ) * ( 35 )**( 1/2 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,380621/4096 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -380621/6144 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-49608563/20736 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 380621/2048 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,1240618921/13824 ) * ( 35 )**( -1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-1240618921/4608 ) * ( 35 )**( -1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,459 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-1377 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-15625/1152 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,15625/384 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,-1294139/3456 ) * ( 35 )**( 1/2 ) * np.log( 7 ) + 
 	 ( complex( 0,1294139/1152 ) * ( 35 )**( 1/2 ) * nu * np.log( 7 ) + 
 	 ( complex( 0,-14348907/1024 ) * ( 35 )**( -1/2 ) * np.log( 18 ) + 
 	 complex( 0,43046721/1024 ) * ( 35 )**( -1/2 ) * nu * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,469/12 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -67/18 * ( 35 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-74873/384 ) * ( 5/7 )**( 1/2 ) * nu + 
 	 ( 67/6 * ( 35 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,3727882/81 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-3727882/27 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,3292407/128 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-9877221/128 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,457687/1920 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -16471187/20736 * ( 35 )**( -1/2 ) * np.pi + 
 	 ( complex( 0,-17744390509/3041280 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 16471187/6912 * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( complex( 0,-15457/4608 ) * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-41843/32 ) * ( 7/5 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,125529/32 ) * ( 7/5 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,1053891/256 ) * ( 35 )**( -1/2 ) * np.log( 3 ) + 
 	 complex( 0,-3161673/256 ) * ( 35 )**( -1/2 ) * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( complex( 0,-84059375/3456 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,84059375/1152 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-20149/2880 ) * ( 7/5 )**( 1/2 ) + 
 	 ( 17789/768 * ( 35 )**( -1/2 ) * np.pi + 
 	 ( complex( 0,1643821673/11404800 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( -17789/256 * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( complex( 0,607837/152064 ) * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,26662627/432 ) * ( 35 )**( -1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-26662627/144 ) * ( 35 )**( -1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-102627/256 ) * ( 35 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,307881/256 ) * ( 35 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-2710625/768 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,2710625/256 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,46393/1152 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -46393/1728 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-830867987/829440 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 46393/576 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-72983/41472 ) * ( 35 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-2991431/96 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,2991431/32 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-501471/128 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,1504413/128 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,110546875/6912 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 complex( 0,-110546875/2304 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( complex( 0,-16117913/10368 ) * ( 35 )**( 1/2 ) * np.log( 7 ) + 
 	 ( complex( 0,16117913/3456 ) * ( 35 )**( 1/2 ) * nu * np.log( 7 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,44701/1152 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -44701/1728 * ( 5/7 )**( 1/2 ) * np.pi + 
 	 ( complex( 0,-402222547/414720 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 44701/576 * ( 5/7 )**( 1/2 ) * np.pi * nu + 
 	 ( complex( 0,-63741523/864 ) * ( 5/7 )**( 1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,63741523/288 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-7924635/256 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,23773905/256 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,44584375/3456 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,-44584375/1152 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,32588773/6912 ) * ( 35 )**( 1/2 ) * np.log( 7 ) + 
 	 complex( 0,-32588773/2304 ) * ( 35 )**( 1/2 ) * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,279331/1920 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -279331/576 * ( 35 )**( -1/2 ) * np.pi + 
 	 ( complex( 0,-2597216527/691200 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 279331/192 * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( complex( 0,-427620107/2304 ) * ( 35 )**( -1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,427620107/768 ) * ( 35 )**( -1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,-405/8 ) * ( 5/7 )**( 1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,1215/8 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-125013125/20736 ) * ( 5/7 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,125013125/6912 ) * ( 5/7 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,2000033/10368 ) * ( 35 )**( 1/2 ) * np.log( 7 ) + 
 	 ( complex( 0,-2000033/3456 ) * ( 35 )**( 1/2 ) * nu * np.log( 7 ) + 
 	 ( complex( 0,14348907/256 ) * ( 35 )**( -1/2 ) * np.log( 18 ) + 
 	 complex( 0,-43046721/256 ) * ( 35 )**( -1/2 ) * nu * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,50627/2880 ) * ( 7/5 )**( 1/2 ) + 
 	 ( -50627/864 * ( 35 )**( -1/2 ) * np.pi + 
 	 ( complex( 0,-167405237/414720 ) * ( 35 )**( -1/2 ) * nu + 
 	 ( 50627/288 * ( 35 )**( -1/2 ) * np.pi * nu + 
 	 ( complex( 0,3518634233/6912 ) * ( 35 )**( -1/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-3518634233/2304 ) * ( 35 )**( -1/2 ) * nu * np.log( 2 ) + 
 	 ( complex( 0,10558269/256 ) * ( 35 )**( -1/2 ) * np.log( 3 ) + 
 	 ( complex( 0,-31674807/256 ) * ( 35 )**( -1/2 ) * nu * np.log( 3 ) + 
 	 ( complex( 0,-1028125/6912 ) * ( 35 )**( 1/2 ) * np.log( 5 ) + 
 	 ( complex( 0,1028125/2304 ) * ( 35 )**( 1/2 ) * nu * np.log( 5 ) + 
 	 ( complex( 0,-23176853/6912 ) * ( 35 )**( 1/2 ) * np.log( 7 ) + 
 	 ( complex( 0,23176853/2304 ) * ( 35 )**( 1/2 ) * nu * np.log( 7 ) + 
 	 ( complex( 0,-14348907/256 ) * ( 35 )**( -1/2 ) * np.log( 18 ) + 
 	 complex( 0,43046721/256 ) * ( 35 )**( -1/2 ) * nu * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(h)

# %% [markdown]
# ## Amplitude $(\ell, m)$ = (4, 3)

# %%
# ## Amplitude $(\ell, m)$ = (4, 3)

def amplitude_43(xi, x, nu, Delta, e):
    
    h = ( ( x )**( 3/2 ) * ( complex( 0,-9/4 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,9/2 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( ( e )**( 2 ) * ( complex( 0,-5/8 ) * ( 5/14 )**( 1/2 ) * Delta + 
 	 ( complex( 0,5/4 ) * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-31/24 ) * ( 5/14 )**( 1/2 ) * Delta + 
 	 complex( 0,31/12 ) * ( 5/14 )**( 1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-41/24 ) * ( 5/14 )**( 1/2 ) * Delta + 
 	 complex( 0,41/12 ) * ( 5/14 )**( 1/2 ) * Delta * nu ) ) ) ) + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-47/12 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,47/6 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-19/4 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,19/2 ) * ( 70 )**( -1/2 ) * Delta * nu ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-13/32 ) * ( 7/10 )**( 1/2 ) * Delta + 
 	 complex( 0,13/16 ) * ( 7/10 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-223/96 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,223/48 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,-327/32 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,327/16 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,-457/32 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,457/16 ) * ( 70 )**( -1/2 ) * Delta * nu ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-5/8 ) * ( 5/14 )**( 1/2 ) * Delta + 
 	 ( complex( 0,5/4 ) * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,41/144 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,-41/72 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-73/48 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,73/24 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,-9071/576 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,9071/288 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-4397/192 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,4397/96 ) * ( 70 )**( -1/2 ) * Delta * nu ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-1445/2304 ) * ( 5/14 )**( 1/2 ) * Delta + 
 	 complex( 0,1445/1152 ) * ( 5/14 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-1459/2304 ) * ( 5/14 )**( 1/2 ) * Delta + 
 	 complex( 0,1459/1152 ) * ( 5/14 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,871/512 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,-871/256 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,3201/512 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,-3201/256 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,-109819/4608 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,109819/2304 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,-164669/4608 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,164669/2304 ) * ( 70 )**( -1/2 ) * Delta * nu ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-5/8 ) * ( 5/14 )**( 1/2 ) * Delta + 
 	 ( complex( 0,5/4 ) * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-283/576 ) * ( 7/10 )**( 1/2 ) * Delta + 
 	 complex( 0,283/288 ) * ( 7/10 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,753/640 ) * ( 7/10 )**( 1/2 ) * Delta + 
 	 complex( 0,-753/320 ) * ( 7/10 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-89/24 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,89/12 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,104119/5760 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,-104119/2880 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,-2847/80 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,2847/40 ) * ( 70 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,-17503/320 ) * ( 70 )**( -1/2 ) * Delta + 
 	 complex( 0,17503/160 ) * ( 70 )**( -1/2 ) * Delta * nu ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 5/2 ) * ( complex( 0,351/44 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-543/176 ) * ( 7/10 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,393/44 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,346/33 ) * ( 2/35 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-85927/1584 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,329/198 ) * ( 7/10 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) \
) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,57/11 ) * ( 70 \
)**( -1/2 ) * Delta + 
 	 ( complex( 0,-6661/1584 ) * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,29/66 ) * ( 35/2 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) \
) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( \
0,-13781/352 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,76011/1408 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,2963/528 ) * ( 5/14 )**( 1/2 ) * Delta * ( nu )**( 2 ) \
) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,30001/352 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-126199/4224 ) * ( 7/10 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,633/176 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,34891/1056 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-32701/12672 ) * ( 35/2 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,8837/528 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,12347/352 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-80711/4224 ) * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,29971/1584 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,4029/176 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-33443/528 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,3803/264 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,47071/1056 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-236197/2112 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,17477/1584 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-8329/1056 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-6871/6336 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,34927/1584 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,28381/704 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-469009/4224 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,10081/528 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,1938229/12672 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-2003453/38016 ) * ( 7/10 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,-15853/4752 ) * ( 5/14 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,26297/704 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-3998681/38016 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,11107/3168 ) * ( 7/10 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,58507/6336 ) * ( 7/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-1257653/38016 ) * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,245809/9504 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-61387/4224 ) * ( 7/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,6488981/38016 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,99503/3168 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,69541/2816 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-5639461/67584 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,11155/8448 ) * ( 35/2 )**( 1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,58039/1152 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-760765/27648 ) * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,71077/3456 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) \
) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,602713/12672 ) \
* ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-13377143/101376 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,845953/38016 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 \
) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,-784441/25344 ) \
* ( 7/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,238392647/608256 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,2157677/76032 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( \
2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,371137/2816 ) * \
( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-21328987/67584 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,110013/2816 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 \
) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,6666733/25344 ) \
* ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-126850541/202752 ) * ( 70 )**( -1/2 ) * Delta * nu + \

 	 complex( 0,-4542893/76032 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( \
2 ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,20323/352 ) * ( 70 )**( -1/2 ) * Delta \
+ 
 	 ( complex( 0,-47891/2112 ) * ( 7/10 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,3139/132 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) \
+ 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,-2936023/7040 ) \
* ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,316071/2816 ) * ( 7/10 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,13187/1056 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) \
) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,173673/2816 ) \
* ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-8439923/50688 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,384191/19008 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 \
) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,1254859/25344 ) \
* ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-21433117/152064 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,75503/3168 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 ) \
) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,11570921/42240 \
) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-39598333/63360 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,12604903/190080 ) * ( 70 )**( -1/2 ) * Delta * ( nu \
)**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( \
0,-3236861/126720 ) * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,152429/38016 ) * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,1248041/12672 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( \
2 ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,110303/1760 ) * \
( 7/10 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-43563823/42240 ) * ( 70 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-498807/3520 ) * ( 70 )**( -1/2 ) * Delta * ( nu )**( 2 \
) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 3 ) * ( -36/5 * ( 2/35 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-27/4 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 16301/360 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,27/2 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -27/2 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 27 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 27/2 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( -27 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( -52/3 * ( 2/35 )**( \
1/2 ) * Delta + 
 	 ( complex( 0,-13/4 ) * ( 5/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( 319/3 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,13/2 ) * ( 5/14 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -81/2 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 81 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 81/2 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 -81 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( -1076/45 * ( 2/35 )**( 1/2 \
) * Delta + 
 	 ( complex( 0,-269/12 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 6953/45 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,269/6 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 151/6 * ( 5/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -151/3 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -81/2 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 81 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) ) + \

 	 ( ( e )**( 2 ) * ( -566/15 * ( 2/35 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-283/8 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 170269/720 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,283/4 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 1861/4 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -1861/2 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -837/4 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( 837/2 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -1499/45 * ( 2/35 )**( 1/2 \
) * Delta + 
 	 ( complex( 0,-1499/48 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 290299/1440 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,1499/24 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -415/24 * ( 5/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 415/12 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 1377/16 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 -1377/8 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) \
) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( -2519/45 * ( 2/35 )**( 1/2 \
) * Delta + 
 	 ( complex( 0,-2519/48 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 529999/1440 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,2519/24 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -14807/24 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 14807/12 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 81/16 * ( 7/10 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -81/8 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 3125/48 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 -3125/24 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) \
) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( -1741/15 \
* ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-1741/32 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 83479/240 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,1741/16 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -2557/16 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 2557/8 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 1269/8 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 -1269/4 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) \
) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -1027/9 * ( 70 )**( -1/2 ) \
* Delta + 
 	 ( complex( 0,-1027/96 ) * ( 5/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( 10207/144 * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,1027/48 ) * ( 5/14 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 17147/16 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -17147/8 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -1053/2 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 1053 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + \

 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -87/5 * ( 7/10 )**( 1/2 ) \
* Delta + 
 	 ( complex( 0,-261/32 ) * ( 7/10 )**( 1/2 ) * np.pi * Delta + 
 	 ( 13139/240 * ( 7/10 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,261/16 ) * ( 7/10 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -8215/16 * ( 5/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 8215/8 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 2997/8 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( -2997/4 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 3125/16 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 -3125/8 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) \
) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( -3403/15 * ( 70 )**( -1/2 ) \
* Delta + 
 	 ( complex( 0,-3403/32 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 543701/720 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,3403/16 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 19317/16 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -19317/8 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 3861/4 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( -3861/2 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -3125/16 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 3125/8 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) \
) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -178/15 * ( 14/5 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-89/8 ) * ( 7/10 )**( 1/2 ) * np.pi * Delta + 
 	 ( 374509/720 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,89/4 ) * ( 7/10 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -5035/4 * ( 5/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 5035/2 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 77409/64 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( -77409/32 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -1229/45 * ( 7/10 )**( 1/2 \
) * Delta + 
 	 ( complex( 0,-68849/768 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 233899/2880 * ( 7/10 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,68849/384 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + \

 	 ( -2623/48 * ( 5/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 2623/24 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 69309/256 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 -69309/128 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) \
) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -10867/135 * ( 2/35 )**( \
1/2 ) * Delta + 
 	 ( complex( 0,-10867/144 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 307421/4320 * ( 7/10 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,10867/72 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 148781/72 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -148781/36 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -4239/4 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 4239/2 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) \
+ 
 	 ( 53125/128 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( -53125/64 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -3701/45 * ( 2/35 )**( \
1/2 ) * Delta + 
 	 ( complex( 0,-3701/48 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 737941/1440 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,3701/24 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 164683/24 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -164683/12 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 5319/2 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( -5319 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -3125/24 * ( 35/2 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 3125/12 * ( 35/2 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) \
) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( -57223/135 * ( 70 )**( -1/2 \
) * Delta + 
 	 ( complex( 0,-57223/288 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 12307073/8640 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,57223/144 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + \

 	 ( -97883/144 * ( 5/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 97883/72 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -746631/256 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( 746631/128 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 3125/128 * ( 35/2 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( -3125/64 * ( 35/2 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 823543/2304 * ( 7/10 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 -823543/1152 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 7 ) ) ) ) \
) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( -17147/80 \
* ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-51391/512 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 212307/320 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,51391/256 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + \

 	 ( 2793389/768 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -2793389/384 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -1917 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 1917 * ( 2/35 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( -655667/2160 * ( 70 )**( \
-1/2 ) * Delta + 
 	 ( complex( 0,-3283913/23040 ) * ( 70 )**( -1/2 ) * np.pi * Delta + \

 	 ( 7747627/8640 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,3283913/11520 ) * ( 70 )**( -1/2 ) * np.pi * Delta * \
nu + 
 	 ( -1709413/3840 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 1709413/1920 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 10071/160 * ( 7/10 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 -10071/80 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) \
) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -232499/1080 * ( 70 )**( \
-1/2 ) * Delta + 
 	 ( complex( 0,-232499/2304 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 1449467/2160 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,232499/1152 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu \
+ 
 	 ( -4827937/384 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 4827937/192 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 348759/128 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( -348759/64 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 146875/192 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 -146875/96 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) \
) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -34667/1080 * ( 7/10 )**( \
1/2 ) * Delta + 
 	 ( complex( 0,-34667/2304 ) * ( 7/10 )**( 1/2 ) * np.pi * Delta + 
 	 ( 381293/540 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,34667/1152 ) * ( 7/10 )**( 1/2 ) * np.pi * Delta * nu \
+ 
 	 ( 21876371/1152 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -21876371/576 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 628101/128 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( -628101/64 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -71875/32 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 71875/16 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) \
) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( -407/16 * ( 7/10 )**( 1/2 \
) * Delta + 
 	 ( complex( 0,-1221/512 ) * ( 35/2 )**( 1/2 ) * np.pi * Delta + 
 	 ( 61403/576 * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,1221/256 ) * ( 35/2 )**( 1/2 ) * np.pi * Delta * nu + \

 	 ( -12639197/768 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 12639197/384 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -62019/32 * ( 7/10 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 62019/16 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 96875/64 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( -96875/32 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 823543/768 * ( 7/10 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 -823543/384 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) \
) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( -231851/2160 * ( 7/10 )**( \
1/2 ) * Delta + 
 	 ( complex( 0,-231851/4608 ) * ( 7/10 )**( 1/2 ) * np.pi * Delta + 
 	 ( 21984367/8640 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,231851/2304 ) * ( 7/10 )**( 1/2 ) * np.pi * Delta * \
nu + 
 	 ( 222528287/11520 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -222528287/5760 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 408213/160 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( -408213/80 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -3125/96 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 3125/48 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -823543/768 * ( 7/10 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 823543/384 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) \
) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( -167/3 * ( 5/14 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-835/32 ) * ( 5/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( 33451/192 * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,835/16 ) * ( 5/14 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( 1938803/48 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -1938803/24 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 1019871/128 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( -1019871/64 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( -14087/30 * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-212267/960 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 317719/1152 * ( 5/14 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,212267/480 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -336841/480 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 336841/240 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 507627/5120 * ( 7/10 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 -507627/2560 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -181903/675 * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-2893697/23040 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 1293821/10800 * ( 7/10 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,2893697/11520 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 174593/144 * ( 5/14 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -174593/72 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -8345889/2560 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 8345889/1280 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( -3446875/768 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 3446875/384 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -96/5 * ( 14/5 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-36889/2048 ) * ( 7/10 )**( 1/2 ) * np.pi * Delta + 
 	 ( 1203383/1440 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,36889/1024 ) * ( 7/10 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -19453/6 * ( 7/10 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 19453/3 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 10837287/2048 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( -10837287/1024 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 8021875/6144 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 -8021875/3072 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -1567/27 * ( 5/14 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-7835/288 ) * ( 5/14 )**( 1/2 ) * np.pi * Delta + 
 	 ( 1581229/1728 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,7835/144 ) * ( 5/14 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -6776911/144 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 6776911/72 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -67453371/2048 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( 67453371/1024 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 88065625/18432 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( -88065625/9216 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 14000231/6144 * ( 7/10 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 -14000231/3072 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( -2491/45 * ( 2/35 )**( 1/2 ) * Delta + 
 	 ( complex( 0,-2491/48 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 49897/192 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,2491/24 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 9040813/120 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -9040813/60 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 8265861/2560 * ( 7/10 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -8265861/1280 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -753125/768 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 753125/384 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -38706521/7680 * ( 7/10 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 38706521/3840 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( -192511/150 * ( 70 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-192511/320 ) * ( 70 )**( -1/2 ) * np.pi * Delta + 
 	 ( 125975443/28800 * ( 70 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,192511/160 ) * ( 70 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -2049990793/30720 * ( 70 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 2049990793/15360 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -4977369/10240 * ( 70 )**( -1/2 ) * Delta * np.log( 3 ) + 
 	 ( 4977369/5120 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -15625/6144 * ( 5/14 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 15625/3072 * ( 5/14 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 5764801/6144 * ( 7/10 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 ( -5764801/3072 * ( 7/10 )**( 1/2 ) * Delta * nu * np.log( 7 ) + 
 	 ( 129140163/10240 * ( 70 )**( -1/2 ) * Delta * np.log( 18 ) + 
 	 -129140163/5120 * ( 70 )**( -1/2 ) * Delta * nu * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(h)

# %% [markdown]
# ## Amplitude $(\ell, m)$ = (4, 2)

# %%
def amplitude_42(xi, x, nu, Delta, e):
    
    h = 1/63 * ( 5 )**( 1/2 ) * ( ( x )**( 3/2 ) * ( complex( 0,-13/320 ) * ( e )**( 4 ) * nu + 
 	 ( complex( 0,-11/96 ) * ( e )**( 6 ) * nu + 
 	 ( complex( 0,-13/2880 ) * ( e )**( 5 ) * ( np.e )**( complex( 0,-1 ) * xi ) * nu + 
 	 ( complex( 0,-13/5760 ) * ( e )**( 6 ) * ( np.e )**( complex( 0,-2 ) * xi ) * nu + 
 	 ( complex( 0,-767/2880 ) * ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * nu + 
 	 ( complex( 0,-299/768 ) * ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * nu + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,-13/120 ) * ( e )**( 3 ) * nu + 
 	 complex( 0,5/64 ) * ( e )**( 5 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,13/120 ) * ( e )**( 3 ) * nu + 
 	 complex( 0,37/192 ) * ( e )**( 5 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-169/960 ) * ( e )**( 4 ) * nu + 
 	 complex( 0,169/1440 ) * ( e )**( 6 ) * nu ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-13/240 ) * ( e )**( 2 ) * nu + 
 	 ( complex( 0,7/96 ) * ( e )**( 4 ) * nu + 
 	 complex( 0,503/3840 ) * ( e )**( 6 ) * nu ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x * ( 1 + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( 1717/160 + 
 	 -5151/160 * nu ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( 11927/1536 + 
 	 -11927/512 * nu ) + 
 	 ( -3 * nu + 
 	 ( ( e )**( 6 ) * ( -13/16 + 
 	 39/16 * nu ) + 
 	 ( ( e )**( 4 ) * ( -9/8 + 
 	 27/8 * nu ) + 
 	 ( ( e )**( 2 ) * ( -5/2 + 
 	 15/2 * nu ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( -4069/384 + 
 	 4069/128 * nu ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( -1219/80 + 
 	 3657/80 * nu ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( ( e )**( 3 ) * ( -27/32 + 
 	 81/32 * nu ) + 
 	 ( ( e )**( 5 ) * ( -163/192 + 
 	 163/64 * nu ) + 
 	 e * ( -2 + 
 	 6 * nu ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 4 ) * ( 7/24 + 
 	 -7/8 * nu ) + 
 	 ( ( e )**( 6 ) * ( -29/32 + 
 	 87/32 * nu ) + 
 	 ( e )**( 2 ) * ( -13/4 + 
 	 39/4 * nu ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( e * ( 7/4 + 
 	 -21/4 * nu ) + 
 	 ( ( e )**( 5 ) * ( -577/768 + 
 	 577/256 * nu ) + 
 	 ( e )**( 3 ) * ( -63/16 + 
 	 189/16 * nu ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 5 ) * ( 1145/512 + 
 	 -3435/512 * nu ) + 
 	 ( e )**( 3 ) * ( -79/16 + 
 	 237/16 * nu ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 2 ) * ( 11/4 + 
 	 -33/4 * nu ) + 
 	 ( ( e )**( 6 ) * ( 5/16 + 
 	 -15/16 * nu ) + 
 	 ( e )**( 4 ) * ( -143/24 + 
 	 143/8 * nu ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 6 ) * ( 449/80 + 
 	 -1347/80 * nu ) + 
 	 ( e )**( 4 ) * ( -175/24 + 
 	 175/8 * nu ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 3 ) * ( 127/32 + 
 	 -381/32 * nu ) + 
 	 ( e )**( 5 ) * ( -1159/128 + 
 	 3477/128 * nu ) ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 4 ) * ( 67/12 + 
 	 -67/4 * nu ) + 
 	 ( e )**( 6 ) * ( -137/10 + 
 	 411/10 * nu ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 2 ) * ( -437/110 + 
 	 ( 805/66 * nu + 
 	 ( -19/22 * ( nu )**( 2 ) + 
 	 ( ( e )**( 2 ) * ( 689/110 + 
 	 ( -1561/66 * nu + 
 	 337/22 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 4 ) * ( 17379/880 + 
 	 ( -12033/176 * nu + 
 	 4509/176 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( 1211/44 + 
 	 ( -12467/132 * nu + 
 	 2881/88 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( 69672451/675840 + 
 	 ( -32639053/101376 * nu + 
 	 652721/16896 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( 539383/2816 + 
 	 ( -3147997/5280 * nu + 
 	 230333/3520 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( 136865851/675840 + 
 	 ( -34987721/50688 * nu + 
 	 7369849/33792 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( 23438449/70400 + 
 	 ( -5981029/5280 * nu + 
 	 1223819/3520 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 3 ) * ( 303583/14080 + 
 	 ( -144563/2112 * nu + 
 	 4039/352 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 5 ) * ( -8908027/225280 + 
 	 ( 1907569/16896 * nu + 
 	 209815/11264 * ( nu )**( 2 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 6 ) * ( -5515703/52800 + 
 	 ( 3278083/10560 * nu + 
 	 37981/3520 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 4 ) * ( 269081/5280 + 
 	 ( -126755/792 * nu + 
 	 11533/528 * ( nu )**( 2 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( e * ( -377/352 + 
 	 ( 751/264 * nu + 
 	 49/44 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 3 ) * ( 34697/14080 + 
 	 ( -4509/352 * nu + 
 	 12153/704 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 5 ) * ( 8022787/337920 + 
 	 ( -4131781/50688 * nu + 
 	 239381/8448 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( e * ( 21899/1760 + 
 	 ( -5689/132 * nu + 
 	 1589/88 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 3 ) * ( 262217/14080 + 
 	 ( -44811/704 * nu + 
 	 7803/352 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 5 ) * ( 9366043/337920 + 
 	 ( -2390405/25344 * nu + 
 	 523681/16896 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 2 ) * ( 487/80 + 
 	 ( -479/24 * nu + 
 	 41/8 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 4 ) * ( -51257/5280 + 
 	 ( 18233/792 * nu + 
 	 2573/132 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 6 ) * ( 126149/3840 + 
 	 ( -21277/192 * nu + 
 	 529/16 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 4 ) * ( 76513/5280 + 
 	 ( -39463/792 * nu + 
 	 608/33 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( 276293/8448 + 
 	 ( -235325/2112 * nu + 
 	 6415/176 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 2 ) * ( 28691/880 + 
 	 ( -29611/264 * nu + 
 	 3637/88 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 5 ) * ( -159593/20480 + 
 	 ( 78199/3072 * nu + 
 	 -1403/512 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 3 ) * ( 923071/14080 + 
 	 ( -237187/1056 * nu + 
 	 54347/704 * ( nu )**( 2 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 6 ) * ( -12499/192 + 
 	 ( 210359/960 * nu + 
 	 -18143/320 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 4 ) * ( 125281/1056 + 
 	 ( -641953/1584 * nu + 
 	 17527/132 * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 3 ) * ( 1038039/200200 + 
 	 ( -606751/28600 * nu + 
 	 ( 400453/25740 * ( nu )**( 2 ) + 
 	 ( 25783/17160 * ( nu )**( 3 ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( -7174239833/12812800 + 
 	 ( 3715200197/1830400 * nu + 
 	 ( 650343299/823680 * ( nu )**( 2 ) + 
 	 -592861393/549120 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( -2451086739/7321600 + 
 	 ( 104965805459/87859200 * nu + 
 	 ( 12332896379/39536640 * ( nu )**( 2 ) + 
 	 -6057684923/13178880 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( 77513103263/64064000 + 
 	 ( ( -40808001427/9152000 + 
 	 complex( 0,-667/384 ) * np.pi ) * nu + 
 	 ( 2489313601/1029600 * ( nu )**( 2 ) + 
 	 -13813391/686400 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( 28092103167/51251200 + 
 	 ( ( -180374373961/87859200 + 
 	 complex( 0,-1711/1440 ) * np.pi ) * nu + 
 	 ( 5900916433/4942080 * ( nu )**( 2 ) + 
 	 -41327401/26357760 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( 166203/1664 + 
 	 ( ( -642069/1664 + 
 	 complex( 0,-641/640 ) * np.pi ) * nu + 
 	 ( 2333231/7488 * ( nu )**( 2 ) + 
 	 70229/4992 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( -712277/200200 + 
 	 ( -535597/171600 * nu + 
 	 ( 1955323/51480 * ( nu )**( 2 ) + 
 	 58765/3432 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( 36797777/800800 + 
 	 ( ( -42922821/228800 + 
 	 complex( 0,-29/160 ) * np.pi ) * nu + 
 	 ( 3737301/22880 * ( nu )**( 2 ) + 
 	 430081/22880 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 6 ) * ( -4025225989/9609600 + 
 	 ( ( 10850478851/8236800 + 
 	 complex( 0,-9223/5760 ) * np.pi ) * nu + 
 	 ( -18934651/205920 * ( nu )**( 2 ) + 
 	 -2756619/183040 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 4 ) * ( 696546353/3203200 + 
 	 ( ( -1155278671/1372800 + 
 	 complex( 0,-377/480 ) * np.pi ) * nu + 
 	 ( 34223411/61776 * ( nu )**( 2 ) + 
 	 248929/51480 * ( nu )**( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 5 ) * ( -1131775677/10250240 + 
 	 ( ( 994000895/3514368 + 
 	 complex( 0,-1381/1440 ) * np.pi ) * nu + 
 	 ( 2406137717/13178880 * ( nu )**( 2 ) + 
 	 241363/4392960 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 3 ) * ( 439386449/6406400 + 
 	 ( ( -526268577/1830400 + 
 	 complex( 0,-29/60 ) * np.pi ) * nu + 
 	 ( 98677529/411840 * ( nu )**( 2 ) + 
 	 288293/49920 * ( nu )**( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( e * ( 45999/50050 + 
 	 ( -3974897/228800 * nu + 
 	 ( 1069741/25740 * ( nu )**( 2 ) + 
 	 223591/68640 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( 11994691/6406400 + 
 	 ( ( -250143689/5491200 + 
 	 complex( 0,29/60 ) * np.pi ) * nu + 
 	 ( 11031089/91520 * ( nu )**( 2 ) + 
 	 94739/5720 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 5 ) * ( 2100269019/25625600 + 
 	 ( ( -14705033417/43929600 + 
 	 complex( 0,3121/1440 ) * np.pi ) * nu + 
 	 ( 706189921/2471040 * ( nu )**( 2 ) + 
 	 248884463/13178880 * ( nu )**( 3 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 2 ) * ( 10634661/800800 + 
 	 ( ( -8410049/114400 + 
 	 complex( 0,-29/120 ) * np.pi ) * nu + 
 	 ( 10104899/102960 * ( nu )**( 2 ) + 
 	 29473/6240 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -5814803/400400 + 
 	 ( ( -5129953/343200 + 
 	 complex( 0,-473/1440 ) * np.pi ) * nu + 
 	 ( 23210267/123552 * ( nu )**( 2 ) + 
 	 407699/37440 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 6 ) * ( 209676865/1537536 + 
 	 ( ( -351880033/658944 + 
 	 complex( 0,13897/23040 ) * np.pi ) * nu + 
 	 ( 327883993/823680 * ( nu )**( 2 ) + 
 	 869057/45760 * ( nu )**( 3 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( ( e )**( 5 ) * ( 298905597/3660800 + 
 	 ( ( -13781090237/43929600 + 
 	 complex( 0,-29/1440 ) * np.pi ) * nu + 
 	 ( 443942617/1797120 * ( nu )**( 2 ) + 
 	 20464685/1317888 * ( nu )**( 3 ) ) ) ) + 
 	 ( e * ( -12522/715 + 
 	 ( 2467119/45760 * nu + 
 	 ( -243553/20592 * ( nu )**( 2 ) + 
 	 130147/6864 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 3 ) * ( 33152891/1281280 + 
 	 ( -117069697/1098240 * nu + 
 	 ( 4217001/45760 * ( nu )**( 2 ) + 
 	 3983143/183040 * ( nu )**( 3 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 6 ) * ( 2344627321/38438400 + 
 	 ( ( -3838202437/16473600 + 
 	 complex( 0,-29/2880 ) * np.pi ) * nu + 
 	 ( 2427641/10296 * ( nu )**( 2 ) + 
 	 353227/183040 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( -3969279/72800 + 
 	 ( 20860771/114400 * nu + 
 	 ( -3141253/102960 * ( nu )**( 2 ) + 
 	 1237517/68640 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 4 ) * ( 3026123/400400 + 
 	 ( -362639/10400 * nu + 
 	 ( 24863737/617760 * ( nu )**( 2 ) + 
 	 19482367/411840 * ( nu )**( 3 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 3 ) * ( -700733947/6406400 + 
 	 ( 688202731/1830400 * nu + 
 	 ( -9549269/823680 * ( nu )**( 2 ) + 
 	 -3354821/137280 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 5 ) * ( 19463517/7321600 + 
 	 ( -87606287/7987200 * nu + 
 	 ( -131735129/1647360 * ( nu )**( 2 ) + 
 	 1322691737/8785920 * ( nu )**( 3 ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 4 ) * ( -627139661/3203200 + 
 	 ( 314192039/457600 * nu + 
 	 ( 50048927/617760 * ( nu )**( 2 ) + 
 	 -32063279/205920 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 6 ) * ( 49282997/1501500 + 
 	 ( -4812852521/41184000 * nu + 
 	 ( -770843167/2059200 * ( nu )**( 2 ) + 
 	 38029463/83200 * ( nu )**( 3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 5/2 ) * ( complex( 0,-21/5 ) + 
 	 ( 2 * np.pi + 
 	 ( ( complex( 0,84/5 ) + 
 	 -6 * np.pi ) * nu + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 3 ) * ( complex( 0,-6153/320 ) + 
 	 ( 853/96 * np.pi + 
 	 ( complex( 0,-355073/7920 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,28927/320 ) + 
 	 ( -853/32 * np.pi + 
 	 complex( 0,-65/16 ) * np.log( 2 ) ) ) + 
 	 complex( 0,65/48 ) * np.log( 2 ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,60627/1280 ) + 
 	 ( -7951/384 * np.pi + 
 	 ( complex( 0,-97751/1920 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,-2042383/15360 ) + 
 	 ( 7951/128 * np.pi + 
 	 complex( 0,607/64 ) * np.log( 2 ) ) ) + 
 	 complex( 0,-607/192 ) * np.log( 2 ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,231/20 ) + 
 	 ( -11/2 * np.pi + 
 	 ( nu * ( complex( 0,-3887/120 ) + 
 	 ( 33/2 * np.pi + 
 	 complex( 0,3 ) * np.log( 2 ) ) ) + 
 	 complex( 0,-1 ) * np.log( 2 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 4 ) * ( complex( 0,-2289/80 ) + 
 	 ( 38/3 * np.pi + 
 	 ( complex( 0,-461123/6336 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,525271/3840 ) + 
 	 ( -38 * np.pi + 
 	 complex( 0,-23/4 ) * np.log( 2 ) ) ) + 
 	 complex( 0,23/12 ) * np.log( 2 ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,120379/1600 ) + 
 	 ( -60151/1920 * np.pi + 
 	 ( complex( 0,-3294901/38016 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-297/80 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-2479427/11520 ) + 
 	 ( 60151/640 * np.pi + 
 	 ( complex( 0,891/80 ) * np.log( 2 ) + 
 	 complex( 0,2187/640 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-729/640 ) * np.log( 3 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( e * ( complex( 0,-63/8 ) + 
 	 ( 15/4 * np.pi + 
 	 ( nu * ( complex( 0,1213/40 ) + 
 	 ( -45/4 * np.pi + 
 	 complex( 0,-3/2 ) * np.log( 2 ) ) ) + 
 	 complex( 0,1/2 ) * np.log( 2 ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( complex( 0,2919/160 ) + 
 	 ( -139/16 * np.pi + 
 	 ( complex( 0,355073/7920 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,-13729/192 ) + 
 	 ( 417/16 * np.pi + 
 	 complex( 0,39/8 ) * np.log( 2 ) ) ) + 
 	 complex( 0,-13/8 ) * np.log( 2 ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,85183/2560 ) + 
 	 ( -12325/768 * np.pi + 
 	 ( complex( 0,2062703/12672 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-39117/128 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-3747787/23040 ) + 
 	 ( 12325/256 * np.pi + 
 	 ( complex( 0,117351/128 ) * np.log( 2 ) + 
 	 complex( 0,-28431/64 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,9477/64 ) * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 2 ) * ( complex( 0,-63/5 ) + 
 	 ( 6 * np.pi + 
 	 ( complex( 0,-177751/7920 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,10891/192 ) + 
 	 ( -18 * np.pi + 
 	 complex( 0,-3 ) * np.log( 2 ) ) ) + 
 	 complex( 0,1 ) * np.log( 2 ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,2359/80 ) + 
 	 ( -27/2 * np.pi + 
 	 ( complex( 0,-18169/1584 ) * ( nu )**( 2 ) + 
 	 ( nu * ( complex( 0,-100741/1152 ) + 
 	 ( 81/2 * np.pi + 
 	 complex( 0,25/4 ) * np.log( 2 ) ) ) + 
 	 complex( 0,-25/12 ) * np.log( 2 ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,12481/320 ) + 
 	 ( -3691/192 * np.pi + 
 	 ( complex( 0,221369/3168 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-7265/16 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-767167/5280 ) + 
 	 ( 3691/64 * np.pi + 
 	 ( complex( 0,21795/16 ) * np.log( 2 ) + 
 	 complex( 0,-43011/64 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,14337/64 ) * np.log( 3 ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,-214557/5120 ) + 
 	 ( 135721/7680 * np.pi + 
 	 ( complex( 0,-20908981/190080 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,8233/3840 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,9299827/46080 ) + 
 	 ( -135721/2560 * np.pi + 
 	 ( complex( 0,-8233/1280 ) * np.log( 2 ) + 
 	 complex( 0,-2187/1280 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,729/1280 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,273/10 ) + 
 	 ( -13 * np.pi + 
 	 ( complex( 0,-177179/10560 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-195 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-288317/3840 ) + 
 	 ( 39 * np.pi + 
 	 ( complex( 0,585 ) * np.log( 2 ) + 
 	 complex( 0,-2187/8 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,729/8 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,-3885/64 ) + 
 	 ( 140117/5760 * np.pi + 
 	 ( complex( 0,-20360713/126720 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,1387/720 ) * np.log( 2 ) + 
 	 ( complex( 0,729/640 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,7509643/25600 ) + 
 	 ( -140117/1920 * np.pi + 
 	 ( complex( 0,-1387/240 ) * np.log( 2 ) + 
 	 ( complex( 0,-2187/640 ) * np.log( 3 ) + 
 	 complex( 0,-34/15 ) * np.log( 4 ) ) ) ) ) + 
 	 complex( 0,34/45 ) * np.log( 4 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( e * ( complex( 0,42/5 ) + 
 	 ( -4 * np.pi + 
 	 ( complex( 0,-497/24 ) + 
 	 12 * np.pi ) * nu ) ) + 
 	 ( ( e )**( 3 ) * ( complex( 0,6657/320 ) + 
 	 ( -317/32 * np.pi + 
 	 ( complex( 0,-1747/16 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-19701/320 ) + 
 	 ( 951/32 * np.pi + 
 	 ( complex( 0,5241/16 ) * np.log( 2 ) + 
 	 complex( 0,-2187/16 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,729/16 ) * np.log( 3 ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,4725/128 ) + 
 	 ( -1125/64 * np.pi + 
 	 ( complex( 0,-70843/38016 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,41113/32 ) * np.log( 2 ) + 
 	 ( complex( 0,-8019/32 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,-2556023/23040 ) + 
 	 ( 3375/64 * np.pi + 
 	 ( complex( 0,-123339/32 ) * np.log( 2 ) + 
 	 ( complex( 0,24057/32 ) * np.log( 3 ) + 
 	 complex( 0,40625/32 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-40625/96 ) * np.log( 5 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 3 ) * ( complex( 0,11067/160 ) + 
 	 ( -527/16 * np.pi + 
 	 ( complex( 0,4661/24 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-64331/320 ) + 
 	 ( 1581/16 * np.pi + 
 	 ( complex( 0,-4661/8 ) * np.log( 2 ) + 
 	 complex( 0,3125/8 ) * np.log( 5 ) ) ) ) + 
 	 complex( 0,-3125/24 ) * np.log( 5 ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,10563/1024 ) + 
 	 ( -2515/512 * np.pi + 
 	 ( complex( 0,-1244215/768 ) * np.log( 2 ) + 
 	 ( complex( 0,-44469/64 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,-179733/5120 ) + 
 	 ( 7545/512 * np.pi + 
 	 ( complex( 0,1244215/256 ) * np.log( 2 ) + 
 	 ( complex( 0,133407/64 ) * np.log( 3 ) + 
 	 complex( 0,-871875/256 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,290625/256 ) * np.log( 5 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 2 ) * ( complex( 0,609/20 ) + 
 	 ( -29/2 * np.pi + 
 	 ( nu * ( complex( 0,-41263/480 ) + 
 	 ( 87/2 * np.pi + 
 	 complex( 0,96 ) * np.log( 2 ) ) ) + 
 	 complex( 0,-32 ) * np.log( 2 ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,1911/80 ) + 
 	 ( -91/8 * np.pi + 
 	 ( complex( 0,8123/12 ) * np.log( 2 ) + 
 	 ( complex( 0,-729/8 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,-4663/64 ) + 
 	 ( 273/8 * np.pi + 
 	 ( complex( 0,-8123/4 ) * np.log( 2 ) + 
 	 ( complex( 0,2187/8 ) * np.log( 3 ) + 
 	 complex( 0,3125/4 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-3125/12 ) * np.log( 5 ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,1519/32 ) + 
 	 ( -1085/48 * np.pi + 
 	 ( complex( 0,-176893/190080 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-84035/24 ) * np.log( 2 ) + 
 	 ( complex( 0,-61965/64 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,-1658503/11520 ) + 
 	 ( 1085/16 * np.pi + 
 	 ( complex( 0,84035/8 ) * np.log( 2 ) + 
 	 ( complex( 0,185895/64 ) * np.log( 3 ) + 
 	 complex( 0,-809375/128 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,809375/384 ) * np.log( 5 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( complex( 0,861/20 ) + 
 	 ( -11821/576 * np.pi + 
 	 ( complex( 0,-993545/12672 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,18649/9 ) * np.log( 2 ) + 
 	 ( complex( 0,-28431/64 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,-387047/3840 ) + 
 	 ( 11821/192 * np.pi + 
 	 ( complex( 0,-18649/3 ) * np.log( 2 ) + 
 	 ( complex( 0,85293/64 ) * np.log( 3 ) + 
 	 complex( 0,184375/96 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-184375/288 ) * np.log( 5 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 4 ) * ( complex( 0,2149/16 ) + 
 	 ( -1535/24 * np.pi + 
 	 ( complex( 0,-3413/12 ) * np.log( 2 ) + 
 	 ( complex( 0,-729/2 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,-455339/1152 ) + 
 	 ( 1535/8 * np.pi + 
 	 ( complex( 0,3413/4 ) * np.log( 2 ) + 
 	 ( complex( 0,2187/2 ) * np.log( 3 ) + 
 	 complex( 0,-3125/4 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,3125/12 ) * np.log( 5 ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-2513/64 ) + 
 	 ( 1795/96 * np.pi + 
 	 ( complex( 0,265011/80 ) * np.log( 2 ) + 
 	 ( complex( 0,980991/320 ) * np.log( 3 ) + 
 	 ( complex( 0,-559375/384 ) * np.log( 5 ) + 
 	 ( nu * ( complex( 0,525391/4800 ) + 
 	 ( -1795/32 * np.pi + 
 	 ( complex( 0,-795033/80 ) * np.log( 2 ) + 
 	 ( complex( 0,-2942973/320 ) * np.log( 3 ) + 
 	 ( complex( 0,559375/128 ) * np.log( 5 ) + 
 	 complex( 0,823543/160 ) * np.log( 7 ) ) ) ) ) ) + 
 	 complex( 0,-823543/480 ) * np.log( 7 ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,307867/1280 ) + 
 	 ( -43981/384 * np.pi + 
 	 ( complex( 0,304911/320 ) * np.log( 2 ) + 
 	 ( complex( 0,729 ) * np.log( 3 ) + 
 	 ( complex( 0,-3125/32 ) * np.log( 5 ) + 
 	 ( nu * ( complex( 0,-32838757/46080 ) + 
 	 ( 43981/128 * np.pi + 
 	 ( complex( 0,-914733/320 ) * np.log( 2 ) + 
 	 ( complex( 0,-2187 ) * np.log( 3 ) + 
 	 ( complex( 0,9375/32 ) * np.log( 5 ) + 
 	 complex( 0,823543/320 ) * np.log( 7 ) ) ) ) ) ) + 
 	 complex( 0,-823543/960 ) * np.log( 7 ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,40971/100 ) + 
 	 ( -1951/10 * np.pi + 
 	 ( complex( 0,-1924951/360 ) * np.log( 2 ) + 
 	 ( complex( 0,-2187/8 ) * np.log( 3 ) + 
 	 ( complex( 0,-3125/288 ) * np.log( 5 ) + 
 	 ( nu * ( complex( 0,-624175/512 ) + 
 	 ( 5853/10 * np.pi + 
 	 ( complex( 0,1924951/120 ) * np.log( 2 ) + 
 	 ( complex( 0,6561/8 ) * np.log( 3 ) + 
 	 ( complex( 0,3125/96 ) * np.log( 5 ) + 
 	 complex( 0,-823543/160 ) * np.log( 7 ) ) ) ) ) ) + 
 	 complex( 0,823543/480 ) * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(h)

# %% [markdown]
# ## Amplitude $(\ell, m)$ = (5, 5)

# %%
# ## Amplitude $(\ell, m)$ = (5, 5)

def amplitude_55(xi, x, nu, Delta, e):
    
    h = ( x )**( 2 ) * ( 5/1152 * ( 66 )**( -1/2 ) * ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * Delta * nu + 
 	 ( e )**( 6 ) * ( -25/1152 * ( 66 )**( -1/2 ) * ( np.e )**( complex( 0,4 ) * xi ) * Delta * nu + 25/1152 * ( 66 )**( -1/2 ) * ( np.e )**( complex( 0,6 ) * xi ) * Delta * nu ) ) + ( ( x )**( 3/2 ) * ( complex( 0,625/96 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-625/48 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,763/96 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-763/48 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,1589/96 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-1589/48 ) * ( 66 )**( -1/2 ) * Delta * nu ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,1115/192 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-1115/96 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,2251/192 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-2251/96 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,6419/192 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-6419/96 ) * ( 66 )**( -1/2 ) * Delta * nu ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-1085/768 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,1085/384 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,4973/768 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-4973/384 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,13297/768 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-13297/384 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,46879/768 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-46879/384 ) * ( 66 )**( -1/2 ) * Delta * nu ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,1205/192 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-1205/96 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,725/144 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-725/72 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-3017/144 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,3017/72 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,117037/4608 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-117037/2304 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,484589/4608 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-484589/2304 ) * ( 66 )**( -1/2 ) * Delta * nu ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,11009/18432 ) * ( 11/6 )**( 1/2 ) * Delta + 
 	 complex( 0,-11009/9216 ) * ( 11/6 )**( 1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,13759/12288 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-13759/6144 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,135461/18432 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-135461/9216 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,1364135/36864 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-1364135/18432 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,-781487/12288 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,781487/6144 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,6429385/36864 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-6429385/18432 ) * ( 66 )**( -1/2 ) * Delta * nu ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,305/48 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,-305/24 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,16001/2304 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-16001/1152 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,-323903/46080 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,323903/23040 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,34057/2304 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-34057/1152 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,411581/7680 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-411581/3840 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-6791551/46080 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,6791551/23040 ) * ( 66 )**( -1/2 ) * Delta * nu ) + 
 	 ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,2162093/7680 ) * ( 66 )**( -1/2 ) * Delta + 
 	 complex( 0,-2162093/3840 ) * ( 66 )**( -1/2 ) * Delta * nu ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 5/2 ) * ( complex( 0,-164375/3744 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,26875/234 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-2500/117 ) * ( 2/33 )**( 1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-33377/4680 ) * ( 11/6 )**( 1/2 ) * Delta + 
 	 ( complex( 0,140077/7488 ) * ( 11/6 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,-223891/3744 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-413753/4680 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,1861969/7488 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-401645/3744 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,-1841329/14976 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,409685/1248 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-350425/3744 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-20624753/149760 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,1793213/4992 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-159727/1872 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-21139337/149760 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,6462385/14976 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-799351/3744 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-7645369/49920 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,24687755/59904 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-3364259/29952 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,-34528591/149760 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,35843087/59904 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-3518503/29952 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-2237761/11520 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,2326145/4608 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-283369/2304 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,-3300721/16640 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,40423129/59904 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-11496289/29952 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-3978317/19968 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,8038955/14976 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-2157865/14976 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-276626381/898560 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,67473577/89856 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-2859391/22464 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-164338429/898560 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,44472023/89856 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-1528591/11232 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,-671504411/1797120 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,173494495/179712 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-3513545/22464 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-448586779/1797120 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,177221381/179712 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-29242901/44928 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,-201001519/399360 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,1070741713/958464 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-34524949/479232 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( complex( 0,-419585159/1797120 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,905862491/1437696 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-117917191/718848 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( complex( 0,-229892563/1198080 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,56211079/106496 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-79878523/479232 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( complex( 0,-425768201/1797120 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,102671693/159744 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-125191049/718848 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,-425313535/718848 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,44224525/319488 ) * ( 11/6 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,-289630115/1437696 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,-17874275/718848 ) * ( 11/6 )**( 1/2 ) * Delta + 
 	 ( complex( 0,3925953065/2875392 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-1527249805/1437696 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-755453/29952 ) * ( 11/6 )**( 1/2 ) * Delta + 
 	 ( complex( 0,701575/936 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-1459235/7488 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,-15368441773/17971200 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,138854069/898560 ) * ( 11/6 )**( 1/2 ) * Delta * nu + 
 	 complex( 0,92665571/898560 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( complex( 0,-974120233/3594240 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,131347189/179712 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-33015979/179712 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-26270669/1198080 ) * ( 11/6 )**( 1/2 ) * Delta + 
 	 ( complex( 0,61163315/89856 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-36719489/179712 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( complex( 0,-302228053/1996800 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,394961143/898560 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-37710313/179712 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,-1378763561/1497600 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,353582221/149760 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-18728993/74880 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,-86236441/374400 ) * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,179357543/99840 ) * ( 66 )**( -1/2 ) * Delta * nu + 
 	 complex( 0,-50535455/29952 ) * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 3 ) * ( 113125/1344 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,3125/96 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -17639/80 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-3125/48 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 3125/48 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -3125/24 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -3125/48 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( 3125/24 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( e * ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 1394243/6720 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,7703/96 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -199619/360 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-7703/48 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -15625/48 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 15625/24 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -81 * ( 6/11 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 162 * ( 6/11 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 15625/48 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 -15625/24 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( 1716061/6720 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,9481/96 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -7061/32 * ( 3/22 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,-9481/48 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 1979/48 * ( 11/6 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -1979/24 * ( 11/6 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -15625/48 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 15625/24 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( 95749/2688 * ( 11/6 )**( 1/2 ) * Delta + 
 	 ( complex( 0,2645/192 ) * ( 11/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( -4649/9 * ( 2/33 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,-2645/96 ) * ( 11/6 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -327065/96 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 327065/48 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -405 * ( 6/11 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 810 * ( 6/11 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 265625/96 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( -265625/48 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 15551339/26880 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,85919/384 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -4296407/2880 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-85919/192 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 331679/192 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -331679/96 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -2997/128 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 2997/64 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -390625/384 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 390625/192 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( 11294219/26880 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,62399/384 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -22932619/20160 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-62399/192 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 528959/192 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -528959/96 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 405 * ( 6/11 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -810 * ( 6/11 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -78125/128 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( 78125/64 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -823543/384 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 823543/192 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 2188471/3584 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,60455/256 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -770917/480 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-60455/128 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -5847595/384 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 5847595/192 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -309015/128 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 309015/64 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 2078125/192 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 -2078125/96 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( 20646851/17920 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,114071/256 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -34108291/11520 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-114071/128 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 5646095/1152 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -5646095/576 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -14985/128 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 14985/64 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -734375/288 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 734375/144 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 41660951/53760 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,230171/768 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -5694323/2688 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-230171/384 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -1100893/128 * ( 3/22 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 1100893/64 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -6075/4 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 6075/2 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 296875/576 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( -296875/288 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 4117715/384 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 -4117715/192 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( 31400423/53760 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,173483/768 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -1260641/8960 * ( 11/6 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,-173483/384 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 7953515/384 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -7953515/192 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 11907/2 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -11907 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -46875/16 * ( 3/22 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 46875/8 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -4117715/384 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 4117715/192 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( 4498393/5376 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,124265/384 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -44556173/20160 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-124265/192 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 1880865/64 * ( 3/22 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -1880865/32 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 22584825/1024 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -22584825/512 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -67046875/1536 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( 67046875/768 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 64824607/80640 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,358147/1152 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -36631699/17280 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-358147/576 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -27162013/576 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 27162013/288 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -727677/128 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 727677/64 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 35515625/1152 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 -35515625/576 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 343483157/161280 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,1897697/2304 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -6289253/1152 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-1897697/1152 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 500211/128 * ( 3/22 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -500211/64 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -374625/1024 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 374625/512 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -34484375/6144 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 34484375/3072 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( -102942875/3072 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 ( 102942875/1536 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 12722671/16128 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,351455/1152 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -42102251/20160 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-351455/576 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -93473665/576 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 93473665/288 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -34425/2 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 34425 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 5140625/384 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( -5140625/192 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 28824005/384 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 -28824005/192 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( 218045089/161280 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,1204669/2304 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -225264763/60480 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-1204669/1152 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 2490878233/18432 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -2490878233/9216 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 2565/2 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -2565 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -296875/18432 * ( 11/6 )**( 1/2 ) * Delta * np.log( 5 ) + 
 	 ( 296875/9216 * ( 11/6 )**( 1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -20588575/1024 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 ( 20588575/512 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) + 
 	 ( -14348907/2048 * ( 3/22 )**( 1/2 ) * Delta * np.log( 18 ) + 
 	 14348907/1024 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( 21961997/286720 * ( 11/6 )**( 1/2 ) * Delta + 
 	 ( complex( 0,121337/4096 ) * ( 11/6 )**( 1/2 ) * np.pi * Delta + 
 	 ( -20729653/9216 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-121337/2048 ) * ( 11/6 )**( 1/2 ) * np.pi * Delta * nu + 
 	 ( -2200855765/18432 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 2200855765/9216 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -6015465/512 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 6015465/256 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 170046875/2304 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 -170046875/1152 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( 1934372521/516096 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,53435705/36864 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -68934815239/7188480 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-53435705/18432 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -239/1280 * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( 463093945/18432 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -463093945/9216 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -234765/256 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 234765/128 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -26121875/2304 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 26121875/1152 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 1397703539/1290240 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,7722119/18432 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -396687317/138240 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-7722119/9216 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -5592984985/9216 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 5592984985/4608 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -40821111/512 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 40821111/256 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 823203125/9216 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( -823203125/4608 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 424124645/1536 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 -424124645/768 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( 1439096429/1290240 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,7950809/18432 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -5690729873/1935360 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-7950809/9216 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 76251577/3072 * ( 11/6 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -76251577/1536 * ( 11/6 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 15532425/256 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -15532425/128 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -435546875/3072 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( 435546875/1536 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -193532605/2304 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 193532605/1152 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( 1172705335/516096 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,32395175/36864 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -762128641/120960 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-32395175/18432 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -3351979315/9216 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 3351979315/4608 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -2565/64 * ( 33/2 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 2565/32 * ( 33/2 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -124971875/2304 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( 124971875/1152 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 78236585/4608 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 ( -78236585/2304 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) + 
 	 ( 71744535/2048 * ( 3/22 )**( 1/2 ) * Delta * np.log( 18 ) + 
 	 -71744535/1024 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( 818526707/860160 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,4522247/12288 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -1073430997/430080 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-4522247/6144 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 2852245163/3072 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -2852245163/1536 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 393255/16 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -393255/8 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -11546875/1152 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( 11546875/576 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -53530295/256 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 ( 53530295/128 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) + 
 	 ( -71744535/2048 * ( 3/22 )**( 1/2 ) * Delta * np.log( 18 ) + 
 	 71744535/1024 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( 4958495/3584 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,136975/256 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -49152161/13440 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-136975/128 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -6040039435/3456 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 6040039435/1728 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -513418095/2048 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 513418095/1024 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 9401078125/27648 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( -9401078125/13824 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 251233249/537600 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,1388029/7680 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -30409949/249600 * ( 11/6 )**( 1/2 ) * Delta * nu + 
 	 ( complex( 0,-1388029/3840 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 17/18 * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( -1024221091/3840 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( 1024221091/1920 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -45792513/2048 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 45792513/1024 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 1946040625/12288 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 -1946040625/6144 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( 3424150217/537600 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,5448351499/2211840 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -1218365321/74880 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-5448351499/1105920 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -17/18 * ( 66 )**( -1/2 ) * Delta * ( nu )**( 2 ) + 
 	 ( 1724453293/34560 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -1724453293/17280 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -33071895/16384 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 33071895/8192 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -9532553125/442368 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 9532553125/221184 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( 1280609365/18432 * ( 11/6 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 ( -1280609365/9216 * ( 11/6 )**( 1/2 ) * Delta * nu * np.log( 7 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 65819021/46080 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,2545487/4608 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -606378473/161280 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-2545487/2304 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 1609889167/2304 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -1609889167/1152 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 2320645221/16384 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -2320645221/8192 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -18160421875/49152 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( 18160421875/24576 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -9087797005/49152 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 9087797005/24576 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 1548255719/1612800 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,8553899/23040 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -112549967/46080 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-8553899/11520 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( -21052172961/20480 * ( 3/22 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( 21052172961/10240 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( -140535/8 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( 140535/4 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -9882840625/36864 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( 9882840625/18432 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( 1782970595/6144 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 ( -1782970595/3072 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) + 
 	 ( 4864279473/20480 * ( 3/22 )**( 1/2 ) * Delta * np.log( 18 ) + 
 	 -4864279473/10240 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( 1998473671/537600 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,11041291/7680 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -2786150623/268800 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-11041291/3840 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 4797743813/81920 * ( 11/6 )**( 1/2 ) * Delta * np.log( 2 ) + 
 	 ( -4797743813/40960 * ( 11/6 )**( 1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 243/8 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -243/4 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( 120000115625/442368 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( -120000115625/221184 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -78236585/147456 * ( 11/6 )**( 1/2 ) * Delta * np.log( 7 ) + 
 	 ( 78236585/73728 * ( 11/6 )**( 1/2 ) * Delta * nu * np.log( 7 ) + 
 	 ( -25937424601/2211840 * ( 11/6 )**( 1/2 ) * Delta * np.log( 11 ) + 
 	 ( 25937424601/1105920 * ( 11/6 )**( 1/2 ) * Delta * nu * np.log( 11 ) + 
 	 ( -1076168025/16384 * ( 3/22 )**( 1/2 ) * Delta * np.log( 18 ) + 
 	 1076168025/8192 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( 20834729/15360 * ( 66 )**( -1/2 ) * Delta + 
 	 ( complex( 0,805763/1536 ) * ( 66 )**( -1/2 ) * np.pi * Delta + 
 	 ( -387177533/107520 * ( 66 )**( -1/2 ) * Delta * nu + 
 	 ( complex( 0,-805763/768 ) * ( 66 )**( -1/2 ) * np.pi * Delta * nu + 
 	 ( 520583772901/147456 * ( 66 )**( -1/2 ) * Delta * np.log( 2 ) + 
 	 ( -520583772901/73728 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 2 ) + 
 	 ( 2472069645/16384 * ( 3/22 )**( 1/2 ) * Delta * np.log( 3 ) + 
 	 ( -2472069645/8192 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 3 ) + 
 	 ( -4917390625/49152 * ( 66 )**( -1/2 ) * Delta * np.log( 5 ) + 
 	 ( 4917390625/24576 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 5 ) + 
 	 ( -139225708951/147456 * ( 66 )**( -1/2 ) * Delta * np.log( 7 ) + 
 	 ( 139225708951/73728 * ( 66 )**( -1/2 ) * Delta * nu * np.log( 7 ) + 
 	 ( -1793613375/16384 * ( 3/22 )**( 1/2 ) * Delta * np.log( 18 ) + 
 	 1793613375/8192 * ( 3/22 )**( 1/2 ) * Delta * nu * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(h)

# %% [markdown]
# ## Amplitude $(\ell, m)$ = (5, 4)

# %%
# ## Amplitude $(\ell, m)$ = (5, 4)

def amplitude_54(xi, x, nu, Delta, e):
    
    h = ( ( x )**( 2 ) * ( -32/9 * ( 165 )**( -1/2 ) + 
 	 ( 32/9 * ( 5/33 )**( 1/2 ) * nu + 
 	 ( -32/9 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( -7879/1152 * ( 5/33 )**( 1/2 ) + 
 	 ( 39395/1152 * ( 5/33 )**( 1/2 ) * nu + 
 	 -39395/1152 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( -27161/1152 * ( 165 )**( -1/2 ) + 
 	 ( 27161/1152 * ( 5/33 )**( 1/2 ) * nu + 
 	 -27161/1152 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -12373/1152 * ( 165 )**( -1/2 ) + 
 	 ( 12373/1152 * ( 5/33 )**( 1/2 ) * nu + 
 	 -12373/1152 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,1 ) * xi ) * ( -11663/1152 * ( 165 )**( -1/2 ) + 
 	 ( 11663/1152 * ( 5/33 )**( 1/2 ) * nu + 
 	 -11663/1152 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( -1319/144 * ( 165 )**( -1/2 ) + 
 	 ( 1319/144 * ( 5/33 )**( 1/2 ) * nu + 
 	 -1319/144 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( -359/48 * ( 165 )**( -1/2 ) + 
 	 ( 359/48 * ( 5/33 )**( 1/2 ) * nu + 
 	 -359/48 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -151/12 * ( 165 )**( -1/2 ) + 
 	 ( 151/12 * ( 5/33 )**( 1/2 ) * nu + 
 	 ( -151/12 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -12769/216 * ( 165 )**( -1/2 ) + 
 	 ( 12769/216 * ( 5/33 )**( 1/2 ) * nu + 
 	 -12769/216 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( -2791/72 * ( 165 )**( -1/2 ) + 
 	 ( 2791/72 * ( 5/33 )**( 1/2 ) * nu + 
 	 -2791/72 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -277/27 * ( 165 )**( -1/2 ) + 
 	 ( 277/27 * ( 5/33 )**( 1/2 ) * nu + 
 	 -277/27 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,2 ) * xi ) * ( -41/6 * ( 165 )**( -1/2 ) + 
 	 ( 41/6 * ( 5/33 )**( 1/2 ) * nu + 
 	 -41/6 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( -167/18 * ( 165 )**( -1/2 ) + 
 	 ( 167/18 * ( 5/33 )**( 1/2 ) * nu + 
 	 ( -167/18 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -61/36 * ( 11/15 )**( 1/2 ) + 
 	 ( 61/36 * ( 55/3 )**( 1/2 ) * nu + 
 	 -61/36 * ( 55/3 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( -1/4 * ( 55/3 )**( 1/2 ) + 
 	 ( 5/4 * ( 55/3 )**( 1/2 ) * nu + 
 	 -5/4 * ( 55/3 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,5 ) * xi ) * ( -5434439/55296 * ( 165 )**( -1/2 ) + 
 	 ( 5434439/55296 * ( 5/33 )**( 1/2 ) * nu + 
 	 -5434439/55296 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-5 ) * xi ) * ( -380621/6144 * ( 165 )**( -1/2 ) + 
 	 ( 380621/6144 * ( 5/33 )**( 1/2 ) * nu + 
 	 -380621/6144 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( -385661/27648 * ( 165 )**( -1/2 ) + 
 	 ( 385661/27648 * ( 5/33 )**( 1/2 ) * nu + 
 	 -385661/27648 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( 96869/18432 * ( 165 )**( -1/2 ) + 
 	 ( -96869/18432 * ( 5/33 )**( 1/2 ) * nu + 
 	 96869/18432 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( -11743/9216 * ( 11/15 )**( 1/2 ) + 
 	 ( 11743/9216 * ( 55/3 )**( 1/2 ) * nu + 
 	 -11743/9216 * ( 55/3 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( -9179/18432 * ( 11/15 )**( 1/2 ) + 
 	 ( 9179/18432 * ( 55/3 )**( 1/2 ) * nu + 
 	 -9179/18432 * ( 55/3 )**( 1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( -437/144 * ( 5/33 )**( 1/2 ) + 
 	 ( 2185/144 * ( 5/33 )**( 1/2 ) * nu + 
 	 ( -2185/144 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( -28411/1728 * ( 165 )**( -1/2 ) + 
 	 ( 28411/1728 * ( 5/33 )**( 1/2 ) * nu + 
 	 -28411/1728 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( -26927/1728 * ( 165 )**( -1/2 ) + 
 	 ( 26927/1728 * ( 5/33 )**( 1/2 ) * nu + 
 	 -26927/1728 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( -457687/2880 * ( 165 )**( -1/2 ) + 
 	 ( 457687/576 * ( 165 )**( -1/2 ) * nu + 
 	 -457687/576 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-6 ) * xi ) * ( -279331/2880 * ( 165 )**( -1/2 ) + 
 	 ( 279331/576 * ( 165 )**( -1/2 ) * nu + 
 	 -279331/576 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 33103/4320 * ( 165 )**( -1/2 ) + 
 	 ( -33103/864 * ( 165 )**( -1/2 ) * nu + 
 	 33103/864 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) ) ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( 147839/4320 * ( 165 )**( -1/2 ) + 
 	 ( -147839/864 * ( 165 )**( -1/2 ) * nu + 
 	 147839/864 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 3 ) * ( 71216/4095 * ( 165 )**( -1/2 ) + 
 	 ( -5264/585 * ( 11/15 )**( 1/2 ) * nu + 
 	 ( 16672/117 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( -1808/39 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) + 
 	 ( ( e )**( 4 ) * ( 3593159/21840 * ( 165 )**( -1/2 ) + 
 	 ( -17772301/18720 * ( 165 )**( -1/2 ) * nu + 
 	 ( 2455357/1872 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( -373247/1872 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 76975/864 * ( 5/33 )**( 1/2 ) + 
 	 ( -844601/1728 * ( 5/33 )**( 1/2 ) * nu + 
 	 ( 511493/864 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 -509/864 * ( 55/3 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( -862669/6240 * ( 165 )**( -1/2 ) + 
 	 ( 59997371/112320 * ( 165 )**( -1/2 ) * nu + 
 	 ( -84353/3744 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -4890047/11232 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 182977/945 * ( 165 )**( -1/2 ) + 
 	 ( -596557/540 * ( 165 )**( -1/2 ) * nu + 
 	 ( 3686/27 * ( 11/15 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 -12673/54 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( 258917/16380 * ( 11/15 )**( 1/2 ) + 
 	 ( -1748246/1755 * ( 165 )**( -1/2 ) * nu + 
 	 ( 7061/26 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 -277703/1404 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( 199763/2730 * ( 165 )**( -1/2 ) + 
 	 ( -59933/1560 * ( 11/15 )**( 1/2 ) * nu + 
 	 ( 278849/468 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 ( -4778/39 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 14153/910 * ( 165 )**( -1/2 ) + 
 	 ( -419713/3120 * ( 165 )**( -1/2 ) * nu + 
 	 ( 308123/936 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -29123/156 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-2 ) * xi ) * ( 87377/8190 * ( 11/15 )**( 1/2 ) + 
 	 ( -6106699/9360 * ( 165 )**( -1/2 ) * nu + 
 	 ( 262217/312 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -16307/156 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( ( np.e )**( complex( 0,3 ) * xi ) * ( -729329/26208 * ( 165 )**( -1/2 ) + 
 	 ( 829663/19968 * ( 165 )**( -1/2 ) * nu + 
 	 ( 2133379/7488 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -8872333/29952 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( 29858441/262080 * ( 165 )**( -1/2 ) + 
 	 ( -197953447/299520 * ( 165 )**( -1/2 ) * nu + 
 	 ( 872369/936 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -5227741/29952 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 1355843/10920 * ( 165 )**( -1/2 ) + 
 	 ( -23647721/33280 * ( 165 )**( -1/2 ) * nu + 
 	 ( 7264729/7488 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -1502729/9984 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-3 ) * xi ) * ( 62146801/262080 * ( 165 )**( -1/2 ) + 
 	 ( -11877209/99840 * ( 11/15 )**( 1/2 ) * nu + 
 	 ( 3049873/1872 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -3033211/29952 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) + 
 	 ( e * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 178357/7280 * ( 165 )**( -1/2 ) + 
 	 ( -5692813/37440 * ( 165 )**( -1/2 ) * nu + 
 	 ( 15973/312 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 -392753/3744 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-1 ) * xi ) * ( 306091/65520 * ( 11/15 )**( 1/2 ) + 
 	 ( -10801691/37440 * ( 165 )**( -1/2 ) * nu + 
 	 ( 181913/468 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -298223/3744 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( ( np.e )**( complex( 0,1 ) * xi ) * ( 2649912359/12579840 * ( 165 )**( -1/2 ) + 
 	 ( -8782747609/7188480 * ( 165 )**( -1/2 ) * nu + 
 	 ( 33927667/19968 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -12084343/239616 * ( 5/33 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( 77903081/399360 * ( 165 )**( -1/2 ) + 
 	 ( -5441912231/4792320 * ( 165 )**( -1/2 ) * nu + 
 	 ( 21464117/13312 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -13467437/479232 * ( 11/15 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,5 ) * xi ) * ( -1037276477/2795520 * ( 165 )**( -1/2 ) + 
 	 ( 2577908527/1597440 * ( 165 )**( -1/2 ) * nu + 
 	 ( -305587693/359424 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -287715947/479232 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( 144274457/399360 * ( 165 )**( -1/2 ) + 
 	 ( -872359027/4792320 * ( 11/15 )**( 1/2 ) * nu + 
 	 ( 5688383/6656 * ( 3/55 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 -149650081/479232 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( 957101573/4193280 * ( 165 )**( -1/2 ) + 
 	 ( -3138812933/2396160 * ( 165 )**( -1/2 ) * nu + 
 	 ( 159925351/89856 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -54793021/239616 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-5 ) * xi ) * ( 20048483387/25159680 * ( 165 )**( -1/2 ) + 
 	 ( -62548694287/14376960 * ( 165 )**( -1/2 ) * nu + 
 	 ( 308456417/59904 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 80955163/479232 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( 1465235/26208 * ( 5/33 )**( 1/2 ) + 
 	 ( -1207055/3744 * ( 5/33 )**( 1/2 ) * nu + 
 	 ( 275359/624 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 ( -212087/3744 * ( 5/33 )**( 1/2 ) * ( nu )**( 3 ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( 470694401/1572480 * ( 165 )**( -1/2 ) + 
 	 ( -384423749/224640 * ( 165 )**( -1/2 ) * nu + 
 	 ( 4689601/22464 * ( 11/15 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 -1032779/44928 * ( 11/15 )**( 1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,6 ) * xi ) * ( -2143077487/2620800 * ( 165 )**( -1/2 ) + 
 	 ( 1396623103/374400 * ( 165 )**( -1/2 ) * nu + 
 	 ( -730907/832 * ( 3/55 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 -58134049/74880 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( 170808661/1310400 * ( 165 )**( -1/2 ) + 
 	 ( -154533259/187200 * ( 165 )**( -1/2 ) * nu + 
 	 ( 16012811/11232 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -21870253/37440 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( 2802897271/3931200 * ( 165 )**( -1/2 ) + 
 	 ( -2156466109/561600 * ( 165 )**( -1/2 ) * nu + 
 	 ( 259770811/56160 * ( 165 )**( -1/2 ) * ( nu )**( 2 ) + 
 	 -48589919/112320 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( 43991333/174720 * ( 165 )**( -1/2 ) + 
 	 ( -110120531/74880 * ( 165 )**( -1/2 ) * nu + 
 	 ( 9278227/22464 * ( 5/33 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 -1505069/4992 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) + 
 	 ( np.e )**( complex( 0,-6 ) * xi ) * ( 3606019181/2620800 * ( 165 )**( -1/2 ) + 
 	 ( -2801110349/374400 * ( 165 )**( -1/2 ) * nu + 
 	 ( 12036853/4160 * ( 3/55 )**( 1/2 ) * ( nu )**( 2 ) + 
 	 46231331/74880 * ( 165 )**( -1/2 ) * ( nu )**( 3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(h)

# %% [markdown]
# ## Amplitude $(\ell, m)$ = (5, 3)

# %%
def amplitude_53(xi, x, nu, Delta, e):
    
    h = complex( 0,9/32 ) * ( 3/110 )**( 1/2 ) * Delta * ( ( x )**( 2 ) * ( complex( 0,-31/2187 ) * ( e )**( 6 ) * nu + 
 	 ( complex( 0,217/2916 ) * ( e )**( 5 ) * ( np.e )**( complex( 0,1 ) * xi ) * nu + 
 	 ( complex( 0,527/2916 ) * ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * nu + 
 	 ( complex( 0,1457/4374 ) * ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * nu + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( complex( 0,62/2187 ) * ( e )**( 3 ) * nu + 
 	 complex( 0,-1481/8748 ) * ( e )**( 5 ) * nu ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( complex( 0,-62/729 ) * ( e )**( 4 ) * nu + 
 	 complex( 0,-23/972 ) * ( e )**( 6 ) * nu ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( complex( 0,62/729 ) * ( e )**( 4 ) * nu + 
 	 complex( 0,-287/972 ) * ( e )**( 6 ) * nu ) ) ) ) ) ) ) + 
 	 ( ( x )**( 3/2 ) * ( -1 + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( ( e )**( 5 ) * ( 61705/46656 + 
 	 -61705/23328 * nu ) + 
 	 ( ( e )**( 3 ) * ( 2303/1944 + 
 	 -2303/972 * nu ) + 
 	 e * ( 217/243 + 
 	 -434/243 * nu ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 2 ) * ( 1015/486 + 
 	 -1015/243 * nu ) + 
 	 ( ( e )**( 6 ) * ( 8153/5832 + 
 	 -8153/2916 * nu ) + 
 	 ( e )**( 4 ) * ( 406/729 + 
 	 -812/729 * nu ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( 33481/2160 + 
 	 -33481/1080 * nu ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( 935549/93312 + 
 	 -935549/46656 * nu ) + 
 	 ( ( e )**( 2 ) * ( 325/162 + 
 	 -325/81 * nu ) + 
 	 ( ( e )**( 4 ) * ( 235/162 + 
 	 -235/81 * nu ) + 
 	 ( ( e )**( 6 ) * ( 110/81 + 
 	 -220/81 * nu ) + 
 	 ( 2 * nu + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( -1737101/93312 + 
 	 1737101/46656 * nu ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( -61879/2160 + 
 	 61879/1080 * nu ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 3 ) * ( 91/24 + 
 	 -91/12 * nu ) + 
 	 ( e )**( 5 ) * ( -9481/10368 + 
 	 9481/5184 * nu ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( ( e )**( 3 ) * ( 8113/1944 + 
 	 -8113/972 * nu ) + 
 	 ( ( e )**( 5 ) * ( 50855/46656 + 
 	 -50855/23328 * nu ) + 
 	 e * ( -553/243 + 
 	 1106/243 * nu ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 4 ) * ( 73561/11664 + 
 	 -73561/5832 * nu ) + 
 	 ( e )**( 6 ) * ( -461219/116640 + 
 	 461219/58320 * nu ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 4 ) * ( 5906/729 + 
 	 -11812/729 * nu ) + 
 	 ( ( e )**( 6 ) * ( -2567/5832 + 
 	 2567/2916 * nu ) + 
 	 ( e )**( 2 ) * ( -2065/486 + 
 	 2065/243 * nu ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 5 ) * ( 154169/10368 + 
 	 -154169/5184 * nu ) + 
 	 ( e )**( 3 ) * ( -1571/216 + 
 	 1571/108 * nu ) ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 6 ) * ( 3059741/116640 + 
 	 -3059741/58320 * nu ) + 
 	 ( e )**( 4 ) * ( -137959/11664 + 
 	 137959/5832 * nu ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( ( x )**( 5/2 ) * ( 69/13 + 
 	 ( -464/39 * nu + 
 	 ( 88/39 * ( nu )**( 2 ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( -7555229/21060 + 
 	 ( 75667597/84240 * nu + 
 	 -12937207/42120 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( -124826483/606528 + 
 	 ( 3762614237/7278336 * nu + 
 	 -669201257/3639168 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( -6098147/28080 + 
 	 ( 3835963/8424 * nu + 
 	 -80839/1404 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( -361723/8424 + 
 	 ( 349996/3159 * nu + 
 	 -297169/6318 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 4 ) * ( -420451/16848 + 
 	 ( 826789/12636 * nu + 
 	 -387083/12636 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( -21340991/202176 + 
 	 ( 1595954707/7278336 * nu + 
 	 -95435527/3639168 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 2 ) * ( -6583/1404 + 
 	 ( 47521/3159 * nu + 
 	 -43847/3159 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 6 ) * ( -29279239/606528 + 
 	 ( 28091677/227448 * nu + 
 	 -22837033/454896 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 4 ) * ( -1292237/50544 + 
 	 ( 15081277/227448 * nu + 
 	 -1675469/56862 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 2 ) * ( -605819/25272 + 
 	 ( 2334277/37908 * nu + 
 	 -262649/9477 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 3 ) * ( -473321/8424 + 
 	 ( 2403589/16848 * nu + 
 	 -482533/8424 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 5 ) * ( -1109609/67392 + 
 	 ( 35931959/808704 * nu + 
 	 -9667355/404352 * ( nu )**( 2 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( ( e )**( 5 ) * ( -3764837/101088 + 
 	 ( 348024025/3639168 * nu + 
 	 -73280437/1819584 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 3 ) * ( -168413/8424 + 
 	 ( 7872305/151632 * nu + 
 	 -1816241/75816 * ( nu )**( 2 ) ) ) + 
 	 e * ( -19684/3159 + 
 	 ( 315493/18954 * nu + 
 	 -95113/9477 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 6 ) * ( 396779801/3032640 + 
 	 ( -571135909/2274480 * nu + 
 	 -67203697/2274480 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 4 ) * ( -4474123/101088 + 
 	 ( 40999771/454896 * nu + 
 	 -529513/56862 * ( nu )**( 2 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 5 ) * ( 1086323/22464 + 
 	 ( -68285767/808704 * nu + 
 	 -12711509/404352 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 3 ) * ( -36181/2808 + 
 	 ( 412291/16848 * nu + 
 	 -8195/8424 * ( nu )**( 2 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 6 ) * ( -10121129/202176 + 
 	 ( 57001717/454896 * nu + 
 	 -21095579/454896 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 4 ) * ( 1890505/151632 + 
 	 ( -3248125/227448 * nu + 
 	 -755984/28431 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 2 ) * ( 811/648 + 
 	 ( -13681/2916 * nu + 
 	 1772/729 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( ( e )**( 5 ) * ( -10057649/303264 + 
 	 ( 313374071/3639168 * nu + 
 	 -68955803/1819584 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 3 ) * ( -22897/25272 + 
 	 ( 1506055/151632 * nu + 
 	 -1518631/75816 * ( nu )**( 2 ) ) ) + 
 	 e * ( 6172/1053 + 
 	 ( -260005/18954 * nu + 
 	 29065/9477 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 4 ) * ( -33997793/303264 + 
 	 ( 128654969/454896 * nu + 
 	 -12036025/113724 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 6 ) * ( 26151427/1010880 + 
 	 ( -27103825/454896 * nu + 
 	 2802611/454896 * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 3 ) * ( complex( 0,543/70 ) + 
 	 ( -3 * np.pi + 
 	 ( complex( 0,6 ) * np.log( 2 ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 3 ) * ( complex( 0,3067769/45360 ) + 
 	 ( -16949/648 * np.pi + 
 	 ( complex( 0,173773/28431 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,22933/324 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-192196846/995085 ) + 
 	 ( 16949/324 * np.pi + 
 	 ( complex( 0,-22933/162 ) * np.log( 2 ) + 
 	 complex( 0,141 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-141/2 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,-52068451/725760 ) + 
 	 ( 860203/31104 * np.pi + 
 	 ( complex( 0,-5885501/227448 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-1450429/1728 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,303033139/2021760 ) + 
 	 ( -860203/15552 * np.pi + 
 	 ( complex( 0,1450429/864 ) * np.log( 2 ) + 
 	 complex( 0,-999 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,999/2 ) * np.log( 3 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 4 ) * ( complex( 0,45872821/408240 ) + 
 	 ( -2026123/46656 * np.pi + 
 	 ( complex( 0,57790/3159 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,352705/2916 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-430415623/1326780 ) + 
 	 ( 2026123/23328 * np.pi + 
 	 ( complex( 0,-352705/1458 ) * np.log( 2 ) + 
 	 complex( 0,7701/32 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-7701/64 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-579627341/4082400 ) + 
 	 ( 25491137/466560 * np.pi + 
 	 ( complex( 0,-1209499/37908 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-8170501/5832 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,4215387053/13267800 ) + 
 	 ( -25491137/233280 * np.pi + 
 	 ( complex( 0,8170501/2916 ) * np.log( 2 ) + 
 	 complex( 0,-542271/320 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,542271/640 ) * np.log( 3 ) ) ) ) ) ) ) + 
 	 ( nu * ( complex( 0,-83702/3645 ) + 
 	 ( 6 * np.pi + 
 	 ( complex( 0,-12 ) * np.log( 2 ) + 
 	 complex( 0,12 ) * np.log( 3 ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( complex( 0,-18281/3780 ) + 
 	 ( 101/54 * np.pi + 
 	 ( complex( 0,-9199/81 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-274/45 ) + 
 	 ( -101/27 * np.pi + 
 	 ( complex( 0,18398/81 ) * np.log( 2 ) + 
 	 complex( 0,-126 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,63 ) * np.log( 3 ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( complex( 0,1173133943/6531840 ) + 
 	 ( -32362817/466560 * np.pi + 
 	 ( complex( 0,108935/2808 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,1702213/8640 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-5549477587/10614240 ) + 
 	 ( 32362817/233280 * np.pi + 
 	 ( complex( 0,-1702213/4320 ) * np.log( 2 ) + 
 	 complex( 0,7833/20 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-7833/40 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( complex( 0,25343077/90720 ) + 
 	 ( -1398377/12960 * np.pi + 
 	 ( complex( 0,8116553/113724 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,3019199/9720 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-6515308687/7960680 ) + 
 	 ( 1398377/6480 * np.pi + 
 	 ( complex( 0,-3019199/4860 ) * np.log( 2 ) + 
 	 complex( 0,394941/640 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-394941/1280 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( complex( 0,-6 ) * np.log( 3 ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( e * ( complex( 0,66427/3402 ) + 
 	 ( -1835/243 * np.pi + 
 	 ( complex( 0,18 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-13612/243 ) + 
 	 ( 3670/243 * np.pi + 
 	 ( complex( 0,-36 ) * np.log( 2 ) + 
 	 complex( 0,36 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-18 ) * np.log( 3 ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( complex( 0,-375937/27216 ) + 
 	 ( 10385/1944 * np.pi + 
 	 ( complex( 0,-81563/324 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,16147/1944 ) + 
 	 ( -10385/972 * np.pi + 
 	 ( complex( 0,81563/162 ) * np.log( 2 ) + 
 	 complex( 0,-288 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,144 ) * np.log( 3 ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,-149648809/3265920 ) + 
 	 ( 826789/46656 * np.pi + 
 	 ( complex( 0,403321/25272 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,8176873/7776 ) * np.log( 2 ) + 
 	 ( complex( 0,-11031/32 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,2528242/47385 ) + 
 	 ( -826789/23328 * np.pi + 
 	 ( complex( 0,-8176873/3888 ) * np.log( 2 ) + 
 	 ( complex( 0,11031/16 ) * np.log( 3 ) + 
 	 complex( 0,734375/1944 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-734375/3888 ) * np.log( 5 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( e * ( complex( 0,-25159/17010 ) + 
 	 ( 139/243 * np.pi + 
 	 ( complex( 0,-8470/243 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-11591/1215 ) + 
 	 ( -278/243 * np.pi + 
 	 ( complex( 0,16940/243 ) * np.log( 2 ) + 
 	 complex( 0,-36 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,18 ) * np.log( 3 ) ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( complex( 0,-3118811/136080 ) + 
 	 ( 17231/1944 * np.pi + 
 	 ( complex( 0,252305/972 ) * np.log( 2 ) + 
 	 ( complex( 0,-153/2 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,32863/1215 ) + 
 	 ( -17231/972 * np.pi + 
 	 ( complex( 0,-252305/486 ) * np.log( 2 ) + 
 	 ( complex( 0,153 ) * np.log( 3 ) + 
 	 complex( 0,15625/162 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-15625/324 ) * np.log( 5 ) ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,-185644279/3265920 ) + 
 	 ( 1025659/46656 * np.pi + 
 	 ( complex( 0,5826181/23328 ) * np.log( 2 ) + 
 	 ( complex( 0,11211/32 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,6793319/77760 ) + 
 	 ( -1025659/23328 * np.pi + 
 	 ( complex( 0,-5826181/11664 ) * np.log( 2 ) + 
 	 ( complex( 0,-11211/16 ) * np.log( 3 ) + 
 	 complex( 0,578125/972 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-578125/1944 ) * np.log( 5 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 2 ) * ( complex( 0,2608391/68040 ) + 
 	 ( -14411/972 * np.pi + 
 	 ( complex( 0,18635/486 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,-87641/810 ) + 
 	 ( 14411/486 * np.pi + 
 	 ( complex( 0,-18635/243 ) * np.log( 2 ) + 
 	 complex( 0,153/2 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,-153/4 ) * np.log( 3 ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-6812297/204120 ) + 
 	 ( 37637/2916 * np.pi + 
 	 ( complex( 0,-57790/3159 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,-697829/1458 ) * np.log( 2 ) + 
 	 ( nu * ( complex( 0,79457197/1326780 ) + 
 	 ( -37637/1458 * np.pi + 
 	 ( complex( 0,697829/729 ) * np.log( 2 ) + 
 	 complex( 0,-1119/2 ) * np.log( 3 ) ) ) ) + 
 	 complex( 0,1119/4 ) * np.log( 3 ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-6938273/116640 ) + 
 	 ( 8616097/373248 * np.pi + 
 	 ( complex( 0,-1381379/37908 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,10931317/5832 ) * np.log( 2 ) + 
 	 ( complex( 0,-328863/512 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,117284795/1061424 ) + 
 	 ( -8616097/186624 * np.pi + 
 	 ( complex( 0,-10931317/2916 ) * np.log( 2 ) + 
 	 ( complex( 0,328863/256 ) * np.log( 3 ) + 
 	 complex( 0,40109375/62208 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-40109375/124416 ) * np.log( 5 ) ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-251047/7560 ) + 
 	 ( 1387/108 * np.pi + 
 	 ( complex( 0,89855/162 ) * np.log( 2 ) + 
 	 ( complex( 0,-2781/16 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,105457/2430 ) + 
 	 ( -1387/54 * np.pi + 
 	 ( complex( 0,-89855/81 ) * np.log( 2 ) + 
 	 ( complex( 0,2781/8 ) * np.log( 3 ) + 
 	 complex( 0,265625/1296 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-265625/2592 ) * np.log( 5 ) ) ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( complex( 0,-216295/3024 ) + 
 	 ( 5975/216 * np.pi + 
 	 ( complex( 0,-343919/113724 ) * ( nu )**( 2 ) + 
 	 ( complex( 0,3371/4 ) * np.log( 2 ) + 
 	 ( complex( 0,19011/32 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,913827097/7960680 ) + 
 	 ( -5975/108 * np.pi + 
 	 ( complex( 0,-3371/2 ) * np.log( 2 ) + 
 	 ( complex( 0,-19011/16 ) * np.log( 3 ) + 
 	 complex( 0,3640625/2592 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-3640625/5184 ) * np.log( 5 ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 3 ) * ( complex( 0,-3224153/45360 ) + 
 	 ( 17813/648 * np.pi + 
 	 ( complex( 0,-3437/36 ) * np.log( 2 ) + 
 	 ( complex( 0,51 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,1080761/9720 ) + 
 	 ( -17813/324 * np.pi + 
 	 ( complex( 0,3437/18 ) * np.log( 2 ) + 
 	 ( complex( 0,-102 ) * np.log( 3 ) + 
 	 complex( 0,-15625/162 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,15625/324 ) * np.log( 5 ) ) ) ) ) ) + 
 	 ( e )**( 5 ) * ( complex( 0,-5888473/145152 ) + 
 	 ( 162665/10368 * np.pi + 
 	 ( complex( 0,-798721/576 ) * np.log( 2 ) + 
 	 ( complex( 0,-10683/8 ) * np.log( 3 ) + 
 	 ( complex( 0,1859375/3888 ) * np.log( 5 ) + 
 	 ( nu * ( complex( 0,609487/10080 ) + 
 	 ( -162665/5184 * np.pi + 
 	 ( complex( 0,798721/288 ) * np.log( 2 ) + 
 	 ( complex( 0,10683/4 ) * np.log( 3 ) + 
 	 ( complex( 0,-1859375/1944 ) * np.log( 5 ) + 
 	 complex( 0,-14000231/7776 ) * np.log( 7 ) ) ) ) ) ) + 
 	 complex( 0,14000231/15552 ) * np.log( 7 ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 2 ) * ( complex( 0,-1648729/68040 ) + 
 	 ( 9109/972 * np.pi + 
 	 ( complex( 0,40043/486 ) * np.log( 2 ) + 
 	 ( complex( 0,-63/4 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,68971/2430 ) + 
 	 ( -9109/486 * np.pi + 
 	 ( complex( 0,-40043/243 ) * np.log( 2 ) + 
 	 ( complex( 0,63/2 ) * np.log( 3 ) + 
 	 complex( 0,15625/486 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-15625/972 ) * np.log( 5 ) ) ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( complex( 0,-8013413/204120 ) + 
 	 ( 44273/2916 * np.pi + 
 	 ( complex( 0,-94481/1458 ) * np.log( 2 ) + 
 	 ( complex( 0,717/4 ) * np.log( 3 ) + 
 	 ( nu * ( complex( 0,840269/14580 ) + 
 	 ( -44273/1458 * np.pi + 
 	 ( complex( 0,94481/729 ) * np.log( 2 ) + 
 	 ( complex( 0,-717/2 ) * np.log( 3 ) + 
 	 complex( 0,171875/1458 ) * np.log( 5 ) ) ) ) ) + 
 	 complex( 0,-171875/2916 ) * np.log( 5 ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,-1951723/23328 ) + 
 	 ( 377405/11664 * np.pi + 
 	 ( complex( 0,-27889277/5832 ) * np.log( 2 ) + 
 	 ( complex( 0,-1841901/512 ) * np.log( 3 ) + 
 	 ( complex( 0,854796875/373248 ) * np.log( 5 ) + 
 	 ( nu * ( complex( 0,56152253/408240 ) + 
 	 ( -377405/5832 * np.pi + 
 	 ( complex( 0,27889277/2916 ) * np.log( 2 ) + 
 	 ( complex( 0,1841901/256 ) * np.log( 3 ) + 
 	 ( complex( 0,-854796875/186624 ) * np.log( 5 ) + 
 	 complex( 0,-238003927/62208 ) * np.log( 7 ) ) ) ) ) ) + 
 	 complex( 0,238003927/124416 ) * np.log( 7 ) ) ) ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 4 ) * ( complex( 0,-64675463/408240 ) + 
 	 ( 357323/5832 * np.pi + 
 	 ( complex( 0,-728075/2916 ) * np.log( 2 ) + 
 	 ( complex( 0,-9201/64 ) * np.log( 3 ) + 
 	 ( complex( 0,-109375/2592 ) * np.log( 5 ) + 
 	 ( nu * ( complex( 0,27595669/102060 ) + 
 	 ( -357323/2916 * np.pi + 
 	 ( complex( 0,728075/1458 ) * np.log( 2 ) + 
 	 ( complex( 0,9201/32 ) * np.log( 3 ) + 
 	 ( complex( 0,109375/1296 ) * np.log( 5 ) + 
 	 complex( 0,-14000231/23328 ) * np.log( 7 ) ) ) ) ) ) + 
 	 complex( 0,14000231/46656 ) * np.log( 7 ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( complex( 0,899027/816480 ) + 
 	 ( -4967/11664 * np.pi + 
 	 ( complex( 0,355220131/29160 ) * np.log( 2 ) + 
 	 ( complex( 0,1981347/640 ) * np.log( 3 ) + 
 	 ( complex( 0,-2609375/5184 ) * np.log( 5 ) + 
 	 ( nu * ( complex( 0,-14847043/816480 ) + 
 	 ( 4967/5832 * np.pi + 
 	 ( complex( 0,-355220131/14580 ) * np.log( 2 ) + 
 	 ( complex( 0,-1981347/320 ) * np.log( 3 ) + 
 	 ( complex( 0,2609375/2592 ) * np.log( 5 ) + 
 	 complex( 0,2624631541/233280 ) * np.log( 7 ) ) ) ) ) ) + 
 	 complex( 0,-2624631541/466560 ) * np.log( 7 ) ) ) ) ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( complex( 0,-2038673047/6531840 ) + 
 	 ( 11263387/93312 * np.pi + 
 	 ( complex( 0,678026617/233280 ) * np.log( 2 ) + 
 	 ( complex( 0,5043/40 ) * np.log( 3 ) + 
 	 ( complex( 0,15625/1944 ) * np.log( 5 ) + 
 	 ( nu * ( complex( 0,1815483851/3265920 ) + 
 	 ( -11263387/46656 * np.pi + 
 	 ( complex( 0,-678026617/116640 ) * np.log( 2 ) + 
 	 ( complex( 0,-5043/20 ) * np.log( 3 ) + 
 	 ( complex( 0,-15625/972 ) * np.log( 5 ) + 
 	 complex( 0,14000231/7776 ) * np.log( 7 ) ) ) ) ) ) + 
 	 complex( 0,-14000231/15552 ) * np.log( 7 ) ) ) ) ) ) ) + 
 	 ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( complex( 0,-259615721/453600 ) + 
 	 ( 1434341/6480 * np.pi + 
 	 ( complex( 0,-7606027943/622080 ) * np.log( 2 ) + 
 	 ( complex( 0,-61359/2560 ) * np.log( 3 ) + 
 	 ( complex( 0,78125/124416 ) * np.log( 5 ) + 
 	 ( complex( 0,98001617/124416 ) * np.log( 7 ) + 
 	 ( nu * ( complex( 0,203282951/194400 ) + 
 	 ( -1434341/3240 * np.pi + 
 	 ( complex( 0,7606027943/311040 ) * np.log( 2 ) + 
 	 ( complex( 0,61359/1280 ) * np.log( 3 ) + 
 	 ( complex( 0,-78125/62208 ) * np.log( 5 ) + 
 	 ( complex( 0,-98001617/62208 ) * np.log( 7 ) + 
 	 complex( 0,-6908733/1280 ) * np.log( 18 ) ) ) ) ) ) ) + 
 	 complex( 0,6908733/2560 ) * np.log( 18 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(h)

# %%
def amp54(xi, x, nu):
    h = -32/9 * ( 165 )**( -1/2 ) * ( ( x )**( 2 ) * ( 1 + 
 	 ( -5 * nu + 
 	 ( 5 * ( nu )**( 2 ) + 
 	 ( ( e )**( 2 ) * ( 167/64 + 
 	 ( -835/64 * nu + 
 	 835/64 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 4 ) * ( 453/128 + 
 	 ( -2265/128 * nu + 
 	 2265/128 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( 2185/512 + 
 	 ( -10925/512 * nu + 
 	 10925/512 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( 1141863/65536 + 
 	 ( -5709315/65536 * nu + 
 	 5709315/65536 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( 279331/10240 + 
 	 ( -279331/2048 * nu + 
 	 279331/2048 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( 5434439/196608 + 
 	 ( -27172195/196608 * nu + 
 	 27172195/196608 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( 457687/10240 + 
 	 ( -457687/2048 * nu + 
 	 457687/2048 * ( nu )**( 2 ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( e * ( 1077/512 + 
 	 ( -5385/512 * nu + 
 	 5385/512 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 3 ) * ( 12373/4096 + 
 	 ( -61865/4096 * nu + 
 	 61865/4096 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 5 ) * ( 385661/98304 + 
 	 ( -1928305/98304 * nu + 
 	 1928305/98304 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( e * ( 1319/512 + 
 	 ( -6595/512 * nu + 
 	 6595/512 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 3 ) * ( 11663/4096 + 
 	 ( -58315/4096 * nu + 
 	 58315/4096 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 5 ) * ( 129173/32768 + 
 	 ( -645865/32768 * nu + 
 	 645865/32768 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 4 ) * ( 277/96 + 
 	 ( -1385/96 * nu + 
 	 1385/96 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 2 ) * ( 495/128 + 
 	 ( -2475/128 * nu + 
 	 2475/128 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 6 ) * ( 26927/6144 + 
 	 ( -134635/6144 * nu + 
 	 134635/6144 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 4 ) * ( 123/64 + 
 	 ( -615/64 * nu + 
 	 615/64 * ( nu )**( 2 ) ) ) + 
 	 ( ( e )**( 6 ) * ( 28411/6144 + 
 	 ( -142055/6144 * nu + 
 	 142055/6144 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 2 ) * ( 671/128 + 
 	 ( -3355/128 * nu + 
 	 3355/128 * ( nu )**( 2 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 5 ) * ( 100969/65536 + 
 	 ( -504845/65536 * nu + 
 	 504845/65536 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 3 ) * ( 27161/4096 + 
 	 ( -135805/4096 * nu + 
 	 135805/4096 * ( nu )**( 2 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 5 ) * ( -96869/65536 + 
 	 ( 484345/65536 * nu + 
 	 -484345/65536 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 3 ) * ( 39395/4096 + 
 	 ( -196975/4096 * nu + 
 	 196975/4096 * ( nu )**( 2 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 6 ) * ( -33103/15360 + 
 	 ( 33103/3072 * nu + 
 	 -33103/3072 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 4 ) * ( 2791/256 + 
 	 ( -13955/256 * nu + 
 	 13955/256 * ( nu )**( 2 ) ) ) ) + 
 	 ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 6 ) * ( -147839/15360 + 
 	 ( 147839/3072 * nu + 
 	 -147839/3072 * ( nu )**( 2 ) ) ) + 
 	 ( e )**( 4 ) * ( 12769/768 + 
 	 ( -63845/768 * nu + 
 	 63845/768 * ( nu )**( 2 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) + 
 	 ( x )**( 3 ) * ( -4451/910 + 
 	 ( 3619/130 * nu + 
 	 ( -521/13 * ( nu )**( 2 ) + 
 	 ( 339/26 * ( nu )**( 3 ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,-6 ) * xi ) * ( -3606019181/9318400 + 
 	 ( 2801110349/1331200 * nu + 
 	 ( -324995031/133120 * ( nu )**( 2 ) + 
 	 -46231331/266240 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,-5 ) * xi ) * ( -20048483387/89456640 + 
 	 ( 62548694287/51118080 * nu + 
 	 ( -308456417/212992 * ( nu )**( 2 ) + 
 	 -80955163/1703936 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 2 ) * ( -599289/29120 + 
 	 ( 1977789/16640 * nu + 
 	 ( -278849/1664 * ( nu )**( 2 ) + 
 	 7167/208 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -10779477/232960 + 
 	 ( 17772301/66560 * nu + 
 	 ( -2455357/6656 * ( nu )**( 2 ) + 
 	 373247/6656 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( -7326175/93184 + 
 	 ( 6035275/13312 * nu + 
 	 ( -4130385/6656 * ( nu )**( 2 ) + 
 	 1060435/13312 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 5 ) * ( np.e )**( complex( 0,5 ) * xi ) * ( 3111829431/29818880 + 
 	 ( -7733725581/17039360 * nu + 
 	 ( 305587693/1277952 * ( nu )**( 2 ) + 
 	 287715947/1703936 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 6 ) * ( np.e )**( complex( 0,6 ) * xi ) * ( 2143077487/9318400 + 
 	 ( -1396623103/1331200 * nu + 
 	 ( 19734489/26624 * ( nu )**( 2 ) + 
 	 58134049/266240 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-1 ) * xi ) * ( e * ( -3367001/232960 + 
 	 ( 10801691/133120 * nu + 
 	 ( -181913/1664 * ( nu )**( 2 ) + 
 	 298223/13312 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( -4067529/116480 + 
 	 ( 212829489/1064960 * nu + 
 	 ( -7264729/26624 * ( nu )**( 2 ) + 
 	 4508187/106496 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 5 ) * ( -957101573/14909440 + 
 	 ( 3138812933/8519680 * nu + 
 	 ( -159925351/319488 * ( nu )**( 2 ) + 
 	 54793021/851968 * ( nu )**( 3 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,1 ) * xi ) * ( e * ( -1605213/232960 + 
 	 ( 5692813/133120 * nu + 
 	 ( -239595/3328 * ( nu )**( 2 ) + 
 	 392753/13312 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 3 ) * ( -29858441/931840 + 
 	 ( 197953447/1064960 * nu + 
 	 ( -872369/3328 * ( nu )**( 2 ) + 
 	 5227741/106496 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 5 ) * ( -2649912359/44728320 + 
 	 ( 8782747609/25559040 * nu + 
 	 ( -101783001/212992 * ( nu )**( 2 ) + 
 	 60421715/851968 * ( nu )**( 3 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-2 ) * xi ) * ( ( e )**( 2 ) * ( -961147/29120 + 
 	 ( 6106699/33280 * nu + 
 	 ( -786651/3328 * ( nu )**( 2 ) + 
 	 48921/1664 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -2848087/58240 + 
 	 ( 874123/3120 * nu + 
 	 ( -317745/832 * ( nu )**( 2 ) + 
 	 277703/4992 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 6 ) * ( -470694401/5591040 + 
 	 ( 384423749/798720 * nu + 
 	 ( -51585611/79872 * ( nu )**( 2 ) + 
 	 11360569/159744 * ( nu )**( 3 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,2 ) * xi ) * ( ( e )**( 2 ) * ( -127377/29120 + 
 	 ( 1259139/33280 * nu + 
 	 ( -308123/3328 * ( nu )**( 2 ) + 
 	 87369/1664 * ( nu )**( 3 ) ) ) ) + 
 	 ( ( e )**( 4 ) * ( -182977/3360 + 
 	 ( 596557/1920 * nu + 
 	 ( -20273/48 * ( nu )**( 2 ) + 
 	 12673/192 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 6 ) * ( -131973999/1863680 + 
 	 ( 110120531/266240 * nu + 
 	 ( -46391135/79872 * ( nu )**( 2 ) + 
 	 4515207/53248 * ( nu )**( 3 ) ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,-3 ) * xi ) * ( ( e )**( 3 ) * ( -62146801/931840 + 
 	 ( 391947897/1064960 * nu + 
 	 ( -3049873/6656 * ( nu )**( 2 ) + 
 	 3033211/106496 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 5 ) * ( -233709243/4259840 + 
 	 ( 5441912231/17039360 * nu + 
 	 ( -193177053/425984 * ( nu )**( 2 ) + 
 	 148141807/1703936 * ( nu )**( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,3 ) * xi ) * ( ( e )**( 3 ) * ( 729329/93184 + 
 	 ( -2488989/212992 * nu + 
 	 ( -2133379/26624 * ( nu )**( 2 ) + 
 	 8872333/106496 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 5 ) * ( -432823371/4259840 + 
 	 ( 9595949297/17039360 * nu + 
 	 ( -153586341/212992 * ( nu )**( 2 ) + 
 	 149650081/1703936 * ( nu )**( 3 ) ) ) ) ) + 
 	 ( ( np.e )**( complex( 0,4 ) * xi ) * ( ( e )**( 6 ) * ( -2802897271/13977600 + 
 	 ( 2156466109/1996800 * nu + 
 	 ( -259770811/199680 * ( nu )**( 2 ) + 
 	 48589919/399360 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 4 ) * ( 2588007/66560 + 
 	 ( -59997371/399360 * nu + 
 	 ( 84353/13312 * ( nu )**( 2 ) + 
 	 4890047/39936 * ( nu )**( 3 ) ) ) ) ) + 
 	 ( np.e )**( complex( 0,-4 ) * xi ) * ( ( e )**( 4 ) * ( -384875/3072 + 
 	 ( 4223005/6144 * nu + 
 	 ( -2557465/3072 * ( nu )**( 2 ) + 
 	 27995/3072 * ( nu )**( 3 ) ) ) ) + 
 	 ( e )**( 6 ) * ( -170808661/4659200 + 
 	 ( 154533259/665600 * nu + 
 	 ( -16012811/39936 * ( nu )**( 2 ) + 
 	 21870253/133120 * ( nu )**( 3 ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) )
    
    return(h)
